# %%
import pickle

# %%
file_to_read = open("diz_classifiers_bert_svm_df_dist_5.pickle", "rb")

loaded_dictionary = pickle.load(file_to_read)

print(loaded_dictionary)
# Out:
# {'clf_Layer_1': {'accuracy': 0.5195530726256983, 'f1_score': array([0.54462935, 0.49155405]), 'y_test': array([0, 0, 0, ..., 0, 0, 0]), 'y_pred': array([0, 1, 0, ..., 0, 1, 1]), 'y_score': array([[0.5106799 , 0.4893201 ],
#        [0.48314356, 0.51685644],
#        [0.51337536, 0.48662464],
#        ...,
#        [0.5       , 0.5       ],
#        [0.49157763, 0.50842237],
# ...

# %%
len(loaded_dictionary['clf_Layer_1']['ids_proba'])
# Out:
# 2506
