# %%
import random
from random import sample
import pandas as pd
import pickle
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

# %%
n_samples = 5000 # Number of samples to create
X = sorted(np.random.rand(n_samples)) * 5 # Create sorted random samples

# Create 6-dimensional empty vector
linear_y = np.empty((len(X), 6))

# Put same value in every channel of 6-dimensional vector
for i in range(linear_y.shape[1]) :
    linear_y[:,i] = X

# %%
len(X)
# Out:
# 5000

# %%
linear_y, linear_y.shape
# Out:
# (array([[1.63011502e-04, 1.63011502e-04, 1.63011502e-04, 1.63011502e-04,
#          1.63011502e-04, 1.63011502e-04],
#         [1.78485634e-04, 1.78485634e-04, 1.78485634e-04, 1.78485634e-04,
#          1.78485634e-04, 1.78485634e-04],
#         [3.93511332e-04, 3.93511332e-04, 3.93511332e-04, 3.93511332e-04,
#          3.93511332e-04, 3.93511332e-04],
#         ...,
#         [9.99226839e-01, 9.99226839e-01, 9.99226839e-01, 9.99226839e-01,
#          9.99226839e-01, 9.99226839e-01],
#         [9.99597873e-01, 9.99597873e-01, 9.99597873e-01, 9.99597873e-01,
#          9.99597873e-01, 9.99597873e-01],
#         [9.99794415e-01, 9.99794415e-01, 9.99794415e-01, 9.99794415e-01,
#          9.99794415e-01, 9.99794415e-01]]),
#  (25000, 6))

# %%
n_samples = 5000 # Number of samples to create
X = np.sort(np.random.rand(n_samples)) * 5 # Create sorted random samples

nonlinear_y = np.empty((len(X), 6)) # Create 6-dimensional empty vector

# Put same value in every channel of 6-dimensional vector
for i in range(nonlinear_y.shape[1]) :
    if i == 1:
        nonlinear_y[:,i] = np.power(X, 2)
    else :
        nonlinear_y[:,i] = [2*np.cos(15 * np.pi * x ) for x in X]        

nonlinear_y[:,2] = np.abs(nonlinear_y[:,2])

# %%
nonlinear_y, nonlinear_y.shape
# Out:
# (array([[ 1.99997414e+00,  1.16437096e-08,  1.99997414e+00,
#           1.99997414e+00,  1.99997414e+00,  1.99997414e+00],
#         [ 1.99818667e+00,  8.16696741e-07,  1.99818667e+00,
#           1.99818667e+00,  1.99818667e+00,  1.99818667e+00],
#         [ 1.99711645e+00,  1.29882212e-06,  1.99711645e+00,
#           1.99711645e+00,  1.99711645e+00,  1.99711645e+00],
#         ...,
#         [-1.99266969e+00,  2.49818292e+01,  1.99266969e+00,
#          -1.99266969e+00, -1.99266969e+00, -1.99266969e+00],
#         [-1.99413416e+00,  2.49837460e+01,  1.99413416e+00,
#          -1.99413416e+00, -1.99413416e+00, -1.99413416e+00],
#         [-1.99975578e+00,  2.49966838e+01,  1.99975578e+00,
#          -1.99975578e+00, -1.99975578e+00, -1.99975578e+00]]),
#  (5000, 6))

# %%
fig = plt.figure(figsize= (30, 20))
ax = fig.add_subplot(131,projection='3d')
ax.scatter(linear_y[:,0], linear_y[:,1], linear_y[:,2], marker= '.', color= '#2ade2a', s= 28, alpha= 0.4)
ax.set_title("Linear Data", fontsize= 20)

ax = fig.add_subplot(132,projection='3d')
ax.scatter(nonlinear_y[:,0], nonlinear_y[:,1], nonlinear_y[:,2], marker= '.', color= '#FF5151', s= 28, alpha= 0.4)
ax.set_title("Random Non Linear Data", fontsize= 20)
# Out:
# Text(0.5, 0.92, 'Random Non Linear Data')

# %%
path_risorse = "../bert_features/"

# %%
training_to_read = open(path_risorse + "df_dist_5_training_bert_features_for_layers.pickle", "rb")
test_to_read = open(path_risorse + "df_dist_5_test_bert_features_for_layers.pickle", "rb")

df_training_bert_features_for_layers = pickle.load(training_to_read)

df_test_bert_features_for_layers = pickle.load(test_to_read)

df_name = "df_dist_5"

# %%
for layer in list(range(1, 13))[0:1]:

        #in ogni chiave (livello) ho id, features e classe di training e test

        #creo training e test con le features (vettori di BERT) per ogni specifico livello
        X_train = np.array([i[1] for i in df_training_bert_features_for_layers["{}_training".format(df_name)]["Layer_{}".format(layer)]])

        X_test = np.array([i[1] for i in df_test_bert_features_for_layers["{}_test".format(df_name)]["Layer_{}".format(layer)]])
    
        print("X_train")
        print(X_train, X_train.shape)
        print()
        print("X_test")
        print(X_test, X_test.shape)
        
        # Create 6-dimensional empty vector
        linear_y = np.empty((X_train.shape[0], X_train.shape[1]))
        
        # Put same value in every channel of 6-dimensional vector
        for i in range(linear_y.shape[1]) :
            linear_y[:,i] = X_train
            
        fig = plt.figure(figsize= (30, 20))
        ax = fig.add_subplot(131,projection='3d')
        ax.scatter(linear_y[:,0], linear_y[:,1], linear_y[:,2], marker= '.', color= '#2ade2a', s= 28, alpha= 0.4)
        ax.set_title("Linear Data", fontsize= 20)
# Out:
# X_train
# [[-3.92717957e-01 -3.58672351e-01 -1.82918563e-01 ...  4.84587625e-02
#   -2.30945498e-02 -1.01459372e+00]
#  [-2.83960372e-01 -3.83586794e-01 -9.04244855e-02 ... -3.14037502e-02
#    8.85018986e-03 -9.22348380e-01]
#  [-2.80656040e-01 -1.22303694e-01 -1.86879739e-01 ...  5.09023666e-04
#    5.20667732e-02 -7.05089569e-01]
#  ...
#  [-4.25213814e-01 -4.80214417e-01 -6.53776601e-02 ... -9.46214348e-02
#   -4.09793854e-03 -1.08906126e+00]
#  [-2.93775052e-01 -5.31288624e-01 -1.25899211e-01 ... -6.73866123e-02
#    2.28193067e-02 -7.69472361e-01]
#  [-3.91961396e-01 -6.06029451e-01 -7.86460191e-02 ... -7.29579031e-02
#    6.62491545e-02 -6.61969066e-01]] (9600, 1536)
#
# X_test
# [[-0.31752577 -0.49168295 -0.08391216 ...  0.03618802  0.00471442
#   -0.8747952 ]
#  [-0.2995919  -0.45244205 -0.0852947  ... -0.05849209  0.0350163
#   -0.63023096]
#  [-0.38466349 -0.54168189 -0.05328073 ... -0.0314704   0.02412446
#   -0.69415808]
#  ...
# ...

# %%
df_dist_5_ridotto
# Out:
#            Id                                         Sentence_1  \
# 0      155542                           Abbiamo fatto il taglio.
# 1      113574  Per esempio, è la sequenza di un gene sano mes...
# 2      136855                                      E come si fa?
# 3      189953  Quindi, iniziamo a riflettere sulle differenti...
# 4       26761           La prima componente fondamentale è Cas9.
# ...       ...                                                ...
# 11995  146563  Ricominciai a immaginare, a sognare, e mi face...
# 11996  158091  Si fa tantissimo parlare in ambito pedagogico ...
# 11997  173818  "Come facciamo a chiedergli di mantenersi nel ...
# 11998   19649  Lavoro anche fisico proprio in termini di sudo...
# 11999   68487  Un altro degli strumenti che da il teatro è qu...
#
#                                               Sentence_2  Class
# 0      Questo DNA "toppa" può essere fornito da noi, ...      1
# ...
