# %%
import json
import os
import numpy as np
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
from docx import Document
from docx.shared import Pt
import pickle
import os
from tqdm import tqdm
import time
from langdetect import detect
import matplotlib.pyplot as plt
import collections
from IPython.display import display

import spacy.cli
from spacy.language import Language
import math

from IPython.display import display
import nltk

from transformers import BertTokenizer
import seaborn as sns
from tabulate import tabulate
import prettytable
from prettytable import PrettyTable
from textwrap import fill
from deepdiff import DeepDiff
from tqdm import tqdm
from itertools import chain
import random
from collections import Counter
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
def get_mislassified_and_correct_predictions(test, pred):
    
    """
    Cerco le differenze fra le predizioni e le labels originali, facendo una DeepDiff fra il dizionario delle 
    predizioni e il dizionario delle label vere. Ecco quello che si ottiene
    
    Esempio:
    prova test:  {345: 1, 123: 0}
    prova pred:  {345: 1, 123: 1}

    diff_labels:  {'root[123]': {'new_value': 1, 'old_value': 0}}
    """
    
    # ottengo gli eventi classificati in modo errato
    misclassified_events = DeepDiff(test, pred)['values_changed']
    
    # prendo le chiavi degli eventi classificati in modo errato
    keys_misclassified_events = set(int(k.replace('root[', '').replace(']', '')) for k in misclassified_events)
    
    # e faccio la differenza fra tutti gli eventi classificati e gli eventi classificati male, 
    # perchè voglio ottenere gli eventi classificati correttamente 
    set_classified_events = set(list(pred.keys()))
    
    keys_correct_events = set_classified_events - keys_misclassified_events
    
    diz_correct_events = {}
    
    for k in keys_correct_events:
        diz_correct_events[k] = pred[k]
        
    misclassified_events = {int(k.replace('root[', '').replace(']', '')):v for k,v in misclassified_events.items()}
        
    return misclassified_events, diz_correct_events, keys_misclassified_events, keys_correct_events

# %%
def get_diff_classifications(lista_df_test, lista_dist, lista_diz_pred, lista_clf_epoch):
    
    diz_global = {}

    for df_test, dist, diz_pred in tqdm(zip(lista_df_test, lista_dist, lista_diz_pred)):
        
        diz_global[dist] = {}

        test = df_test.set_index('Id')[['Class']].astype('int64').to_dict(orient='dict')['Class']
    
        for clf_epoch in lista_clf_epoch:
            
            diz_global[dist][clf_epoch] = {}

            pred = {k:int(val) for k,val in diz_pred['{}'.format(dist)][clf_epoch]['ids_preds'].items()}
        
            misclassified_events, diz_correct_events, \
                keys_misclassified_events, keys_correct_events = get_mislassified_and_correct_predictions(test, pred)
            
            diz_global[dist][clf_epoch]['misclassified_events'] = misclassified_events
            diz_global[dist][clf_epoch]['diz_correct_events'] = diz_correct_events
            diz_global[dist][clf_epoch]['keys_misclassified_events'] = keys_misclassified_events
            diz_global[dist][clf_epoch]['keys_correct_events'] = keys_correct_events
            
    return diz_global

# %%
def save_dataframe(file_name, dataframe_to_save):
    
    try:
        dataframe_to_save.to_csv(path_salvataggio+file_name+".csv", index = False, sep = "\t", encoding='utf-8')
        print("File salvato correttamente")
        
    except:
        print("Errore nel salvataggio")
    
    return

# %% [markdown]
# **Vogliamo trovare eventi classificati correttamente o meno sia dai singoli classificatori, sia da entrambi i classificatori, in modo da mostrare le rispettive probabilità di classificazione e capire la sicurezza del modello nel predire un certo risultato.**

# %%
path_pickle = "../pickle/"

# %%
path_dataset = "../dataset/train_test/"

# %%
path_salvataggio = "../dataset/confronti_classificazione_eventi/"

# %%
path_diz_res = "../eventi_classificati_bene_male/"

# %%
path_images = "../plots/"
path_images_tit_ridotti = "../plots_titoli_ridotti/"

# %% [markdown]
# # Dataset di test originali

# %%
df_dist_5_test = pd.read_csv(path_dataset + "df_dist_5_with_ids_ridotto_test.csv", sep="\t")
df_dist_10_test = pd.read_csv(path_dataset + "df_dist_10_with_ids_ridotto_test.csv", sep="\t")
df_dist_20_test = pd.read_csv(path_dataset + "df_dist_20_with_ids_ridotto_test.csv", sep="\t")
df_dist_30_test = pd.read_csv(path_dataset + "df_dist_30_with_ids_ridotto_test.csv", sep="\t")
df_random_speech_test = pd.read_csv(path_dataset + "df_random_speech_with_ids_ridotto_test.csv", sep="\t")

# %%
df_dist_5_test
# Out:
#           Id                                         Sentence_1  \
# 0       3511            È questo «in nome del popolo italiano»?
# 1     443194  Non guardiamo a soluzioni come l'erezione di m...
# 2     438394  La popolazione carceraria è scesa a 52.164 e s...
# 3     313751  Mi fermo perché non voglio offendere nessuno, ...
# 4     488165  La prima riunione europea dei Ministri della s...
# ...      ...                                                ...
# 2395   35231  Non è un caso che il Governo e la maggioranza ...
# 2396  300044  Anzi, svolse sempre con passione e consapevole...
# 2397   74207  È chiaro che una catastrofe delle dimensioni d...
# 2398  390608  Se doveva cadere così in basso, era più dignit...
# 2399  187838  Non ci sono parole per ringraziare i nostri me...
#
#                                              Sentence_2  Class
# 0     Signor Presidente, ho chiesto di intervenire a...      1
# 1     Tutto ciò deve necessariamente avvenire attrav...      1
# 2     Sei anni fa i detenuti erano 67.971 e 21.494 l...      0
# 3                                     Ci ridono dietro!      1
# 4     Siamo un grande Paese, che ha svolto un lavoro...      1
# ...                                                 ...    ...
# 2395  Ma neanche il testo di mediazione che la Commi...      0
# 2396  Con lui scompare una figura importante della s...      0
# 2397  Cito, prima di invitare l'Assemblea all'approv...      1
# 2398  Un'Assemblea tanto grande quanto debole, i cui...      1
# 2399  Penso allo sconforto di chi ha perso un genito...      1
#
# [2400 rows x 4 columns]

# %%
for id_ev in diz_intersections_svm['df_dist_5']['other_events_correct']:
    display(df_dist_5_test[df_dist_5_test['Id'] == id_ev])
# Out:
#         Id                                         Sentence_1  \
# 2192  4227  Indìco la votazione nominale con scrutinio sim...
#
#                   Sentence_2  Class
# 2192  Il Senato non approva.      1
#          Id                                      Sentence_1  \
# 413  173444  Il mio appello è che la legge venga approvata.
#
#                                             Sentence_2  Class
# 413  Adesso cosa accadrà, colleghi - in questo sens...      0
#           Id                                         Sentence_1  \
# 1423  183816  Da una prima lettura, emerge un'evidente contr...
#
#                                              Sentence_2  Class
# 1423  «La corruzione in Italia è un fenomeno di sist...      1
#           Id                                         Sentence_1  \
# 1553  830743  Lo dico anche rispetto all'intervento del sena...
#
#                                              Sentence_2  Class
# 1553  Lo vorrei informare che sull'edilizia scolasti...      0
#          Id                                         Sentence_1  \
# 966  767259  Al centro ci saranno i beni pubblici che torne...
#
#                                             Sentence_2  Class
# 966  Al centro torneranno i diritti, in primo luogo...      1
#         Id                                         Sentence_1  \
# 308  34717  Nei mesi passati il Governo turco è parso comp...
#
#                                             Sentence_2  Class
# 308  Questo ordine del giorno unitario è un forte i...      0
#          Id                                         Sentence_1  \
# 1985  50850  Fin dal mio insediamento, ho insistito su un c...
#
#                                              Sentence_2  Class
# 1985  Proprio il processo di globalizzazione, l'intr...      0
#           Id                                         Sentence_1  \
# 1681  627620  Una vita, dicevo, improntata alla considerazio...
#
#                           Sentence_2  Class
# 1681  Ha avuto una vita ricchissima.      1
#           Id                                         Sentence_1  \
# 2341  309540  Ai sensi dell'articolo 102 - bis del Regolamen...
#
#                                              Sentence_2  Class
# 2341  Indìco la votazione nominale con scrutinio sim...      1
#           Id                                         Sentence_1  \
# 2272  190126  Deve farlo in nome non più dell'ideologia, ma ...
#
#                                              Sentence_2  Class
# 2272  Prendiamo il decreto sulla riforma della pubbl...      0
#          Id                                         Sentence_1  \
# 1307  18223  L'obiettivo del Governo e della maggioranza pa...
#
#                                              Sentence_2  Class
# 1307  Ci sono altri Paesi, come ad esempio gli Stati...      0
#          Id                                         Sentence_1  \
# 631  240695  Noi pensiamo che il reddito di cittadinanza - ...
#
#                                             Sentence_2  Class
# 631  L'inserimento di coloro che sono in Italia da ...      0
#           Id                                         Sentence_1  \
# 1786  134594  Basta parole, però, basta perché la buona volo...
#
#                                              Sentence_2  Class
# 1786  Spero che nessuno di noi richiami la pazienza ...      0
#          Id                                         Sentence_1  \
# 405  128709  Infatti nel caso in cui in punto di fatto si v...
#
#                                             Sentence_2  Class
# 405  Penso che oggi la politica dia una delle rispo...      1
#           Id                                         Sentence_1  \
# 1177  864591  Non posso quindi esimermi da un abbraccio affe...
#
#                                         Sentence_2  Class
# 1177  È in gioco il bene della comunità nazionale.      1
#           Id                                         Sentence_1  \
# 1188  663505  Io penso che il Senato sia pronto a svolgere q...
#
#                                              Sentence_2  Class
# 1188  Infatti, lo stesso senatore Tremonti ha ricord...      1
#           Id                                         Sentence_1  \
# 1059  260309  Ciò porterà anche a prevedere il doppio turno:...
#
#                                              Sentence_2  Class
# 1059  L'esigenza di coinvolgere il corpo elettorale ...      0
#           Id                                         Sentence_1  \
# 1478  822229  Intanto, dare conto dei diritti dei pensionati...
#
#                                              Sentence_2  Class
# 1478  Io ero abituata a sentire dire, da una certa p...      1
#           Id                                         Sentence_1  \
# 1356  440791  Ogni giorno che si ritarda sono 2 milioni in p...
#
#                                              Sentence_2  Class
# 1356  È giusto che guadagnino, ma questo guadagno po...      0
#           Id                                         Sentence_1  \
# 1829  305880  In quest'Aula si è instaurata - ahimè - la cat...
#
#                                              Sentence_2  Class
# 1829  Sono famiglie distrutte, di cui alcuni compone...      1
#         Id                                         Sentence_1  \
# 39  407642  Peraltro, il Paese, come sappiamo, ha un gap d...
#
#                                            Sentence_2  Class
# 39  L'obiettivo è quello di realizzare interventi ...      0
#           Id                                         Sentence_1  \
# 1514  829790  Inoltre, in tanti centri c'era - e credo ci si...
#
#                                              Sentence_2  Class
# 1514  Faccio però presente che mio fratello gemello ...      1
#          Id                                         Sentence_1  \
# 738  592866  Ovviamente dobbiamo interpellare il presidente...
#
#                                             Sentence_2  Class
# 738  Signora Ministro, ho a portata di mano la famo...      0
#           Id                                         Sentence_1  \
# 2207  124516  Tempo fa, sul quotidiano «Corriere della sera»...
#
#                                              Sentence_2  Class
# 2207  Celentano lo diceva per la musica: se la music...      0
#           Id                                         Sentence_1  \
# 2169  622184  Oggi quella rotta del tabacco risulta essere c...
#
#                                              Sentence_2  Class
# 2169  In sostanza, millenni di amicizia e di scambi ...      0
#           Id                                         Sentence_1  \
# 1597  848244  Una volta i treni, le rotaie e le stazioni ven...
#
#                                              Sentence_2  Class
# 1597  Si chiama Centostazioni, ma forse sarebbe megl...      0
#           Id                                         Sentence_1  \
# 2385  552823  La sua storia è dunque tremendamente attuale, ...
#
#                                              Sentence_2  Class
# 2385  Ci chiede di essere genuini con noi stessi e c...      0
#           Id                     Sentence_1  \
# 1352  796667  E qui ne vedremo delle belle.
#
#                                              Sentence_2  Class
# 1352  E poco importa se il Presidente del Consiglio ...      0

# %%
df_dist_5_test[df_dist_5_test['Id'] == 173444]
# Out:
#          Id                                      Sentence_1  \
# 413  173444  Il mio appello è che la legge venga approvata.
#
#                                             Sentence_2  Class
# 413  Adesso cosa accadrà, colleghi - in questo sens...      0

# %%
for clf in lista_clf:
    print(diz_dist_5_svm['df_dist_5'][clf]['ids_preds'][173444])
# Out:
# 1
# 1
# 1
# 0
# 1
# 1
# 1
# 1
# 1
# 1
# 1
# 1

# %%
diz_intersections_svm['df_dist_5']['other_events_correct']
# Out:
# {4227,
#  18223,
#  34717,
#  50850,
#  124516,
#  128709,
#  134594,
#  173444,
#  183816,
#  190126,
#  240695,
#  260309,
#  305880,
#  309540,
#  407642,
#  440791,
#  552823,
#  592866,
#  622184,
#  627620,
#  663505,
#  767259,
#  796667,
#  822229,
#  829790,
#  830743,
#  848244,
#  864591}

# %% [markdown]
# # Risultati classificazione SVM

# %%
dist_5_svm = open(path_pickle + "/" + "diz_classifiers_bert_svm_df_dist_5.pickle", "rb")
dist_10_svm = open(path_pickle + "/" + "diz_classifiers_bert_svm_df_dist_10.pickle", "rb")
dist_20_svm = open(path_pickle + "/" + "diz_classifiers_bert_svm_df_dist_20.pickle", "rb")
dist_30_svm = open(path_pickle + "/" + "diz_classifiers_bert_svm_df_dist_30.pickle", "rb")
dist_random_speech_svm = open(path_pickle + "/" + "diz_classifiers_bert_svm_df_random_speech.pickle", "rb")

diz_dist_5_svm = pickle.load(dist_5_svm)
diz_dist_10_svm = pickle.load(dist_10_svm)
diz_dist_20_svm = pickle.load(dist_20_svm)
diz_dist_30_svm = pickle.load(dist_30_svm)
diz_random_speech_svm = pickle.load(dist_random_speech_svm)

# %% [markdown]
# # Risultati classificazione BERT fine-tunato

# %%
dist_5_bf = open(path_pickle + "/" + "df_dist_5_diz_bert_finetuning.pickle", "rb")
dist_10_bf = open(path_pickle + "/" + "df_dist_10_diz_bert_finetuning.pickle", "rb")
dist_20_bf = open(path_pickle + "/" + "df_dist_20_diz_bert_finetuning.pickle", "rb")
dist_30_bf = open(path_pickle + "/" + "df_dist_30_diz_bert_finetuning.pickle", "rb")
random_speech_bf = open(path_pickle + "/" + "df_random_speech_diz_bert_finetuning.pickle", "rb")

diz_dist_5_bf = pickle.load(dist_5_bf)
diz_dist_10_bf = pickle.load(dist_10_bf)
diz_dist_20_bf = pickle.load(dist_20_bf)
diz_dist_30_bf = pickle.load(dist_30_bf)
diz_random_speech_bf = pickle.load(random_speech_bf)

# %%
risorsa = "ParlaMint"

# %%
lista_clf = ["clf_{}".format(i) for i in range(1,13)]
print(lista_clf)
print()

lista_epoche = ['Epoch{}'.format(i) for i in range (0,5)]
print(lista_epoche)
print()

lista_dist = ['df_dist_5', 'df_dist_10', 'df_dist_20', 'df_dist_30', 'df_random_speech']
print(lista_dist)

lista_df_test = [df_dist_5_test, df_dist_10_test, df_dist_20_test, df_dist_30_test, df_random_speech_test]

lista_diz_pred_svm = [diz_dist_5_svm, diz_dist_10_svm, diz_dist_20_svm, diz_dist_30_svm, diz_random_speech_svm]

lista_diz_pred_bert_finetunato = [diz_dist_5_bf, diz_dist_10_bf, diz_dist_20_bf, diz_dist_30_bf, diz_random_speech_bf]
# Out:
# ['clf_1', 'clf_2', 'clf_3', 'clf_4', 'clf_5', 'clf_6', 'clf_7', 'clf_8', 'clf_9', 'clf_10', 'clf_11', 'clf_12']
#
# ['Epoch0', 'Epoch1', 'Epoch2', 'Epoch3', 'Epoch4']
#
# ['df_dist_5', 'df_dist_10', 'df_dist_20', 'df_dist_30', 'df_random_speech']

# %% [markdown]
# ### Prendiamo, per ogni distanza, per ogni classificatore o epoca, tutti gli eventi classificati correttamente o in modo errato

# %%
diz_global_svm = get_diff_classifications(lista_df_test, lista_dist, lista_diz_pred_svm, lista_clf)
# Out:
# 5it [00:05,  1.17s/it]

# %%
diz_global_bert = get_diff_classifications(lista_df_test, lista_dist, lista_diz_pred_bert_finetunato, lista_epoche)
# Out:
# 5it [00:02,  2.18it/s]

# %%
diz_global_bert['df_dist_5'].keys()
# Out:
# dict_keys(['Epoch0', 'Epoch1', 'Epoch2', 'Epoch3', 'Epoch4'])

# %%
for dist in diz_global_svm:
    print("{}: {} clf".format(dist, len(diz_global_svm[dist])))
# Out:
# df_dist_5: 12 clf
# df_dist_10: 12 clf
# df_dist_20: 12 clf
# df_dist_30: 12 clf
# df_random_speech: 12 clf

# %%
for dist in diz_global_bert:
    print("{}: {} epochs".format(dist, len(diz_global_bert[dist])))
# Out:
# df_dist_5: 5 epochs
# df_dist_10: 5 epochs
# df_dist_20: 5 epochs
# df_dist_30: 5 epochs
# df_random_speech: 5 epochs

# %%
diz_global_svm['df_dist_5']['clf_1'].keys()
# Out:
# dict_keys(['misclassified_events', 'diz_correct_events', 'keys_misclassified_events', 'keys_correct_events'])

# %%
diz_global_svm['df_dist_5']['clf_1']['diz_correct_events']
# Out:
# {223234: 1,
#  315394: 1,
#  430083: 0,
#  897029: 0,
#  718850: 0,
#  22534: 0,
#  804872: 0,
#  643080: 0,
#  813066: 0,
#  743431: 1,
#  673804: 0,
#  694281: 1,
#  12302: 0,
#  464910: 0,
#  217107: 1,
#  507927: 0,
#  843799: 1,
#  880674: 1,
#  466979: 0,
#  583716: 0,
#  81957: 0,
#  671787: 0,
#  886827: 0,
#  796717: 1,
#  354347: 0,
#  639023: 0,
#  419887: 0,
#  460848: 0,
#  886835: 0,
#  446521: 0,
#  806969: 0,
#  823355: 1,
#  405561: 0,
#  127037: 0,
#  684090: 1,
#  344127: 0,
#  24640: 0,
#  819265: 1,
#  256063: 1,
#  79931: 0,
#  309311: 0,
#  368710: 0,
#  219207: 0,
#  41032: 0,
#  575560: 0,
#  194636: 1,
#  192591: 1,
#  823378: 1,
#  325714: 0,
#  542804: 1,
#  122966: 0,
#  444512: 1,
#  170080: 0,
#  569442: 0,
#  311395: 1,
#  235621: 1,
#  290918: 0,
#  845929: 1,
#  753770: 0,
#  127083: 0,
#  71787: 1,
#  2157: 1,
#  675949: 1,
#  268399: 1,
#  407665: 0,
#  454770: 1,
#  311411: 1,
#  34931: 0,
#  155765: 0,
#  718961: 0,
#  714872: 1,
#  438394: 0,
#  516219: 0,
#  868475: 1,
#  532605: 0,
#  112762: 0,
#  219259: 1,
#  692352: 1,
#  129148: 1,
#  473218: 0,
#  886916: 0,
#  311431: 0,
#  360584: 0,
#  698503: 0,
#  223370: 1,
#  579723: 0,
#  200844: 1,
#  260236: 1,
#  63628: 0,
#  819344: 1,
#  190608: 0,
#  51346: 0,
#  419986: 1,
#  280723: 0,
#  172181: 0,
#  252048: 1,
#  178321: 0,
#  399508: 1,
#  166042: 1,
#  360603: 1,
#  690330: 1,
#  290970: 1,
#  37019: 1,
#  708765: 1,
#  882843: 0,
#  858267: 0,
#  628903: 1,
#  661671: 1,
#  788650: 1,
#  600238: 1,
#  788655: 0,
#  16561: 0,
#  338098: 1,
#  344243: 0,
#  157877: 0,
#  458934: 1,
#  786617: 1,
#  211129: 0,
#  286907: 0,
#  188: 0,
#  878779: 1,
#  100542: 0,
#  166079: 1,
#  321728: 0,
#  755905: 0,
#  321727: 0,
#  196803: 0,
#  411843: 1,
#  18628: 0,
#  712902: 1,
#  377031: 0,
#  159941: 1,
#  143560: 0,
#  651466: 0,
#  143564: 0,
#  649421: 0,
#  497869: 1,
#  444623: 0,
#  221393: 1,
#  504017: 1,
#  579793: 1,
#  303316: 1,
#  286935: 1,
#  823511: 1,
#  735449: 1,
#  65754: 0,
#  760028: 0,
#  567517: 1,
#  469214: 0,
#  643295: 0,
#  874721: 0,
#  737506: 0,
#  426210: 0,
#  463075: 1,
#  262373: 1,
#  884965: 0,
#  606439: 0,
#  69860: 0,
#  880870: 1,
#  78056: 0,
#  448738: 1,
#  805100: 0,
#  340205: 1,
#  506085: 0,
#  678118: 0,
#  440558: 0,
#  704753: 1,
#  303346: 1,
#  872692: 0,
#  133365: 1,
#  655606: 0,
#  323830: 1,
#  243956: 0,
#  8441: 0,
#  522489: 1,
#  213247: 0,
#  327937: 1,
#  119041: 1,
#  430337: 1,
#  112897: 0,
#  737544: 0,
#  61704: 0,
#  508170: 1,
#  469263: 0,
#  604431: 1,
#  260367: 0,
#  12562: 1,
#  530704: 1,
#  842003: 1,
#  207126: 1,
#  694550: 1,
#  80152: 0,
#  418073: 1,
#  51486: 0,
#  237855: 1,
#  731424: 1,
#  151838: 0,
#  287015: 0,
#  37161: 1,
#  338222: 0,
#  6448: 1,
#  37169: 0,
#  153905: 1,
#  518453: 0,
#  31030: 1,
#  502071: 1,
#  399670: 0,
#  377145: 1,
#  885050: 1,
#  205115: 0,
#  80188: 1,
#  278845: 0,
#  809278: 0,
#  235839: 0,
#  454976: 1,
#  416066: 0,
#  715075: 0,
#  311620: 0,
#  565573: 1,
#  872774: 1,
#  194888: 0,
#  397642: 0,
#  43339: 0,
#  115021: 1,
#  729422: 0,
#  293197: 1,
#  254289: 0,
#  500050: 1,
#  811346: 1,
#  606546: 1,
#  211287: 1,
#  121179: 1,
#  155997: 1,
#  356: 0,
#  776551: 1,
#  620911: 0,
#  285041: 0,
#  387442: 0,
#  782709: 1,
#  323961: 1,
#  82300: 0,
#  170364: 1,
#  758147: 0,
#  49542: 0,
#  864649: 0,
#  283019: 0,
#  348556: 0,
#  55691: 0,
#  483726: 0,
#  35214: 0,
#  536975: 0,
#  170385: 0,
#  438674: 0,
#  223636: 0,
#  631189: 1,
#  575892: 0,
#  600471: 1,
#  76183: 0,
#  10646: 1,
#  848279: 1,
#  315799: 0,
#  520601: 0,
#  776602: 0,
#  809375: 1,
#  229793: 1,
#  549281: 1,
#  510372: 0,
#  516517: 1,
#  780709: 1,
#  225701: 0,
#  68009: 0,
#  367018: 0,
#  520619: 1,
#  344492: 1,
#  633260: 0,
#  340400: 0,
#  758193: 0,
#  113073: 0,
#  778675: 1,
#  334258: 0,
#  309684: 1,
#  879030: 1,
#  383414: 1,
#  106936: 0,
#  256447: 0,
#  33216: 1,
#  158144: 0,
#  471490: 0,
#  6591: 1,
#  424386: 0,
#  618950: 0,
#  440776: 0,
#  674249: 0,
#  330187: 0,
#  532942: 0,
#  184782: 0,
#  328144: 0,
#  502226: 1,
#  721363: 0,
#  440791: 0,
#  147928: 1,
#  596446: 1,
#  229855: 1,
#  461279: 0,
#  750047: 0,
#  569824: 1,
#  141795: 0,
#  451044: 0,
#  360934: 1,
#  365030: 1,
#  81915: 0,
#  487914: 0,
#  678383: 0,
#  467440: 0,
#  426481: 0,
#  113135: 1,
#  739827: 1,
#  418292: 0,
#  86515: 1,
#  20982: 1,
#  166391: 1,
#  14839: 0,
#  287225: 0,
#  401915: 0,
#  811516: 0,
#  643579: 0,
#  451071: 1,
#  500224: 0,
#  510466: 0,
#  664067: 0,
#  885252: 1,
#  373250: 0,
#  801284: 1,
#  342536: 1,
#  569866: 0,
#  700944: 0,
#  530963: 0,
#  573972: 0,
#  277014: 1,
#  545305: 0,
#  467482: 1,
#  401947: 0,
#  264732: 1,
#  350750: 0,
#  877091: 1,
#  201251: 1,
#  559656: 1,
#  481833: 0,
#  111146: 1,
#  879150: 1,
#  764462: 1,
#  221746: 1,
#  166455: 0,
#  858679: 1,
#  414266: 0,
#  74300: 0,
#  805436: 1,
#  793151: 0,
#  574017: 0,
#  203330: 1,
#  696903: 1,
#  856647: 0,
#  176712: 1,
#  688714: 1,
#  393803: 0,
#  580170: 0,
#  846419: 1,
#  584278: 1,
#  412248: 0,
#  758363: 1,
#  830046: 1,
#  580190: 0,
#  326242: 0,
#  879203: 0,
#  789091: 1,
#  635491: 0,
#  696934: 1,
#  772711: 1,
#  10855: 0,
#  639593: 0,
#  125545: 1,
#  182889: 0,
#  135785: 1,
#  864876: 0,
#  23144: 1,
#  268910: 1,
#  45684: 1,
#  113269: 0,
#  100985: 1,
#  203387: 1,
#  12926: 1,
#  453247: 0,
#  694913: 1,
#  139906: 1,
#  522882: 1,
#  666244: 0,
#  117380: 1,
#  658063: 0,
#  567954: 1,
#  494231: 0,
#  608921: 0,
#  189082: 1,
#  98972: 0,
#  180892: 1,
#  256669: 1,
#  580254: 0,
#  729760: 0,
#  496289: 1,
#  555682: 1,
#  76453: 1,
#  838313: 1,
#  414377: 0,
#  586411: 1,
#  90796: 0,
#  10924: 1,
#  772780: 0,
#  793262: 0,
#  53937: 0,
#  328371: 1,
#  463540: 1,
#  688821: 0,
#  844469: 0,
#  101046: 1,
#  299704: 1,
#  471736: 0,
#  621238: 0,
#  387774: 1,
#  449122: 0,
#  697026: 0,
#  512707: 1,
#  283332: 0,
#  12997: 0,
#  398022: 1,
#  160457: 1,
#  8907: 0,
#  395979: 1,
#  31435: 0,
#  576206: 1,
#  248531: 1,
#  369368: 1,
#  10968: 1,
#  781016: 1,
#  297688: 0,
#  651994: 0,
#  627417: 1,
#  645860: 1,
#  688873: 1,
#  707305: 1,
#  596714: 1,
#  381676: 0,
#  385774: 1,
#  191214: 1,
#  813807: 1,
#  240368: 0,
#  537330: 0,
#  744179: 0,
#  373492: 0,
#  680693: 1,
#  23285: 0,
#  467704: 0,
#  373500: 0,
#  674557: 1,
#  58110: 0,
#  283388: 0,
#  791295: 1,
#  500483: 1,
#  621320: 1,
#  746252: 1,
#  877325: 0,
#  166669: 1,
#  8975: 1,
#  457489: 0,
#  697107: 1,
#  717589: 1,
#  817945: 1,
#  197403: 1,
#  887579: 0,
#  600860: 0,
#  805659: 0,
#  467743: 1,
#  37662: 1,
#  308001: 1,
#  711456: 1,
#  168740: 1,
#  776997: 1,
#  351014: 0,
#  336681: 1,
#  324393: 0,
#  820013: 1,
#  365359: 1,
#  6959: 0,
#  373553: 1,
#  789298: 1,
#  539440: 1,
#  777012: 1,
#  475958: 0,
#  690999: 1,
#  527164: 1,
#  76610: 0,
#  518980: 0,
#  645958: 0,
#  695112: 1,
#  224076: 1,
#  103246: 1,
#  754511: 1,
#  256847: 1,
#  590673: 0,
#  627536: 0,
#  215891: 0,
#  430931: 1,
#  146255: 1,
#  58198: 0,
#  205654: 1,
#  707416: 0,
#  721754: 1,
#  21338: 0,
#  555870: 1,
#  381791: 1,
#  158560: 0,
#  830305: 0,
#  578405: 1,
#  95078: 0,
#  381800: 1,
#  486249: 1,
#  379753: 0,
#  609130: 1,
#  80749: 1,
#  586607: 0,
#  510836: 1,
#  195446: 0,
#  291706: 1,
#  332670: 0,
#  729983: 1,
#  516992: 0,
#  443263: 0,
#  557954: 1,
#  844673: 1,
#  641924: 0,
#  801663: 1,
#  711557: 1,
#  895880: 0,
#  84872: 1,
#  476042: 1,
#  875402: 0,
#  773004: 0,
#  844685: 1,
#  58257: 1,
#  72593: 0,
#  818067: 1,
#  844693: 1,
#  226197: 0,
#  267159: 1,
#  478105: 0,
#  144281: 0,
#  76700: 0,
#  631709: 1,
#  287646: 0,
#  674717: 1,
#  248735: 0,
#  544825: 0,
#  734110: 0,
#  848798: 1,
#  703392: 0,
#  359330: 0,
#  539555: 0,
#  93096: 0,
#  394153: 0,
#  5033: 0,
#  539563: 0,
#  807855: 1,
#  574384: 0,
#  828338: 1,
#  144309: 0,
#  9144: 0,
#  670649: 0,
#  820154: 0,
#  648123: 1,
#  512955: 0,
#  56252: 0,
#  310206: 0,
#  871359: 1,
#  553919: 1,
#  170944: 1,
#  811973: 0,
#  816072: 1,
#  412619: 0,
#  779213: 0,
#  383949: 1,
#  138189: 1,
#  211920: 1,
#  209873: 1,
#  846804: 0,
#  130004: 1,
#  218070: 1,
#  324566: 1,
#  435161: 1,
#  881628: 0,
#  666589: 1,
#  87005: 1,
#  709599: 1,
#  717792: 0,
#  29665: 0,
#  592866: 0,
#  672739: 0,
#  349154: 0,
#  31718: 1,
#  496615: 0,
#  93161: 0,
#  3050: 0,
#  424937: 0,
#  9199: 0,
#  84976: 0,
#  441328: 0,
#  15343: 1,
#  420853: 0,
#  375798: 1,
#  70648: 0,
#  875512: 0,
#  535546: 0,
#  873468: 0,
#  652286: 1,
#  228356: 1,
#  646150: 0,
#  779273: 0,
#  898057: 0,
#  865294: 0,
#  222223: 0,
#  207887: 1,
#  463887: 1,
#  668688: 1,
#  750606: 1,
#  799762: 0,
#  728086: 1,
#  248856: 1,
#  697372: 0,
#  35868: 1,
#  93213: 0,
#  494622: 1,
#  414752: 1,
#  334878: 1,
#  867361: 1,
#  199717: 1,
#  658472: 0,
#  482347: 0,
#  457773: 1,
#  590895: 0,
#  240687: 0,
#  347185: 0,
#  330801: 0,
#  875567: 0,
#  615479: 0,
#  492602: 0,
#  414778: 0,
#  627772: 0,
#  488508: 0,
#  781374: 1,
#  709695: 1,
#  382011: 0,
#  195648: 0,
#  672837: 0,
#  379973: 0,
#  496711: 1,
#  373832: 0,
#  459849: 0,
#  660553: 1,
#  107595: 1,
#  390218: 0,
#  269385: 1,
#  357454: 0,
#  482380: 1,
#  832598: 1,
#  515159: 1,
#  541784: 0,
#  621659: 0,
#  441437: 1,
#  277599: 1,
#  480352: 0,
#  314465: 1,
#  62560: 0,
#  775265: 1,
#  193637: 1,
#  226407: 1,
#  488552: 1,
#  220267: 1,
#  746607: 1,
#  494705: 1,
#  175219: 1,
#  218227: 1,
#  128116: 0,
#  783477: 0,
#  494711: 1,
#  892020: 0,
#  259194: 1,
#  287867: 0,
#  23680: 1,
#  281729: 1,
#  453761: 1,
#  373893: 0,
#  148614: 1,
#  320647: 0,
#  492680: 0,
#  119942: 0,
#  717958: 1,
#  652428: 0,
#  832653: 0,
#  461966: 1,
#  529548: 0,
#  74896: 1,
#  50321: 1,
#  855188: 1,
#  115863: 0,
#  87193: 0,
#  511132: 1,
#  898205: 0,
#  693406: 1,
#  849055: 0,
#  744605: 1,
#  496801: 0,
#  103586: 0,
#  56479: 1,
#  17575: 0,
#  464041: 0,
#  122028: 0,
#  292019: 0,
#  292022: 1,
#  853175: 1,
#  670907: 0,
#  634044: 1,
#  216255: 1,
#  322753: 0,
#  244929: 1,
#  173254: 1,
#  64714: 1,
#  832717: 0,
#  109778: 0,
#  333013: 1,
#  580821: 0,
#  64728: 0,
#  539865: 1,
#  459994: 1,
#  136410: 0,
#  130269: 0,
#  697566: 0,
#  253150: 1,
#  777440: 1,
#  384227: 0,
#  265446: 0,
#  42215: 1,
#  54502: 1,
#  468205: 0,
#  322797: 0,
#  58607: 0,
#  763119: 0,
#  601330: 0,
#  277747: 1,
#  838900: 0,
#  240885: 1,
#  883957: 0,
#  728310: 1,
#  599289: 0,
#  877818: 0,
#  738555: 1,
#  701690: 1,
#  548089: 1,
#  118014: 0,
#  195837: 1,
#  228607: 1,
#  470275: 0,
#  460036: 1,
#  324869: 1,
#  60678: 1,
#  161030: 0,
#  261382: 1,
#  759051: 1,
#  392459: 1,
#  341264: 1,
#  312593: 1,
#  570647: 1,
#  218392: 1,
#  722201: 1,
#  541977: 0,
#  812315: 1,
#  701720: 0,
#  220440: 0,
#  605470: 1,
#  302367: 0,
#  179488: 1,
#  623905: 0,
#  255267: 0,
#  449832: 1,
#  716073: 1,
#  802095: 0,
#  548144: 1,
#  654640: 0,
#  875828: 1,
#  103735: 0,
#  646458: 0,
#  748860: 0,
#  404797: 1,
#  91454: 1,
#  593214: 0,
#  68925: 1,
#  372034: 1,
#  83267: 0,
#  218436: 1,
#  113989: 1,
#  230726: 1,
#  871751: 1,
#  200012: 0,
#  490828: 0,
#  165198: 1,
#  214351: 0,
#  746835: 1,
#  423251: 0,
#  707927: 1,
#  681304: 1,
#  126295: 1,
#  361818: 0,
#  816471: 1,
#  703835: 0,
#  66909: 1,
#  480605: 1,
#  859490: 0,
#  511333: 0,
#  159078: 0,
#  773477: 0,
#  85352: 0,
#  839016: 0,
#  861546: 1,
#  511339: 1,
#  693606: 0,
#  177510: 0,
#  44398: 1,
#  390509: 1,
#  531816: 1,
#  261485: 1,
#  753004: 1,
#  671090: 0,
#  714100: 0,
#  320885: 1,
#  476534: 0,
#  857461: 1,
#  417139: 0,
#  875894: 0,
#  128378: 1,
#  146811: 1,
#  554367: 1,
#  253311: 0,
#  583042: 0,
#  699781: 0,
#  286087: 0,
#  599432: 0,
#  859533: 0,
#  132496: 1,
#  458129: 1,
#  298387: 0,
#  19862: 1,
#  294296: 1,
#  282010: 0,
#  351645: 0,
#  826781: 0,
#  241055: 1,
#  454050: 1,
#  60835: 0,
#  497058: 0,
#  146853: 1,
#  673193: 1,
#  337322: 0,
#  1451: 0,
#  114090: 1,
#  742831: 0,
#  163254: 1,
#  157111: 0,
#  3511: 1,
#  372155: 0,
#  824763: 0,
#  187838: 1,
#  429507: 1,
#  62916: 1,
#  472516: 0,
#  220617: 0,
#  308682: 0,
#  214477: 0,
#  234958: 1,
#  138701: 1,
#  390608: 1,
#  370129: 1,
#  212430: 0,
#  544211: 1,
#  824787: 1,
#  226772: 1,
#  742869: 1,
#  523733: 0,
#  257496: 1,
#  9693: 1,
#  714205: 0,
#  792037: 0,
#  888294: 0,
#  97766: 0,
#  482662: 1,
#  208364: 0,
#  789998: 0,
#  527854: 0,
#  447983: 0,
#  443892: 1,
#  894452: 1,
#  472566: 1,
#  642551: 0,
#  882168: 0,
#  507381: 0,
#  316922: 0,
#  802300: 1,
#  437759: 1,
#  402944: 1,
#  280065: 1,
#  216576: 0,
#  880130: 0,
#  32259: 0,
#  411144: 1,
#  255500: 1,
#  296461: 0,
#  415244: 0,
#  128532: 1,
#  478743: 0,
#  822808: 1,
#  44568: 0,
#  849431: 1,
#  194073: 1,
#  654877: 1,
#  357918: 0,
#  527904: 0,
#  755235: 0,
#  456231: 1,
#  728616: 1,
#  390698: 1,
#  396843: 1,
#  728618: 0,
#  534062: 0,
#  476718: 1,
#  290351: 1,
#  777774: 0,
#  173618: 0,
#  239155: 0,
#  591411: 0,
#  728623: 0,
#  345654: 0,
#  648758: 1,
#  583225: 1,
#  802361: 1,
#  648763: 0,
#  294458: 1,
#  742973: 1,
#  689726: 0,
#  341567: 1,
#  507453: 1,
#  681538: 0,
#  9795: 1,
#  427589: 0,
#  118341: 1,
#  433733: 0,
#  497225: 1,
#  603723: 0,
#  357964: 1,
#  605774: 1,
#  304720: 1,
#  360018: 1,
#  83541: 0,
#  394838: 0,
#  77398: 0,
#  308821: 0,
#  530006: 0,
#  50778: 1,
#  368216: 0,
#  325215: 0,
#  30307: 0,
#  392804: 1,
#  5733: 1,
#  513637: 0,
#  622184: 0,
#  423530: 1,
#  212590: 1,
#  433777: 1,
#  609907: 0,
#  568948: 0,
#  52852: 1,
#  710259: 0,
#  474740: 0,
#  796280: 1,
#  214648: 1,
#  585337: 0,
#  30330: 0,
#  509564: 0,
#  562812: 0,
#  308861: 1,
#  495232: 1,
#  480899: 0,
#  542340: 1,
#  423557: 0,
#  343688: 0,
#  870025: 1,
#  ...}

# %%
len(diz_global_svm['df_dist_5']['clf_1']['diz_correct_events'])
# Out:
# 1191

# %%
len(diz_global_svm['df_dist_5']['clf_1']['misclassified_events'])
# Out:
# 1209

# %%
len(diz_global_svm['df_dist_30']['clf_2']['diz_correct_events'])
# Out:
# 1255

# %%
len(diz_global_svm['df_dist_30']['clf_2']['misclassified_events'])
# Out:
# 1145

# %%
diz_global_svm['df_dist_5']['clf_1']['misclassified_events']
# Out:
# {443194: {'new_value': 0, 'old_value': 1},
#  313751: {'new_value': 0, 'old_value': 1},
#  488165: {'new_value': 0, 'old_value': 1},
#  830293: {'new_value': 0, 'old_value': 1},
#  853371: {'new_value': 0, 'old_value': 1},
#  685888: {'new_value': 0, 'old_value': 1},
#  232417: {'new_value': 1, 'old_value': 0},
#  541149: {'new_value': 0, 'old_value': 1},
#  46178: {'new_value': 0, 'old_value': 1},
#  540716: {'new_value': 1, 'old_value': 0},
#  361898: {'new_value': 0, 'old_value': 1},
#  635059: {'new_value': 0, 'old_value': 1},
#  324849: {'new_value': 1, 'old_value': 0},
#  774682: {'new_value': 0, 'old_value': 1},
#  837601: {'new_value': 1, 'old_value': 0},
#  137103: {'new_value': 0, 'old_value': 1},
#  829932: {'new_value': 0, 'old_value': 1},
#  461581: {'new_value': 0, 'old_value': 1},
#  411505: {'new_value': 1, 'old_value': 0},
#  542332: {'new_value': 0, 'old_value': 1},
#  824470: {'new_value': 0, 'old_value': 1},
#  246159: {'new_value': 1, 'old_value': 0},
#  143086: {'new_value': 0, 'old_value': 1},
#  148625: {'new_value': 0, 'old_value': 1},
#  465987: {'new_value': 0, 'old_value': 1},
#  737044: {'new_value': 0, 'old_value': 1},
#  271821: {'new_value': 0, 'old_value': 1},
#  694832: {'new_value': 1, 'old_value': 0},
#  83817: {'new_value': 1, 'old_value': 0},
#  847218: {'new_value': 0, 'old_value': 1},
#  460302: {'new_value': 0, 'old_value': 1},
#  638696: {'new_value': 0, 'old_value': 1},
#  466693: {'new_value': 0, 'old_value': 1},
#  127371: {'new_value': 1, 'old_value': 0},
#  152468: {'new_value': 0, 'old_value': 1},
#  548288: {'new_value': 1, 'old_value': 0},
#  488938: {'new_value': 0, 'old_value': 1},
#  285562: {'new_value': 1, 'old_value': 0},
#  846214: {'new_value': 1, 'old_value': 0},
#  514550: {'new_value': 0, 'old_value': 1},
#  449901: {'new_value': 0, 'old_value': 1},
#  ...}

# %% [markdown]
# ### Prendiamo gli insiemi di eventi classificati bene o male di tutti i classificatori o di tutte le epoche, col fine di fare l'intersezione e individuare eventi classificati bene o male da tutti i modelli (CONFRONTI INTERNI)

# %%
def get_total_set_classifications(lista_dist, lista_clf_epoch, diz_global):
    
    diz_total_set_classifications = {}

    for dist in lista_dist:
        
        diz_total_set_classifications[dist] = {}
        
        lista_set_misclassified = []
        lista_set_correct = []
        
        for clf_epoch in lista_clf_epoch:
            lista_set_misclassified.append(diz_global[dist][clf_epoch]['keys_misclassified_events'])
            lista_set_correct.append(diz_global[dist][clf_epoch]['keys_correct_events'])
            
        diz_total_set_classifications[dist]['lista_set_misclassified'] = lista_set_misclassified
        diz_total_set_classifications[dist]['lista_set_correct'] = lista_set_correct
        
    return diz_total_set_classifications

# %%
diz_total_set_classifications_svm = get_total_set_classifications(lista_dist, lista_clf, diz_global_svm)

# %%
diz_total_set_classifications_bert = get_total_set_classifications(lista_dist, lista_epoche, diz_global_bert)

# %%
len(diz_total_set_classifications_svm['df_dist_5']['lista_set_misclassified'])
# Out:
# 12

# %% [markdown]
# ### Facciamo l'intersezione delle classificazioni degli eventi fra clf o epoche, a parità di complessità

# %%
def get_intersection_total(diz, lista_dist):
    
    diz_intersections = {}
    
    for dist in lista_dist:
        
        diz_intersections[dist] = {}
        
        # prendo soltanto gli eventi classificati bene o male da tutti i clf
        intersection_misclassified = \
                        diz[dist]['lista_set_misclassified'][0].intersection(*diz[dist]['lista_set_misclassified'])
        
        intersection_correct = diz[dist]['lista_set_correct'][0].intersection(*diz[dist]['lista_set_correct'])
        
        # prendo gli eventi classificati bene o male che appaiono solo in un set
        # getting frequencies using Counter()
        # from_iterable() flattens the list 
        
        freq_misclassified = collections.Counter(chain.from_iterable(diz[dist]['lista_set_misclassified']))
        # getting frequency count 1 
        res_misclassified = {idx for idx in freq_misclassified if freq_misclassified[idx] == 1}
        
        freq_correct = collections.Counter(chain.from_iterable(diz[dist]['lista_set_correct']))
        res_correct = {idx for idx in freq_correct if freq_correct[idx] == 1}
        
        diz_intersections[dist]['intersection_misclassified'] = intersection_misclassified
        diz_intersections[dist]['intersection_correct'] = intersection_correct
        diz_intersections[dist]['other_events_misclassified'] = res_misclassified
        diz_intersections[dist]['other_events_correct'] = res_correct
        
    return diz_intersections

# %% [markdown]
# ### Intersezioni di eventi classificati bene o male da tutti i clf o in tutte le epoche, più eventi classificati bene o male da un solo clf o in una sola epoca

# %%
diz_intersections_svm = get_intersection_total(diz_total_set_classifications_svm, lista_dist)

# %%
diz_intersections_bert = get_intersection_total(diz_total_set_classifications_bert, lista_dist)

# %%
diz_intersections_svm
# Out:
# {'df_dist_5': {'intersection_misclassified': {195285, 228695},
#   'intersection_correct': {351014, 414778, 464910, 518453, 537330},
#   'other_events_misclassified': {5733,
#    9795,
#    23285,
#    31030,
#    45684,
#    51346,
#    55691,
#    82300,
#    106936,
#    141795,
#    144281,
#    148614,
#    195648,
#    249764,
#    292022,
#    300711,
#    309684,
#    325215,
#    360584,
#    367018,
#    368710,
#    411144,
#    411308,
#    416066,
#    423689,
#    527854,
#    534062,
#    557954,
#    600238,
#    605470,
#    666589,
#    689726,
#    714872,
#    718850,
#    730480,
#    775265,
#    793151,
#    842003,
#    849055,
#    868043},
#   'other_events_correct': {4227,
#    18223,
#    34717,
#    50850,
#    124516,
#    128709,
#    134594,
#    173444,
#    183816,
#    190126,
#    240695,
#    260309,
#    305880,
#    309540,
#    407642,
#    440791,
#    552823,
#    592866,
#    622184,
#    627620,
#    663505,
#    767259,
#    796667,
#    822229,
#    829790,
#    830743,
#    848244,
#    864591}},
#  'df_dist_10': {'intersection_misclassified': {4297,
#    26519,
#    57011,
#    58483,
#    58648,
#    60715,
#    63918,
#    65017,
#    67344,
#    71952,
#    73832,
#    81029,
#    87325,
#    91544,
#    91914,
#    95410,
#    95726,
#    105765,
#    110900,
#    124119,
#    132617,
#    144171,
#    145655,
#    158479,
#    166587,
#    169635,
#    176681,
#    180629,
#    186835,
#    196178,
#    206389,
#    209298,
#    228168,
#    234188,
#    238470,
#    242048,
#    260541,
#    267615,
#    284376,
#    285243,
#    289752,
#    292724,
#    295040,
#    297121,
#    297191,
#    318308,
#    321079,
#    358102,
#    366651,
#    368745,
#    392213,
#    393104,
#    396466,
#    401691,
#    410469,
#    10507,
#    12973,
#    18819,
#    20534,
#    26579,
#    26838,
#    52485,
#    53803,
#    60317,
#    61619,
#    67913,
#    71200,
#    71350,
#    72846,
#    75760,
#    101203,
#    122955,
#    123678,
#    131310,
#    133499,
#    136835,
#    137850,
#    141736,
#    144344,
#    161603,
#    184874,
#    188196,
#    194939,
#    198986,
#    208547,
#    221609,
#    230876,
#    231692,
#    238738,
#    240899,
#    250068,
#    251902,
#    260392,
#    267025,
#    270023,
#    277660,
#    290132,
#    293795,
#    309807,
#    313441,
#    327506,
#    335283,
#    337134,
#    347301,
#    351925,
#    352123,
#    355969,
#    380937,
#    382588,
#    387145,
#    397850,
#    406429,
#    411574,
#    412654,
#    417941,
#    423056,
#    425685,
#    431574,
#    434432,
#    443556,
#    452922,
#    456120,
#    463734,
#    465882,
#    466296,
#    482299,
#    491573,
#    498307,
#    504274,
#    521270,
#    522906,
#    524388,
#    543868,
#    554304,
#    557812,
#    558203,
#    559064,
#    559483,
#    561774,
#    564859,
#    567222,
#    568652,
#    577688,
#    581608,
#    582019,
#    623422,
#    623749,
#    632093,
#    640014,
#    643286,
#    647530,
#    673748,
#    681378,
#    695795,
#    702780,
#    704177,
#    714127,
#    714165,
#    723872,
#    724213,
#    748987,
#    753318,
#    767097,
#    773698,
#    798802,
#    810923,
#    818073,
#    822547,
#    833719,
#    839147,
#    840699,
#    862854,
#    863447,
#    873751,
#    877007,
#    886280}}}

# %%
lista_df_test
# Out:
# [          Id                                         Sentence_1  \
#  0       3511            È questo «in nome del popolo italiano»?
#  1     443194  Non guardiamo a soluzioni come l'erezione di m...
#  2     438394  La popolazione carceraria è scesa a 52.164 e s...
#  3     313751  Mi fermo perché non voglio offendere nessuno, ...
#  4     488165  La prima riunione europea dei Ministri della s...
#  ...      ...                                                ...
#  2395   35231  Non è un caso che il Governo e la maggioranza ...
#  2396  300044  Anzi, svolse sempre con passione e consapevole...
#  2397   74207  È chiaro che una catastrofe delle dimensioni d...
#  2398  390608  Se doveva cadere così in basso, era più dignit...
#  2399  187838  Non ci sono parole per ringraziare i nostri me...
#
#                                               Sentence_2  Class
#  0     Signor Presidente, ho chiesto di intervenire a...      1
#  1     Tutto ciò deve necessariamente avvenire attrav...      1
#  2     Sei anni fa i detenuti erano 67.971 e 21.494 l...      0
#  3                                     Ci ridono dietro!      1
#  4     Siamo un grande Paese, che ha svolto un lavoro...      1
#  ...                                                 ...    ...
#  2395  Ma neanche il testo di mediazione che la Commi...      0
#  2396  Con lui scompare una figura importante della s...      0
#  2397  Cito, prima di invitare l'Assemblea all'approv...      1
#  2398  Un'Assemblea tanto grande quanto debole, i cui...      1
#  2399  Penso allo sconforto di chi ha perso un genito...      1
#
#  [2400 rows x 4 columns],
#            Id                                         Sentence_1  \
#  0      14266  Ha preso visione di carte, ha fatto i controll...
#  1     579957  C'è stata la volontà di sforzarsi di fare sint...
#  2      46520  Indìco la votazione nominale con scrutinio sim...
#  3      58326  Sono felice e contenta - e lo dico per soddisf...
#  4     509841  Purtroppo il controllo oggi è affidato soltant...
#  ...      ...                                                ...
#  2395  716012  In questa richiesta c'è la testimonianza della...
#  2396   82687  Signor Presidente, più di un anno fa ho deposi...
#  2397  190832  Oggi lei conferma questa impostazione e la arr...
#  2398  435685  Lasciate che mostrino tutte le loro divisioni ...
#  2399   64616  Il modello semipresidenziale presenterebbe ino...
#
#                                               Sentence_2  Class
#  0     Con questo disegno di legge noi vogliamo migli...      1
#  1     È troppo facile fare promesse elettorali che n...      1
#  2                                Il Senato non approva.      0
#  3     Non stiamo discutendo, come qualcuno ci diceva...      0
#  4     Vorrei richiamare l'attenzione anche su una se...      0
#  ...                                                 ...    ...
#  2395  I provvedimenti in generale da parte della pub...      1
#  2396  In terzo luogo, presentano diversi trucchi per...      1
#  2397  Due temi più di ogni altro sono chiari nella l...      0
#  2398  Prendo atto a malincuore che - pare - i princi...      1
#  2399  Per quanto concerne i limiti derivanti dalla m...      0
#
#  [2400 rows x 4 columns],
#            Id                                         Sentence_1  \
#  0     872979  Forse il cambiamento si limitava al portare gl...
#  1     196247  Un fatto che ha destato in noi grande inquietu...
#  2     519084  In buona sostanza riproduce le stesse fattispe...
#  3     651123  Si tratta di un ghetto che, nonostante l'impeg...
#  4     824922  Ma, come sappiamo, la questione può essere sup...
#  ...      ...                                                ...
#  2395  523401  In questi mesi, quante visite mediche sono sal...
#  2396   17750  Il decreto - legge in esame, che dà un'altra f...
#  2397  288870  I Paesi esteri mandano i loro capitali qui e f...
#  2398  451578  Indìco la votazione nominale con scrutinio sim...
#  2399  773832                             Il Senato non approva.
#
#                                               Sentence_2  Class
#  0     Anzi, proprio lei ha chiesto a noi di cambiare...      0
#  1     Un evento che noi del Gruppo parlamentare Movi...      0
#  2     È invece punito con la pena della reclusione d...      1
#  3     Sono emendamenti assolutamente puntuali che ch...      1
#  4     In questa disciplina si distinguono i Paesi te...      0
#  ...                                                 ...    ...
#  2395  Se c'è un Ministro dell'interno, che si faccia...      1
#  2396  La raccolta differenziata in Campania è al min...      1
#  2397                       I problemi vanno affrontati!      1
#  2398                             Il Senato non approva.      0
#  2399  Risultano pertanto preclusi la restante parte ...      0
#
#  [2400 rows x 4 columns],
#            Id                                         Sentence_1  \
#  0     752594  Signor Presidente, voglio iniziare ricordando ...
#  1     147441  Adesso il Governo si è impegnato molto su ques...
#  2     118812  Credo sia quindi indispensabile che si diffond...
#  3     396655  Signora Presidente, il tema della lotta alle m...
#  4     192358  Ecco, siamo diventati cittadini che camminano ...
#  ...      ...                                                ...
#  2395  419047  Solo una minima parte di coloro che, anche in ...
#  2396  425997  A tal fine, è stato costituito un sistema di c...
#  2397  579555                             Il Senato non approva.
#  2398  398376  Indìco la votazione nominale con scrutinio sim...
#  2399  106289  Voi avete posto la fiducia - ve lo vorrei rico...
#
#                                               Sentence_2  Class
#  0     Il primo è che quella elettorale è una legge f...      0
#  1     La scuola ha affrontato tre mesi difficilissim...      1
#  2     L'articolo 7 dispone invece la soppressione di...      1
#  3     È proprio questo il senso delle relazioni che ...      0
#  4     Dovremo iniziare a guardarci dal di fuori, dov...      0
#  ...                                                 ...    ...
#  2395  Nei giorni scorsi abbiamo fatto una figuraccia...      0
#  2396  Vorrei ancora ricordare il disegno di legge ap...      0
#  2397  L'emendamento 2.1320 è precluso dalla reiezion...      0
#  2398  Passiamo alla votazione della prima parte dell...      1
#  2399                     Ma è questa la questione vera.      1
#
#  [2400 rows x 4 columns],
#            Id                                         Sentence_1  \
#  0     104187  Penso - ad esempio - al numero molto alto di d...
#  1     816288  Attesa la dichiarazione del relatore e la sua ...
#  2     794533  Signor Presidente, ci troviamo in quest'Aula a...
#  3      90004  Signor Presidente, recependo le indicazioni de...
#  4     193562  Mi creda: non c'è nessun bisogno di alzare la ...
#  ...      ...                                                ...
#  2395  449610  Minaccioso ovviamente nei confronti di Gentilo...
#  2396  770109  Chiedo, perlomeno, di riconoscere le qualità c...
#  2397  193789  Per quanto di competenza dell'amministrazione ...
#  2398  331022  Avverto che nel corso della seduta odierna pot...
#  2399  552730  Signor Presidente, annuncio di ritirare l'emen...
#
#                                               Sentence_2  Class
#  0     Se quindi si accedesse per concorso - e lo dic...      0
#  1     Signor Presidente, avendolo sottoscritto per t...      0
#  2     Siamo di fronte, infatti, ad un Parlamento del...      0
#  3     In effetti, in 7ᵃ Commissione sono attualmente...      0
#  4     Ho interloquito con lei nella maniera che ho r...      0
#  ...                                                 ...    ...
#  2395  L'immane massacro di milioni di ebrei, ma anch...      1
#  2396  L'elenco dei senatori in congedo e assenti per...      1
#  2397  Allo stesso giornalista non risultano inoltre ...      0
#  2398  Pertanto decorre da questo momento il termine ...      0
#  2399  Peccato non avere la capacità e la cognizione ...      1
#
#  [2400 rows x 4 columns]]

# %%
diz_intersections_svm['df_dist_5']['other_events_correct']
# Out:
# {4227,
#  18223,
#  34717,
#  50850,
#  124516,
#  128709,
#  134594,
#  173444,
#  183816,
#  190126,
#  240695,
#  260309,
#  305880,
#  309540,
#  407642,
#  440791,
#  552823,
#  592866,
#  622184,
#  627620,
#  663505,
#  767259,
#  796667,
#  822229,
#  829790,
#  830743,
#  848244,
#  864591}

# %%
diz_global_svm['df_dist_5']['clf_1'].keys()
# Out:
# dict_keys(['misclassified_events', 'diz_correct_events', 'keys_misclassified_events', 'keys_correct_events'])

# %%
for clf in lista_clf:
    print(clf, diz_global_svm['df_dist_5'][clf]['misclassified_events'][228695])
# Out:
# clf_1 {'new_value': 1, 'old_value': 0}
# clf_2 {'new_value': 1, 'old_value': 0}
# clf_3 {'new_value': 1, 'old_value': 0}
# clf_4 {'new_value': 1, 'old_value': 0}
# clf_5 {'new_value': 1, 'old_value': 0}
# clf_6 {'new_value': 1, 'old_value': 0}
# clf_7 {'new_value': 1, 'old_value': 0}
# clf_8 {'new_value': 1, 'old_value': 0}
# clf_9 {'new_value': 1, 'old_value': 0}
# clf_10 {'new_value': 1, 'old_value': 0}
# clf_11 {'new_value': 1, 'old_value': 0}
# clf_12 {'new_value': 1, 'old_value': 0}

# %%
for clf in lista_clf:
    print(clf, diz_global_svm['df_dist_5'][clf]['misclassified_events'].get(173444))
# Out:
# clf_1 {'new_value': 1, 'old_value': 0}
# clf_2 {'new_value': 1, 'old_value': 0}
# clf_3 {'new_value': 1, 'old_value': 0}
# clf_4 None
# clf_5 {'new_value': 1, 'old_value': 0}
# clf_6 {'new_value': 1, 'old_value': 0}
# clf_7 {'new_value': 1, 'old_value': 0}
# clf_8 {'new_value': 1, 'old_value': 0}
# clf_9 {'new_value': 1, 'old_value': 0}
# clf_10 {'new_value': 1, 'old_value': 0}
# clf_11 {'new_value': 1, 'old_value': 0}
# clf_12 {'new_value': 1, 'old_value': 0}

# %%
diz_global_svm['df_dist_5']['clf_4']['diz_correct_events'].get(173444)
# Out:
# 0

# %%
totale = list()
for id_pred in diz_intersections_svm['df_dist_5']['intersection_misclassified']:
    
    lst_tmp = list(set([diz_global_svm['df_dist_5'][clf]['misclassified_events'][id_pred]['new_value']
              for clf in lista_clf]))
    
    totale.extend(lst_tmp)
    
print(Counter(totale))
# Out:
# Counter({0: 1, 1: 1})

# %%
totale = list()

for id_pred in diz_intersections_svm['df_dist_5']['intersection_correct']:
    
    lst_tmp = list(set([diz_global_svm['df_dist_5'][clf]['diz_correct_events'][id_pred]
              for clf in lista_clf]))
    
    totale.extend(lst_tmp)
    
c = Counter(totale)
c.setdefault(0, 0)
c.setdefault(1, 0)
print(c)
# Out:
# Counter({0: 5, 1: 0})

# %%
totale = list()
lst_tmp = []
for id_pred in diz_intersections_svm['df_dist_5']['other_events_misclassified']:
    
    for clf in lista_clf:
        if diz_global_svm['df_dist_5'][clf]['misclassified_events'].get(id_pred):
            totale.append(diz_global_svm['df_dist_5'][clf]['misclassified_events'][id_pred]['new_value'])
    
print(Counter(totale))
# Out:
# Counter({1: 21, 0: 19})

# %%
totale = list()
for id_pred in diz_intersections_svm['df_dist_5']['other_events_correct']:
    for clf in lista_clf:
        if diz_global_svm['df_dist_5'][clf]['diz_correct_events'].get(id_pred) != None:
            totale.append(diz_global_svm['df_dist_5'][clf]['diz_correct_events'][id_pred])

    
print(Counter(totale))
# Out:
# Counter({0: 17, 1: 11})

# %%
diz_global_svm['df_dist_5']['clf_4']['diz_correct_events'][173444]
# Out:
# 0

# %%
def get_dettaglio_classi_intersezioni(lista_clf, diz_global, dizionario_intersezione_classificatori, lista_dist):
    
    diz_total = {}
    
    for distanza in lista_dist:
        
        diz_total[distanza] = {}
        
        # classificati male da tutti
        totale = list()
        for id_pred in dizionario_intersezione_classificatori[distanza]['intersection_misclassified']:

            lst_tmp = list(set([diz_global[distanza][clf]['misclassified_events'][id_pred]['new_value'] \
                                for clf in lista_clf]))
            totale.extend(lst_tmp)
            
        c = Counter(totale)
        c.setdefault(0, 0)
        c.setdefault(1, 0)
        diz_total[distanza]['errati_da_tutti'] = dict(sorted(c.items()))

        # classificati bene da tutti
        totale = list()
        for id_pred in dizionario_intersezione_classificatori[distanza]['intersection_correct']:

            lst_tmp = list(set([diz_global[distanza][clf]['diz_correct_events'][id_pred] \
                      for clf in lista_clf]))

            totale.extend(lst_tmp)

        c = Counter(totale)
        c.setdefault(0, 0)
        c.setdefault(1, 0)
        diz_total[distanza]['corretti_da_tutti'] = dict(sorted(c.items()))

        # classificati male da uno solo
        totale = list()
        for id_pred in dizionario_intersezione_classificatori[distanza]['other_events_misclassified']:
            for clf in lista_clf:
                if diz_global[distanza][clf]['misclassified_events'].get(id_pred):
                    totale.append(diz_global[distanza][clf]['misclassified_events'][id_pred]['new_value'])

        c = Counter(totale)
        c.setdefault(0, 0)
        c.setdefault(1, 0)
        diz_total[distanza]['errati_da_uno_solo'] = dict(sorted(c.items()))


        # corretti solo da uno
        totale = list()
        for id_pred in dizionario_intersezione_classificatori[distanza]['other_events_correct']:
            for clf in lista_clf:
                if diz_global[distanza][clf]['diz_correct_events'].get(id_pred) != None:
                    totale.append(diz_global[distanza][clf]['diz_correct_events'][id_pred])

        c = Counter(totale)
        c.setdefault(0, 0)
        c.setdefault(1, 0)
        diz_total[distanza]['corretti_da_uno_solo'] = dict(sorted(c.items()))
    
    return diz_total

# %%
dettaglio_classi_intersezioni_svm = \
        get_dettaglio_classi_intersezioni(lista_clf, diz_global_svm, diz_intersections_svm, lista_dist)

# %%
dettaglio_classi_intersezioni_bert = \
        get_dettaglio_classi_intersezioni(lista_epoche, diz_global_bert, diz_intersections_bert, lista_dist)

# %%
dettaglio_classi_intersezioni_svm
# Out:
# {'df_dist_5': {'errati_da_tutti': {0: 1, 1: 1},
#   'corretti_da_tutti': {0: 5, 1: 0},
#   'errati_da_uno_solo': {0: 19, 1: 21},
#   'corretti_da_uno_solo': {0: 17, 1: 11}},
#  'df_dist_10': {'errati_da_tutti': {0: 56, 1: 52},
#   'corretti_da_tutti': {0: 72, 1: 82},
#   'errati_da_uno_solo': {0: 79, 1: 82},
#   'corretti_da_uno_solo': {0: 73, 1: 70}},
#  'df_dist_20': {'errati_da_tutti': {0: 72, 1: 76},
#   'corretti_da_tutti': {0: 95, 1: 105},
#   'errati_da_uno_solo': {0: 84, 1: 103},
#   'corretti_da_uno_solo': {0: 73, 1: 79}},
#  'df_dist_30': {'errati_da_tutti': {0: 75, 1: 73},
#   'corretti_da_tutti': {0: 104, 1: 118},
#   'errati_da_uno_solo': {0: 90, 1: 124},
#   'corretti_da_uno_solo': {0: 76, 1: 93}},
#  'df_random_speech': {'errati_da_tutti': {0: 136, 1: 123},
#   'corretti_da_tutti': {0: 266, 1: 290},
#   'errati_da_uno_solo': {0: 94, 1: 177},
#   'corretti_da_uno_solo': {0: 40, 1: 84}}}

# %%
dettaglio_classi_intersezioni_bert
# Out:
# {'df_dist_5': {'errati_da_tutti': {0: 174, 1: 186},
#   'corretti_da_tutti': {0: 349, 1: 415},
#   'errati_da_uno_solo': {0: 198, 1: 193},
#   'corretti_da_uno_solo': {0: 172, 1: 139}},
#  'df_dist_10': {'errati_da_tutti': {0: 201, 1: 200},
#   'corretti_da_tutti': {0: 512, 1: 457},
#   'errati_da_uno_solo': {0: 171, 1: 175},
#   'corretti_da_uno_solo': {0: 89, 1: 129}},
#  'df_dist_20': {'errati_da_tutti': {0: 139, 1: 156},
#   'corretti_da_tutti': {0: 483, 1: 490},
#   'errati_da_uno_solo': {0: 209, 1: 189},
#   'corretti_da_uno_solo': {0: 129, 1: 125}},
#  'df_dist_30': {'errati_da_tutti': {0: 199, 1: 197},
#   'corretti_da_tutti': {0: 604, 1: 569},
#   'errati_da_uno_solo': {0: 146, 1: 107},
#   'corretti_da_uno_solo': {0: 108, 1: 97}},
#  'df_random_speech': {'errati_da_tutti': {0: 55, 1: 131},
#   'corretti_da_tutti': {0: 679, 1: 882},
#   'errati_da_uno_solo': {0: 105, 1: 162},
#   'corretti_da_uno_solo': {0: 65, 1: 43}}}

# %%
prova = pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_5'], orient='index')

# %%
prova
# Out:
#                        0   1
# errati_da_tutti        1   1
# corretti_da_tutti      5   0
# errati_da_uno_solo    19  21
# corretti_da_uno_solo  17  11

# %%
diz_grafici = {}
for distanza in lista_dist:
    print(distanza)
# Out:
# df_dist_5
# df_dist_10
# df_dist_20
# df_dist_30
# df_random_speech

# %%
sns.set_style("dark")
ax = prova.plot(kind="bar")
for label in ax.containers:
    ax.bar_label(label)
plt.xticks(rotation=30)
plt.legend(loc='upper left', labels=['Consecutivi', 'Non consecutivi'])
plt.title("Dettaglio classi")
plt.tight_layout()
plt.show()

# %%
sns.set_style("dark")
fig, axs = plt.subplots(figsize=(17,10),nrows=2, ncols=3)
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_5'], orient='index').plot(ax=axs[0,0], kind='bar', color=['#1f77b4', '#ff7f0e'])
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_10'], orient='index').plot(ax=axs[0,1], kind='bar', color=['#1f77b4', '#ff7f0e'])
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_20'], orient='index').plot(ax=axs[0,2], kind='bar', color=['#1f77b4', '#ff7f0e'])
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_30'], orient='index').plot(ax=axs[1,0], kind='bar', color=['#1f77b4', '#ff7f0e'])
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_random_speech'], orient='index').plot(ax=axs[1,1], kind='bar', color=['#1f77b4', '#ff7f0e'])

fig.delaxes(axs[1][2])
for ax, dist in zip(axs.flat, lista_dist):
    for label in ax.containers:
        ax.bar_label(label)
    
    # reordering the labels
    handles, labels = plt.gca().get_legend_handles_labels()
  
    # specify order
    order = [0,1]

    # pass handle & labels lists along with order as below
    ax.legend([handles[i] for i in order], [labels[i] for i in order], 
              labels=['Consecutivi', 'Non consecutivi'])
        
    ax.tick_params(axis='x', labelrotation=30)
    #ax.legend(loc='upper left', labels=['Consecutivi', 'Non consecutivi'])
    ax.set_title("Dettaglio classi {}".format(dist))


fig.tight_layout()
plt.show()

# %% [markdown]
# ## Dettaglio classi SVM

# %%
sns.set_style("dark")
fig, axs = plt.subplots(figsize=(17,10),nrows=2, ncols=3)
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_5'], orient='index').plot(ax=axs[0,0], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_10'], orient='index').plot(ax=axs[0,1], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_20'], orient='index').plot(ax=axs[0,2], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_dist_30'], orient='index').plot(ax=axs[1,0], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_svm['df_random_speech'], orient='index').plot(ax=axs[1,1], kind='bar')

fig.delaxes(axs[1][2])
for ax, dist in zip(axs.flat, lista_dist):
    for label in ax.containers:
        ax.bar_label(label)
    
    ax.tick_params(axis='x', labelrotation=30)
    ax.legend(loc='upper left', labels=['Consecutivi', 'Non consecutivi'])
    ax.set_title("{}".format(dist).title())


fig.tight_layout()
title = "ParlaMint_dettaglio_classi_svm"
fig.savefig(path_images_tit_ridotti + title, dpi=fig.dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# Osservando tutti i grafici si nota subito che, mentre per la distanza 5 osserviamo più eventi classificati in modo errato o corretto da un solo classificatore e pochissime classificazioni in comune, per le altre distanze registriamo una situazione diversa, in particolare per la distanza random speech, in cui vediamo una prevalenza di classificazioni corrette da parte di tutti e una minoranza di classificazioni corrette o errate da parte di un solo classificatore. Per quanto concerne queste ultime, possiamo vedere che, in entrambi i casi, dominano gli eventi non consecutivi: nel caso delle classificazioni errate, questo indica che alcune frasi che eranno effettivamente cosecutive non sono state percepite come tali da un solo classificatore; nell'altro caso, invece, probabilmente si è trattato di frasi più complesse, in cui la mancanza di coerenza del loro accostamento è stata intercettata solo da un classificatore.
# In merito alle altre distanze possiamo osservare che, all'aumentare delle distanza, cresce il numero di eventi non consecutivi classificati i modo corretto da tutti. Per tutte le distanze notiamo che, all'interno degli eventi classificati in modo errato da un solo classsificatore, prevale la classe 1, ciò significa che molto spesso un solo classificatore ha considerato non consecutivi eventi che invece lo erano.

# %% [markdown]
# ## Dettaglio classi Bert

# %%
sns.set_style("dark")
fig, axs = plt.subplots(figsize=(17,10),nrows=2, ncols=3)
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_bert['df_dist_5'], orient='index').plot(ax=axs[0,0], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_bert['df_dist_10'], orient='index').plot(ax=axs[0,1], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_bert['df_dist_20'], orient='index').plot(ax=axs[0,2], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_bert['df_dist_30'], orient='index').plot(ax=axs[1,0], kind='bar')
pd.DataFrame.from_dict(dettaglio_classi_intersezioni_bert['df_random_speech'], orient='index').plot(ax=axs[1,1], kind='bar')

fig.delaxes(axs[1][2])

for ax, dist in zip(axs.flat, lista_dist):
    for label in ax.containers:
        ax.bar_label(label)
  
    ax.tick_params(axis='x', labelrotation=30)
    ax.legend(loc='upper left', labels=['Consecutivi', 'Non consecutivi'])
    ax.set_title("{}".format(dist).title())

fig.tight_layout()
title = "ParlaMint_dettaglio_classi_bert"
fig.savefig(path_images_tit_ridotti + title, dpi=fig.dpi, bbox_inches='tight')
plt.show()

# %% [markdown]
# Osservando i grafici si nota che c'è una maggioranza di eventi classificati correttamente da tutte le epoche, con una prevalenza di eventi non consecutivi in particolare nella distanza random speech. Questo risultato probabilmente è dovuto al fatto che emerge più chiaramente l'incoerenza derivante dall'accostamento di due frasi appartenenti a interventi diversi.
# In quest'ultimo caso, inoltre, si registra una minima parte di eventi classificati in modo errato o corretto da una sola epoca.
# Per quanto concerne le altre distanze, non si nota una particolare diffferenza fra le due classi, in termini di classificazioni errate o corrette da una sola epoca o da tutte.

# %%
import matplotlib.colors as mcolors
print(mcolors.TABLEAU_COLORS)
# Out:
# {'tab:blue': '#1f77b4', 'tab:orange': '#ff7f0e', 'tab:green': '#2ca02c', 'tab:red': '#d62728', 'tab:purple': '#9467bd', 'tab:brown': '#8c564b', 'tab:pink': '#e377c2', 'tab:gray': '#7f7f7f', 'tab:olive': '#bcbd22', 'tab:cyan': '#17becf'}

# %%
diz_global_svm['df_dist_5']['clf_1']['diz_correct_events'][351014]
# Out:
# 0

# %% [markdown]
# # Calcoliamo la percentuale di overlapping

# %%
lista_epoche
# Out:
# ['Epoch0', 'Epoch1', 'Epoch2', 'Epoch3', 'Epoch4']

# %%
diz_totali_fp_fn_tp_tn_svm = {}

for distanza in lista_dist:
    diz_totali_fp_fn_tp_tn_svm[distanza] = {}
    totale_fp_fn_svm = 0
    totale_tp_tn_svm = 0
    for clf in lista_clf:
        totale_tp_tn_svm += len(diz_global_svm[distanza][clf]['diz_correct_events'])
        totale_fp_fn_svm += len(diz_global_svm[distanza][clf]['misclassified_events'])
    diz_totali_fp_fn_tp_tn_svm[distanza]['totale_tp_tn'] = totale_tp_tn_svm
    diz_totali_fp_fn_tp_tn_svm[distanza]['totale_fp_fn'] = totale_fp_fn_svm

# %%
diz_totali_fp_fn_tp_tn_bert = {}

for distanza in lista_dist:
    diz_totali_fp_fn_tp_tn_bert[distanza] = {}
    totale_fp_fn_bert = 0
    totale_tp_tn_bert = 0
    for epoca in lista_epoche:
        totale_tp_tn_bert += len(diz_global_bert[distanza][epoca]['diz_correct_events'])
        totale_fp_fn_bert += len(diz_global_bert[distanza][epoca]['misclassified_events'])
    diz_totali_fp_fn_tp_tn_bert[distanza]['totale_tp_tn'] = totale_tp_tn_bert
    diz_totali_fp_fn_tp_tn_bert[distanza]['totale_fp_fn'] = totale_fp_fn_bert

# %%
diz_totali_fp_fn_tp_tn_svm
# Out:
# {'df_dist_5': {'totale_tp_tn': 14335, 'totale_fp_fn': 14465},
#  'df_dist_10': {'totale_tp_tn': 15050, 'totale_fp_fn': 13750},
#  'df_dist_20': {'totale_tp_tn': 15243, 'totale_fp_fn': 13557},
#  'df_dist_30': {'totale_tp_tn': 15311, 'totale_fp_fn': 13489},
#  'df_random_speech': {'totale_tp_tn': 17356, 'totale_fp_fn': 11444}}

# %%
diz_totali_fp_fn_tp_tn_bert
# Out:
# {'df_dist_5': {'totale_tp_tn': 7115, 'totale_fp_fn': 4885},
#  'df_dist_10': {'totale_tp_tn': 7633, 'totale_fp_fn': 4367},
#  'df_dist_20': {'totale_tp_tn': 7945, 'totale_fp_fn': 4055},
#  'df_dist_30': {'totale_tp_tn': 8038, 'totale_fp_fn': 3962},
#  'df_random_speech': {'totale_tp_tn': 9699, 'totale_fp_fn': 2301}}

# %%
#calcolo percentuale della lunghezza di ogni insieme rispetto al totale, per tutti i livelli di complessità

def ottieni_percentuali(dizionario_intersezione_classificatori, list_df_test, diz_totali_fp_fn_tp_tn):
    
    dizionario_percentuali= {}
    
    for distanza, df_test in zip(dizionario_intersezione_classificatori, list_df_test):
    
        print(df_test.shape)
        
        dizionario_percentuali[distanza] = {}
        
        errati_da_tutti = dizionario_intersezione_classificatori[distanza]['intersection_misclassified']
        corretti_da_tutti = dizionario_intersezione_classificatori[distanza]['intersection_correct']
        errati_da_uno_solo = dizionario_intersezione_classificatori[distanza]['other_events_misclassified']
        corretti_da_uno_solo = dizionario_intersezione_classificatori[distanza]['other_events_correct']
        
        print(distanza)
        print("errati_da_tutti", len(errati_da_tutti))
        print("corretti_da_tutti", len(corretti_da_tutti))
        print("errati_da_uno_solo", len(errati_da_uno_solo))
        print("corretti_da_uno_solo", len(corretti_da_uno_solo))
        print()
        print("totale_fp_fn", diz_totali_fp_fn_tp_tn[distanza]['totale_fp_fn'])
        print("totale_tp_tn", diz_totali_fp_fn_tp_tn[distanza]['totale_tp_tn'])
        print()
        
        perc_errati_da_tutti_su_totale_classificati = (len(errati_da_tutti) * 100) / df_test.shape[0]
        perc_corretti_da_tutti_su_totale_classificati = (len(corretti_da_tutti) * 100) / df_test.shape[0]
        perc_errati_da_uno_solo_su_totale_classificati = (len(errati_da_uno_solo) * 100) / df_test.shape[0]
        perc_corretti_da_uno_solo_su_totale_classificati = (len(corretti_da_uno_solo) * 100) / df_test.shape[0]
        
        #perc_errati_da_tutti_su_totale_fp_fn = (len(errati_da_tutti) * 100) / diz_totali_fp_fn_tp_tn[distanza]['totale_fp_fn']
        #perc_corretti_da_tutti_su_totale_tp_tn = (len(corretti_da_tutti) * 100) / diz_totali_fp_fn_tp_tn[distanza]['totale_tp_tn']
        #perc_errati_da_uno_solo_su_totale_fp_fn = (len(errati_da_uno_solo) * 100) / diz_totali_fp_fn_tp_tn[distanza]['totale_fp_fn']
        #perc_corretti_da_uno_solo_su_totale_tp_tn = (len(corretti_da_uno_solo) * 100) / diz_totali_fp_fn_tp_tn[distanza]['totale_tp_tn']
        
        dizionario_percentuali[distanza]['perc_errati_da_tutti_su_totale_classificati'] = "%.2f" % perc_errati_da_tutti_su_totale_classificati + "%"
        dizionario_percentuali[distanza]['perc_corretti_da_tutti_su_totale_classificati'] = "%.2f" % perc_corretti_da_tutti_su_totale_classificati + "%"
        dizionario_percentuali[distanza]['perc_errati_da_uno_solo_su_totale_classificati'] = "%.2f" % perc_errati_da_uno_solo_su_totale_classificati + "%"
        dizionario_percentuali[distanza]['perc_corretti_da_uno_solo_su_totale_classificati'] = "%.2f" % perc_corretti_da_uno_solo_su_totale_classificati + "%"
        
        #dizionario_percentuali[distanza]['perc_errati_da_tutti_su_totale_fp_fn'] = "%.2f" % perc_errati_da_tutti_su_totale_fp_fn + "%"
        #dizionario_percentuali[distanza]['perc_corretti_da_tutti_su_totale_tp_tn'] = "%.2f" % perc_corretti_da_tutti_su_totale_tp_tn + "%"
        #dizionario_percentuali[distanza]['perc_errati_da_uno_solo_su_totale_fp_fn'] = "%.2f" % perc_errati_da_uno_solo_su_totale_fp_fn + "%"
        #dizionario_percentuali[distanza]['perc_corretti_da_uno_solo_su_totale_tp_tn'] = "%.2f" % perc_corretti_da_uno_solo_su_totale_tp_tn + "%"
        
    return dizionario_percentuali

# %%
diz_percentuali_svm = ottieni_percentuali(diz_intersections_svm, lista_df_test, diz_totali_fp_fn_tp_tn_svm)
# Out:
# (2400, 4)
# df_dist_5
# errati_da_tutti 2
# corretti_da_tutti 5
# errati_da_uno_solo 40
# corretti_da_uno_solo 28
#
# totale_fp_fn 14465
# totale_tp_tn 14335
#
# (2400, 4)
# df_dist_10
# errati_da_tutti 108
# corretti_da_tutti 154
# errati_da_uno_solo 161
# corretti_da_uno_solo 143
#
# totale_fp_fn 13750
# totale_tp_tn 15050
#
# (2400, 4)
# df_dist_20
# errati_da_tutti 148
# corretti_da_tutti 200
# errati_da_uno_solo 187
# corretti_da_uno_solo 152
#
# totale_fp_fn 13557
# totale_tp_tn 15243
#
# (2400, 4)
# df_dist_30
# errati_da_tutti 148
# corretti_da_tutti 222
# errati_da_uno_solo 214
# corretti_da_uno_solo 169
#
# totale_fp_fn 13489
# totale_tp_tn 15311
#
# (2400, 4)
# df_random_speech
# errati_da_tutti 259
# corretti_da_tutti 556
# errati_da_uno_solo 271
# corretti_da_uno_solo 124
#
# totale_fp_fn 11444
# totale_tp_tn 17356

# %%
diz_percentuali_bert = ottieni_percentuali(diz_intersections_bert, lista_df_test, diz_totali_fp_fn_tp_tn_bert)
# Out:
# (2400, 4)
# df_dist_5
# errati_da_tutti 360
# corretti_da_tutti 764
# errati_da_uno_solo 391
# corretti_da_uno_solo 311
#
# totale_fp_fn 4885
# totale_tp_tn 7115
#
# (2400, 4)
# df_dist_10
# errati_da_tutti 401
# corretti_da_tutti 969
# errati_da_uno_solo 346
# corretti_da_uno_solo 218
#
# totale_fp_fn 4367
# totale_tp_tn 7633
#
# (2400, 4)
# df_dist_20
# errati_da_tutti 295
# corretti_da_tutti 973
# errati_da_uno_solo 398
# corretti_da_uno_solo 254
#
# totale_fp_fn 4055
# totale_tp_tn 7945
#
# (2400, 4)
# df_dist_30
# errati_da_tutti 396
# corretti_da_tutti 1173
# errati_da_uno_solo 253
# corretti_da_uno_solo 205
#
# totale_fp_fn 3962
# totale_tp_tn 8038
#
# (2400, 4)
# df_random_speech
# errati_da_tutti 186
# corretti_da_tutti 1561
# errati_da_uno_solo 267
# corretti_da_uno_solo 108
#
# totale_fp_fn 2301
# totale_tp_tn 9699

# %%
diz_percentuali_svm
# Out:
# {'df_dist_5': {'perc_errati_da_tutti_su_totale_classificati': '0.08%',
#   'perc_corretti_da_tutti_su_totale_classificati': '0.21%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '1.67%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '1.17%'},
#  'df_dist_10': {'perc_errati_da_tutti_su_totale_classificati': '4.50%',
#   'perc_corretti_da_tutti_su_totale_classificati': '6.42%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '6.71%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '5.96%'},
#  'df_dist_20': {'perc_errati_da_tutti_su_totale_classificati': '6.17%',
#   'perc_corretti_da_tutti_su_totale_classificati': '8.33%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '7.79%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '6.33%'},
#  'df_dist_30': {'perc_errati_da_tutti_su_totale_classificati': '6.17%',
#   'perc_corretti_da_tutti_su_totale_classificati': '9.25%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '8.92%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '7.04%'},
#  'df_random_speech': {'perc_errati_da_tutti_su_totale_classificati': '10.79%',
#   'perc_corretti_da_tutti_su_totale_classificati': '23.17%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '11.29%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '5.17%'}}

# %%
diz_percentuali_bert
# Out:
# {'df_dist_5': {'perc_errati_da_tutti_su_totale_classificati': '15.00%',
#   'perc_corretti_da_tutti_su_totale_classificati': '31.83%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '16.29%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '12.96%'},
#  'df_dist_10': {'perc_errati_da_tutti_su_totale_classificati': '16.71%',
#   'perc_corretti_da_tutti_su_totale_classificati': '40.38%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '14.42%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '9.08%'},
#  'df_dist_20': {'perc_errati_da_tutti_su_totale_classificati': '12.29%',
#   'perc_corretti_da_tutti_su_totale_classificati': '40.54%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '16.58%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '10.58%'},
#  'df_dist_30': {'perc_errati_da_tutti_su_totale_classificati': '16.50%',
#   'perc_corretti_da_tutti_su_totale_classificati': '48.88%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '10.54%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '8.54%'},
#  'df_random_speech': {'perc_errati_da_tutti_su_totale_classificati': '7.75%',
#   'perc_corretti_da_tutti_su_totale_classificati': '65.04%',
#   'perc_errati_da_uno_solo_su_totale_classificati': '11.12%',
#   'perc_corretti_da_uno_solo_su_totale_classificati': '4.50%'}}

# %%
df_perc_svm = pd.DataFrame(diz_percentuali_svm).T

# %% [markdown]
# df_perc_svm.rename(columns={'classificati_in_modo_sbagliato_da_tutti':"Eventi classificati in modo errato da tutti", \
#                          'classificati_correttamente_da_tutti': "Eventi classificati in modo corretto da tutti", \
#                           'classificati_in_modo_sbagliato_da_uno_solo': "Eventi classificati in modo errato da uno solo", \
#                           'classificati_correttamente_da_uno_solo': "Eventi classificati in modo corretto da uno solo"},
#                   inplace=True)

# %%
df_perc_svm
# Out:
#                  perc_errati_da_tutti_su_totale_classificati  \
# df_dist_5                                              0.08%
# df_dist_10                                             4.50%
# df_dist_20                                             6.17%
# df_dist_30                                             6.17%
# df_random_speech                                      10.79%
#
#                  perc_corretti_da_tutti_su_totale_classificati  \
# df_dist_5                                                0.21%
# df_dist_10                                               6.42%
# df_dist_20                                               8.33%
# df_dist_30                                               9.25%
# df_random_speech                                        23.17%
#
#                  perc_errati_da_uno_solo_su_totale_classificati  \
# df_dist_5                                                 1.67%
# df_dist_10                                                6.71%
# df_dist_20                                                7.79%
# df_dist_30                                                8.92%
# df_random_speech                                         11.29%
#
#                  perc_corretti_da_uno_solo_su_totale_classificati
# df_dist_5                                                   1.17%
# df_dist_10                                                  5.96%
# df_dist_20                                                  6.33%
# df_dist_30                                                  7.04%
# df_random_speech                                            5.17%

# %% [markdown]
# Possiamo notare che, per tutte le casistiche, c'è una vicinanza fra lele percentuali per le distanze 20 e 30, mentre osserviamo valori inferiori per la distannza 10. Per quanto riguarda il livello di complessità più basso (distanza 5) osserviamo valori molto bassi.
# Per quanto concerne la distanza random speech, si registra una percentuale di eventi classificati in modo corretto da tutti i classificatori superiore a quella degli eventi la cui classificazione è risultata errata per tutti. Tale dato è superiore anche rispetto agli eventi classificati in modo errato o corretto da un solo classificatore.

# %%
df_perc_bert = pd.DataFrame(diz_percentuali_bert).T

# %% [markdown]
# df_perc_bert.rename(columns={'classificati_in_modo_sbagliato_da_tutti':"Eventi classificati in modo errato da tutte", \
#                          'classificati_correttamente_da_tutti': "Eventi classificati in modo corretto da tutte", \
#                           'classificati_in_modo_sbagliato_da_uno_solo': "Eventi classificati in modo errato da una sola", \
#                           'classificati_correttamente_da_uno_solo': "Eventi classificati in modo corretto da una sola"},
#                   inplace=True)

# %%
df_perc_bert
# Out:
#                  perc_errati_da_tutti_su_totale_classificati  \
# df_dist_5                                             15.00%
# df_dist_10                                            16.71%
# df_dist_20                                            12.29%
# df_dist_30                                            16.50%
# df_random_speech                                       7.75%
#
#                  perc_corretti_da_tutti_su_totale_classificati  \
# df_dist_5                                               31.83%
# df_dist_10                                              40.38%
# df_dist_20                                              40.54%
# df_dist_30                                              48.88%
# df_random_speech                                        65.04%
#
#                  perc_errati_da_uno_solo_su_totale_classificati  \
# df_dist_5                                                16.29%
# df_dist_10                                               14.42%
# df_dist_20                                               16.58%
# df_dist_30                                               10.54%
# df_random_speech                                         11.12%
#
#                  perc_corretti_da_uno_solo_su_totale_classificati
# df_dist_5                                                  12.96%
# df_dist_10                                                  9.08%
# df_dist_20                                                 10.58%
# df_dist_30                                                  8.54%
# df_random_speech                                            4.50%

# %% [markdown]
# A un primo sguardo, risulta subito evidente che, a prescindere dai livelli di complessità, osserviamo dei valori percentuali più alti per gli eventi corretti da tutte le epoche, rispetto a quelli errati da tutte, in modo particolare per la distanza random speech (come atteso). Non c'è una differenza rilevante fra le varie distanze per quanto riguarda le percentuali di eventi classificati in modo sbagliato da una sola epoca, sebbene si riscontri qualche valore più alto per la distanza 5 e 20. In merito agli eventi classificati in moddo corretto da una sola epoca notiamo che il valore più alto è ddimostrato dalla distanza 5, seguita alla 20, mentre per la random speech troviamo il valore più basso.

# %%
save_dataframe('df_perc_svm', df_perc_svm)
# Out:
# File salvato correttamente

# %%
save_dataframe('df_perc_bert', df_perc_bert)
# Out:
# File salvato correttamente

# %%
# per ogni distanza calcolo la percentuale di TP/FP e TN/FN sul totale di eventi classificati correttamente o meno
# da tutti i classificatori o da tutte le epoche

def ottieni_percentuali_tp_fp_tn_fn(dizionario_classificatori, list_df_test, diz_global, lista_clf_epoch, modello):
    
    dizionario_percentuali = {}
    
    for distanza, df_test in zip(dizionario_classificatori, list_df_test):
    
        print("Distanza {} - test shape: {}".format(distanza, df_test.shape))
        print()
        dizionario_percentuali[distanza] = {}
        
        errati_da_tutti = dizionario_classificatori[distanza]['intersection_misclassified']
        corretti_da_tutti = dizionario_classificatori[distanza]['intersection_correct']
        errati_da_uno_solo = dizionario_classificatori[distanza]['other_events_misclassified']
        corretti_da_uno_solo = dizionario_classificatori[distanza]['other_events_correct']
        
        dizionario_errati_corretti = {}
        dizionario_errati_corretti['errati_da_tutti'] = errati_da_tutti
        dizionario_errati_corretti['corretti_da_tutti'] = corretti_da_tutti
        dizionario_errati_corretti['errati_da_uno_solo'] = errati_da_uno_solo
        dizionario_errati_corretti['corretti_da_uno_solo'] = corretti_da_uno_solo
        
        diz_tp_fp_tn_fn = get_liste_tp_fp_tn_fn(distanza, \
                                                dizionario_errati_corretti, \
                                                diz_global, \
                                                lista_clf_epoch, \
                                                dizionario_errati_corretti, modello)
        
        for chiave in dizionario_errati_corretti:
            dizionario_percentuali[distanza][chiave] = {}
            dizionario_percentuali[distanza][chiave]['percentuale_consecutivi'] = "%.2f" % diz_tp_fp_tn_fn[chiave]['percentuale_consecutivi'] + "%"
            dizionario_percentuali[distanza][chiave]['percentuale_non_consecutivi'] = "%.2f" % diz_tp_fp_tn_fn[chiave]['percentuale_non_consecutivi'] + "%"
        
        print()
        
    return dizionario_percentuali

# %%
def get_liste_tp_fp_tn_fn(distanza, dizionario_intersezioni_classificatori, diz_global, lista_clf_epoch, \
                          dizionario_errati_corretti, modello):
    
    diz_tp_fp_tn_fn = {}
    
    if modello == 'svm':
        num_classificazioni_comuni = 12
    else:
        num_classificazioni_comuni = 5
    
    for chiave in dizionario_errati_corretti:
        
        diz_tp_fp_tn_fn[chiave] = {}
        
        consecutivi = []
        non_consecutivi = []
        
        # per ogni chiave voglio la quantità di esempi non_consecutivi e consecutivi rispetto al totale
        for evento in dizionario_errati_corretti[chiave]:
            
            # False Positive / False Negative
            if chiave == 'errati_da_tutti':
                lista_esiti_clf = []
                
                for clf_epoch in lista_clf_epoch:
                    esito_evento = diz_global[distanza][clf_epoch]['misclassified_events'][evento]
                    
                    if esito_evento['new_value'] == esito_evento['old_value']:
                        print("Errore errati_da_tutti! Ho trovato esempi uguali per l'evento {} (complessità {})".format(evento, \
                                                                                                          distanza))
                    lista_esiti_clf.append(esito_evento['new_value'])
                
                if len(lista_esiti_clf) != num_classificazioni_comuni:
                    print(lista_esiti_clf)
                    print("Errore errati_da_tutti! la lista delle classificazioni non e' di lunghezza pari a {}!".format(num_classificazioni_comuni))
                
                lista_esiti_clf = set(lista_esiti_clf)
                if len(lista_esiti_clf) > 1:
                    print(lista_esiti_clf)
                    print("Errore errati_da_tutti! Ho trovato esempi uguali per l'evento {} (complessità {} e clf {})".format(evento,distanza, clf_epoch))
                else:
                    esito_evento = list(lista_esiti_clf)[0]
                    if esito_evento == 1:
                        non_consecutivi.append(evento)
                    elif esito_evento == 0:
                        consecutivi.append(evento)
            
            # True Positive / True Negative
            elif chiave == 'corretti_da_tutti':
                lista_esiti_clf = []

                for clf_epoch in lista_clf_epoch:
                    esito_evento = diz_global[distanza][clf_epoch]['diz_correct_events'][evento]
                    if esito_evento == None:
                        print("Errore! Non ho trovato l'evento {} per il classificatore {}".format(evento, clf_epoch))
                    else:
                        lista_esiti_clf.append(esito_evento)
                    
                if len(lista_esiti_clf) != num_classificazioni_comuni:
                    print(lista_esiti_clf)
                    print("Errore corretti_da_tutti! la lista delle classificazioni non e' di lunghezza pari a {}!".format(num_classificazioni_comuni))
                
                lista_esiti_clf = set(lista_esiti_clf)
                if len(lista_esiti_clf) > 1:
                    print(lista_esiti_clf)
                    print("Errore corretti_da_tutti! Ho trovato esempi uguali per l'evento {} (complessità {} e clf {})".format(evento,distanza, clf_epoch))
                else:
                    esito_evento = list(lista_esiti_clf)[0]
                    if esito_evento == 1:
                        non_consecutivi.append(evento)
                    elif esito_evento == 0:
                        consecutivi.append(evento)
                    
            elif chiave == 'errati_da_uno_solo':
                lista_esiti_clf = []
                
                for clf_epoch in lista_clf_epoch:
                    if diz_global[distanza][clf_epoch]['misclassified_events'].get(evento):
                        esito_evento = diz_global[distanza][clf_epoch]['misclassified_events'][evento]
                        lista_esiti_clf.append(esito_evento['new_value'])
                        
                if len(lista_esiti_clf) > 1:
                    #print(lista_esiti_clf)
                    print("Errore errati_da_uno_solo! Ho trovato esempi uguali per l'evento {} (complessità {} e clf {})".format(evento,distanza, clf_epoch))
                elif len(lista_esiti_clf) == 0:
                    print("Errore errati_da_uno_solo! lista vuota! {} (complessità {} e clf {})".format(evento,distanza, clf_epoch))
                else:
                    esito_evento = lista_esiti_clf[0]
                    if esito_evento == 1:
                        non_consecutivi.append(evento)
                    elif esito_evento == 0:
                        consecutivi.append(evento)
                        
            elif chiave == 'corretti_da_uno_solo':
                lista_esiti_clf = []
                
                for clf_epoch in lista_clf_epoch:
                    result = diz_global[distanza][clf_epoch]['diz_correct_events'].get(evento)
                    if result != None:
                        esito_evento = result
                        lista_esiti_clf.append(esito_evento)
        
                if len(lista_esiti_clf) > 1:
                    print("Errore corretti_da_uno_solo! Ho trovato esempi uguali per l'evento {} (complessità {} e clf {})".format(evento,distanza, clf_epoch))
                elif len(lista_esiti_clf) == 0:
                    print("Errore corretti_da_uno_solo! lista vuota! {} (complessità {} e clf {})".format(evento,distanza, clf_epoch))
                else:
                    esito_evento = lista_esiti_clf[0]
                    if esito_evento == 1:
                        non_consecutivi.append(evento)
                    elif esito_evento == 0:
                        consecutivi.append(evento)
        
        print("{}: {} ----> consecutivi({}) + non_consecutivi({}) = {}".format(chiave, \
                                                                    len(dizionario_errati_corretti[chiave]), \
                                                                    len(consecutivi), \
                                                                    len(non_consecutivi), \
                                                                    len(consecutivi)+len(non_consecutivi)))
        diz_tp_fp_tn_fn[chiave]['consecutivi'] = consecutivi
        diz_tp_fp_tn_fn[chiave]['non_consecutivi'] = non_consecutivi
        diz_tp_fp_tn_fn[chiave]['percentuale_consecutivi'] = (len(consecutivi) * 100) / len(dizionario_errati_corretti[chiave])
        diz_tp_fp_tn_fn[chiave]['percentuale_non_consecutivi'] = (len(non_consecutivi) * 100) / len(dizionario_errati_corretti[chiave])
              
    return diz_tp_fp_tn_fn

# %%
percentuali_tp_fp_tn_fn_svm = ottieni_percentuali_tp_fp_tn_fn(diz_intersections_svm, lista_df_test, \
                                                              diz_global_svm, lista_clf, 'svm')
# Out:
# Distanza df_dist_5 - test shape: (2400, 4)
#
# errati_da_tutti: 2 ----> consecutivi(1) + non_consecutivi(1) = 2
# corretti_da_tutti: 5 ----> consecutivi(5) + non_consecutivi(0) = 5
# errati_da_uno_solo: 40 ----> consecutivi(19) + non_consecutivi(21) = 40
# corretti_da_uno_solo: 28 ----> consecutivi(17) + non_consecutivi(11) = 28
#
# Distanza df_dist_10 - test shape: (2400, 4)
#
# errati_da_tutti: 108 ----> consecutivi(56) + non_consecutivi(52) = 108
# corretti_da_tutti: 154 ----> consecutivi(72) + non_consecutivi(82) = 154
# errati_da_uno_solo: 161 ----> consecutivi(79) + non_consecutivi(82) = 161
# corretti_da_uno_solo: 143 ----> consecutivi(73) + non_consecutivi(70) = 143
#
# Distanza df_dist_20 - test shape: (2400, 4)
#
# errati_da_tutti: 148 ----> consecutivi(72) + non_consecutivi(76) = 148
# corretti_da_tutti: 200 ----> consecutivi(95) + non_consecutivi(105) = 200
# errati_da_uno_solo: 187 ----> consecutivi(84) + non_consecutivi(103) = 187
# corretti_da_uno_solo: 152 ----> consecutivi(73) + non_consecutivi(79) = 152
#
# Distanza df_dist_30 - test shape: (2400, 4)
#
# errati_da_tutti: 148 ----> consecutivi(75) + non_consecutivi(73) = 148
# corretti_da_tutti: 222 ----> consecutivi(104) + non_consecutivi(118) = 222
# errati_da_uno_solo: 214 ----> consecutivi(90) + non_consecutivi(124) = 214
# corretti_da_uno_solo: 169 ----> consecutivi(76) + non_consecutivi(93) = 169
#
# Distanza df_random_speech - test shape: (2400, 4)
#
# errati_da_tutti: 259 ----> consecutivi(136) + non_consecutivi(123) = 259
# corretti_da_tutti: 556 ----> consecutivi(266) + non_consecutivi(290) = 556
# errati_da_uno_solo: 271 ----> consecutivi(94) + non_consecutivi(177) = 271
# corretti_da_uno_solo: 124 ----> consecutivi(40) + non_consecutivi(84) = 124

# %%
percentuali_tp_fp_tn_fn_bert = ottieni_percentuali_tp_fp_tn_fn(diz_intersections_bert, lista_df_test, \
                                                              diz_global_bert, lista_epoche, 'bert')
# Out:
# Distanza df_dist_5 - test shape: (2400, 4)
#
# errati_da_tutti: 360 ----> consecutivi(174) + non_consecutivi(186) = 360
# corretti_da_tutti: 764 ----> consecutivi(349) + non_consecutivi(415) = 764
# errati_da_uno_solo: 391 ----> consecutivi(198) + non_consecutivi(193) = 391
# corretti_da_uno_solo: 311 ----> consecutivi(172) + non_consecutivi(139) = 311
#
# Distanza df_dist_10 - test shape: (2400, 4)
#
# errati_da_tutti: 401 ----> consecutivi(201) + non_consecutivi(200) = 401
# corretti_da_tutti: 969 ----> consecutivi(512) + non_consecutivi(457) = 969
# errati_da_uno_solo: 346 ----> consecutivi(171) + non_consecutivi(175) = 346
# corretti_da_uno_solo: 218 ----> consecutivi(89) + non_consecutivi(129) = 218
#
# Distanza df_dist_20 - test shape: (2400, 4)
#
# errati_da_tutti: 295 ----> consecutivi(139) + non_consecutivi(156) = 295
# corretti_da_tutti: 973 ----> consecutivi(483) + non_consecutivi(490) = 973
# errati_da_uno_solo: 398 ----> consecutivi(209) + non_consecutivi(189) = 398
# corretti_da_uno_solo: 254 ----> consecutivi(129) + non_consecutivi(125) = 254
#
# Distanza df_dist_30 - test shape: (2400, 4)
#
# errati_da_tutti: 396 ----> consecutivi(199) + non_consecutivi(197) = 396
# corretti_da_tutti: 1173 ----> consecutivi(604) + non_consecutivi(569) = 1173
# errati_da_uno_solo: 253 ----> consecutivi(146) + non_consecutivi(107) = 253
# corretti_da_uno_solo: 205 ----> consecutivi(108) + non_consecutivi(97) = 205
#
# Distanza df_random_speech - test shape: (2400, 4)
#
# errati_da_tutti: 186 ----> consecutivi(55) + non_consecutivi(131) = 186
# corretti_da_tutti: 1561 ----> consecutivi(679) + non_consecutivi(882) = 1561
# errati_da_uno_solo: 267 ----> consecutivi(105) + non_consecutivi(162) = 267
# corretti_da_uno_solo: 108 ----> consecutivi(65) + non_consecutivi(43) = 108

# %%
df_perc_svm_specifica_perc = pd.DataFrame.from_dict({(i,j): percentuali_tp_fp_tn_fn_svm[i][j] 
                           for i in percentuali_tp_fp_tn_fn_svm.keys() 
                           for j in percentuali_tp_fp_tn_fn_svm[i].keys()},
                       orient='index')

# %%
df_perc_svm_specifica_perc
# Out:
#                                       percentuale_consecutivi  \
# df_dist_5        errati_da_tutti                       50.00%
#                  corretti_da_tutti                    100.00%
#                  errati_da_uno_solo                    47.50%
#                  corretti_da_uno_solo                  60.71%
# df_dist_10       errati_da_tutti                       51.85%
#                  corretti_da_tutti                     46.75%
#                  errati_da_uno_solo                    49.07%
#                  corretti_da_uno_solo                  51.05%
# df_dist_20       errati_da_tutti                       48.65%
#                  corretti_da_tutti                     47.50%
#                  errati_da_uno_solo                    44.92%
#                  corretti_da_uno_solo                  48.03%
# df_dist_30       errati_da_tutti                       50.68%
#                  corretti_da_tutti                     46.85%
#                  errati_da_uno_solo                    42.06%
#                  corretti_da_uno_solo                  44.97%
# df_random_speech errati_da_tutti                       52.51%
#                  corretti_da_tutti                     47.84%
#                  errati_da_uno_solo                    34.69%
#                  corretti_da_uno_solo                  32.26%
#
#                                       percentuale_non_consecutivi
# df_dist_5        errati_da_tutti                           50.00%
#                  corretti_da_tutti                          0.00%
#                  errati_da_uno_solo                        52.50%
#                  corretti_da_uno_solo                      39.29%
# df_dist_10       errati_da_tutti                           48.15%
#                  corretti_da_tutti                         53.25%
#                  errati_da_uno_solo                        50.93%
#                  corretti_da_uno_solo                      48.95%
# df_dist_20       errati_da_tutti                           51.35%
#                  corretti_da_tutti                         52.50%
#                  errati_da_uno_solo                        55.08%
#                  corretti_da_uno_solo                      51.97%
# df_dist_30       errati_da_tutti                           49.32%
#                  corretti_da_tutti                         53.15%
#                  errati_da_uno_solo                        57.94%
#                  corretti_da_uno_solo                      55.03%
# df_random_speech errati_da_tutti                           47.49%
#                  corretti_da_tutti                         52.16%
#                  errati_da_uno_solo                        65.31%
#                  corretti_da_uno_solo                      67.74%

# %%
df_perc_bert_specifica_perc = pd.DataFrame.from_dict({(i,j): percentuali_tp_fp_tn_fn_bert[i][j] 
                           for i in percentuali_tp_fp_tn_fn_bert.keys() 
                           for j in percentuali_tp_fp_tn_fn_bert[i].keys()},
                       orient='index')

# %%
df_perc_bert_specifica_perc
# Out:
#                                       percentuale_consecutivi  \
# df_dist_5        errati_da_tutti                       48.33%
#                  corretti_da_tutti                     45.68%
#                  errati_da_uno_solo                    50.64%
#                  corretti_da_uno_solo                  55.31%
# df_dist_10       errati_da_tutti                       50.12%
#                  corretti_da_tutti                     52.84%
#                  errati_da_uno_solo                    49.42%
#                  corretti_da_uno_solo                  40.83%
# df_dist_20       errati_da_tutti                       47.12%
#                  corretti_da_tutti                     49.64%
#                  errati_da_uno_solo                    52.51%
#                  corretti_da_uno_solo                  50.79%
# df_dist_30       errati_da_tutti                       50.25%
#                  corretti_da_tutti                     51.49%
#                  errati_da_uno_solo                    57.71%
#                  corretti_da_uno_solo                  52.68%
# df_random_speech errati_da_tutti                       29.57%
#                  corretti_da_tutti                     43.50%
#                  errati_da_uno_solo                    39.33%
#                  corretti_da_uno_solo                  60.19%
#
#                                       percentuale_non_consecutivi
# df_dist_5        errati_da_tutti                           51.67%
#                  corretti_da_tutti                         54.32%
#                  errati_da_uno_solo                        49.36%
#                  corretti_da_uno_solo                      44.69%
# df_dist_10       errati_da_tutti                           49.88%
#                  corretti_da_tutti                         47.16%
#                  errati_da_uno_solo                        50.58%
#                  corretti_da_uno_solo                      59.17%
# df_dist_20       errati_da_tutti                           52.88%
#                  corretti_da_tutti                         50.36%
#                  errati_da_uno_solo                        47.49%
#                  corretti_da_uno_solo                      49.21%
# df_dist_30       errati_da_tutti                           49.75%
#                  corretti_da_tutti                         48.51%
#                  errati_da_uno_solo                        42.29%
#                  corretti_da_uno_solo                      47.32%
# df_random_speech errati_da_tutti                           70.43%
#                  corretti_da_tutti                         56.50%
#                  errati_da_uno_solo                        60.67%
#                  corretti_da_uno_solo                      39.81%

# %%
save_dataframe('df_perc_svm_specifica_perc', df_perc_svm_specifica_perc)

# %%
save_dataframe('df_perc_bert_specifica_perc', df_perc_bert_specifica_perc)

# %% [markdown]
# ### Selezioniamo alcuni esempi di eventi da mostrare per i confronti interni ai modelli

# %%
def get_interventi_scelti_intersezione_confronti_interni(diz, lista_dist):
    
    diz_dist = {}
    
    for dist in lista_dist:
        
        diz_dist[dist] = {}
        
        #classificati bene o male da tutti i clf o epoche
        try:
            lista_eventi_scelti_intersezione_errati = random.sample(diz[dist]['intersection_misclassified'], 4)
        except:
            lista_eventi_scelti_intersezione_errati = random.sample(diz[dist]['intersection_misclassified'], 2)
        lista_eventi_scelti_intersezione_corretti = random.sample(diz[dist]['intersection_correct'], 4)
         
        #classificati bene o male solo da un clf o un'epoca
        lista_eventi_scelti_intersezione_altri_errati = random.sample(diz[dist]['other_events_misclassified'], 4)
        lista_eventi_scelti_intersezione_altri_corretti = random.sample(diz[dist]['other_events_correct'], 4)
        
        diz_dist[dist]['lista_eventi_scelti_intersezione_errati'] = lista_eventi_scelti_intersezione_errati
        diz_dist[dist]['lista_eventi_scelti_intersezione_corretti'] = lista_eventi_scelti_intersezione_corretti
        diz_dist[dist]['lista_eventi_scelti_intersezione_altri_errati'] = lista_eventi_scelti_intersezione_altri_errati
        diz_dist[dist]['lista_eventi_scelti_intersezione_altri_corretti'] = lista_eventi_scelti_intersezione_altri_corretti
        
    return diz_dist

# %%
diz_dist_svm_table = get_interventi_scelti_intersezione_confronti_interni(diz_intersections_svm, lista_dist)

# %%
diz_dist_bert_table = get_interventi_scelti_intersezione_confronti_interni(diz_intersections_bert, lista_dist)

# %% [markdown]
# ### Selezioniamo alcuni esempi da mostrare per i confronti incrociati, ovvero prendiamo alcuni esempi di eventi classificati bene o male da tutti i clf o le epoche dei differenti modelli e confrontiamo i risultati delle classificazioni

# %%
def get_confronti_incrociati(lista_dist, diz_svm, diz_bert):
    
    diz_confronti_incrociati = {}
    
    for dist in lista_dist:
        
        diz_confronti_incrociati[dist] = {}
        
        diz_confronti_incrociati[dist]['lista_eventi_scelti_intersezione_errati'] = []
        diz_confronti_incrociati[dist]['lista_eventi_scelti_intersezione_corretti'] = []
        
        try:
            eventi_classificati_male_svm = random.sample(diz_svm[dist]['lista_eventi_scelti_intersezione_errati'], 3)
        except:
            eventi_classificati_male_svm = random.sample(diz_svm[dist]['lista_eventi_scelti_intersezione_errati'], 2)
            
        eventi_classificati_male_bert = random.sample(diz_bert[dist]['lista_eventi_scelti_intersezione_errati'], 3)
        
        eventi_classificati_bene_svm = random.sample(diz_svm[dist]['lista_eventi_scelti_intersezione_corretti'], 3)
        eventi_classificati_bene_bert = random.sample(diz_svm[dist]['lista_eventi_scelti_intersezione_corretti'], 3)
        
        diz_confronti_incrociati[dist]['lista_eventi_scelti_intersezione_errati'].extend(eventi_classificati_male_svm)
        diz_confronti_incrociati[dist]['lista_eventi_scelti_intersezione_errati'].extend(eventi_classificati_male_bert)
        
        diz_confronti_incrociati[dist]['lista_eventi_scelti_intersezione_corretti'].extend(eventi_classificati_bene_svm)
        diz_confronti_incrociati[dist]['lista_eventi_scelti_intersezione_corretti'].extend(eventi_classificati_bene_bert)
        
        
    return diz_confronti_incrociati

# %%
diz_confronti_incrociati = get_confronti_incrociati(lista_dist, diz_dist_svm_table, diz_dist_bert_table)

# %%
diz_confronti_incrociati
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': [228695,
#    195285,
#    330672,
#    747146,
#    360018],
#   'lista_eventi_scelti_intersezione_corretti': [414778,
#    464910,
#    537330,
#    537330,
#    518453,
#    464910]},
#  'df_dist_10': {'lista_eventi_scelti_intersezione_errati': [493852,
#    425573,
#    792573,
#    614377,
#    525624,
#    332430],
#   'lista_eventi_scelti_intersezione_corretti': [182710,
#    462203,
#    332302,
#    828348,
#    462203,
#    332302]},
#  'df_dist_20': {'lista_eventi_scelti_intersezione_errati': [604608,
#    578568,
#    670427,
#    448386,
#    382168,
#    382335],
#   'lista_eventi_scelti_intersezione_corretti': [453760,
#    141615,
#    20411,
#    141615,
#    453760,
#    673095]},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': [791038,
#    451088,
#    880161,
#    282654,
#    793878,
#    237514],
#   'lista_eventi_scelti_intersezione_corretti': [453798,
#    276356,
#    318497,
#    276356,
#    453798,
#    318497]},
#  'df_random_speech': {'lista_eventi_scelti_intersezione_errati': [490307,
#    167370,
#    44241,
#    465592,
#    615072,
#    351925],
#   'lista_eventi_scelti_intersezione_corretti': [136364,
#    598163,
#    74785,
#    136364,
#    598163,
#    74785]}}

# %%
diz_dist_svm_table
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': [228695, 195285],
#   'lista_eventi_scelti_intersezione_corretti': [518453,
#    464910,
#    537330,
#    414778],
#   'lista_eventi_scelti_intersezione_altri_errati': [5733,
#    557954,
#    368710,
#    45684],
#   'lista_eventi_scelti_intersezione_altri_corretti': [124516,
#    260309,
#    440791,
#    50850]},
#  'df_dist_10': {'lista_eventi_scelti_intersezione_errati': [401691,
#    792573,
#    425573,
#    493852],
#   'lista_eventi_scelti_intersezione_corretti': [462203,
#    828348,
#    182710,
#    332302],
#   'lista_eventi_scelti_intersezione_altri_errati': [798681,
#    516959,
#    68621,
#    158019],
#   'lista_eventi_scelti_intersezione_altri_corretti': [35436,
#    343745,
#    512339,
#    886124]},
#  'df_dist_20': {'lista_eventi_scelti_intersezione_errati': [670427,
#    214010,
#    578568,
#    604608],
#   'lista_eventi_scelti_intersezione_corretti': [141615, 453760, 673095, 20411],
#   'lista_eventi_scelti_intersezione_altri_errati': [229837,
#    495658,
#    329309,
#    606317],
#   'lista_eventi_scelti_intersezione_altri_corretti': [889594,
#    33582,
#    613084,
#    307901]},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': [451088,
#    289493,
#    880161,
#    791038],
#   'lista_eventi_scelti_intersezione_corretti': [453798, 276356, 318497, 26475],
#   'lista_eventi_scelti_intersezione_altri_errati': [512684,
#    280710,
#    637884,
#    634012],
#   'lista_eventi_scelti_intersezione_altri_corretti': [187558,
#    527740,
#    111886,
#    622598]},
#  'df_random_speech': {'lista_eventi_scelti_intersezione_errati': [636188,
#    167370,
#    44241,
#    490307],
#   'lista_eventi_scelti_intersezione_corretti': [136364, 74785, 327854, 598163],
#   'lista_eventi_scelti_intersezione_altri_errati': [18768,
#    287660,
#    606882,
#    191503],
#   'lista_eventi_scelti_intersezione_altri_corretti': [877007,
#    122955,
#    61619,
#    5811]}}

# %%
diz_dist_bert_table
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': [717398,
#    360018,
#    330672,
#    747146],
#   'lista_eventi_scelti_intersezione_corretti': [173046,
#    461426,
#    548144,
#    530704],
#   'lista_eventi_scelti_intersezione_altri_errati': [529548,
#    148614,
#    892241,
#    604431],
#   'lista_eventi_scelti_intersezione_altri_corretti': [290747,
#    849431,
#    718961,
#    638696]},
#  'df_dist_10': {'lista_eventi_scelti_intersezione_errati': [614377,
#    525624,
#    59000,
#    332430],
#   'lista_eventi_scelti_intersezione_corretti': [869894,
#    266866,
#    299153,
#    712164],
#   'lista_eventi_scelti_intersezione_altri_errati': [227766,
#    410469,
#    297067,
#    413538],
#   'lista_eventi_scelti_intersezione_altri_corretti': [269460,
#    241066,
#    760651,
#    218140]},
#  'df_dist_20': {'lista_eventi_scelti_intersezione_errati': [145772,
#    448386,
#    382168,
#    382335],
#   'lista_eventi_scelti_intersezione_corretti': [750527, 247257, 22567, 715746],
#   'lista_eventi_scelti_intersezione_altri_errati': [231166,
#    332121,
#    795456,
#    95730],
#   'lista_eventi_scelti_intersezione_altri_corretti': [773695,
#    558708,
#    374493,
#    156318]},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': [237514,
#    793878,
#    532423,
#    282654],
#   'lista_eventi_scelti_intersezione_corretti': [522394, 26864, 593663, 314849],
#   'lista_eventi_scelti_intersezione_altri_errati': [835626,
#    398376,
#    837800,
#    149195],
#   'lista_eventi_scelti_intersezione_altri_corretti': [822263,
#    393080,
#    410172,
#    729329]},
#  'df_random_speech': {'lista_eventi_scelti_intersezione_errati': [781854,
#    615072,
#    351925,
#    465592],
#   'lista_eventi_scelti_intersezione_corretti': [574299,
#    168734,
#    716760,
#    343387],
#   'lista_eventi_scelti_intersezione_altri_errati': [701817,
#    74365,
#    363150,
#    450666],
#   'lista_eventi_scelti_intersezione_altri_corretti': [805466,
#    321950,
#    600234,
#    780547]}}

# %%
a = {'eleonora': {'prova': 1, 'ciao': 2}}

pd.DataFrame.from_dict(a, orient='index', columns=['prova', 'ciao'])
# Out:
#           prova  ciao
# eleonora      1     2

# %%
def costruisci_tabella_confronti_interni(diz_eventi_scelti, lista_dist, clf_epoch_list, \
                                         lista_df_test, lista_diz_pred):
    
    diz_total = {}
    
    for df_test, dist, diz_pred in tqdm(zip(lista_df_test, lista_dist, lista_diz_pred)):
        
        diz_total[dist] = {}
        
        for key in diz_eventi_scelti[dist]:
            
            diz_total[dist][key] = {}
            
            for evento in diz_eventi_scelti[dist][key]:
                val = df_test[df_test['Id'] == evento][['Sentence_1', 'Sentence_2', 'Class']].to_dict(orient='index')
                val_k = list(val.keys())[0]
                diz_total[dist][key][evento] = val[val_k]
                
                if key in ('lista_eventi_scelti_intersezione_errati', 'lista_eventi_scelti_intersezione_corretti'):
                    
                    #se trattiamo l'intersezione fra clf a parità di distanza (complessità del dataset)
                    #prendo la classe predetta dal primo classificatore per comodità
                    classe_predetta = diz_pred[dist][clf_epoch_list[0]]['ids_preds'][evento]
                    
                    diz_total[dist][key][evento].update({
                        'Pred': classe_predetta
                    })
                    
                    for clf_epoch in clf_epoch_list:
                        diz_total[dist][key][evento].update({ \
                            "{}P".format(clf_epoch) : "%.2f"%diz_pred[dist][clf_epoch]['ids_proba'][evento][classe_predetta]
                        })
                elif key in ('lista_eventi_scelti_intersezione_altri_errati', 'lista_eventi_scelti_intersezione_altri_corretti'):
                    
                    for clf_epoch in clf_epoch_list:
                        diz_total[dist][key][evento].update({ \
                            "{}pr".format(clf_epoch.replace('lf_', '')) : diz_pred[dist][clf_epoch]['ids_preds'][evento], \
                            "{}P".format(clf_epoch.replace('lf_', '')) : "%.2f"%max(diz_pred[dist][clf_epoch]['ids_proba'][evento])
                        })
                        
                        
    return diz_total

# %%
def costruisci_tabella_confronti_incrociati(diz_eventi_scelti, lista_dist, clf_epoch_list, \
                                            lista_df_test, lista_diz_pred):
    
    diz_total = {}
    
    for df_test, dist, diz_pred in tqdm(zip(lista_df_test, lista_dist, lista_diz_pred)):
        
        diz_total[dist] = {}
        
        for key in diz_eventi_scelti[dist]:
            
            diz_total[dist][key] = {}
            
            for evento in diz_eventi_scelti[dist][key]:
                val = df_test[df_test['Id'] == evento][['Sentence_1', 'Sentence_2', 'Class']].to_dict(orient='index')
                val_k = list(val.keys())[0]
                diz_total[dist][key][evento] = val[val_k]
                
                for clf_epoch in clf_epoch_list:
                    diz_total[dist][key][evento].update({ \
                        "{}pred".format(clf_epoch.replace('lf_', '')) : diz_pred[dist][clf_epoch]['ids_preds'][evento], 
                        "{}P".format(clf_epoch.replace('lf_', '')) : "%.2f"%max(diz_pred[dist][clf_epoch]['ids_proba'][evento])
                    })
                        
                        
    return diz_total

# %%
diz_tabella_total_svm = costruisci_tabella_confronti_interni(diz_dist_svm_table, lista_dist, lista_clf, \
                                                             lista_df_test, lista_diz_pred_svm)
# Out:
# 5it [00:00, 37.38it/s]

# %%
diz_tabella_total_bert = costruisci_tabella_confronti_interni(diz_dist_bert_table, lista_dist, lista_epoche, \
                                                             lista_df_test, lista_diz_pred_bert_finetunato)
# Out:
# 5it [00:00, 23.67it/s]

# %%
diz_confronti_incrociati_svm = costruisci_tabella_confronti_incrociati(diz_dist_svm_table, lista_dist, lista_clf, \
                                                            lista_df_test, lista_diz_pred_svm)
# Out:
# 5it [00:00, 34.99it/s]

# %%
diz_confronti_incrociati_bert = costruisci_tabella_confronti_incrociati(diz_dist_bert_table, lista_dist, lista_epoche, \
                                                             lista_df_test, lista_diz_pred_bert_finetunato)
# Out:
# 5it [00:00, 33.81it/s]

# %%
def salva_diz(path, diz, name):
    
    with open('{}{}.pickle'.format(path, name), 'wb') as handle:
        pickle.dump(diz, handle)
        
    return "Dizionario salvato correttamente"

# %%
salva_diz(path_diz_res, diz_tabella_total_svm, 'diz_tabella_total_svm')
# Out:
# 'Dizionario salvato correttamente'

# %%
salva_diz(path_diz_res, diz_tabella_total_bert, 'diz_tabella_total_bert')
# Out:
# 'Dizionario salvato correttamente'

# %%
salva_diz(path_diz_res, diz_confronti_incrociati_svm, 'diz_confronti_incrociati_svm')
# Out:
# 'Dizionario salvato correttamente'

# %%
salva_diz(path_diz_res, diz_confronti_incrociati_bert, 'diz_confronti_incrociati_bert')
# Out:
# 'Dizionario salvato correttamente'

# %%
diz_tabella_total_svm
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': {228695: {'Sentence_1': 'Il più comprende il meno, seppur fosse discutibile la questione che pongo.',
#     'Sentence_2': "Accogliendo il mio subemendamento si andrebbe ad inserire, rispetto ai soggetti indiziati del delitto di cui all'articolo 416 del codice penale, finalizzato alla commissione di taluno dei delitti di cui agli articoli 314, primo comma, 316, eccetera eccetera, anche l'articolo 640 - bis.",
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.52',
#     'clf_2P': '0.52',
#     'clf_3P': '0.50',
#     'clf_4P': '0.50',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.53',
#     'clf_12P': '0.51'},
#    195285: {'Sentence_1': "Passiamo all'emendamento 13.0.13, su cui la 5ᵃ Commissione ha espresso parere contrario ai sensi dell'articolo 81 della Costituzione.",
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.51',
#     'clf_3P': '0.50',
#     'clf_4P': '0.50',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.50',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_corretti': {518453: {'Sentence_1': "Nei mari adiacenti, per il contrasto al fenomeno della pirateria, l'Italia partecipa alla missione europea Atalanta, con 2 mezzi navali, 2 aerei e un numero massimo di 407 unità di personale.",
#     'Sentence_2': "Per tutte le missioni già in atto, la proroga è fino al 31 dicembre e, per ogni missione, la relazione analitica riporta, come previsto dalla legge, due schede: la prima con il resoconto di quanto si è fatto nel 2018; la seconda con le risorse e gli assetti per l'anno in corso.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.50',
#     'clf_3P': '0.50',
#     'clf_4P': '0.51',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.50',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'},
#    464910: {'Sentence_1': 'È cosa ben strana che si registri un dibattito sulla legge principale, che è la legge di stabilità, e non si senta la maggioranza difendere il Governo.',
#     'Sentence_2': "Non capisco se questo è dovuto al tentativo di anticipare quanto prima - saranno contenti loro - l'incardinamento della legge elettorale, o se, invece, è perché hanno serie difficoltà a difendere il Governo e a parlare bene della legge di stabilità.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.51',
#     'clf_3P': '0.50',
#     'clf_4P': '0.51',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.50',
#     'clf_12P': '0.50'},
#    537330: {'Sentence_1': "Con molta difficoltà avevamo erogato - e ribadiamo il nostro parere assolutamente contrario in proposito - ben 120 milioni di euro a otto Fondazioni lirico sinfoniche d'Italia indebitate per cattiva gestione dei loro consigli d'amministrazione, diretta emanazione dei Comuni e delle Province, secondo le compartecipazioni.",
#     'Sentence_2': 'La più indebitata, guarda caso, era quella del Maggio musicale fiorentino, per cui si è fatta anche la norma, è chiaro, infatti, che si doveva poi soddisfare le esigenze di tutti.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.52',
#     'clf_3P': '0.50',
#     'clf_4P': '0.50',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.50',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'},
#    414778: {'Sentence_1': 'Signor Presidente, pur non avendo seguito specificamente il problema, quando qualche giorno fa è apparso chiaramente che in Assemblea i tempi non erano maturi se si voleva arrivare a una mozione condivisa anche con il Governo sul Venezuela, ho avanzato la proposta di sospendere il dibattito per un tempo - in quel caso fino a martedì - sufficiente per arrivare a una soluzione soddisfacente.',
#     'Sentence_2': 'E così è avvenuto, perché nel frattempo i contrasti di quel giorno si sono stemperati.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.52',
#     'clf_3P': '0.50',
#     'clf_4P': '0.51',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {5733: {'Sentence_1': 'Su questo ci dovete rispondere.',
#     'Sentence_2': "Come si fa a prendere come riferimento, per esempio, qualche altro Paese europeo che utilizza il meccanismo di elezione indiretta di una Camera, ma che nell'altro ramo del Parlamento utilizza il sistema proporzionale senza sbarramenti o comunque senza i premi di maggioranza che sono previsti dal nostro ordinamento?",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.52'},
#    557954: {'Sentence_1': 'Mi spiego.',
#     'Sentence_2': 'Noi invece non abbiamo voluto osare, il Governo non ha voluto osare e ci ritroviamo con questa proposta che secondo me è assolutamente asfittica.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.50'},
#    368710: {'Sentence_1': "D'altra parte, ne abbiamo ratificati tanti in quest'Aula nel corso degli anni e già questa mattina.",
#     'Sentence_2': "Ho preso appunti e abbiamo, infatti, già ratificato lo stesso tipo di accordo con la Colombia, con la Giamaica e con l'Uruguay.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.51',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 0,
#     'c4P': '0.50',
#     'c5pr': 0,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 0,
#     'c7P': '0.50',
#     'c8pr': 0,
#     'c8P': '0.50',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 0,
#     'c12P': '0.50'},
#    45684: {'Sentence_1': "All'AIFA spetta, inoltre, il mantenimento dell'equilibrio economico relativo al tetto fissato per la spesa farmaceutica convenzionata e ospedaliera - come ha puntualmente evidenziato il senatore Barani - che governa tramite l'applicazione di opportune misure di ripiano nel caso di sforamento, come il cosiddetto pay back - che esiste da qualche anno - e l'incentivazione all'impiego di medicinali equivalenti, cioè i generici.",
#     'Sentence_2': "In tal senso, le attività dell'AIFA, per quanto attiene all'ambito regolatorio, sono sicuramente - mi permetterei di segnalarlo - coerenti con l'assetto normativo comunitario e nazionale.",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.52',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {124516: {'Sentence_1': "Tempo fa, sul quotidiano «Corriere della sera» Celentano scrisse difendendo il diritto d'autore, in quel caso della musica, sostenendo che «Se non si pagasse più il pane non ci sarebbero più i fornai», perché nessuno farebbe il pane se fosse gratis.",
#     'Sentence_2': 'Celentano lo diceva per la musica: se la musica viene rubata - presa gratis - sul web, gli autori non hanno remunerazione.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    260309: {'Sentence_1': "Ciò porterà anche a prevedere il doppio turno: penso ad esempio al ballottaggio nel caso dell'Italicum, per come è stato approvato in Parlamento; infatti, per quanto si possa immaginare di modificare quella legge, allo stato attuale abbiamo una situazione in cui sicuramente potremo avere non solo un primo turno, ma anche un secondo turno alle elezioni politiche, oltre che consultazioni regionali ed europee.",
#     'Sentence_2': "L'esigenza di coinvolgere il corpo elettorale è quindi molto presente, ma non di meno abbiamo l'esigenza di dare continuità scolastica e possibilità agli studenti di continuare regolarmente il loro corso di studi senza ripetute interruzioni.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    440791: {'Sentence_1': 'Ogni giorno che si ritarda sono 2 milioni in più che il contribuente, attraverso i pedaggi autostradali, conferisce a queste società.',
#     'Sentence_2': "È giusto che guadagnino, ma questo guadagno potrebbe essere assottigliato a beneficio o dello Stato o dell'utente automobilista.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    50850: {'Sentence_1': 'Fin dal mio insediamento, ho insistito su un concetto: le norme, anche le migliori, non bastano se non sono sostenute da misure organizzative.',
#     'Sentence_2': "Proprio il processo di globalizzazione, l'introduzione di nuove tecnologie in tutti i settori della vita umana, fa sì che il fattore tempo divenga un dato ancora più essenziale.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.50'}}},
#  'df_dist_10': {'lista_eventi_scelti_intersezione_errati': {401691: {'Sentence_1': "Forse bisognerebbe iscriverle in qualche modo a una specie - non so se esiste - di rassegna del cinema di fantasia Infatti, ci ritroviamo ormai regolarmente ad approvare un DEF con valutazioni, dati e previsioni assolutamente sovrastimate e con la puntuale Nota di aggiornamento che corregge i dati e le speranze di crescita, ma nei fatti, così come nella Nota all'ordine del giorno, in realtà si continua sulla stessa strada.",
#     'Sentence_2': 'La chiave di tutto, è inutile che ci giriamo intorno, è evidentemente questa.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.52',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.52',
#     'clf_6P': '0.54',
#     'clf_7P': '0.51',
#     'clf_8P': '0.50',
#     'clf_9P': '0.52',
#     'clf_10P': '0.51',
#     'clf_11P': '0.52',
#     'clf_12P': '0.51'},
#    792573: {'Sentence_1': "Anche a causa di impedimenti e vincoli previsti dal regolamento comunale sulla pubblicità, l'iniziativa non ha trovato adesioni, ad eccezione di un'unica offerta di contributo di circa 60.000 euro.",
#     'Sentence_2': 'Infine, con riferimento agli eventuali aspetti penali della vicenda, il Ministero della giustizia ha comunicato che la procura della Repubblica di Firenze ha delegato alla Guardia di finanza gli accertamenti preliminari tesi a stabilire la sussistenza o meno di reati.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.50',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.52',
#     'clf_6P': '0.52',
#     'clf_7P': '0.52',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.52',
#     'clf_12P': '0.51'},
#    425573: {'Sentence_1': 'Abbiamo trasferito 59 pazienti in terapia intensiva dalla Lombardia in altre Regioni italiane, in ragione di una convenzione, che esisteva già, presso la Protezione civile, che si chiama Cross e che abbiamo reso più stringente e vincolante.',
#     'Sentence_2': 'Abbiamo riconvertito 78 ospedali in Covid Hospitalegge Abbiamo e stiamo lavorando tanto per i dispositivi di protezione individuale: anche qui il mercato è quello che è, ma stiamo riconvertendo tutte le nostre filiere interne, per incrementare la produzione.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.50',
#     'clf_2P': '0.51',
#     'clf_3P': '0.52',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.51',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.50',
#     'clf_11P': '0.51',
#     'clf_12P': '0.52'},
#    493852: {'Sentence_1': "Anche in quest'Aula io ho raccontato come, in una discussione anche con il Presidente del Consiglio, siamo arrivati alla scelta del ruolo unico, che è la scelta di una dirigenza autonoma e indipendente dalla politica e che quindi rispetta non solo formalmente, ma sostanzialmente l'articolo 97 della nostra Costituzione.",
#     'Sentence_2': 'Termino con la vera sfida di questa riforma, che certamente è approvare questo disegno di legge in via definitiva nei diversi rami del Parlamento, ma soprattutto attuarla.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.52',
#     'clf_8P': '0.52',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.50',
#     'clf_12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_corretti': {462203: {'Sentence_1': 'Signora Presidente, io sono rimasto colpito.',
#     'Sentence_2': 'Non se vi ricordate il vecchio film «1997: Fuga da New York», con il personaggio di Jena Plissken, con il muro che divide un mondo da un altro.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.53',
#     'clf_2P': '0.51',
#     'clf_3P': '0.52',
#     'clf_4P': '0.53',
#     'clf_5P': '0.53',
#     'clf_6P': '0.55',
#     'clf_7P': '0.54',
#     'clf_8P': '0.53',
#     'clf_9P': '0.52',
#     'clf_10P': '0.54',
#     'clf_11P': '0.51',
#     'clf_12P': '0.51'},
#    828348: {'Sentence_1': 'Signor Ministro, le dico, anche se molto brevemente, che io ho molto apprezzato il suo richiamo iniziale al rispetto dello Stato di diritto, anche in materia di terrorismo.',
#     'Sentence_2': "Non devo ricordarle che all'epoca del terrorismo molti di noi hanno garantito due cose: rispetto dello Stato di diritto, ma anche l'applicazione delle garanzie processuali nei processi contro i terroristi per il terrorismo interno.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.53',
#     'clf_2P': '0.52',
#     'clf_3P': '0.54',
#     'clf_4P': '0.53',
#     'clf_5P': '0.52',
#     'clf_6P': '0.52',
#     'clf_7P': '0.53',
#     'clf_8P': '0.54',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.51'},
#    182710: {'Sentence_1': "Signor Presidente, senatrici e senatori, signora Vice Ministro, lo stupro come arma di guerra è il cuore più oscuro e torvo, più crudele e abietto del feroce catalogo dei crimini contro l'umanità.",
#     'Sentence_2': "Ma cosa sono i crimini contro l'umanità?",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.51',
#     'clf_3P': '0.53',
#     'clf_4P': '0.54',
#     'clf_5P': '0.52',
#     'clf_6P': '0.52',
#     'clf_7P': '0.52',
#     'clf_8P': '0.52',
#     'clf_9P': '0.52',
#     'clf_10P': '0.51',
#     'clf_11P': '0.52',
#     'clf_12P': '0.52'},
#    332302: {'Sentence_1': 'Il Senato non approva.',
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.51',
#     'clf_2P': '0.50',
#     'clf_3P': '0.51',
#     'clf_4P': '0.50',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.51',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {798681: {'Sentence_1': "Cari colleghi, ricorre oggi il 25° anniversario della strage di via D'Amelio, nella quale furono barbaramente assassinati il giudice Paolo Borsellino e gli uomini di scorta della Polizia di Stato Agostino Catalano, Eddie Walter Cosina, Vincenzo Li Muli, Emanuela Loi e Claudio Traina.",
#     'Sentence_2': "Il nostro primo pensiero - sono certo - si rivolge innanzitutto alle famiglie degli uomini e delle donne uccisi in quell'esplosione.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.52',
#     'c2pr': 0,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 0,
#     'c4P': '0.51',
#     'c5pr': 0,
#     'c5P': '0.51',
#     'c6pr': 0,
#     'c6P': '0.51',
#     'c7pr': 0,
#     'c7P': '0.51',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.50'},
#    516959: {'Sentence_1': 'Quindi, noi riconosciamo tutto, ma riteniamo che si debbano rivalutare subito tali questioni, oltre alle altre che dovranno porsi.',
#     'Sentence_2': 'Infine, lo dico adesso, in sede di esame del Documento di economia e finanza, al Governo.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.52',
#     'c2pr': 0,
#     'c2P': '0.50',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.52',
#     'c5pr': 0,
#     'c5P': '0.52',
#     'c6pr': 0,
#     'c6P': '0.52',
#     'c7pr': 0,
#     'c7P': '0.51',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.52',
#     'c10pr': 0,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    68621: {'Sentence_1': 'Come dicevo, gli altri obiettivi della revisione costituzionale - ovvero la riduzione dei costi e del numero dei parlamentari e la soppressione del CNEL - sono raggiunti, anche se meritano un veloce commento.',
#     'Sentence_2': 'In tal senso, ho proposto un intervento emendativo che ci riporta a questo preciso riferimento europeo.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.50'},
#    158019: {'Sentence_1': "Era un uomo retto ed è stato uno dei non rari casi, certamente non l'unico, di condanna seguita da assoluzione, un caso, in qualche modo, di persecuzione per reati non commessi.",
#     'Sentence_2': 'Lo dico a tutti noi: i parlamentari non sono delle poltrone, voi non siete delle poltrone, noi non siamo delle poltrone.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.53',
#     'c2pr': 0,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.52'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {35436: {'Sentence_1': "L'Italia è un Paese che merita rispetto: il suo popolo, il popolo italiano, merita rispetto.",
#     'Sentence_2': 'E il popolo merita, Presidente, di poter incidere, perché lo prevede la Costituzione, nel processo politico esercitando il suo diritto di voto.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    343745: {'Sentence_1': 'No, ci sono dei contenuti, seri, molto seri.',
#     'Sentence_2': "Mi permetta di portare all'Aula due ricordi.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    512339: {'Sentence_1': "Siamo riusciti anche a sbloccare i fondi dovuti dallo Stato per la Valle d'Aosta e per le nostre due Province, il che consentirà una piena ed efficace politica di bilancio per i prossimi anni.",
#     'Sentence_2': "Desidero inoltre ringraziare il presidente Calderoli, in quanto la modifica al Regolamento del Senato, con la deroga per le minoranze linguistiche e le autonomie speciali, garantisce che il nostro Gruppo sarà in quest'Aula anche in futuro.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.52'},
#    886124: {'Sentence_1': "Signora Presidente, da parte mia provo un certo imbarazzo a dover dire che condivido una serie di riflessioni fatte dal collega Petrocelli, e il fatto che la posizione della Lega si sovrapponga a quella del Movimento 5 Stelle è veramente un po' imbarazzante, ma sono state dette delle verità assolute.",
#     'Sentence_2': 'La distensione del Mediterraneo innanzitutto è un problema italiano.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 0,
#     'c3P': '0.53',
#     'c4pr': 0,
#     'c4P': '0.55',
#     'c5pr': 0,
#     'c5P': '0.53',
#     'c6pr': 0,
#     'c6P': '0.52',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 0,
#     'c8P': '0.52',
#     'c9pr': 0,
#     'c9P': '0.53',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 0,
#     'c12P': '0.52'}}},
#  'df_dist_20': {'lista_eventi_scelti_intersezione_errati': {670427: {'Sentence_1': "Provate per un po' a considerarvi dei meri portavoce; date modo alle persone e ai loro bisogni di fluire semplicemente attraverso di voi; siate portatori sani di bisogni altrui.",
#     'Sentence_2': 'Provate, provate soltanto, vi potrebbe persino piacere.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.57',
#     'clf_2P': '0.55',
#     'clf_3P': '0.56',
#     'clf_4P': '0.55',
#     'clf_5P': '0.55',
#     'clf_6P': '0.55',
#     'clf_7P': '0.54',
#     'clf_8P': '0.56',
#     'clf_9P': '0.55',
#     'clf_10P': '0.53',
#     'clf_11P': '0.52',
#     'clf_12P': '0.55'},
#    214010: {'Sentence_1': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 1.7 /291, presentato dalla senatrice Sudano.",
#     'Sentence_2': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 1.7 /329, presentato dal senatore Margiotta.",
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.52',
#     'clf_2P': '0.51',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.53',
#     'clf_6P': '0.53',
#     'clf_7P': '0.52',
#     'clf_8P': '0.51',
#     'clf_9P': '0.53',
#     'clf_10P': '0.52',
#     'clf_11P': '0.52',
#     'clf_12P': '0.50'},
#    578568: {'Sentence_1': 'Io dico, però - e lo abbiamo detto in tanti e credo che sia il senso più profondo di questa mozione - che autonomia e libertà delle donne significa anche un Paese più forte, più sano, più competitivo.',
#     'Sentence_2': 'Se noi oggi proviamo ad affrontare il tema della ricostruzione non possiamo che partire da lì.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.55',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.53',
#     'clf_8P': '0.57',
#     'clf_9P': '0.58',
#     'clf_10P': '0.53',
#     'clf_11P': '0.55',
#     'clf_12P': '0.53'},
#    604608: {'Sentence_1': "La stessa domanda ci viene anche dall'Europa e da tutte le istanze internazionali che contano.",
#     'Sentence_2': 'Non tacciamo sempre tutto e tutti di interferenza, di attentato alla nostra sovranità!',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.54',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.54',
#     'clf_5P': '0.56',
#     'clf_6P': '0.56',
#     'clf_7P': '0.54',
#     'clf_8P': '0.55',
#     'clf_9P': '0.59',
#     'clf_10P': '0.58',
#     'clf_11P': '0.59',
#     'clf_12P': '0.55'}},
#   'lista_eventi_scelti_intersezione_corretti': {141615: {'Sentence_1': 'Preso atto che non si poteva intervenire su questi elementi, si è invece intervenuti anzitutto con una specificazione del reddito, che è passato da lordo a complessivo; poi - altro elemento evidenziato - si è sostituito il termine per la dichiarazione dei redditi del 2015 al 2014, anzitutto, per dare un elemento di certezza e poi, essendo la dichiarazione dei redditi 2015 un work in progress, per permettere di accelerare le procedure stesse.',
#     'Sentence_2': "È stata eliminata la richiesta della copia di pagamento alla banca in liquidazione e del credito relativo agli strumenti finanziari subordinati; è stato di fatto permesso che, per il reperimento dei documenti, le banche fossero tenute a dare copia all'investitore entro quindici giorni dalla sua richiesta.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.57',
#     'clf_2P': '0.52',
#     'clf_3P': '0.51',
#     'clf_4P': '0.51',
#     'clf_5P': '0.54',
#     'clf_6P': '0.54',
#     'clf_7P': '0.52',
#     'clf_8P': '0.52',
#     'clf_9P': '0.54',
#     'clf_10P': '0.52',
#     'clf_11P': '0.51',
#     'clf_12P': '0.54'},
#    453760: {'Sentence_1': 'La base, invece, non ha una precisa connotazione etnica.',
#     'Sentence_2': 'Detti sodalizi, che mantengono una sostanziale autonomia nei rapporti con la criminalità organizzata italiana, sono dotati di una rete nazionale di referenti a capo di cellule di apparente connotazione folkloristica, dietro le quali si celano agguerrite associazioni criminali che, con modalità di intimidazione, controllo e violenza fisica gestiscono le attività illecite.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.52',
#     'clf_3P': '0.57',
#     'clf_4P': '0.55',
#     'clf_5P': '0.55',
#     'clf_6P': '0.55',
#     'clf_7P': '0.54',
#     'clf_8P': '0.57',
#     'clf_9P': '0.53',
#     'clf_10P': '0.57',
#     'clf_11P': '0.56',
#     'clf_12P': '0.52'},
#    673095: {'Sentence_1': "Ci sono tre documenti: facciamo vedere che una volta tanto riusciamo a metterci d'accordo e facciamone uno, perché deve essere il documento del Senato della Repubblica, non deve essere il documento di una parte del Senato, anche se poi magari tutti e tre verranno votati all'unanimità.",
#     'Sentence_2': 'Forse questa risposta non è esattamente quella che tutti auspichiamo, oppure non è solo quella che tutti auspichiamo.',
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.51',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.53',
#     'clf_8P': '0.55',
#     'clf_9P': '0.54',
#     'clf_10P': '0.56',
#     'clf_11P': '0.52',
#     'clf_12P': '0.53'},
#    20411: {'Sentence_1': "L'Italia ne sta finalmente faticosamente uscendo, ma non possiamo permetterci di ritornare allo status quo precedente, antecedente a questa crisi.",
#     'Sentence_2': "L'Italia, da oltre vent'anni, fatica a tenere il passo delle altre economie avanzate.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.55',
#     'clf_2P': '0.51',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.51',
#     'clf_6P': '0.53',
#     'clf_7P': '0.52',
#     'clf_8P': '0.53',
#     'clf_9P': '0.57',
#     'clf_10P': '0.55',
#     'clf_11P': '0.56',
#     'clf_12P': '0.53'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {229837: {'Sentence_1': 'Lei, sottosegretario Gozi, in parte mi ha risposto.',
#     'Sentence_2': "Poiché è in corso una gara, voglio avvisare i vari Arvedi, Marcegaglia, i turchi di Erdemir e soprattutto i cittadini italiani, visto che dentro c'è Cassa depositi e prestiti, che chi vince la gara rischia di dover restituire gli eventuali finanziamenti, se essi saranno considerati aiuti di Stato.",
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.54',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.54'},
#    495658: {'Sentence_1': 'Si potrebbe fare qui una lunga serie di nomi: basti pensare al decreto dignità e a quello che invece ha comportato; era il decreto - legge che doveva abolire in un colpo solo la povertà nel nostro Paese, ma abbiamo visto invece che è aumentata.',
#     'Sentence_2': 'Si può poi passare attraverso tutti i provvedimenti di questi anni per arrivare al provvedimento di oggi, che la maggioranza ha voluto chiamare sblocca cantieri.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.55',
#     'c2pr': 0,
#     'c2P': '0.52',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.51',
#     'c5pr': 0,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 0,
#     'c7P': '0.50',
#     'c8pr': 0,
#     'c8P': '0.50',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 0,
#     'c10P': '0.52',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.52'},
#    329309: {'Sentence_1': "Nello specifico, l'articolo 1, comma 1, estende fino al 15 ottobre 2020 la facoltà di adottare, con uno o più decreti del Presidente del Consiglio dei ministri, misure tra quelle indicate al comma 2 dell'articolo 1 del decreto - legge n. 19 del 2020, allo scopo di contrastare i rischi sanitari da Covid - 19.",
#     'Sentence_2': 'È inoltre soppresso il riferimento alla delibera del Consiglio dei ministri del 31 gennaio 2020.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.54',
#     'c2pr': 0,
#     'c2P': '0.54',
#     'c3pr': 0,
#     'c3P': '0.57',
#     'c4pr': 0,
#     'c4P': '0.56',
#     'c5pr': 0,
#     'c5P': '0.55',
#     'c6pr': 0,
#     'c6P': '0.56',
#     'c7pr': 0,
#     'c7P': '0.54',
#     'c8pr': 0,
#     'c8P': '0.55',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 0,
#     'c10P': '0.52',
#     'c11pr': 0,
#     'c11P': '0.53',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    606317: {'Sentence_1': 'Poi è andato avanti un iter diverso e abbiamo discusso per ore in Senato, dove abbiamo fatto un testo che la Camera ha rivoltato come un calzino.',
#     'Sentence_2': 'Adesso è tornato un testo in cui si legge addirittura che basta qualsiasi organismo internazionale.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.55',
#     'c2pr': 0,
#     'c2P': '0.52',
#     'c3pr': 0,
#     'c3P': '0.53',
#     'c4pr': 0,
#     'c4P': '0.54',
#     'c5pr': 0,
#     'c5P': '0.52',
#     'c6pr': 0,
#     'c6P': '0.53',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.54',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.58',
#     'c12pr': 0,
#     'c12P': '0.53'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {889594: {'Sentence_1': 'Il primo consiglio fu di stare attento alle sirene.',
#     'Sentence_2': 'Le sirene cantano un canto suadente e hanno un elenco di attributi affascinanti.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.55',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.56',
#     'c4pr': 1,
#     'c4P': '0.54',
#     'c5pr': 1,
#     'c5P': '0.57',
#     'c6pr': 1,
#     'c6P': '0.58',
#     'c7pr': 1,
#     'c7P': '0.54',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.53'},
#    33582: {'Sentence_1': 'Io esprimo la mia solidarietà personale al Presidente della Regione Sardegna.',
#     'Sentence_2': "Quando aveva avanzato proposte su come dovevano essere gestiti i turisti in Regione Sardegna l'avete tutti irriso e avete detto che era un irresponsabile; adesso la colpa è delle discoteche e ci sentiamo dire dai tromboni della politica e da chi fa il fenomeno che la colpa è dei giovani perché non ascoltano, la colpa è dei giovani perché si abbracciano, la colpa è dei giovani perché non mettono le mascherine.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.54',
#     'c8pr': 1,
#     'c8P': '0.54',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    613084: {'Sentence_1': "Dov'è la rete?",
#     'Sentence_2': "Dov'è la cultura?",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.54',
#     'c3pr': 1,
#     'c3P': '0.56',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.54',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.58',
#     'c9pr': 1,
#     'c9P': '0.58',
#     'c10pr': 1,
#     'c10P': '0.55',
#     'c11pr': 0,
#     'c11P': '0.55',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    307901: {'Sentence_1': "C'è un dato dal quale noi non possiamo prescindere, ed è quello del secondo comma dell'articolo 57, che riproduce la lettera dell'articolo 2, secondo cui i Consigli regionali eleggono i senatori tra i propri componenti.",
#     'Sentence_2': 'Questo dato, lo dico alla collega De Petris e anche al collega De Cristofaro, i cui interventi ho molto apprezzato e sui quali tornerò, conferma, come diceva poco fa il senatore Quagliariello - e potrei non aggiungere niente a quanto ha detto -, che la scelta operata è una scelta che prevede che il Senato sia il luogo della rappresentanza delle istituzioni territoriali e che la sua composizione sia affidata a consiglieri regionali e sindaci.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.53',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.53',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.53',
#     'c7pr': 1,
#     'c7P': '0.54',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 0,
#     'c12P': '0.50'}}},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': {451088: {'Sentence_1': 'Assolutamente no.',
#     'Sentence_2': 'Con il "Drugs on street", un progetto di prevenzione notturna, con cui si mettevano insieme carabinieri, polizia, vigili urbani e associazioni di volontariato per controllare e monitorare dalle ore 23 fino alle 4 del mattino, specialmente nelle notti delle stragi, ossia il sabato sera, abbiamo ottenuto risultati straordinari.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.55',
#     'clf_3P': '0.57',
#     'clf_4P': '0.53',
#     'clf_5P': '0.56',
#     'clf_6P': '0.53',
#     'clf_7P': '0.54',
#     'clf_8P': '0.55',
#     'clf_9P': '0.51',
#     'clf_10P': '0.53',
#     'clf_11P': '0.52',
#     'clf_12P': '0.51'},
#    289493: {'Sentence_1': "Cito questo punto perché l'ho considerato un passo avanti molto importante delle istituzioni internazionali, che guardano e devono guardare sempre di più ai temi non soltanto nella centralità degli aspetti finanziari.",
#     'Sentence_2': 'È un errore immaginare che il cuore di tutto siano le decisioni finanziarie: il cuore di tutto deve essere la somma delle decisioni, e bisogna cercare di mettere insieme i vari aspetti.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.56',
#     'clf_2P': '0.53',
#     'clf_3P': '0.52',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.51',
#     'clf_8P': '0.53',
#     'clf_9P': '0.52',
#     'clf_10P': '0.51',
#     'clf_11P': '0.54',
#     'clf_12P': '0.51'},
#    880161: {'Sentence_1': 'Il senatore Solinas entra in Aula.. Congratulazioni.',
#     'Sentence_2': "Facciamo anche noi gli auguri al senatore Solinas, perché alleato con il centrodestra ha vinto, mentre alleati con i grillini svendono l'Italia alla Cina.",
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.59',
#     'clf_2P': '0.53',
#     'clf_3P': '0.52',
#     'clf_4P': '0.51',
#     'clf_5P': '0.52',
#     'clf_6P': '0.51',
#     'clf_7P': '0.53',
#     'clf_8P': '0.53',
#     'clf_9P': '0.53',
#     'clf_10P': '0.53',
#     'clf_11P': '0.57',
#     'clf_12P': '0.57'},
#    791038: {'Sentence_1': "Analogamente è stato fatto in Egitto e in Algeria e analogamente viene fatto, per due volte, nella patria dell'illuminismo e della cultura europea, proprio in un centro che è il grande polo di attrazione turistica e culturale del mondo.",
#     'Sentence_2': "A partire da noi, dall'Italia e dall'Europa, è necessaria una grande unità tra le forze politiche e devo dare atto ai due Ministri che sono intervenuti di aver fatto questo appello all'unità.",
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.53',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.53',
#     'clf_8P': '0.53',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.53'}},
#   'lista_eventi_scelti_intersezione_corretti': {453798: {'Sentence_1': 'In primo luogo, le università cosiddette virtuose, cioè quelle con parametri di bilancio previsti dal decreto legislativo n. 49 del 2012, possono riutilizzare per intero i punti organico che si sono liberati per cessazione dei contratti dei ricercatori di tipo A, quelli senza tenure track per intenderci.',
#     'Sentence_2': "Per il triennio 2015 - 2017 - quindi da quest'anno fino al 2017 -, le università possono fissare il numero delle assunzioni dei professori ordinari, favorendo quindi il ricambio, perché - perdonatemi - i giovani non sono solo necessariamente ricercatori, ma possono esserci anche giovani brillanti che vanno in cattedra a un'età relativamente bassa.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.54',
#     'clf_3P': '0.53',
#     'clf_4P': '0.54',
#     'clf_5P': '0.52',
#     'clf_6P': '0.53',
#     'clf_7P': '0.53',
#     'clf_8P': '0.52',
#     'clf_9P': '0.52',
#     'clf_10P': '0.50',
#     'clf_11P': '0.53',
#     'clf_12P': '0.54'},
#    276356: {'Sentence_1': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 2.44, presentato dal senatore D'Ambrosio Lettieri e da altri senatori.",
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.52',
#     'clf_3P': '0.51',
#     'clf_4P': '0.51',
#     'clf_5P': '0.52',
#     'clf_6P': '0.51',
#     'clf_7P': '0.51',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.53',
#     'clf_12P': '0.51'},
#    318497: {'Sentence_1': "Non c'entrano niente l'articolo 68 o altri aspetti della tutela della funzione parlamentare: qui c'è una legge del 1989 che riguarda le funzioni del Governo e dei Ministri, alla quale abbiamo fatto riferimento.",
#     'Sentence_2': 'Il tribunale dei Ministri, come ho detto, non ritiene che sia un atto puramente politico, ma amministrativo, quindi sindacabile dal giudice.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.56',
#     'clf_2P': '0.53',
#     'clf_3P': '0.55',
#     'clf_4P': '0.55',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.52',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'},
#    26475: {'Sentence_1': 'Ricordo che quando tenemmo il primo incontro dopo il primo terremoto Renzi diceva di avere tutti i soldi per la ricostruzione: lo avete detto in Parlamento a gente che è ancora in mezzo alla strada perché i soldi non li avete tirati fuori.',
#     'Sentence_2': 'Dove li aveva Renzi?',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.59',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.53',
#     'clf_5P': '0.54',
#     'clf_6P': '0.54',
#     'clf_7P': '0.51',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.52',
#     'clf_11P': '0.51',
#     'clf_12P': '0.52'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {512684: {'Sentence_1': "Questa è l'essenza di questo Governo: togliere le libertà democratiche al nostro Paese, in uno Stato, signor Ministro, dove proprio in vista della stagione turistica si è permesso di tutto e di più, senza controlli, perché chi doveva controllare non ha controllato, per poi puntare il dito sulle Regioni, per poi dire che il Presidente della Regione Sardegna è stato inefficiente.",
#     'Sentence_2': "Bastava prendere uno di quelli che voi chiamate eroi e mandarlo all'Organizzazione mondiale della sanità.",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.55',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.56',
#     'c6pr': 1,
#     'c6P': '0.53',
#     'c7pr': 1,
#     'c7P': '0.53',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.52',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    280710: {'Sentence_1': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 8.135, presentato dal senatore Arrigoni.",
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.51',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.53',
#     'c5pr': 0,
#     'c5P': '0.52',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 0,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    637884: {'Sentence_1': "Tuttavia, penso che su questo ci voglia un po' più di umiltà.",
#     'Sentence_2': 'E pensiamo che questa battaglia politica che oggi combattiamo non la facciamo solo per noi.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.57',
#     'c2pr': 1,
#     'c2P': '0.55',
#     'c3pr': 1,
#     'c3P': '0.55',
#     'c4pr': 1,
#     'c4P': '0.58',
#     'c5pr': 1,
#     'c5P': '0.58',
#     'c6pr': 1,
#     'c6P': '0.55',
#     'c7pr': 1,
#     'c7P': '0.53',
#     'c8pr': 1,
#     'c8P': '0.54',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.54'},
#    634012: {'Sentence_1': "In più, leggendo le disposizioni che si vogliono introdurre con questo disegno di legge, si delinea un regime fortemente repressivo, peraltro dal profilo incerto; talvolta l'aspetto repressivo non assume i connotati di qualcosa che possa risolvere il problema.",
#     'Sentence_2': 'Ecco perché il Gruppo di Forza Italia, a malincuore e con grande dispiacere, esprimerà un voto di astensione, quando avrebbe voluto essere favorevole.. Congratulazioni.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.57',
#     'c12pr': 0,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {187558: {'Sentence_1': 'Il testo che abbiamo esaminato questa mattina prevede, invece, di istituire un apposito organismo consultivo, con la partecipazione di rappresentanti di tutti i soggetti pubblici e privati, e che ai componenti dei predetti organismi non spetta alcun compenso, indennità, eccetera.',
#     'Sentence_2': "È del tutto evidente che in materia di protezione civile stiamo parlando di aria fritta, perché non c'è bisogno di una legge per comporre un organismo consultivo guidato dal sindaco all'interno del Comune.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.54',
#     'c4pr': 1,
#     'c4P': '0.54',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.53',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    527740: {'Sentence_1': 'Lo dico anche agli editori: non si deve censurare nulla, ma allora si pubblicassero i libri nella collana dei Gialli.',
#     'Sentence_2': 'Ebbene, si arrivò al punto - e qui interviene anche una memoria diretta e personale - che per molti mesi, signor Presidente, si scrisse che si trattava di una faida interna ai missini, come lo si scrisse per la strage di Primavalle, una vicenda che riguarda Potere operaio non le Brigate Rosse.',
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.52',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.52',
#     'c5pr': 0,
#     'c5P': '0.54',
#     'c6pr': 0,
#     'c6P': '0.52',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 0,
#     'c8P': '0.53',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.50'},
#    111886: {'Sentence_1': 'Questo serve, infatti.',
#     'Sentence_2': "In Commissione, però, grazie ad un emendamento della relatrice Granato, che all'epoca non era relatrice del provvedimento, appoggiato dalla relatrice di due settimane fa e da tutti noi, si era aumentata la quota destinata ai precari sino al 70 per cento.",
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.50',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 0,
#     'c4P': '0.55',
#     'c5pr': 0,
#     'c5P': '0.53',
#     'c6pr': 0,
#     'c6P': '0.54',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.52',
#     'c10pr': 0,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 0,
#     'c12P': '0.52'},
#    622598: {'Sentence_1': "Ho retrodatato allora la polemica antiparlamentarista di cento anni, all'impresa fiumana, che faceva la costituzione, sì, ma con Keller e con D'Annunzio, era l'epoca in cui le trasvolate erano eroiche: erano andati a gettare volantini tricolori sopra l'Austria, nella fase della prima guerra mondiale; sono venuti sopra Montecitorio a gettare il vaso da notte, per dire che il Parlamento faceva schifo in segno di irrisione.",
#     'Sentence_2': "Quindi non c'è niente di nuovo.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.53',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.54',
#     'c12pr': 1,
#     'c12P': '0.52'}}},
#  'df_random_speech': {'lista_eventi_scelti_intersezione_errati': {636188: {'Sentence_1': 'Ha facoltà di parlare il presidente del Consiglio dei ministri, dottor Renzi.',
#     'Sentence_2': 'Avverto che le proposte di risoluzione dovranno essere presentate entro la conclusione del dibattito.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.69',
#     'clf_2P': '0.58',
#     'clf_3P': '0.61',
#     'clf_4P': '0.64',
#     'clf_5P': '0.64',
#     'clf_6P': '0.66',
#     'clf_7P': '0.66',
#     'clf_8P': '0.68',
#     'clf_9P': '0.69',
#     'clf_10P': '0.69',
#     'clf_11P': '0.55',
#     'clf_12P': '0.69'},
#    167370: {'Sentence_1': "Signor Presidente, il parere sull'emendamento 34.200 è contrario.",
#     'Sentence_2': 'Signor Presidente, esprimo parere contrario sugli emendamenti 37.200, 37.201 e 37.202.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.74',
#     'clf_2P': '0.69',
#     'clf_3P': '0.69',
#     'clf_4P': '0.70',
#     'clf_5P': '0.71',
#     'clf_6P': '0.73',
#     'clf_7P': '0.76',
#     'clf_8P': '0.77',
#     'clf_9P': '0.74',
#     'clf_10P': '0.68',
#     'clf_11P': '0.59',
#     'clf_12P': '0.59'},
#    44241: {'Sentence_1': 'Un Governo come quello Renzi, che fa di un argomento etico il fondamento del suo programma e che perciò pone su di esso una questione di fiducia, assume conseguentemente, fortemente, prepotentemente la forma di un Governo etico.',
#     'Sentence_2': 'Siamo anche convinti che la possibilità di formare specialisti del territorio, pronti per affrontare le sfide del Servizio sanitario nazionale che sono rappresentate dai mutati scenari di salute, dal maggiore impatto delle cronicità e dalle incombenze poste dalla stessa pandemia, richieda risposte organizzate e integrate proprio a livello di comunità.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.65',
#     'clf_2P': '0.67',
#     'clf_3P': '0.59',
#     'clf_4P': '0.61',
#     'clf_5P': '0.59',
#     'clf_6P': '0.61',
#     'clf_7P': '0.62',
#     'clf_8P': '0.59',
#     'clf_9P': '0.58',
#     'clf_10P': '0.59',
#     'clf_11P': '0.54',
#     'clf_12P': '0.50'},
#    490307: {'Sentence_1': 'Il Senato non approva.',
#     'Sentence_2': "Verrà esclusa la responsabilità penale del medico, anche per colpa grave, se rispetterà le buone pratiche e le linee guida previste, come a dire che ci si potrà trincerare al sicuro dietro un testo, evitando l'adozione delle scelte terapeutiche più adeguate e sfociando verso una standardizzazione a discapito del rapporto medico - paziente, per un risarcimento che già oggi tarda ad arrivare e facendo sì che coloro che si sono resi colpevoli con il loro operato, ma salvi dalle linee guida, continueranno ad operare nelle stesse strutture mettendo in pericolo altri pazienti.",
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.66',
#     'clf_2P': '0.66',
#     'clf_3P': '0.66',
#     'clf_4P': '0.66',
#     'clf_5P': '0.70',
#     'clf_6P': '0.67',
#     'clf_7P': '0.64',
#     'clf_8P': '0.64',
#     'clf_9P': '0.61',
#     'clf_10P': '0.55',
#     'clf_11P': '0.56',
#     'clf_12P': '0.62'}},
#   'lista_eventi_scelti_intersezione_corretti': {136364: {'Sentence_1': 'È davvero assurdo scrivere un emendamento, che per carità condividiamo, in cui prevediamo una premialità per la denuncia obbligatoria delle richieste estorsive.',
#     'Sentence_2': 'Se uno viene da me e avanza una richiesta di estorsione sono obbligato ad andare dal magistrato e a presentare denuncia.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.57',
#     'clf_2P': '0.65',
#     'clf_3P': '0.62',
#     'clf_4P': '0.66',
#     'clf_5P': '0.60',
#     'clf_6P': '0.60',
#     'clf_7P': '0.63',
#     'clf_8P': '0.57',
#     'clf_9P': '0.57',
#     'clf_10P': '0.55',
#     'clf_11P': '0.55',
#     'clf_12P': '0.62'},
#    74785: {'Sentence_1': "Se mi è consentito, vorrei invitare i senatori proponenti a ritirare l'emendamento.",
#     'Sentence_2': "Se invece venisse accolta l'osservazione che ho fatto sull'emendamento del senatore Casson, potrei ritirare il mio emendamento.",
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.63',
#     'clf_2P': '0.62',
#     'clf_3P': '0.65',
#     'clf_4P': '0.59',
#     'clf_5P': '0.55',
#     'clf_6P': '0.53',
#     'clf_7P': '0.50',
#     'clf_8P': '0.54',
#     'clf_9P': '0.62',
#     'clf_10P': '0.63',
#     'clf_11P': '0.66',
#     'clf_12P': '0.61'},
#    327854: {'Sentence_1': "Un ulteriore elemento, giustamente evidenziato e che ha anch'esso caratterizzato i lavori della Giunta, riguarda l'allocazione dei costi, o meglio, la previsione dei costi e la loro allocazione all'interno del Consiglio di Presidenza.",
#     'Sentence_2': "Proclamo il risultato della votazione a scrutinio segreto per l'elezione del Presidente del Senato: Hanno ottenuto voti i senatori: Proclamo eletta Presidente del Senato la senatrice Maria Elisabetta Alberti Casellati.",
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.61',
#     'clf_2P': '0.52',
#     'clf_3P': '0.56',
#     'clf_4P': '0.59',
#     'clf_5P': '0.60',
#     'clf_6P': '0.56',
#     'clf_7P': '0.50',
#     'clf_8P': '0.53',
#     'clf_9P': '0.52',
#     'clf_10P': '0.54',
#     'clf_11P': '0.56',
#     'clf_12P': '0.63'},
#    598163: {'Sentence_1': "Quindi, se a un certo punto la Francia decide di bombardare la Libia, va bene, perché non c'è un vincolo europeo che impedisca di muovere guerra contro gli interessi di un altro Stato membro dell'Unione europea; in compenso, ci dicono se le materie fecali le dobbiamo trattare come rifiuti oppure no.",
#     'Sentence_2': 'Cosa sosteniamo allora?',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.53',
#     'clf_2P': '0.59',
#     'clf_3P': '0.72',
#     'clf_4P': '0.63',
#     'clf_5P': '0.54',
#     'clf_6P': '0.59',
#     'clf_7P': '0.59',
#     'clf_8P': '0.64',
#     'clf_9P': '0.66',
#     'clf_10P': '0.65',
#     'clf_11P': '0.70',
#     'clf_12P': '0.76'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {18768: {'Sentence_1': 'Venendo al disegno di legge di ratifica, esso si compone di quattro articoli.',
#     'Sentence_2': "Passiamo alla votazione dell'articolo 90.",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.71',
#     'c2pr': 1,
#     'c2P': '0.62',
#     'c3pr': 1,
#     'c3P': '0.54',
#     'c4pr': 1,
#     'c4P': '0.59',
#     'c5pr': 1,
#     'c5P': '0.56',
#     'c6pr': 1,
#     'c6P': '0.55',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.55',
#     'c11pr': 0,
#     'c11P': '0.59',
#     'c12pr': 1,
#     'c12P': '0.50'},
#    287660: {'Sentence_1': "Signor Presidente, onorevoli colleghi, volevo dire innanzitutto, con particolare riguardo all'intervento della senatrice De Petris, che è mio per prima il rammarico di non avere potuto convocare la Commissione per prendere atto della calendarizzazione in Aula della legge elettorale.",
#     'Sentence_2': "Tutti i colleghi hanno visto che ciò è stato impossibile per mancanza di una soluzione di continuità tra la Conferenza dei Capigruppo e l'inizio dei lavori d'Aula.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.54',
#     'c2pr': 0,
#     'c2P': '0.52',
#     'c3pr': 0,
#     'c3P': '0.58',
#     'c4pr': 0,
#     'c4P': '0.55',
#     'c5pr': 0,
#     'c5P': '0.55',
#     'c6pr': 0,
#     'c6P': '0.60',
#     'c7pr': 0,
#     'c7P': '0.58',
#     'c8pr': 0,
#     'c8P': '0.56',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    606882: {'Sentence_1': 'La seduta è sospesa.',
#     'Sentence_2': 'Il Governo, dunque, sta facendo tutto il possibile per migliorare la vita degli italiani e dare un impulso forte al rilancio economico e alla crescita.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.61',
#     'c4pr': 1,
#     'c4P': '0.55',
#     'c5pr': 1,
#     'c5P': '0.56',
#     'c6pr': 1,
#     'c6P': '0.61',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.56',
#     'c9pr': 0,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.53',
#     'c12pr': 1,
#     'c12P': '0.67'},
#    191503: {'Sentence_1': 'Signor Presidente, in primis vorrei dichiarare che nessuno della maggioranza ha mai detto di voler utilizzare le riserve auree per il pagamento del debito pubblico o per coprire le spese correnti.',
#     'Sentence_2': "Se si fa un'affermazione simile e poi si dà la colpa alla maggioranza dell'aumento dello spread e della sfiducia dei mercati verso l'Italia, è sempre un concetto sbagliato.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.53',
#     'c2pr': 1,
#     'c2P': '0.55',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.58',
#     'c5pr': 0,
#     'c5P': '0.62',
#     'c6pr': 0,
#     'c6P': '0.59',
#     'c7pr': 0,
#     'c7P': '0.58',
#     'c8pr': 0,
#     'c8P': '0.57',
#     'c9pr': 0,
#     'c9P': '0.61',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 0,
#     'c12P': '0.58'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {877007: {'Sentence_1': "La norma oggetto di novella fa riferimento, oltre che all'incremento delle prestazioni a carico del dipartimento scientifico del Policlinico militare Celio, causato anche dalle emergenze biologiche e dalla connessa necessità di sviluppo di test per patogeni rari, alla finalità di far fronte alle esigenze straordinarie e urgenti derivanti dalla diffusione del virus SARS - Cov - 2 di garantire i livelli essenziali di assistenza e di sostenere e supportare le altre strutture del Servizio sanitario nazionale.",
#     'Sentence_2': "Ricordo che gli emendamenti approvati dalla Commissione sono stati inviati ai Gruppi, che hanno quindi un'ora di tempo a partire da ora per presentare subemendamenti.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 1,
#     'c2P': '0.62',
#     'c3pr': 1,
#     'c3P': '0.60',
#     'c4pr': 1,
#     'c4P': '0.60',
#     'c5pr': 1,
#     'c5P': '0.54',
#     'c6pr': 1,
#     'c6P': '0.58',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.60',
#     'c9pr': 1,
#     'c9P': '0.60',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.54',
#     'c12pr': 1,
#     'c12P': '0.52'},
#    122955: {'Sentence_1': 'I chiarimenti forniti dal Consiglio di Stato hanno, dunque, dato finalmente il necessario impulso alla redazione dello schema di decreto ministeriale e della bozza di correlato disciplinare tecnico, entrambi in fase di avanzatissima definizione.',
#     'Sentence_2': 'In questo contesto, come la storia insegna, sono compatibili modelli elettorali puramente proporzionali, modelli misti o modelli maggioritari.',
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.58',
#     'c2pr': 0,
#     'c2P': '0.64',
#     'c3pr': 0,
#     'c3P': '0.62',
#     'c4pr': 0,
#     'c4P': '0.60',
#     'c5pr': 0,
#     'c5P': '0.61',
#     'c6pr': 0,
#     'c6P': '0.67',
#     'c7pr': 0,
#     'c7P': '0.65',
#     'c8pr': 0,
#     'c8P': '0.67',
#     'c9pr': 0,
#     'c9P': '0.65',
#     'c10pr': 0,
#     'c10P': '0.52',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    61619: {'Sentence_1': "Onorevoli colleghi, il Ministro dell'economia e delle finanze ha presentato la Nota di variazioni al bilancio di previsione dello Stato per l'anno finanziario 2018 e bilancio pluriennale per il triennio 2018 - 2020.",
#     'Sentence_2': 'La revisione dei meccanismi di indicizzazione del provvedimento del 2011 ha interessato infatti circa il 30 per cento dei pensionati, vale a dire 4, 400 milioni di cittadini.',
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.55',
#     'c2pr': 1,
#     'c2P': '0.56',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.59',
#     'c5pr': 0,
#     'c5P': '0.59',
#     'c6pr': 0,
#     'c6P': '0.61',
#     'c7pr': 0,
#     'c7P': '0.64',
#     'c8pr': 0,
#     'c8P': '0.70',
#     'c9pr': 0,
#     'c9P': '0.65',
#     'c10pr': 0,
#     'c10P': '0.59',
#     'c11pr': 0,
#     'c11P': '0.58',
#     'c12pr': 0,
#     'c12P': '0.54'},
#    5811: {'Sentence_1': 'Risultano pertanto assorbiti gli emendamenti 23.0.5 e 23.0.270.',
#     'Sentence_2': "L'emendamento 23.410 è stato ritirato.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.58',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.61',
#     'c6pr': 1,
#     'c6P': '0.60',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.61',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.59'}}}}

# %%
diz_tabella_total_svm.keys()
# Out:
# dict_keys(['df_dist_5', 'df_dist_10', 'df_dist_20', 'df_dist_30', 'df_random_speech'])

# %% [markdown]
# # SVM confronti interni

# %%
def salva_dataset_risultati(diz_tabella_modello, modello, lista_dist, risorsa):
    
    for dist in lista_dist:
    
        for k in diz_tabella_modello[dist]:
            df = pd.DataFrame(diz_tabella_modello[dist][k]).T
            save_dataframe("{} - {}_{}_{}".format(risorsa, dist, modello, k), df)

# %%
salva_dataset_risultati(diz_tabella_total_svm, 'SVM', lista_dist, risorsa)
# Out:
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente

# %%
salva_dataset_risultati(diz_tabella_total_bert, 'BERT', lista_dist, risorsa)
# Out:
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente

# %%
salva_dataset_risultati(diz_confronti_incrociati_svm, 'SVM_incroci', lista_dist, risorsa)
# Out:
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente

# %%
salva_dataset_risultati(diz_confronti_incrociati_bert, 'BERT_incroci', lista_dist, risorsa)
# Out:
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente
# File salvato correttamente

# %%
pd.DataFrame(diz_tabella_total_bert['df_random_speech']['lista_eventi_scelti_intersezione_altri_errati']).T
# Out:
#                                                Sentence_1  \
# 701817  Le brigate rosse hanno scelto questi come loro...
# 74365   Le mozioni, interpellanze e interrogazioni per...
# 363150  La nostra posizione in questo senso è che non ...
# 450666  Tutto questo si perderà, perché nella visione ...
#
#                                                Sentence_2 Class Epoch0pr  \
# 701817  Insieme a loro, nei decenni, sono stati ricord...     0        0
# 74365   Ricordo che il Senato tornerà a riunirsi in se...     0        1
# 363150  Inoltre - l'ho già ricordato - l'accordo dovrà...     0        1
# 450666  Non possiamo permettere queste ingerenze, né l...     0        0
#
#        Epoch0P Epoch1pr Epoch1P Epoch2pr Epoch2P Epoch3pr Epoch3P Epoch4pr  \
# 701817    0.55        1    0.53        0    0.99        0    1.00        0
# 74365     0.56        0    0.84        0    0.95        0    1.00        0
# 363150    0.52        0    0.70        0    1.00        0    0.99        0
# 450666    0.70        1    0.54        0    0.92        0    0.97        0
#
#        Epoch4P
# 701817    0.99
# 74365     1.00
# 363150    0.99
# 450666    0.95

# %%
pd.DataFrame(diz_tabella_total_svm['df_dist_5']['lista_eventi_scelti_intersezione_errati']).T
# Out:
#                                                Sentence_1  \
# 228695  Il più comprende il meno, seppur fosse discuti...
# 195285  Passiamo all'emendamento 13.0.13, su cui la 5ᵃ...
#
#                                                Sentence_2 Class Pred clf_1P  \
# 228695  Accogliendo il mio subemendamento si andrebbe ...     0    1   0.52
# 195285                             Il Senato non approva.     1    0   0.51
#
#        clf_2P clf_3P clf_4P clf_5P clf_6P clf_7P clf_8P clf_9P clf_10P  \
# 228695   0.52   0.50   0.50   0.50   0.50   0.50   0.50   0.51    0.51
# 195285   0.51   0.50   0.50   0.50   0.50   0.50   0.50   0.50    0.51
#
#        clf_11P clf_12P
# 228695    0.53    0.51
# 195285    0.51    0.51

# %%
pd.DataFrame(diz_tabella_total_svm['df_dist_5']['lista_eventi_scelti_intersezione_errati']).T
# Out:
#                                                Sentence_1  \
# 105167  La cosiddetta "wisdom of crowds", un libro del...
# 149296  Ma non fidandovi l'uno degli altri, avete paur...
# 178915  Quindi interagire con l'intelligenza artificia...
# 122891  Oppure sono effettivamente patrimonio, cioè be...
#
#                                                Sentence_2 Class Pred clf_1_P  \
# 105167  Una persona ha detto, valore più basso, che ce...     1    0    0.51
# 149296  Ad esempio ritagliando di nascosto le fiches o...     0    1    0.51
# 178915  Questo non era un robot, era un pupazzo con 87...     1    0    0.51
# 122891                                       Un restauro.     1    0    0.51
#
#        clf_2_P clf_3_P clf_4_P clf_5_P clf_6_P clf_7_P clf_8_P clf_9_P  \
# 105167    0.53    0.52    0.51    0.53    0.53    0.53    0.54    0.50
# 149296    0.51    0.52    0.52    0.53    0.53    0.52    0.51    0.52
# 178915    0.52    0.53    0.52    0.53    0.52    0.51    0.50    0.51
# 122891    0.53    0.52    0.51    0.51    0.50    0.50    0.55    0.52
#
#        clf_10_P clf_11_P clf_12_P
# 105167     0.51     0.52     0.50
# 149296     0.52     0.51     0.51
# 178915     0.51     0.50     0.50
# 122891     0.51     0.51     0.50

# %%
pd.DataFrame(diz_tabella_total_svm['df_dist_5']['lista_eventi_scelti_intersezione_altri_corretti']).T
# Out:
#                                                Sentence_1  \
# 892     I miei due amici che mi accompagnavano dormiva...
# 4249    Pensa a proteggere se stessa, a consumare poch...
# 8929    Oppure raccontare di come Brian Acton, quest'a...
# 140002  Quindi stiamo cercando di dare il massimo valo...
#
#                                                Sentence_2 Class clf_1_pred  \
# 892     Sono uscite due cose: La prima, è che i miei g...     1          1
# 4249    Immediatamente scatta un allarme e inonda il s...     1          0
# 8929    Perché io credo che la differenza, in fin dei ...     1          0
# 140002  Mi piace più parlare di sostenibilità, di prod...     1          0
#
#        clf_1_P clf_2_pred clf_2_P clf_3_pred clf_3_P clf_4_pred  ...  \
# 892       0.50          0    0.51          0    0.51          0  ...
# 4249      0.50          0    0.52          0    0.51          0  ...
# 8929      0.50          1    0.52          0    0.51          0  ...
# 140002    0.50          0    0.50          0    0.52          0  ...
#
#        clf_8_pred clf_8_P clf_9_pred clf_9_P clf_10_pred clf_10_P clf_11_pred  \
# 892             0    0.50          0    0.51           0     0.51           0
# 4249            0    0.52          0    0.51           0     0.50           0
# 8929            0    0.51          0    0.51           0     0.51           0
# 140002          0    0.52          0    0.51           1     0.50           0
#
#        clf_11_P clf_12_pred clf_12_P
# 892        0.51           0     0.50
# 4249       0.50           1     0.51
# 8929       0.50           0     0.50
# 140002     0.51           0     0.50
#
# [4 rows x 27 columns]

# %%
pd.DataFrame(diz_tabella_total_svm['df_dist_5']['lista_eventi_scelti_intersezione_altri_errati']).T
# Out:
#                                                Sentence_1  \
# 50178   Però anche tre sogni, a pensarci bene, che bam...
# 166701  Le nostre miniere sono sperdute in mezzo ai de...
# 99703   Chiediamoci ancora una volta: ma perché questo...
# 198866  In che professione rientra fare ciò che compor...
#
#                                                Sentence_2 Class clf_1_pred  \
# 50178   Mi viene da sorridere perché di solito, nel mi...     1          1
# 166701  Le nostre acciaierie, che produciamo, hanno, d...     0          0
# 99703   Mah, insomma, potrei sempre dire: "Va bene, io...     0          1
# 198866  Nasce per riuscire a vivere in determinate con...     1          1
#
#        clf_1_P clf_2_pred clf_2_P clf_3_pred clf_3_P clf_4_pred  ...  \
# 50178     0.51          1    0.52          1    0.52          1  ...
# 166701    0.50          0    0.51          0    0.51          0  ...
# 99703     0.50          0    0.50          0    0.51          0  ...
# 198866    0.50          1    0.53          1    0.53          1  ...
#
#        clf_8_pred clf_8_P clf_9_pred clf_9_P clf_10_pred clf_10_P clf_11_pred  \
# 50178           1    0.52          1    0.53           1     0.51           1
# 166701          1    0.50          0    0.50           0     0.51           0
# 99703           0    0.51          0    0.52           0     0.51           0
# 198866          1    0.51          1    0.52           1     0.50           1
#
#        clf_11_P clf_12_pred clf_12_P
# 50178      0.50           0     0.50
# 166701     0.52           0     0.50
# 99703      0.51           0     0.50
# 198866     0.50           1     0.50
#
# [4 rows x 27 columns]

# %%
diz_confronti_incrociati_svm
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': {105167: {'Sentence_1': 'La cosiddetta "wisdom of crowds", un libro del 2004 mai tradotto in italiano.',
#     'Sentence_2': "Una persona ha detto, valore più basso, che ce ne sono 70, Il dato reale è di 287: la media raggiunta da voi è 272, l'errore è più o meno pari al 5%.",
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.53',
#     'c3pred': 0,
#     'c3P': '0.52',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.53',
#     'c7pred': 0,
#     'c7P': '0.53',
#     'c8pred': 0,
#     'c8P': '0.54',
#     'c9pred': 0,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.52',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    149296: {'Sentence_1': "Ma non fidandovi l'uno degli altri, avete paura che possano imbrogliare.",
#     'Sentence_2': 'Ad esempio ritagliando di nascosto le fiches o passandosele sotto il tavolo.',
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.52',
#     'c4pred': 1,
#     'c4P': '0.52',
#     'c5pred': 1,
#     'c5P': '0.53',
#     'c6pred': 1,
#     'c6P': '0.53',
#     'c7pred': 1,
#     'c7P': '0.52',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.52',
#     'c10pred': 1,
#     'c10P': '0.52',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    178915: {'Sentence_1': "Quindi interagire con l'intelligenza artificiale è qualcosa che nella vita di tutti i giorni possiamo fare, ma anche nel nostro lavoro: è vero che i robot stanno sostituendo molti lavori manuali, soprattutto i lavori più pesanti, i lavori più ripetitivi.",
#     'Sentence_2': "Questo non era un robot, era un pupazzo con 87 parti in movimento, una decina nel volto per rappresentare proprio l'empatia ai sentimenti umani nel momento in cui veniva a parlare con dei ragazzi, con gli esseri umani.",
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.52',
#     'c3pred': 0,
#     'c3P': '0.53',
#     'c4pred': 0,
#     'c4P': '0.52',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.52',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    122891: {'Sentence_1': 'Oppure sono effettivamente patrimonio, cioè bene, cioè potenziale rigenerabile?',
#     'Sentence_2': 'Un restauro.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.53',
#     'c3pred': 0,
#     'c3P': '0.52',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 0,
#     'c8P': '0.55',
#     'c9pred': 0,
#     'c9P': '0.52',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_corretti': {23286: {'Sentence_1': "Non c'è bisogno di una terza volta.",
#     'Sentence_2': 'Ma che cosa vi aspettavate?',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.52',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    155973: {'Sentence_1': 'Cosa intendo?',
#     'Sentence_2': 'Dovete scusarci, perché questa è la nostra prima presentazione interattiva, e quindi siamo tutti e due abbastanza tesi.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.52',
#     'c4pred': 1,
#     'c4P': '0.52',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.53',
#     'c8pred': 1,
#     'c8P': '0.53',
#     'c9pred': 1,
#     'c9P': '0.53',
#     'c10pred': 1,
#     'c10P': '0.52',
#     'c11pred': 1,
#     'c11P': '0.52',
#     'c12pred': 1,
#     'c12P': '0.52'},
#    92955: {'Sentence_1': 'Si presentava ai convegni e alle conferenze importanti così.',
#     'Sentence_2': "Appena arrivato ha chiesto subito scusa ad Albert Einstein che l'ha fatto aspettare 40 minuti.",
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.53',
#     'c3pred': 1,
#     'c3P': '0.53',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.52',
#     'c8pred': 1,
#     'c8P': '0.52',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    75655: {'Sentence_1': "Ma l'innovazione di gran lunga più importante, quella che è responsabile del 50% dell'aumento di produzione che si è avuto negli anni, è il miglioramento genetico.",
#     'Sentence_2': 'Ma il tempo del progresso non è lo stesso per tutti, o ovunque.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.52',
#     'c9pred': 1,
#     'c9P': '0.52',
#     'c10pred': 1,
#     'c10P': '0.52',
#     'c11pred': 1,
#     'c11P': '0.52',
#     'c12pred': 1,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {50178: {'Sentence_1': "Però anche tre sogni, a pensarci bene, che bambini della mia età, cresciuti negli anni '80, avevano.",
#     'Sentence_2': 'Mi viene da sorridere perché di solito, nel mio lavoro, sono io che metto altre persone sul palcoscenico, metto altre persone davanti alle telecamere; e oggi che ci sono qui io, effettivamente dico che non è così semplice.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.52',
#     'c4pred': 1,
#     'c4P': '0.52',
#     'c5pred': 1,
#     'c5P': '0.53',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.52',
#     'c9pred': 1,
#     'c9P': '0.53',
#     'c10pred': 1,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    166701: {'Sentence_1': 'Le nostre miniere sono sperdute in mezzo ai deserti, molte volte in profondità.',
#     'Sentence_2': 'Le nostre acciaierie, che produciamo, hanno, di fatto, temperature altissime, quindi non permettono questa prossimità fisica.',
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.52',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    99703: {'Sentence_1': 'Chiediamoci ancora una volta: ma perché questo implica che il presente è esteso, è spesso?',
#     'Sentence_2': 'Mah, insomma, potrei sempre dire: "Va bene, io sto guardando un\'immagine di quattro anni fa.',
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.52',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.52',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    198866: {'Sentence_1': 'In che professione rientra fare ciò che comporta il vivere in montagna?',
#     'Sentence_2': 'Nasce per riuscire a vivere in determinate condizioni.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.53',
#     'c3pred': 1,
#     'c3P': '0.53',
#     'c4pred': 1,
#     'c4P': '0.52',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.52',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {892: {'Sentence_1': 'I miei due amici che mi accompagnavano dormivano profondamente, profondamente.',
#     'Sentence_2': "Sono uscite due cose: La prima, è che i miei genitori tanto sportivi, che quindi andavamo sempre a sciare, tutti i weekend, e noi, da Roma, naturalmente non avevamo un'automobile adatta al ghiaccio, alla neve, ma non importa, si faceva lo stesso!",
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.52',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    4249: {'Sentence_1': 'Pensa a proteggere se stessa, a consumare poche energie, ha questo istinto di autoconservazione e, per fare questo, non esita a mentirci.',
#     'Sentence_2': 'Immediatamente scatta un allarme e inonda il sangue con sostanze che ci fanno reagire.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.52',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.52',
#     'c8pred': 0,
#     'c8P': '0.52',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    8929: {'Sentence_1': "Oppure raccontare di come Brian Acton, quest'altro signore alle mie spalle, il fondatore di Whatsapp, quando cercava lavoro è stato rifiutato prima da Facebook e poi da Twitter.",
#     'Sentence_2': 'Perché io credo che la differenza, in fin dei conti sia veramente lì.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    140002: {'Sentence_1': 'Quindi stiamo cercando di dare il massimo valore a questi scarti industriali biologici e di trovare i prodotti adatti per dargli una nuova vita.',
#     'Sentence_2': "Mi piace più parlare di sostenibilità, di prodotti sostenibili, perché abbiamo un po' nella nostra mente che un prodotto riciclato sia sempre di scarsa qualità, di seconda scelta.",
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.52',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.52',
#     'c8pred': 0,
#     'c8P': '0.52',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.50'}}},
#  'df_dist_10': {'lista_eventi_scelti_intersezione_errati': {86547: {'Sentence_1': 'Come vedete, non ha funzionato proprio bene.',
#     'Sentence_2': 'Questi sono tre filamenti di seta di ragno, sono lunghi 35 cm, guarda caso come il piano armonico di un violino, e sono prodotti da un esemplare femmina di "golden orb - weaver", che è questo ragno.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.53',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    94213: {'Sentence_1': "Il nostro lavoro consisteva nel tagliare delle asperità della roccia che sporgevano per più di un metro e mezzo e profilarle con l'esplosivo.",
#     'Sentence_2': 'Con questi massi abbiamo poi riempito le cavità, realizzando dei muretti tipici dei terrazzamenti che ci sono sulle Alpi senza snaturare il contesto dei luoghi e questo è stato apprezzato.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.52',
#     'c6pred': 0,
#     'c6P': '0.53',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.52',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.51'},
#    199708: {'Sentence_1': "La plastica che sta in un pannolino non è la plastica del tappo della bottiglietta d'acqua.",
#     'Sentence_2': "C'è la cellulosa, e quindi è un rifiuto di carta, quello che si mette nei rifiuti di carta a casa; c'è la plastica, quindi, è un rifiuto di plastica; e c'è quello che, qua, lo devo chiamare contributo umano, che lo rende un rifiuto organico.",
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 0,
#     'c8P': '0.52',
#     'c9pred': 0,
#     'c9P': '0.52',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    17682: {'Sentence_1': 'Siamo gente comune e potremmo essere i vostri figli, potremmo essere quelli seduti accanto a voi o voi alla nostra età.',
#     'Sentence_2': 'E tutto questo per sottolineare che non sentiamo e non abbiamo mai sentito di avere niente in più rispetto a nessuno, se non la speranza di contribuire a fare di questo il paese nel quale saremmo voluti crescere.',
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.52',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_corretti': {100632: {'Sentence_1': 'Quindi faranno da complemento a questo, molto probabilmente.',
#     'Sentence_2': 'Con Facebook è possibile completare questa serie e capire il trend, e ricostruirlo fino ad oggi, in un valore inestimabile dal punto di vista della conoscenza di quello che sta succedendo in questo momento.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.52',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.53',
#     'c7pred': 1,
#     'c7P': '0.53',
#     'c8pred': 1,
#     'c8P': '0.53',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    120997: {'Sentence_1': "Tornando alla nostra esperienza, noi al momento della selezione, ovviamente dopo un periodo di totale euforia, ci siamo resi conto di aver pochissimo tempo per portare quella che nel momento della selezione era un'idea geniale, ma completamente astratta, a qualcosa poi di concreto.",
#     'Sentence_2': 'Come previsto dal programma, infatti, avevamo circa sette mesi, da marzo ad ottobre, per passare dalla fase idea, alla fase poi di test.',
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.50',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.52',
#     'c9pred': 0,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    119171: {'Sentence_1': "Il mio corpo, il mio cervello proietta sempre l'immagine di me proprio com'era: Niente può cambiarla.",
#     'Sentence_2': 'Maggiore è la stima che nutriamo in noi stessi, migliore è la percezione che la gente avrà di noi.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.52',
#     'c8pred': 1,
#     'c8P': '0.52',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    91036: {'Sentence_1': "Aveva i capelli neri come l'ebano, la bocca rossa come una rosa e la carnagione bianca come la neve.",
#     'Sentence_2': "C'era una volta un uomo molto ricco.",
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.53',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {29166: {'Sentence_1': 'Significa progresso economico, oltre che scientifico, significa benessere.',
#     'Sentence_2': 'Però uno potrebbe ancora obiettare che non rispondiamo alla domanda del bambino.',
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.50',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.52',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.51'},
#    148586: {'Sentence_1': 'E quindi, studiando e togliendo gli elementi del passato, ci rimane una porzione di futuro.',
#     'Sentence_2': 'Se la analizziamo rispetto alla dinamica che sta avendo, alla diffusione, a come cresce, possiamo già avere in mano degli elementi che ci permettono di studiare il futuro.',
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.50',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    30087: {'Sentence_1': 'Cena, asparagi, amici.',
#     'Sentence_2': 'Sono entrato che fatturava 60 milioni, 15 anni dopo ne fatturava 630.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.53',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.55',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    161961: {'Sentence_1': "Come con la malattia, dove la sofferenza e il dolore mi facevano riscoprire un po' più forte.",
#     'Sentence_2': "Scoprivo, metro dopo metro, il coraggio che si nasconde dietro l'affrontare qualcosa che sembra impossibile.",
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.52',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.52',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.52',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {65533: {'Sentence_1': 'O meglio, la mia testa no, ma forse il mio cuore si.',
#     'Sentence_2': 'Perché io credo che nella vita nulla succeda per caso.',
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    40700: {'Sentence_1': 'È una parte poco conosciuta del cervello, è qua dietro, e lì dentro ci sono i centri di controllo del respiro e di regolazione del sistema cardio - circolatorio.',
#     'Sentence_2': 'Cosa vuol dire questa frase qui?',
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.53',
#     'c7pred': 1,
#     'c7P': '0.52',
#     'c8pred': 1,
#     'c8P': '0.52',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    165440: {'Sentence_1': 'Troppo tardi!',
#     'Sentence_2': 'Poi, però, ho pensato che forse la parte di me, la parte creativa che non avevo mai sviluppato in precedenza, è proprio quella in cui potevo riuscire meglio.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.52',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.52',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    139908: {'Sentence_1': 'Ed è ciascuno di voi.',
#     'Sentence_2': "È l'essere umano, e vediamo di non sprecarlo.",
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'}}},
#  'df_dist_20': {'lista_eventi_scelti_intersezione_errati': {197250: {'Sentence_1': 'Ho scoperto un quartiere di botteghe senza parcheggio, di stradine a senso unico che non corrispondevano al senso di marcia da e per il lavoro.',
#     'Sentence_2': "Ho scoperto bar dove alle 6 del pomeriggio non c'è aperitivo, ma si chiude, perché alle 5 del mattino la macchina del caffè è già calda.",
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.50',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    37765: {'Sentence_1': "Ma tu così mandi all'aria la banca.",
#     'Sentence_2': 'Il signor Firbo?',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.52',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.52'},
#    13221: {'Sentence_1': 'Il buon senso si, ma la pratica no.',
#     'Sentence_2': 'Altro esempio di uomo in vantaggio sulla macchina: la macchina va su motori statistici, su considerazioni di statistica, su medie, gaussiane, normale.',
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.50',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    8397: {'Sentence_1': 'Perché noi raggiungiamo lo stato di "Flow" quando il nostro gruppo, grazie a noi, raggiunge la massima performance.',
#     'Sentence_2': 'Diventiamo vittime del potere, delle autorità, dei media.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.52',
#     'c4pred': 0,
#     'c4P': '0.52',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_corretti': {31798: {'Sentence_1': "Penso che proprio l'abbiamo inventata noi.",
#     'Sentence_2': 'Ciascuno, nel suo piccolo, o grande, può essere attivatore - attore - di cambiamento.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    134949: {'Sentence_1': 'E crea Netflix.',
#     'Sentence_2': 'Ma se io ho un\'idea e tu hai un\'idea, quando andremo via, avremo entrambi due idee."',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.50',
#     'c5pred': 1,
#     'c5P': '0.50',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    103749: {'Sentence_1': 'E questo passare oltre ha creato dei problemi non banali.',
#     'Sentence_2': "Perché un'informazione passa senza filtri, emerge e impatta sull'opinione pubblica, come abbiamo visto nel caso delle vaccinazioni ultimamente, laddove ci sono stati due approcci di comunicazione: uno vigliacco, che è quello che si mette dalla parte della cattedra e la scienza diventa sacerdozio, è quello che non dobbiamo fare, perché c'è sfiducia.",
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.50',
#     'c5pred': 1,
#     'c5P': '0.50',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    196531: {'Sentence_1': 'Vi rendete conto che se ha funzionato fino ad oggi, nella condizione e con la velocità di cambiamento che stiamo vivendo, non potrà funzionare nel futuro.',
#     'Sentence_2': "Un'azienda rigenerativa ha una vocazione che viene scritta nello Statuto.",
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.50',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {8121: {'Sentence_1': "Altro esempio: l'aborto in Italia è legale, eppure la maggior parte delle donne che vuole abortire ha difficoltà a farlo in una struttura pubblica, perché i ginecologi sono perlopiù obiettori, nelle strutture pubbliche.",
#     'Sentence_2': "La verità è che la libertà non è mai qualcosa di neutrale alla razionalità, c'è sempre un nucleo di verità condivise.",
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.50',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.51'},
#    192302: {'Sentence_1': "Il paesaggio: l'uomo ha formato il paesaggio con le sue mani!",
#     'Sentence_2': "Il paesaggio italiano, oggi noi ne abbiamo perso un bel po', ma ce n'è ancora tanto di questo paesaggio stupendo.",
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    118989: {'Sentence_1': 'E senza sapere se il Mondo, fuori, esiste ancora.',
#     'Sentence_2': 'E, prima di tutto, la certezza che, lì, o si perde o si vince tutti insieme.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.50',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    196378: {'Sentence_1': 'Dobbiamo andare oltre quei confini mentali che ci fanno pensare che le cose, le tragedie possano succedere agli altri.',
#     'Sentence_2': 'In regia video, tecnico, grafico 3D nonché coideatore di XCUBE 3D Fabio Cascione Credetemi, per noi è veramente un piacere e un onore essere qui ad aprire questo splendido appuntamento.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {147874: {'Sentence_1': 'Queste non sono caratteristiche essenziali.',
#     'Sentence_2': "Allora cos'è che è essenziale?",
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.50',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    72944: {'Sentence_1': "Devi raggiungere le isole Galapagos, tu devi raggiungere, fai te come, al più presto, quel posto, quell'isola dell'arcipelago.",
#     'Sentence_2': 'Mi giro e dice "No, ancora tempo, ancora tempo."',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.50',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.51'},
#    137494: {'Sentence_1': '", perché era da 2.000 anni che non sentivano l\'Aulos e Pittanu l\'ha ricostruito e l\'ha suonato.',
#     'Sentence_2': 'Queste sarebbero alcune delle cose che mi piacerebbe vedere realizzate in Sardegna, ma adesso vorrei chiudere la conferenza mostrandovi un altro filmato, nel quale Michele Deiana ci fa sentire una parte fondamentale del repertorio sardo, quello più importante, che è il repertorio del ballo.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.50',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    122436: {'Sentence_1': "All'angolo sinistro, signore e signori, con le sue 14 tonnellate di peso una meteora!",
#     'Sentence_2': 'Per me il numero 785, se tu mi dici: "785", io penso a un cavallo.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.50',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 0,
#     'c5P': '0.51',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.52'}}},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': {28934: {'Sentence_1': 'È stato un bello shock, anche perché ne avevamo parlato, sì, ma solo a livello di idea, non di fatto concreto.',
#     'Sentence_2': 'E io penso, e se io accetto e poi il 10 Novembre sono morta, che figura ci faccio?',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.51',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.52',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.52',
#     'c7pred': 0,
#     'c7P': '0.53',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.52',
#     'c12pred': 0,
#     'c12P': '0.51'},
#    154154: {'Sentence_1': 'Se fossimo un paese islamico, probabilmente avremmo noi la palma di questa graduatoria.',
#     'Sentence_2': "Si è salvato perché gli altri compagni l'hanno portato rapidamente all'interno dello spazio abitato e ha potuto liberarsi di questo mezzo bicchier d'acqua in cui stava l'annegando.",
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.50',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.52',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.52',
#     'c10pred': 0,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'},
#    57496: {'Sentence_1': 'Ce lo domandiamo ad ogni progetto.',
#     'Sentence_2': 'Ovvero se noi pensiamo al canto per eccellenza, che è il canto lirico, è anche chiamato il \'bel canto\', pro prio perchè sono stati selezionati i suoni "più belli" a danno di quelli "brutti".',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.52',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.52',
#     'c9pred': 0,
#     'c9P': '0.52',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.51'},
#    46179: {'Sentence_1': 'Questo ci permette di essere degli uomini e delle donne che hanno uno straordinario dono, che è quello delle emozioni.',
#     'Sentence_2': "Però, c'è un però.",
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.52',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.52',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_corretti': {165511: {'Sentence_1': 'Sapete una cosa?',
#     'Sentence_2': 'Proprio lì dentro è nato il nostro primo spettacolo: abbiamo deciso di mettere su un vero spettacolo.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.53',
#     'c10pred': 1,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    173219: {'Sentence_1': "E noi, imprenditori, dobbiamo prenderci la responsabilità del nostro ruolo, dobbiamo avere la capacità di trasmettere la visione, l'opportunità e l'anima di questo lavoro.",
#     'Sentence_2': 'Poi è vero che se tu ti butti col paracadute devi essere ottimista, perché dopo… vabbè, non entriamo in un giro che non finisce più.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.50',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.52',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.52',
#     'c10pred': 1,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    172416: {'Sentence_1': "Può essere l'ospedale: non possiamo lasciare che il cibo diventi solo un servizio alberghiero.",
#     'Sentence_2': 'Le nostre tradizioni che fanno sì che ci sia un quotidiano più frugale, ma sempre buono, e una festa che dobbiamo aspettare e attendere per poter condividere un cibo più ricco con i nostri cari.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.52',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.52',
#     'c9pred': 1,
#     'c9P': '0.52',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    27234: {'Sentence_1': 'Suonando il pianoforte.',
#     'Sentence_2': 'Quando non ho potuto - perché io ho perso tutto quello che avevo - ho immaginato, di suonare il pianoforte.',
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 0,
#     'c3P': '0.51',
#     'c4pred': 0,
#     'c4P': '0.50',
#     'c5pred': 0,
#     'c5P': '0.50',
#     'c6pred': 0,
#     'c6P': '0.51',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.50',
#     'c9pred': 0,
#     'c9P': '0.52',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 0,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {16326: {'Sentence_1': 'Milioni di occhi.',
#     'Sentence_2': 'E quando abbiamo deciso di investire nella tecnologia usando i droni, gli altri ci credevano dei folli.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.53',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    176556: {'Sentence_1': "E dall'informatica ha preso quei metodi che permettono di creare prodotti molto velocemente, facendo innovazione.",
#     'Sentence_2': 'Abbiamo fatto un Wikispeed build party cioè abbiamo costruito una macchina Wikispeed da zero.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.50',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.52',
#     'c7pred': 1,
#     'c7P': '0.53',
#     'c8pred': 1,
#     'c8P': '0.52',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 1,
#     'c11P': '0.52',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    148691: {'Sentence_1': "Sono riuscito a conquistare, nella mia carriera da velocista ancora in corso, l'ingresso nella nazionale italiana nel gruppo sportivo delle Fiamme Azzurre.",
#     'Sentence_2': 'Ce ne accorgiamo solamente quando alziamo la testa dai nostri piccoli - grandi affari personali.',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.50',
#     'c7pred': 0,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.52',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    128282: {'Sentence_1': "Io, vivendo con loro un pochino di tempo, quelle calorie giornalmente non c'erano.",
#     'Sentence_2': 'Ok, mi fermo qui che è meglio!',
#     'Class': 1,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.50',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {33259: {'Sentence_1': 'Non bastano.',
#     'Sentence_2': "Serve un'azione vigorosa dell'uomo.",
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.51',
#     'c2pred': 1,
#     'c2P': '0.52',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.53',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.50',
#     'c11pred': 0,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.51'},
#    16673: {'Sentence_1': "Quindi siamo partiti prima di tutto cercando il consenso dell'azienda senza parlare di metodologia agile, di dettagli implementativi, che fanno sempre paura, ma concentrandoci, focalizzandoci sul 'perché' di questo cambiamento, sui risultati concreti per l'azienda, senza parlare di rivoluzione perché anche questa fa paura.",
#     'Sentence_2': 'La rivoluzione lascia sempre morti in piazza.',
#     'Class': 0,
#     'c1pred': 0,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.50',
#     'c8pred': 1,
#     'c8P': '0.51',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 1,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.51',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    67743: {'Sentence_1': 'Insomma, possiamo proprio dire, con buona pace di Bill Joy, che in realtà il futuro non ha mai avuto così tanto bisogno di noi.',
#     'Sentence_2': 'Beh, voglio iniziare con una domanda: quanti di voi pensano di usare tanto il proprio cellulare?',
#     'Class': 0,
#     'c1pred': 1,
#     'c1P': '0.50',
#     'c2pred': 1,
#     'c2P': '0.50',
#     'c3pred': 1,
#     'c3P': '0.51',
#     'c4pred': 1,
#     'c4P': '0.51',
#     'c5pred': 1,
#     'c5P': '0.51',
#     'c6pred': 1,
#     'c6P': '0.51',
#     'c7pred': 1,
#     'c7P': '0.51',
#     'c8pred': 1,
#     'c8P': '0.50',
#     'c9pred': 1,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 1,
#     'c11P': '0.50',
#     'c12pred': 1,
#     'c12P': '0.50'},
#    17282: {'Sentence_1': 'Allora, facciamo un passo indietro, andiamo nel 2009.',
#     'Sentence_2': 'È stato reinventato.',
#     'Class': 1,
#     'c1pred': 0,
#     'c1P': '0.52',
#     'c2pred': 0,
#     'c2P': '0.51',
#     'c3pred': 1,
#     'c3P': '0.50',
#     'c4pred': 0,
#     'c4P': '0.51',
#     'c5pred': 0,
#     'c5P': '0.53',
#     'c6pred': 0,
#     'c6P': '0.52',
#     'c7pred': 0,
#     'c7P': '0.51',
#     'c8pred': 0,
#     'c8P': '0.51',
#     'c9pred': 0,
#     'c9P': '0.51',
#     'c10pred': 0,
#     'c10P': '0.51',
#     'c11pred': 0,
#     'c11P': '0.51',
#     'c12pred': 0,
#     'c12P': '0.51'}}}}

# %%
diz_confronti_incrociati_bert
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': {5575: {'Sentence_1': 'Nello specifico lui dice: mi ha raccontato questa storia che poi non ha più raccontato negli ultimi 20 anni per cui la socializzo con voi, però lui non la racconta più Come funziona il cervello.',
#     'Sentence_2': "Secondo voi cos'è successo?",
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.56',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.65',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.56',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.85',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.94'},
#    2359: {'Sentence_1': 'Rinforzate le parti bianche!',
#     'Sentence_2': 'Certo, perché gli aerei che sono rientrati sono stati colpiti, ma probabilmente sono stati colpiti in quei punti che non sono necessari per volare.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.70',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.89',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 1,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    11908: {'Sentence_1': 'Il mapathon vuol dire trovarsi tutti in un posto, ognuno con un computer, perché questa è la cosa fondamentale, per mappare tutti insieme.',
#     'Sentence_2': 'Ci siamo trovati in tanti, abbiamo imparato come mappare tutti insieme e abbiamo contribuito anche noi a creare la mappa che è servita a tutti i volontari sul posto per poter intervenire.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.87',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.81',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.95',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    150821: {'Sentence_1': 'Il legno, certo.',
#     'Sentence_2': "Potremmo definirlo quasi l'eroe nascosto della civilizzazione.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.58',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.80',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.88',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.67',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.98'}},
#   'lista_eventi_scelti_intersezione_corretti': {162611: {'Sentence_1': 'Occorre lavorarci tanto.',
#     'Sentence_2': 'È quello che io chiamo "bisogna essere contadini della lingua".',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.91',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.80',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.95',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.74',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.92'},
#    58238: {'Sentence_1': "Sono le donne che possono far aumentare l'occupazione.",
#     'Sentence_2': 'Sono le donne che possono aumentare la sostenibilità del welfare, e sono le donne che possono far crescere il paese, in termini di popolazione.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.95',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.96',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    74052: {'Sentence_1': 'Ve le elenco molto brevemente.',
#     'Sentence_2': 'El Douli è un trafficante.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.59',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.54',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.74',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.96',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.99'},
#    125450: {'Sentence_1': 'In queste zone è sparito completamente, sono rimaste alcune raffigurazioni, ma nessun strumento.',
#     'Sentence_2': "L'unico posto dove questo strumento è sopravvissuto è la Sardegna!",
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.80',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.96',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {138986: {'Sentence_1': 'Mi dicono che in teatro ci sono circa 800 persone, per cui siete attorno al 10 - 15%.',
#     'Sentence_2': 'Perché non 50 e 50?',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.51',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.52',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.69',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.95',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.94'},
#    141297: {'Sentence_1': "Questo è un progetto degli anni '60, l'Archigram, che ancora oggi compagnie spaziali come Bigelow Aerospace, che sta sviluppando questo modulo abitativo, il v330, che avrà la possibilità di contenere 330 metri cubi di volume abitabile.",
#     'Sentence_2': 'Interamente gonfiabile.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.55',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.79',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.72',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.94',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.98'},
#    111028: {'Sentence_1': 'E questo lo vediamo - ci sono anche diverse ditte che lo usano anche per motivare i propri dipendenti.',
#     'Sentence_2': "E i videogiochi, già dalla fine degli anni '80, sono sempre stati considerati come un hobby violento e non adatto ai bambini.",
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.58',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.62',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.57',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.97',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.81'},
#    99619: {'Sentence_1': "L'Amiga invece era una macchina multimediale a tutto tondo.",
#     'Sentence_2': 'Ma anche altri campi, come la realtà virtuale.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.56',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.76',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.64',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.98'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {55291: {'Sentence_1': 'La tecnologia è neutra, quando nasce.',
#     'Sentence_2': 'Siamo noi che decidiamo come applicarla al mondo reale.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.62',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.65',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.94',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.95'},
#    182248: {'Sentence_1': 'Sapendo quello che sta succedendo in questo mondo, nel nostro settore, andiamo in ufficio pensando che possiamo veramente cambiare il mondo.',
#     'Sentence_2': 'E quindi ci siamo intestarditi, abbiamo detto un miliardo e duecento milioni di persone senza elettricità non va bene, facciamo qualche cosa.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.54',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.54',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.92',
#     'Epoch3pred': 1,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.84'},
#    109227: {'Sentence_1': 'Ora, almeno cinque di queste possono essere tranquillamente allenate e sviluppate nel momento in cui io abito in un Paese diverso.',
#     'Sentence_2': 'Mi concentro solo sul primo, Il complex problem solving.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.53',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.52',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.61',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.75',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.56'},
#    112027: {'Sentence_1': 'Tieniti forte, mancano solo altri 180 km.',
#     'Sentence_2': 'Nonostante questo pesante pensiero ero determinato a finire e non importava come, a dire la verità.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.51',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.54',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.70',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.89',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.69'}}},
#  'df_dist_10': {'lista_eventi_scelti_intersezione_errati': {85068: {'Sentence_1': "1827, Joseph Niepce, scopre ed inventa un procedimento che regala all'umanità la prima immagine fotografica della storia.",
#     'Sentence_2': '1930, la Leica commercializza la prima macchina fotografica portatile, ed ora la fotografia può arrivare ovunque: per le strade, e in trincea.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.77',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.92',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.98',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    62092: {'Sentence_1': 'Cosa succederebbe se noi fossimo capaci in qualche modo di decodificare questo codice neurale?',
#     'Sentence_2': "È qui che nascono le interfacce cervello - macchina: Da un'idea tanto semplice, quanto difficile da realizzare.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.64',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.76',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.97',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.94',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.98'},
#    3558: {'Sentence_1': "Le mie sorelle ed io gestiamo un'azienda agricola.",
#     'Sentence_2': "Abbiamo sempre fatto anche dell'altro, e questo forse ci conferisce un'attitudine a cercare di rompere gli schemi classici della produzione, a provare a cambiare.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.63',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.71',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.97',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    107738: {'Sentence_1': 'In effetti, in esso vi è melodia, armonia, ritmo, nonché contrappunto e tutta una congerie di elementi che hanno portato i sardi a chiamarlo "concerto", perché c\'è tutto, non manca nulla.',
#     'Sentence_2': 'Tutti gli strumenti, messi insieme, sono un complesso di 87 strumenti.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.74',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.82',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'}},
#   'lista_eventi_scelti_intersezione_corretti': {179788: {'Sentence_1': '"Se prendi un diploma, studi, trovi lavoro".',
#     'Sentence_2': '"Se ti laurei, ancora di più, probabilmente."',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.90',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.99',
#     'Epoch2pred': 0,
#     'Epoch2P': '1.00',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    138432: {'Sentence_1': 'Voi ve lo ricordate uno dei vostri primi giorni di scuola?',
#     'Sentence_2': 'Quando si rincontrano gli amici, ci si racconta di come sono state le vacanze, delle belle giornate, no?',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.53',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.80',
#     'Epoch2pred': 0,
#     'Epoch2P': '1.00',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    195781: {'Sentence_1': 'Ragazzi: Porca miseria, iniziamo bene!',
#     'Sentence_2': "Il metodo di guida che abbiamo sviluppato negli anni è piuttosto complesso e si basa fondamentalmente sul quadrante dell'orologio per muovere le mani, mentre per i piedi utilizziamo anche le parti del corpo.",
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.66',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.88',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.97',
#     'Epoch3pred': 1,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    61874: {'Sentence_1': 'Ma alla fine, chi ci dà le risposte giuste siamo solamente noi.',
#     'Sentence_2': "E da là l'ho guardata e le ho detto: Pia, facciamo qualcosa insieme?",
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.78',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.92',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 1,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {78220: {'Sentence_1': 'Oggi sembrano fronteggiarsi due tipi di pensiero.',
#     'Sentence_2': 'Ogni tanto, penso che il problema sia che sono un ingegnere: e gli ingegneri, di solito, sono persone molto organizzate.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.53',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.55',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.59',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.57',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.98'},
#    1171: {'Sentence_1': "Sono diversi dalla proprietà privata e anche dalla proprietà pubblica tanto che il giudice della Corte Costituzionale, Paolo Grossi, gli ha definiti: 'un altro modo di possedere', proprio perché fanno riferimento a una specifica forma di legge e sono tutelati come beni ambientali.",
#     'Sentence_2': 'I proprietari sono le comunità a cui sono intestati i beni.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.62',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.81',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.97',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.97',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.97'},
#    71616: {'Sentence_1': 'Quindi la blockchain non ha soltanto il potere di pilotare le nostre decisioni nel modo giusto, ma anche il potere di costringere ancora di più chi è più selfish e più attento al valore economico di quello che fa.',
#     'Sentence_2': 'Perché nella nostra blockchain dobbiamo sempre essere liberi di avere il cervo davanti, abbassare il fucile e non sparargli.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.76',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.52',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.98',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.68',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.61'},
#    17892: {'Sentence_1': "Ma sul vostro letto c'è la vostra doccia che sta saltellando come un bimbo di cinque anni e vi sta imbrattando la cameretta di acqua.",
#     'Sentence_2': 'Bene, aprite gli occhi.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.54',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.59',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.96',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {152982: {'Sentence_1': "Questo è quello che c'è alla nanoscala.",
#     'Sentence_2': 'E questo è quello che ci dobbiamo ricordare quando entriamo in questo uragano di passione che per riprendere quel discorso musicale bellissimo che abbiamo visto in giornata ricorda quel "Like a hurricane" di Neil Young in una storia d\'amore incredibile, che è come un uragano, che ti permea e non ti lascia più.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.58',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.60',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.77',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.97',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.51'},
#    126332: {'Sentence_1': "All'interno di questi deserti, come abbiamo ben capito questa mattina, ci sono delle popolazioni che hanno trovato un modo di vita compatibile con quell'ecosistema piuttosto avaro.",
#     'Sentence_2': 'Una è una mappa.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.69',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.80',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.90',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.73',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.92'},
#    26147: {'Sentence_1': 'O che fosse normale che le donne non potessero votare alle elezioni: guardate, è stato normale nel nostro civilissimo paese fino al dopoguerra!',
#     'Sentence_2': 'Poi, a un certo punto, qualcuno ha detto: basta.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.61',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.65',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.94',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.98'},
#    127824: {'Sentence_1': "Ci siamo messi - abbiamo scritto uno statuto in cui scrivevamo che lo scopo di Nativa era di essere un'azienda rigeneratrice.",
#     'Sentence_2': 'Andare oltre questo concetto di profit.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.73',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.51',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.62',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.91',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.64'}}},
#  'df_dist_20': {'lista_eventi_scelti_intersezione_errati': {189569: {'Sentence_1': 'Questo è un primo esempio delle innovazioni portate da questa grande rivoluzione.',
#     'Sentence_2': "Usando una sostanza nuova, già usata dall'industria alimentare, che si chiama alginato di sodio, prepara queste palline che sono morbide e gommose all'esterno e ripiene di un gustosissimo succo di limone concentrato all'interno.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.66',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.64',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.57',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.90',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    96616: {'Sentence_1': 'Trasformazione che deve passare anche per la trasformazione dei processi e per la trasformazione digitale della Pubblica Amministrazione.',
#     'Sentence_2': "Mi chiede 'perché non ci vieni ad aiutare l'Italia per un paio d'anni? ' ci penso, ci rifletto, Ne parlo ovviamente con mia moglie Monica e parlo col mio capo, Jeff Bezos.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.61',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.81',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.95',
#     'Epoch3pred': 1,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    112751: {'Sentence_1': 'Ecco, comprendere le informazioni e poter così accedere ai servizi rappresenta il primo passo per un progressivo processo di integrazione e di inclusione sociale.',
#     'Sentence_2': 'Per iniziare a sentirsi parte, soprattutto nelle città, perché è nelle città che gran parte degli immigrati, quando ha la possibilità di scegliere, risiede, preferisce risiedere.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.86',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.71',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.76',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.95',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    115285: {'Sentence_1': 'Ma, tornando a noi, inizia ad esserci un via vai di pensieri e di domande nella mia mente: la prima che mi faccio è: "Ma cosa faccio se un giorno mi arriva con un bozzetto, magari costituito da due linee veloci, e mi chiede di realizzare quello che vedo? ".',
#     'Sentence_2': 'O peggio ancora, se mi fermasse per ore e ore a discutere del tono di colore troppo o troppo poco brillante.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.79',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.77',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.58',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.99'}},
#   'lista_eventi_scelti_intersezione_corretti': {7206: {'Sentence_1': "Poi c'è l'orario aperitivo, quindi chiama un drone per fare una foto del drink da sopra, poi un po' di lato, poi a 360°.",
#     'Sentence_2': "Non avevo soldi, avevo tantissima paura, avevo un'idea ma ero la sola a crederci.",
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.85',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.86',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.98',
#     'Epoch3pred': 1,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    86881: {'Sentence_1': 'Da Virginia Woolf a Emily Dickinson ad Anna Frank, al suo diario, ad Hannah Arendt, a Luce Irigaray, a Melania Mazzucco e tante altre.',
#     'Sentence_2': "Sono siti molto importanti, nella storia e nella costruzione dell'identità dei territori e dei paesaggi.",
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.84',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.62',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.87',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.97',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    40916: {'Sentence_1': 'Bene, voi direte: "Questo è un problema che tanti hanno avuto, le stelle il sole, qualche trucchetto per orientarsi in mare l\'uomo l\'ha sempre usato."',
#     'Sentence_2': 'Secondo Banca Italia, le rimesse negli ultimi 10 anni hanno più che raddoppiato il valore della finanziaria del 2016: 64 miliardi.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.66',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.79',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.90',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.97',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    109205: {'Sentence_1': 'La prima cosa che emerge agli occhi è sicuramente il colore.',
#     'Sentence_2': 'Lo spazio è ispirazione, quindi noi attiriamo le menti migliori, le confrontiamo con sfide di questo tipo, e produciamo tecnologie e scienza a protezione della nostra Terra e della nostra vita su di essa.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.85',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.86',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.86',
#     'Epoch3pred': 1,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.99'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {110963: {'Sentence_1': 'Allora io mi sono divertito a ridefinire le età della vita, ne "L\'arte di essere fragili", a partire proprio da questo elemento.',
#     'Sentence_2': "È invalsa ormai quest'idea che le tappe della vita siano su una linea retta: c'è un inizio e poi, per un principio quasi inerziale, arriveremo ai titoli di coda.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.78',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.84',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.66',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.88',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.98'},
#    64979: {'Sentence_1': 'Se noi scendiamo ancora un pochino arriviamo in Anatolia, tornando indietro lungo la strada percorsa delle antenate di mia madre.',
#     'Sentence_2': 'Arriviamo in Anatolia, in Turchia, nella parte meridionale, quasi al confine con la Siria, oggi teatro di guerre tremende, e arriviamo a Göbekli Tepe.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.79',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.96',
#     'Epoch2pred': 0,
#     'Epoch2P': '1.00',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    113747: {'Sentence_1': 'Anche questa non vorrei metterla in termini moralistici.',
#     'Sentence_2': 'Io ho sempre amato lo sport, mi piace competere.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.58',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.73',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.90',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.80',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.91'},
#    165652: {'Sentence_1': 'Perché no?',
#     'Sentence_2': 'È il 2000, e il leggendario programmatore della Silicon Valley Bill Joy scrive un editoriale su Wired dal titolo abbastanza eloquente: "Il futuro non ha bisogno di noi".',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.76',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.70',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.62',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.54',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.96'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {135160: {'Sentence_1': 'Poso il telefono, corro al citofono.',
#     'Sentence_2': '"È l\'idea", penso.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.51',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.79',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.64',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    978: {'Sentence_1': 'Io arrivo dal mondo della sharing economy, non ho studiato né ingegneria, né scienza: ho studiato economia, e poi ho fatto marketing.',
#     'Sentence_2': 'Arrivo in India, vivo a Mumbai qualche mese e lì sento, per la prima volta, parlare di blockchain, che sinceramente io prima non conoscevo.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.79',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.94',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    90879: {'Sentence_1': "Siamo cresciuti, e noi stessi l'abbiamo insegnato ai nostri studenti, un modello di impresa molto calligrafico, un po' come Piero della Francesca che introdusse la prospettiva.",
#     'Sentence_2': 'Una sintesi di vuoti e di pieni, di uomo e di macchina, di chiari e di scuri, è un disegno e un progetto bellissimo.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.73',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.73',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.93',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.93'},
#    22965: {'Sentence_1': 'Chi invece riesce a rispondere non solo ha valorizzato il proprio tempo, ma probabilmente ha anche trovato la felicità.',
#     'Sentence_2': 'Il contrario è stare fermi.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.62',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.78',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.96',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.90',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.82'}}},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': {181717: {'Sentence_1': "'Frocio' non si doveva dire neanche negli anni '80.",
#     'Sentence_2': "Così come 'negro', così come 'puttana'.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.66',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.56',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.95',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.98',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    55700: {'Sentence_1': 'Sicuramente non si rifiuta.',
#     'Sentence_2': 'Il Commendatore, dunque, non ha bisogno di tornare in scena per far sprofondare il libertino agli inferi.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.78',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.68',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.99',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    70561: {'Sentence_1': 'Noi, oggi, ci fidiamo di quello che sta succedendo e di quello che ci protegge nel virtuale.',
#     'Sentence_2': 'Son passati due anni in cui sono successe tantissime cose.',
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.61',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.72',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.59',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.97',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.99'},
#    199643: {'Sentence_1': 'Ma la risorsa era solo quella della squadra, delle persone che avevano intuito questo progetto e veramente ha funzionato.',
#     'Sentence_2': "Cioè, il team a terra diceva: 'Adesso il pilota automatico non funziona.",
#     'Class': 1,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.79',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.82',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.96',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'}},
#   'lista_eventi_scelti_intersezione_corretti': {183968: {'Sentence_1': 'Io ho avuto la grande fortuna di vivere questi sogni.',
#     'Sentence_2': 'Non è vero che loro sono abituati a non bere, sono come noi.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.70',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.82',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.98',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 1,
#     'Epoch4P': '1.00'},
#    128096: {'Sentence_1': 'Uno dei vantaggi essenziali del crowd - funding è che, oltre a permettere ai giovani editori di produrre autononomamente i propri libri sfruttando canali Internet consolidati ed autorevoli, consente di avere immediatamente una diffusione mondiale.',
#     'Sentence_2': "Infatti sono molto felice del fatto che il mio crowd - funding sia finito molto prima del previsto, in quanto ho raggiunto l'obiettivo con un mese d'anticipo rispetto ai tre che avevo preventivato.",
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.87',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.83',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.94',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.99'},
#    73173: {'Sentence_1': 'Oggi noi abbiamo raggiunto 200 transazioni immobiliari, abbiamo concluso circa 200 transazioni immobiliari, quindi il dato è già aumentato rispetto a quello che vi hanno introdotto.',
#     'Sentence_2': 'Siamo ormai a un rate di circa 30, 40 acquisizioni al mese; e cresciamo in modo esponenziale.',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.93',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.94',
#     'Epoch2pred': 0,
#     'Epoch2P': '1.00',
#     'Epoch3pred': 0,
#     'Epoch3P': '1.00',
#     'Epoch4pred': 0,
#     'Epoch4P': '1.00'},
#    160255: {'Sentence_1': "Da un'academy aziendale, insieme all'università.",
#     'Sentence_2': 'Ma l\'iniziativa che più ci riempie di orgoglio è un corso di laurea dal titolo "Innovation and Technology Management".',
#     'Class': 0,
#     'Epoch0pred': 0,
#     'Epoch0P': '0.60',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.90',
#     'Epoch2pred': 0,
#     'Epoch2P': '1.00',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.99',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.99'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {40860: {'Sentence_1': 'Quando il corpo inizia a dolerci e dolerci, smonta di turno alla chetichella, è schifiltosa, non le piace vederci tra la folla.',
#     'Sentence_2': 'Metteva sempre un maglione con i buchi, dei pantaloni lisi, e dei sandali senza calze.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.72',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.82',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.79',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.50',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.97'},
#    119278: {'Sentence_1': "Questo è un grafico che è tratto dal primo D.E.F dell'attuale governo, del governo quindi a maggioranza Grillina e Lega.",
#     'Sentence_2': 'Cominciamo a partire dai numeri: gli italiani sono convinti che una persona su quattro che vive nel nostro paese sia immigrata.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.61',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.61',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.63',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.67',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.95'},
#    10648: {'Sentence_1': 'La frontiera tecnologica è rappresentata dal Deep Learning, cioè apprendimento profondo.',
#     'Sentence_2': 'Perché chi cambia idea, in seguito a esperienze di vita, in seguito a riflessioni, è prima visto come inconsistente che saggio?',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.53',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.52',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.93',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.98',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.82'},
#    176554: {'Sentence_1': "Solo che c'è una differenza: l'alce irlandese non si è accorta che si stava estinguendo; noi invece abbiamo tutti gli strumenti per accorgerci che possiamo esserci infilati in una trappola evolutiva, e che quindi sarebbe bene uscirne il prima possibile.",
#     'Sentence_2': 'Qui vedete il primo pozzo di 130 metri, una voragine profondissima; arriva a quasi 900 metri di profondità sotto la superficie della Terra, ha uno sviluppo attualmente rilevato, conosciuto, di circa 8 km.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.50',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.50',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.76',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.70',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.80'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {105200: {'Sentence_1': 'Semplici, piccoli e leggeri, decisamente meno costosi di qualsiasi prototipo di robot.',
#     'Sentence_2': 'Il vero problema è legato alla mancanza di norme e regole.',
#     'Class': 1,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.53',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.78',
#     'Epoch2pred': 0,
#     'Epoch2P': '0.65',
#     'Epoch3pred': 0,
#     'Epoch3P': '0.92',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.69'},
#    71534: {'Sentence_1': 'Entrambi esseri senzienti, entrambi con lo stesso spirito di vita, entrambi con gli stessi desideri.',
#     'Sentence_2': "Solo che i primi, gli umani, sarebbero usciti, come spesso Gorgona rappresenta l'ultima tappa del cammino detentivo, mentre i secondi, i non umani, sarebbero rimasti e poi usciti quasi sempre sotto forma di pezzi dei loro corpi o di trasformazioni delle loro secrezioni come appunto il formaggio.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.52',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.70',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.79',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.86',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.95'},
#    16595: {'Sentence_1': 'E mi interessa che abbia trovato un senso alla propria vita e alla propria morte.',
#     'Sentence_2': 'La ricerca continua.',
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.65',
#     'Epoch1pred': 1,
#     'Epoch1P': '0.78',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.76',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.58',
#     'Epoch4pred': 0,
#     'Epoch4P': '0.57'},
#    182283: {'Sentence_1': "Dalle automobili senza conducente alla medicina a livello cellulare, cioè diretta alla singola cellula malata, o all'agricoltura di precisione, dove quindi, passando il trattore o il drone, misura pianta per pianta e addirittura foglia per foglia, per vedere se ha bisogno di un po' più d'acqua, un po' più di pesticida, un po' più di fertilizzante, con un chiaro beneficio per l'ambiente invece che spruzzare tutto in modo indiscriminato.",
#     'Sentence_2': "Il fatto che noi si dipenda sempre di più dall'intelligenza artificiale per dare un senso a questa mole di dati, vuol dire che c'è, già oggi, una grossa competizione a livello globale.",
#     'Class': 0,
#     'Epoch0pred': 1,
#     'Epoch0P': '0.60',
#     'Epoch1pred': 0,
#     'Epoch1P': '0.51',
#     'Epoch2pred': 1,
#     'Epoch2P': '0.86',
#     'Epoch3pred': 1,
#     'Epoch3P': '0.95',
#     'Epoch4pred': 1,
#     'Epoch4P': '0.89'}}}}

# %% [markdown]
# # Indici di leggibilità

# %% [markdown]
# Calcoliamo l'indice di leggibilità delle frasi che sono state selezionate, e solo per i dataset considerati per le osservazioni (distanza 5, 30 e random_speech, se presente)

# %%
import textstat

# %% [markdown]
# https://pypi.org/project/textstat/
#
# **flesch_reading_ease** support italian In the Flesch reading-ease test, higher scores indicate material that is easier to read; lower numbers mark passages that are more difficult to read.
#
# **Gulpease Index (Italian)** Language Specific Formulas Returns the Gulpease index of Italian text, which translates to level of education completed. Lower scores require higher level of education to read with ease.

# %%
file_svm_to_read = open(path_diz_res+"diz_tabella_total_svm.pickle", "rb")
tabella_svm = pickle.load(file_svm_to_read)

file_bert_to_read = open(path_diz_res+"diz_tabella_total_bert.pickle", "rb")
tabella_bert = pickle.load(file_bert_to_read)

# %%
distanze_considerate = ['df_dist_5', 'df_dist_30', 'df_random_speech']

# %%
tabella_svm
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': {228695: {'Sentence_1': 'Il più comprende il meno, seppur fosse discutibile la questione che pongo.',
#     'Sentence_2': "Accogliendo il mio subemendamento si andrebbe ad inserire, rispetto ai soggetti indiziati del delitto di cui all'articolo 416 del codice penale, finalizzato alla commissione di taluno dei delitti di cui agli articoli 314, primo comma, 316, eccetera eccetera, anche l'articolo 640 - bis.",
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.52',
#     'clf_2P': '0.52',
#     'clf_3P': '0.50',
#     'clf_4P': '0.50',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.53',
#     'clf_12P': '0.51'},
#    195285: {'Sentence_1': "Passiamo all'emendamento 13.0.13, su cui la 5ᵃ Commissione ha espresso parere contrario ai sensi dell'articolo 81 della Costituzione.",
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.51',
#     'clf_3P': '0.50',
#     'clf_4P': '0.50',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.50',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.51'}},
#   'lista_eventi_scelti_intersezione_corretti': {518453: {'Sentence_1': "Nei mari adiacenti, per il contrasto al fenomeno della pirateria, l'Italia partecipa alla missione europea Atalanta, con 2 mezzi navali, 2 aerei e un numero massimo di 407 unità di personale.",
#     'Sentence_2': "Per tutte le missioni già in atto, la proroga è fino al 31 dicembre e, per ogni missione, la relazione analitica riporta, come previsto dalla legge, due schede: la prima con il resoconto di quanto si è fatto nel 2018; la seconda con le risorse e gli assetti per l'anno in corso.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.50',
#     'clf_3P': '0.50',
#     'clf_4P': '0.51',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.50',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'},
#    464910: {'Sentence_1': 'È cosa ben strana che si registri un dibattito sulla legge principale, che è la legge di stabilità, e non si senta la maggioranza difendere il Governo.',
#     'Sentence_2': "Non capisco se questo è dovuto al tentativo di anticipare quanto prima - saranno contenti loro - l'incardinamento della legge elettorale, o se, invece, è perché hanno serie difficoltà a difendere il Governo e a parlare bene della legge di stabilità.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.51',
#     'clf_3P': '0.50',
#     'clf_4P': '0.51',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.50',
#     'clf_12P': '0.50'},
#    537330: {'Sentence_1': "Con molta difficoltà avevamo erogato - e ribadiamo il nostro parere assolutamente contrario in proposito - ben 120 milioni di euro a otto Fondazioni lirico sinfoniche d'Italia indebitate per cattiva gestione dei loro consigli d'amministrazione, diretta emanazione dei Comuni e delle Province, secondo le compartecipazioni.",
#     'Sentence_2': 'La più indebitata, guarda caso, era quella del Maggio musicale fiorentino, per cui si è fatta anche la norma, è chiaro, infatti, che si doveva poi soddisfare le esigenze di tutti.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.52',
#     'clf_3P': '0.50',
#     'clf_4P': '0.50',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.50',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'},
#    414778: {'Sentence_1': 'Signor Presidente, pur non avendo seguito specificamente il problema, quando qualche giorno fa è apparso chiaramente che in Assemblea i tempi non erano maturi se si voleva arrivare a una mozione condivisa anche con il Governo sul Venezuela, ho avanzato la proposta di sospendere il dibattito per un tempo - in quel caso fino a martedì - sufficiente per arrivare a una soluzione soddisfacente.',
#     'Sentence_2': 'E così è avvenuto, perché nel frattempo i contrasti di quel giorno si sono stemperati.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.52',
#     'clf_3P': '0.50',
#     'clf_4P': '0.51',
#     'clf_5P': '0.50',
#     'clf_6P': '0.50',
#     'clf_7P': '0.50',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {5733: {'Sentence_1': 'Su questo ci dovete rispondere.',
#     'Sentence_2': "Come si fa a prendere come riferimento, per esempio, qualche altro Paese europeo che utilizza il meccanismo di elezione indiretta di una Camera, ma che nell'altro ramo del Parlamento utilizza il sistema proporzionale senza sbarramenti o comunque senza i premi di maggioranza che sono previsti dal nostro ordinamento?",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.52'},
#    557954: {'Sentence_1': 'Mi spiego.',
#     'Sentence_2': 'Noi invece non abbiamo voluto osare, il Governo non ha voluto osare e ci ritroviamo con questa proposta che secondo me è assolutamente asfittica.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.50'},
#    368710: {'Sentence_1': "D'altra parte, ne abbiamo ratificati tanti in quest'Aula nel corso degli anni e già questa mattina.",
#     'Sentence_2': "Ho preso appunti e abbiamo, infatti, già ratificato lo stesso tipo di accordo con la Colombia, con la Giamaica e con l'Uruguay.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.51',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 0,
#     'c4P': '0.50',
#     'c5pr': 0,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 0,
#     'c7P': '0.50',
#     'c8pr': 0,
#     'c8P': '0.50',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 0,
#     'c12P': '0.50'},
#    45684: {'Sentence_1': "All'AIFA spetta, inoltre, il mantenimento dell'equilibrio economico relativo al tetto fissato per la spesa farmaceutica convenzionata e ospedaliera - come ha puntualmente evidenziato il senatore Barani - che governa tramite l'applicazione di opportune misure di ripiano nel caso di sforamento, come il cosiddetto pay back - che esiste da qualche anno - e l'incentivazione all'impiego di medicinali equivalenti, cioè i generici.",
#     'Sentence_2': "In tal senso, le attività dell'AIFA, per quanto attiene all'ambito regolatorio, sono sicuramente - mi permetterei di segnalarlo - coerenti con l'assetto normativo comunitario e nazionale.",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.52',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {124516: {'Sentence_1': "Tempo fa, sul quotidiano «Corriere della sera» Celentano scrisse difendendo il diritto d'autore, in quel caso della musica, sostenendo che «Se non si pagasse più il pane non ci sarebbero più i fornai», perché nessuno farebbe il pane se fosse gratis.",
#     'Sentence_2': 'Celentano lo diceva per la musica: se la musica viene rubata - presa gratis - sul web, gli autori non hanno remunerazione.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    260309: {'Sentence_1': "Ciò porterà anche a prevedere il doppio turno: penso ad esempio al ballottaggio nel caso dell'Italicum, per come è stato approvato in Parlamento; infatti, per quanto si possa immaginare di modificare quella legge, allo stato attuale abbiamo una situazione in cui sicuramente potremo avere non solo un primo turno, ma anche un secondo turno alle elezioni politiche, oltre che consultazioni regionali ed europee.",
#     'Sentence_2': "L'esigenza di coinvolgere il corpo elettorale è quindi molto presente, ma non di meno abbiamo l'esigenza di dare continuità scolastica e possibilità agli studenti di continuare regolarmente il loro corso di studi senza ripetute interruzioni.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    440791: {'Sentence_1': 'Ogni giorno che si ritarda sono 2 milioni in più che il contribuente, attraverso i pedaggi autostradali, conferisce a queste società.',
#     'Sentence_2': "È giusto che guadagnino, ma questo guadagno potrebbe essere assottigliato a beneficio o dello Stato o dell'utente automobilista.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    50850: {'Sentence_1': 'Fin dal mio insediamento, ho insistito su un concetto: le norme, anche le migliori, non bastano se non sono sostenute da misure organizzative.',
#     'Sentence_2': "Proprio il processo di globalizzazione, l'introduzione di nuove tecnologie in tutti i settori della vita umana, fa sì che il fattore tempo divenga un dato ancora più essenziale.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.50'}}},
#  'df_dist_10': {'lista_eventi_scelti_intersezione_errati': {401691: {'Sentence_1': "Forse bisognerebbe iscriverle in qualche modo a una specie - non so se esiste - di rassegna del cinema di fantasia Infatti, ci ritroviamo ormai regolarmente ad approvare un DEF con valutazioni, dati e previsioni assolutamente sovrastimate e con la puntuale Nota di aggiornamento che corregge i dati e le speranze di crescita, ma nei fatti, così come nella Nota all'ordine del giorno, in realtà si continua sulla stessa strada.",
#     'Sentence_2': 'La chiave di tutto, è inutile che ci giriamo intorno, è evidentemente questa.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.52',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.52',
#     'clf_6P': '0.54',
#     'clf_7P': '0.51',
#     'clf_8P': '0.50',
#     'clf_9P': '0.52',
#     'clf_10P': '0.51',
#     'clf_11P': '0.52',
#     'clf_12P': '0.51'},
#    792573: {'Sentence_1': "Anche a causa di impedimenti e vincoli previsti dal regolamento comunale sulla pubblicità, l'iniziativa non ha trovato adesioni, ad eccezione di un'unica offerta di contributo di circa 60.000 euro.",
#     'Sentence_2': 'Infine, con riferimento agli eventuali aspetti penali della vicenda, il Ministero della giustizia ha comunicato che la procura della Repubblica di Firenze ha delegato alla Guardia di finanza gli accertamenti preliminari tesi a stabilire la sussistenza o meno di reati.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.50',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.52',
#     'clf_6P': '0.52',
#     'clf_7P': '0.52',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.52',
#     'clf_12P': '0.51'},
#    425573: {'Sentence_1': 'Abbiamo trasferito 59 pazienti in terapia intensiva dalla Lombardia in altre Regioni italiane, in ragione di una convenzione, che esisteva già, presso la Protezione civile, che si chiama Cross e che abbiamo reso più stringente e vincolante.',
#     'Sentence_2': 'Abbiamo riconvertito 78 ospedali in Covid Hospitalegge Abbiamo e stiamo lavorando tanto per i dispositivi di protezione individuale: anche qui il mercato è quello che è, ma stiamo riconvertendo tutte le nostre filiere interne, per incrementare la produzione.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.50',
#     'clf_2P': '0.51',
#     'clf_3P': '0.52',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.51',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.50',
#     'clf_11P': '0.51',
#     'clf_12P': '0.52'},
#    493852: {'Sentence_1': "Anche in quest'Aula io ho raccontato come, in una discussione anche con il Presidente del Consiglio, siamo arrivati alla scelta del ruolo unico, che è la scelta di una dirigenza autonoma e indipendente dalla politica e che quindi rispetta non solo formalmente, ma sostanzialmente l'articolo 97 della nostra Costituzione.",
#     'Sentence_2': 'Termino con la vera sfida di questa riforma, che certamente è approvare questo disegno di legge in via definitiva nei diversi rami del Parlamento, ma soprattutto attuarla.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.52',
#     'clf_8P': '0.52',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.50',
#     'clf_12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_corretti': {462203: {'Sentence_1': 'Signora Presidente, io sono rimasto colpito.',
#     'Sentence_2': 'Non se vi ricordate il vecchio film «1997: Fuga da New York», con il personaggio di Jena Plissken, con il muro che divide un mondo da un altro.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.53',
#     'clf_2P': '0.51',
#     'clf_3P': '0.52',
#     'clf_4P': '0.53',
#     'clf_5P': '0.53',
#     'clf_6P': '0.55',
#     'clf_7P': '0.54',
#     'clf_8P': '0.53',
#     'clf_9P': '0.52',
#     'clf_10P': '0.54',
#     'clf_11P': '0.51',
#     'clf_12P': '0.51'},
#    828348: {'Sentence_1': 'Signor Ministro, le dico, anche se molto brevemente, che io ho molto apprezzato il suo richiamo iniziale al rispetto dello Stato di diritto, anche in materia di terrorismo.',
#     'Sentence_2': "Non devo ricordarle che all'epoca del terrorismo molti di noi hanno garantito due cose: rispetto dello Stato di diritto, ma anche l'applicazione delle garanzie processuali nei processi contro i terroristi per il terrorismo interno.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.53',
#     'clf_2P': '0.52',
#     'clf_3P': '0.54',
#     'clf_4P': '0.53',
#     'clf_5P': '0.52',
#     'clf_6P': '0.52',
#     'clf_7P': '0.53',
#     'clf_8P': '0.54',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.51'},
#    182710: {'Sentence_1': "Signor Presidente, senatrici e senatori, signora Vice Ministro, lo stupro come arma di guerra è il cuore più oscuro e torvo, più crudele e abietto del feroce catalogo dei crimini contro l'umanità.",
#     'Sentence_2': "Ma cosa sono i crimini contro l'umanità?",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.51',
#     'clf_3P': '0.53',
#     'clf_4P': '0.54',
#     'clf_5P': '0.52',
#     'clf_6P': '0.52',
#     'clf_7P': '0.52',
#     'clf_8P': '0.52',
#     'clf_9P': '0.52',
#     'clf_10P': '0.51',
#     'clf_11P': '0.52',
#     'clf_12P': '0.52'},
#    332302: {'Sentence_1': 'Il Senato non approva.',
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.51',
#     'clf_2P': '0.50',
#     'clf_3P': '0.51',
#     'clf_4P': '0.50',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.51',
#     'clf_8P': '0.50',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {798681: {'Sentence_1': "Cari colleghi, ricorre oggi il 25° anniversario della strage di via D'Amelio, nella quale furono barbaramente assassinati il giudice Paolo Borsellino e gli uomini di scorta della Polizia di Stato Agostino Catalano, Eddie Walter Cosina, Vincenzo Li Muli, Emanuela Loi e Claudio Traina.",
#     'Sentence_2': "Il nostro primo pensiero - sono certo - si rivolge innanzitutto alle famiglie degli uomini e delle donne uccisi in quell'esplosione.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.52',
#     'c2pr': 0,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 0,
#     'c4P': '0.51',
#     'c5pr': 0,
#     'c5P': '0.51',
#     'c6pr': 0,
#     'c6P': '0.51',
#     'c7pr': 0,
#     'c7P': '0.51',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.50'},
#    516959: {'Sentence_1': 'Quindi, noi riconosciamo tutto, ma riteniamo che si debbano rivalutare subito tali questioni, oltre alle altre che dovranno porsi.',
#     'Sentence_2': 'Infine, lo dico adesso, in sede di esame del Documento di economia e finanza, al Governo.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.52',
#     'c2pr': 0,
#     'c2P': '0.50',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.52',
#     'c5pr': 0,
#     'c5P': '0.52',
#     'c6pr': 0,
#     'c6P': '0.52',
#     'c7pr': 0,
#     'c7P': '0.51',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.52',
#     'c10pr': 0,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    68621: {'Sentence_1': 'Come dicevo, gli altri obiettivi della revisione costituzionale - ovvero la riduzione dei costi e del numero dei parlamentari e la soppressione del CNEL - sono raggiunti, anche se meritano un veloce commento.',
#     'Sentence_2': 'In tal senso, ho proposto un intervento emendativo che ci riporta a questo preciso riferimento europeo.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.50',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.50'},
#    158019: {'Sentence_1': "Era un uomo retto ed è stato uno dei non rari casi, certamente non l'unico, di condanna seguita da assoluzione, un caso, in qualche modo, di persecuzione per reati non commessi.",
#     'Sentence_2': 'Lo dico a tutti noi: i parlamentari non sono delle poltrone, voi non siete delle poltrone, noi non siamo delle poltrone.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.53',
#     'c2pr': 0,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.52'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {35436: {'Sentence_1': "L'Italia è un Paese che merita rispetto: il suo popolo, il popolo italiano, merita rispetto.",
#     'Sentence_2': 'E il popolo merita, Presidente, di poter incidere, perché lo prevede la Costituzione, nel processo politico esercitando il suo diritto di voto.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    343745: {'Sentence_1': 'No, ci sono dei contenuti, seri, molto seri.',
#     'Sentence_2': "Mi permetta di portare all'Aula due ricordi.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    512339: {'Sentence_1': "Siamo riusciti anche a sbloccare i fondi dovuti dallo Stato per la Valle d'Aosta e per le nostre due Province, il che consentirà una piena ed efficace politica di bilancio per i prossimi anni.",
#     'Sentence_2': "Desidero inoltre ringraziare il presidente Calderoli, in quanto la modifica al Regolamento del Senato, con la deroga per le minoranze linguistiche e le autonomie speciali, garantisce che il nostro Gruppo sarà in quest'Aula anche in futuro.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.52'},
#    886124: {'Sentence_1': "Signora Presidente, da parte mia provo un certo imbarazzo a dover dire che condivido una serie di riflessioni fatte dal collega Petrocelli, e il fatto che la posizione della Lega si sovrapponga a quella del Movimento 5 Stelle è veramente un po' imbarazzante, ma sono state dette delle verità assolute.",
#     'Sentence_2': 'La distensione del Mediterraneo innanzitutto è un problema italiano.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 0,
#     'c3P': '0.53',
#     'c4pr': 0,
#     'c4P': '0.55',
#     'c5pr': 0,
#     'c5P': '0.53',
#     'c6pr': 0,
#     'c6P': '0.52',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 0,
#     'c8P': '0.52',
#     'c9pr': 0,
#     'c9P': '0.53',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 0,
#     'c12P': '0.52'}}},
#  'df_dist_20': {'lista_eventi_scelti_intersezione_errati': {670427: {'Sentence_1': "Provate per un po' a considerarvi dei meri portavoce; date modo alle persone e ai loro bisogni di fluire semplicemente attraverso di voi; siate portatori sani di bisogni altrui.",
#     'Sentence_2': 'Provate, provate soltanto, vi potrebbe persino piacere.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.57',
#     'clf_2P': '0.55',
#     'clf_3P': '0.56',
#     'clf_4P': '0.55',
#     'clf_5P': '0.55',
#     'clf_6P': '0.55',
#     'clf_7P': '0.54',
#     'clf_8P': '0.56',
#     'clf_9P': '0.55',
#     'clf_10P': '0.53',
#     'clf_11P': '0.52',
#     'clf_12P': '0.55'},
#    214010: {'Sentence_1': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 1.7 /291, presentato dalla senatrice Sudano.",
#     'Sentence_2': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 1.7 /329, presentato dal senatore Margiotta.",
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.52',
#     'clf_2P': '0.51',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.53',
#     'clf_6P': '0.53',
#     'clf_7P': '0.52',
#     'clf_8P': '0.51',
#     'clf_9P': '0.53',
#     'clf_10P': '0.52',
#     'clf_11P': '0.52',
#     'clf_12P': '0.50'},
#    578568: {'Sentence_1': 'Io dico, però - e lo abbiamo detto in tanti e credo che sia il senso più profondo di questa mozione - che autonomia e libertà delle donne significa anche un Paese più forte, più sano, più competitivo.',
#     'Sentence_2': 'Se noi oggi proviamo ad affrontare il tema della ricostruzione non possiamo che partire da lì.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.55',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.53',
#     'clf_8P': '0.57',
#     'clf_9P': '0.58',
#     'clf_10P': '0.53',
#     'clf_11P': '0.55',
#     'clf_12P': '0.53'},
#    604608: {'Sentence_1': "La stessa domanda ci viene anche dall'Europa e da tutte le istanze internazionali che contano.",
#     'Sentence_2': 'Non tacciamo sempre tutto e tutti di interferenza, di attentato alla nostra sovranità!',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.54',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.54',
#     'clf_5P': '0.56',
#     'clf_6P': '0.56',
#     'clf_7P': '0.54',
#     'clf_8P': '0.55',
#     'clf_9P': '0.59',
#     'clf_10P': '0.58',
#     'clf_11P': '0.59',
#     'clf_12P': '0.55'}},
#   'lista_eventi_scelti_intersezione_corretti': {141615: {'Sentence_1': 'Preso atto che non si poteva intervenire su questi elementi, si è invece intervenuti anzitutto con una specificazione del reddito, che è passato da lordo a complessivo; poi - altro elemento evidenziato - si è sostituito il termine per la dichiarazione dei redditi del 2015 al 2014, anzitutto, per dare un elemento di certezza e poi, essendo la dichiarazione dei redditi 2015 un work in progress, per permettere di accelerare le procedure stesse.',
#     'Sentence_2': "È stata eliminata la richiesta della copia di pagamento alla banca in liquidazione e del credito relativo agli strumenti finanziari subordinati; è stato di fatto permesso che, per il reperimento dei documenti, le banche fossero tenute a dare copia all'investitore entro quindici giorni dalla sua richiesta.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.57',
#     'clf_2P': '0.52',
#     'clf_3P': '0.51',
#     'clf_4P': '0.51',
#     'clf_5P': '0.54',
#     'clf_6P': '0.54',
#     'clf_7P': '0.52',
#     'clf_8P': '0.52',
#     'clf_9P': '0.54',
#     'clf_10P': '0.52',
#     'clf_11P': '0.51',
#     'clf_12P': '0.54'},
#    453760: {'Sentence_1': 'La base, invece, non ha una precisa connotazione etnica.',
#     'Sentence_2': 'Detti sodalizi, che mantengono una sostanziale autonomia nei rapporti con la criminalità organizzata italiana, sono dotati di una rete nazionale di referenti a capo di cellule di apparente connotazione folkloristica, dietro le quali si celano agguerrite associazioni criminali che, con modalità di intimidazione, controllo e violenza fisica gestiscono le attività illecite.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.52',
#     'clf_3P': '0.57',
#     'clf_4P': '0.55',
#     'clf_5P': '0.55',
#     'clf_6P': '0.55',
#     'clf_7P': '0.54',
#     'clf_8P': '0.57',
#     'clf_9P': '0.53',
#     'clf_10P': '0.57',
#     'clf_11P': '0.56',
#     'clf_12P': '0.52'},
#    673095: {'Sentence_1': "Ci sono tre documenti: facciamo vedere che una volta tanto riusciamo a metterci d'accordo e facciamone uno, perché deve essere il documento del Senato della Repubblica, non deve essere il documento di una parte del Senato, anche se poi magari tutti e tre verranno votati all'unanimità.",
#     'Sentence_2': 'Forse questa risposta non è esattamente quella che tutti auspichiamo, oppure non è solo quella che tutti auspichiamo.',
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.51',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.53',
#     'clf_8P': '0.55',
#     'clf_9P': '0.54',
#     'clf_10P': '0.56',
#     'clf_11P': '0.52',
#     'clf_12P': '0.53'},
#    20411: {'Sentence_1': "L'Italia ne sta finalmente faticosamente uscendo, ma non possiamo permetterci di ritornare allo status quo precedente, antecedente a questa crisi.",
#     'Sentence_2': "L'Italia, da oltre vent'anni, fatica a tenere il passo delle altre economie avanzate.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.55',
#     'clf_2P': '0.51',
#     'clf_3P': '0.53',
#     'clf_4P': '0.52',
#     'clf_5P': '0.51',
#     'clf_6P': '0.53',
#     'clf_7P': '0.52',
#     'clf_8P': '0.53',
#     'clf_9P': '0.57',
#     'clf_10P': '0.55',
#     'clf_11P': '0.56',
#     'clf_12P': '0.53'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {229837: {'Sentence_1': 'Lei, sottosegretario Gozi, in parte mi ha risposto.',
#     'Sentence_2': "Poiché è in corso una gara, voglio avvisare i vari Arvedi, Marcegaglia, i turchi di Erdemir e soprattutto i cittadini italiani, visto che dentro c'è Cassa depositi e prestiti, che chi vince la gara rischia di dover restituire gli eventuali finanziamenti, se essi saranno considerati aiuti di Stato.",
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.54',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.54'},
#    495658: {'Sentence_1': 'Si potrebbe fare qui una lunga serie di nomi: basti pensare al decreto dignità e a quello che invece ha comportato; era il decreto - legge che doveva abolire in un colpo solo la povertà nel nostro Paese, ma abbiamo visto invece che è aumentata.',
#     'Sentence_2': 'Si può poi passare attraverso tutti i provvedimenti di questi anni per arrivare al provvedimento di oggi, che la maggioranza ha voluto chiamare sblocca cantieri.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.55',
#     'c2pr': 0,
#     'c2P': '0.52',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.51',
#     'c5pr': 0,
#     'c5P': '0.51',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 0,
#     'c7P': '0.50',
#     'c8pr': 0,
#     'c8P': '0.50',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 0,
#     'c10P': '0.52',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.52'},
#    329309: {'Sentence_1': "Nello specifico, l'articolo 1, comma 1, estende fino al 15 ottobre 2020 la facoltà di adottare, con uno o più decreti del Presidente del Consiglio dei ministri, misure tra quelle indicate al comma 2 dell'articolo 1 del decreto - legge n. 19 del 2020, allo scopo di contrastare i rischi sanitari da Covid - 19.",
#     'Sentence_2': 'È inoltre soppresso il riferimento alla delibera del Consiglio dei ministri del 31 gennaio 2020.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.54',
#     'c2pr': 0,
#     'c2P': '0.54',
#     'c3pr': 0,
#     'c3P': '0.57',
#     'c4pr': 0,
#     'c4P': '0.56',
#     'c5pr': 0,
#     'c5P': '0.55',
#     'c6pr': 0,
#     'c6P': '0.56',
#     'c7pr': 0,
#     'c7P': '0.54',
#     'c8pr': 0,
#     'c8P': '0.55',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 0,
#     'c10P': '0.52',
#     'c11pr': 0,
#     'c11P': '0.53',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    606317: {'Sentence_1': 'Poi è andato avanti un iter diverso e abbiamo discusso per ore in Senato, dove abbiamo fatto un testo che la Camera ha rivoltato come un calzino.',
#     'Sentence_2': 'Adesso è tornato un testo in cui si legge addirittura che basta qualsiasi organismo internazionale.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.55',
#     'c2pr': 0,
#     'c2P': '0.52',
#     'c3pr': 0,
#     'c3P': '0.53',
#     'c4pr': 0,
#     'c4P': '0.54',
#     'c5pr': 0,
#     'c5P': '0.52',
#     'c6pr': 0,
#     'c6P': '0.53',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.54',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.58',
#     'c12pr': 0,
#     'c12P': '0.53'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {889594: {'Sentence_1': 'Il primo consiglio fu di stare attento alle sirene.',
#     'Sentence_2': 'Le sirene cantano un canto suadente e hanno un elenco di attributi affascinanti.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.55',
#     'c2pr': 1,
#     'c2P': '0.52',
#     'c3pr': 1,
#     'c3P': '0.56',
#     'c4pr': 1,
#     'c4P': '0.54',
#     'c5pr': 1,
#     'c5P': '0.57',
#     'c6pr': 1,
#     'c6P': '0.58',
#     'c7pr': 1,
#     'c7P': '0.54',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.53'},
#    33582: {'Sentence_1': 'Io esprimo la mia solidarietà personale al Presidente della Regione Sardegna.',
#     'Sentence_2': "Quando aveva avanzato proposte su come dovevano essere gestiti i turisti in Regione Sardegna l'avete tutti irriso e avete detto che era un irresponsabile; adesso la colpa è delle discoteche e ci sentiamo dire dai tromboni della politica e da chi fa il fenomeno che la colpa è dei giovani perché non ascoltano, la colpa è dei giovani perché si abbracciano, la colpa è dei giovani perché non mettono le mascherine.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.54',
#     'c8pr': 1,
#     'c8P': '0.54',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    613084: {'Sentence_1': "Dov'è la rete?",
#     'Sentence_2': "Dov'è la cultura?",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.54',
#     'c3pr': 1,
#     'c3P': '0.56',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.54',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.58',
#     'c9pr': 1,
#     'c9P': '0.58',
#     'c10pr': 1,
#     'c10P': '0.55',
#     'c11pr': 0,
#     'c11P': '0.55',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    307901: {'Sentence_1': "C'è un dato dal quale noi non possiamo prescindere, ed è quello del secondo comma dell'articolo 57, che riproduce la lettera dell'articolo 2, secondo cui i Consigli regionali eleggono i senatori tra i propri componenti.",
#     'Sentence_2': 'Questo dato, lo dico alla collega De Petris e anche al collega De Cristofaro, i cui interventi ho molto apprezzato e sui quali tornerò, conferma, come diceva poco fa il senatore Quagliariello - e potrei non aggiungere niente a quanto ha detto -, che la scelta operata è una scelta che prevede che il Senato sia il luogo della rappresentanza delle istituzioni territoriali e che la sua composizione sia affidata a consiglieri regionali e sindaci.',
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.53',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 1,
#     'c4P': '0.53',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.53',
#     'c7pr': 1,
#     'c7P': '0.54',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 0,
#     'c12P': '0.50'}}},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': {451088: {'Sentence_1': 'Assolutamente no.',
#     'Sentence_2': 'Con il "Drugs on street", un progetto di prevenzione notturna, con cui si mettevano insieme carabinieri, polizia, vigili urbani e associazioni di volontariato per controllare e monitorare dalle ore 23 fino alle 4 del mattino, specialmente nelle notti delle stragi, ossia il sabato sera, abbiamo ottenuto risultati straordinari.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.55',
#     'clf_3P': '0.57',
#     'clf_4P': '0.53',
#     'clf_5P': '0.56',
#     'clf_6P': '0.53',
#     'clf_7P': '0.54',
#     'clf_8P': '0.55',
#     'clf_9P': '0.51',
#     'clf_10P': '0.53',
#     'clf_11P': '0.52',
#     'clf_12P': '0.51'},
#    289493: {'Sentence_1': "Cito questo punto perché l'ho considerato un passo avanti molto importante delle istituzioni internazionali, che guardano e devono guardare sempre di più ai temi non soltanto nella centralità degli aspetti finanziari.",
#     'Sentence_2': 'È un errore immaginare che il cuore di tutto siano le decisioni finanziarie: il cuore di tutto deve essere la somma delle decisioni, e bisogna cercare di mettere insieme i vari aspetti.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.56',
#     'clf_2P': '0.53',
#     'clf_3P': '0.52',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.51',
#     'clf_8P': '0.53',
#     'clf_9P': '0.52',
#     'clf_10P': '0.51',
#     'clf_11P': '0.54',
#     'clf_12P': '0.51'},
#    880161: {'Sentence_1': 'Il senatore Solinas entra in Aula.. Congratulazioni.',
#     'Sentence_2': "Facciamo anche noi gli auguri al senatore Solinas, perché alleato con il centrodestra ha vinto, mentre alleati con i grillini svendono l'Italia alla Cina.",
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.59',
#     'clf_2P': '0.53',
#     'clf_3P': '0.52',
#     'clf_4P': '0.51',
#     'clf_5P': '0.52',
#     'clf_6P': '0.51',
#     'clf_7P': '0.53',
#     'clf_8P': '0.53',
#     'clf_9P': '0.53',
#     'clf_10P': '0.53',
#     'clf_11P': '0.57',
#     'clf_12P': '0.57'},
#    791038: {'Sentence_1': "Analogamente è stato fatto in Egitto e in Algeria e analogamente viene fatto, per due volte, nella patria dell'illuminismo e della cultura europea, proprio in un centro che è il grande polo di attrazione turistica e culturale del mondo.",
#     'Sentence_2': "A partire da noi, dall'Italia e dall'Europa, è necessaria una grande unità tra le forze politiche e devo dare atto ai due Ministri che sono intervenuti di aver fatto questo appello all'unità.",
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.53',
#     'clf_2P': '0.51',
#     'clf_3P': '0.51',
#     'clf_4P': '0.53',
#     'clf_5P': '0.51',
#     'clf_6P': '0.52',
#     'clf_7P': '0.53',
#     'clf_8P': '0.53',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.53'}},
#   'lista_eventi_scelti_intersezione_corretti': {453798: {'Sentence_1': 'In primo luogo, le università cosiddette virtuose, cioè quelle con parametri di bilancio previsti dal decreto legislativo n. 49 del 2012, possono riutilizzare per intero i punti organico che si sono liberati per cessazione dei contratti dei ricercatori di tipo A, quelli senza tenure track per intenderci.',
#     'Sentence_2': "Per il triennio 2015 - 2017 - quindi da quest'anno fino al 2017 -, le università possono fissare il numero delle assunzioni dei professori ordinari, favorendo quindi il ricambio, perché - perdonatemi - i giovani non sono solo necessariamente ricercatori, ma possono esserci anche giovani brillanti che vanno in cattedra a un'età relativamente bassa.",
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.51',
#     'clf_2P': '0.54',
#     'clf_3P': '0.53',
#     'clf_4P': '0.54',
#     'clf_5P': '0.52',
#     'clf_6P': '0.53',
#     'clf_7P': '0.53',
#     'clf_8P': '0.52',
#     'clf_9P': '0.52',
#     'clf_10P': '0.50',
#     'clf_11P': '0.53',
#     'clf_12P': '0.54'},
#    276356: {'Sentence_1': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 2.44, presentato dal senatore D'Ambrosio Lettieri e da altri senatori.",
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.54',
#     'clf_2P': '0.52',
#     'clf_3P': '0.51',
#     'clf_4P': '0.51',
#     'clf_5P': '0.52',
#     'clf_6P': '0.51',
#     'clf_7P': '0.51',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.53',
#     'clf_12P': '0.51'},
#    318497: {'Sentence_1': "Non c'entrano niente l'articolo 68 o altri aspetti della tutela della funzione parlamentare: qui c'è una legge del 1989 che riguarda le funzioni del Governo e dei Ministri, alla quale abbiamo fatto riferimento.",
#     'Sentence_2': 'Il tribunale dei Ministri, come ho detto, non ritiene che sia un atto puramente politico, ma amministrativo, quindi sindacabile dal giudice.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.56',
#     'clf_2P': '0.53',
#     'clf_3P': '0.55',
#     'clf_4P': '0.55',
#     'clf_5P': '0.51',
#     'clf_6P': '0.51',
#     'clf_7P': '0.52',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.51',
#     'clf_11P': '0.51',
#     'clf_12P': '0.50'},
#    26475: {'Sentence_1': 'Ricordo che quando tenemmo il primo incontro dopo il primo terremoto Renzi diceva di avere tutti i soldi per la ricostruzione: lo avete detto in Parlamento a gente che è ancora in mezzo alla strada perché i soldi non li avete tirati fuori.',
#     'Sentence_2': 'Dove li aveva Renzi?',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.59',
#     'clf_2P': '0.53',
#     'clf_3P': '0.53',
#     'clf_4P': '0.53',
#     'clf_5P': '0.54',
#     'clf_6P': '0.54',
#     'clf_7P': '0.51',
#     'clf_8P': '0.51',
#     'clf_9P': '0.51',
#     'clf_10P': '0.52',
#     'clf_11P': '0.51',
#     'clf_12P': '0.52'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {512684: {'Sentence_1': "Questa è l'essenza di questo Governo: togliere le libertà democratiche al nostro Paese, in uno Stato, signor Ministro, dove proprio in vista della stagione turistica si è permesso di tutto e di più, senza controlli, perché chi doveva controllare non ha controllato, per poi puntare il dito sulle Regioni, per poi dire che il Presidente della Regione Sardegna è stato inefficiente.",
#     'Sentence_2': "Bastava prendere uno di quelli che voi chiamate eroi e mandarlo all'Organizzazione mondiale della sanità.",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.55',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.52',
#     'c5pr': 1,
#     'c5P': '0.56',
#     'c6pr': 1,
#     'c6P': '0.53',
#     'c7pr': 1,
#     'c7P': '0.53',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.52',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    280710: {'Sentence_1': "Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 8.135, presentato dal senatore Arrigoni.",
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.51',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.53',
#     'c5pr': 0,
#     'c5P': '0.52',
#     'c6pr': 0,
#     'c6P': '0.50',
#     'c7pr': 0,
#     'c7P': '0.50',
#     'c8pr': 1,
#     'c8P': '0.50',
#     'c9pr': 0,
#     'c9P': '0.50',
#     'c10pr': 0,
#     'c10P': '0.50',
#     'c11pr': 0,
#     'c11P': '0.50',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    637884: {'Sentence_1': "Tuttavia, penso che su questo ci voglia un po' più di umiltà.",
#     'Sentence_2': 'E pensiamo che questa battaglia politica che oggi combattiamo non la facciamo solo per noi.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.57',
#     'c2pr': 1,
#     'c2P': '0.55',
#     'c3pr': 1,
#     'c3P': '0.55',
#     'c4pr': 1,
#     'c4P': '0.58',
#     'c5pr': 1,
#     'c5P': '0.58',
#     'c6pr': 1,
#     'c6P': '0.55',
#     'c7pr': 1,
#     'c7P': '0.53',
#     'c8pr': 1,
#     'c8P': '0.54',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.54'},
#    634012: {'Sentence_1': "In più, leggendo le disposizioni che si vogliono introdurre con questo disegno di legge, si delinea un regime fortemente repressivo, peraltro dal profilo incerto; talvolta l'aspetto repressivo non assume i connotati di qualcosa che possa risolvere il problema.",
#     'Sentence_2': 'Ecco perché il Gruppo di Forza Italia, a malincuore e con grande dispiacere, esprimerà un voto di astensione, quando avrebbe voluto essere favorevole.. Congratulazioni.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.50',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.51',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.51',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.57',
#     'c12pr': 0,
#     'c12P': '0.50'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {187558: {'Sentence_1': 'Il testo che abbiamo esaminato questa mattina prevede, invece, di istituire un apposito organismo consultivo, con la partecipazione di rappresentanti di tutti i soggetti pubblici e privati, e che ai componenti dei predetti organismi non spetta alcun compenso, indennità, eccetera.',
#     'Sentence_2': "È del tutto evidente che in materia di protezione civile stiamo parlando di aria fritta, perché non c'è bisogno di una legge per comporre un organismo consultivo guidato dal sindaco all'interno del Comune.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.54',
#     'c4pr': 1,
#     'c4P': '0.54',
#     'c5pr': 1,
#     'c5P': '0.52',
#     'c6pr': 1,
#     'c6P': '0.52',
#     'c7pr': 1,
#     'c7P': '0.53',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.50',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.51'},
#    527740: {'Sentence_1': 'Lo dico anche agli editori: non si deve censurare nulla, ma allora si pubblicassero i libri nella collana dei Gialli.',
#     'Sentence_2': 'Ebbene, si arrivò al punto - e qui interviene anche una memoria diretta e personale - che per molti mesi, signor Presidente, si scrisse che si trattava di una faida interna ai missini, come lo si scrisse per la strage di Primavalle, una vicenda che riguarda Potere operaio non le Brigate Rosse.',
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.52',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.52',
#     'c5pr': 0,
#     'c5P': '0.54',
#     'c6pr': 0,
#     'c6P': '0.52',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 0,
#     'c8P': '0.53',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.50'},
#    111886: {'Sentence_1': 'Questo serve, infatti.',
#     'Sentence_2': "In Commissione, però, grazie ad un emendamento della relatrice Granato, che all'epoca non era relatrice del provvedimento, appoggiato dalla relatrice di due settimane fa e da tutti noi, si era aumentata la quota destinata ai precari sino al 70 per cento.",
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.50',
#     'c2pr': 0,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.50',
#     'c4pr': 0,
#     'c4P': '0.55',
#     'c5pr': 0,
#     'c5P': '0.53',
#     'c6pr': 0,
#     'c6P': '0.54',
#     'c7pr': 0,
#     'c7P': '0.52',
#     'c8pr': 0,
#     'c8P': '0.51',
#     'c9pr': 0,
#     'c9P': '0.52',
#     'c10pr': 0,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.52',
#     'c12pr': 0,
#     'c12P': '0.52'},
#    622598: {'Sentence_1': "Ho retrodatato allora la polemica antiparlamentarista di cento anni, all'impresa fiumana, che faceva la costituzione, sì, ma con Keller e con D'Annunzio, era l'epoca in cui le trasvolate erano eroiche: erano andati a gettare volantini tricolori sopra l'Austria, nella fase della prima guerra mondiale; sono venuti sopra Montecitorio a gettare il vaso da notte, per dire che il Parlamento faceva schifo in segno di irrisione.",
#     'Sentence_2': "Quindi non c'è niente di nuovo.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.50',
#     'c3pr': 1,
#     'c3P': '0.51',
#     'c4pr': 1,
#     'c4P': '0.53',
#     'c5pr': 1,
#     'c5P': '0.50',
#     'c6pr': 0,
#     'c6P': '0.51',
#     'c7pr': 1,
#     'c7P': '0.52',
#     'c8pr': 1,
#     'c8P': '0.52',
#     'c9pr': 1,
#     'c9P': '0.50',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.54',
#     'c12pr': 1,
#     'c12P': '0.52'}}},
#  'df_random_speech': {'lista_eventi_scelti_intersezione_errati': {636188: {'Sentence_1': 'Ha facoltà di parlare il presidente del Consiglio dei ministri, dottor Renzi.',
#     'Sentence_2': 'Avverto che le proposte di risoluzione dovranno essere presentate entro la conclusione del dibattito.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.69',
#     'clf_2P': '0.58',
#     'clf_3P': '0.61',
#     'clf_4P': '0.64',
#     'clf_5P': '0.64',
#     'clf_6P': '0.66',
#     'clf_7P': '0.66',
#     'clf_8P': '0.68',
#     'clf_9P': '0.69',
#     'clf_10P': '0.69',
#     'clf_11P': '0.55',
#     'clf_12P': '0.69'},
#    167370: {'Sentence_1': "Signor Presidente, il parere sull'emendamento 34.200 è contrario.",
#     'Sentence_2': 'Signor Presidente, esprimo parere contrario sugli emendamenti 37.200, 37.201 e 37.202.',
#     'Class': 0,
#     'Pred': 1,
#     'clf_1P': '0.74',
#     'clf_2P': '0.69',
#     'clf_3P': '0.69',
#     'clf_4P': '0.70',
#     'clf_5P': '0.71',
#     'clf_6P': '0.73',
#     'clf_7P': '0.76',
#     'clf_8P': '0.77',
#     'clf_9P': '0.74',
#     'clf_10P': '0.68',
#     'clf_11P': '0.59',
#     'clf_12P': '0.59'},
#    44241: {'Sentence_1': 'Un Governo come quello Renzi, che fa di un argomento etico il fondamento del suo programma e che perciò pone su di esso una questione di fiducia, assume conseguentemente, fortemente, prepotentemente la forma di un Governo etico.',
#     'Sentence_2': 'Siamo anche convinti che la possibilità di formare specialisti del territorio, pronti per affrontare le sfide del Servizio sanitario nazionale che sono rappresentate dai mutati scenari di salute, dal maggiore impatto delle cronicità e dalle incombenze poste dalla stessa pandemia, richieda risposte organizzate e integrate proprio a livello di comunità.',
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.65',
#     'clf_2P': '0.67',
#     'clf_3P': '0.59',
#     'clf_4P': '0.61',
#     'clf_5P': '0.59',
#     'clf_6P': '0.61',
#     'clf_7P': '0.62',
#     'clf_8P': '0.59',
#     'clf_9P': '0.58',
#     'clf_10P': '0.59',
#     'clf_11P': '0.54',
#     'clf_12P': '0.50'},
#    490307: {'Sentence_1': 'Il Senato non approva.',
#     'Sentence_2': "Verrà esclusa la responsabilità penale del medico, anche per colpa grave, se rispetterà le buone pratiche e le linee guida previste, come a dire che ci si potrà trincerare al sicuro dietro un testo, evitando l'adozione delle scelte terapeutiche più adeguate e sfociando verso una standardizzazione a discapito del rapporto medico - paziente, per un risarcimento che già oggi tarda ad arrivare e facendo sì che coloro che si sono resi colpevoli con il loro operato, ma salvi dalle linee guida, continueranno ad operare nelle stesse strutture mettendo in pericolo altri pazienti.",
#     'Class': 1,
#     'Pred': 0,
#     'clf_1P': '0.66',
#     'clf_2P': '0.66',
#     'clf_3P': '0.66',
#     'clf_4P': '0.66',
#     'clf_5P': '0.70',
#     'clf_6P': '0.67',
#     'clf_7P': '0.64',
#     'clf_8P': '0.64',
#     'clf_9P': '0.61',
#     'clf_10P': '0.55',
#     'clf_11P': '0.56',
#     'clf_12P': '0.62'}},
#   'lista_eventi_scelti_intersezione_corretti': {136364: {'Sentence_1': 'È davvero assurdo scrivere un emendamento, che per carità condividiamo, in cui prevediamo una premialità per la denuncia obbligatoria delle richieste estorsive.',
#     'Sentence_2': 'Se uno viene da me e avanza una richiesta di estorsione sono obbligato ad andare dal magistrato e a presentare denuncia.',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.57',
#     'clf_2P': '0.65',
#     'clf_3P': '0.62',
#     'clf_4P': '0.66',
#     'clf_5P': '0.60',
#     'clf_6P': '0.60',
#     'clf_7P': '0.63',
#     'clf_8P': '0.57',
#     'clf_9P': '0.57',
#     'clf_10P': '0.55',
#     'clf_11P': '0.55',
#     'clf_12P': '0.62'},
#    74785: {'Sentence_1': "Se mi è consentito, vorrei invitare i senatori proponenti a ritirare l'emendamento.",
#     'Sentence_2': "Se invece venisse accolta l'osservazione che ho fatto sull'emendamento del senatore Casson, potrei ritirare il mio emendamento.",
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.63',
#     'clf_2P': '0.62',
#     'clf_3P': '0.65',
#     'clf_4P': '0.59',
#     'clf_5P': '0.55',
#     'clf_6P': '0.53',
#     'clf_7P': '0.50',
#     'clf_8P': '0.54',
#     'clf_9P': '0.62',
#     'clf_10P': '0.63',
#     'clf_11P': '0.66',
#     'clf_12P': '0.61'},
#    327854: {'Sentence_1': "Un ulteriore elemento, giustamente evidenziato e che ha anch'esso caratterizzato i lavori della Giunta, riguarda l'allocazione dei costi, o meglio, la previsione dei costi e la loro allocazione all'interno del Consiglio di Presidenza.",
#     'Sentence_2': "Proclamo il risultato della votazione a scrutinio segreto per l'elezione del Presidente del Senato: Hanno ottenuto voti i senatori: Proclamo eletta Presidente del Senato la senatrice Maria Elisabetta Alberti Casellati.",
#     'Class': 1,
#     'Pred': 1,
#     'clf_1P': '0.61',
#     'clf_2P': '0.52',
#     'clf_3P': '0.56',
#     'clf_4P': '0.59',
#     'clf_5P': '0.60',
#     'clf_6P': '0.56',
#     'clf_7P': '0.50',
#     'clf_8P': '0.53',
#     'clf_9P': '0.52',
#     'clf_10P': '0.54',
#     'clf_11P': '0.56',
#     'clf_12P': '0.63'},
#    598163: {'Sentence_1': "Quindi, se a un certo punto la Francia decide di bombardare la Libia, va bene, perché non c'è un vincolo europeo che impedisca di muovere guerra contro gli interessi di un altro Stato membro dell'Unione europea; in compenso, ci dicono se le materie fecali le dobbiamo trattare come rifiuti oppure no.",
#     'Sentence_2': 'Cosa sosteniamo allora?',
#     'Class': 0,
#     'Pred': 0,
#     'clf_1P': '0.53',
#     'clf_2P': '0.59',
#     'clf_3P': '0.72',
#     'clf_4P': '0.63',
#     'clf_5P': '0.54',
#     'clf_6P': '0.59',
#     'clf_7P': '0.59',
#     'clf_8P': '0.64',
#     'clf_9P': '0.66',
#     'clf_10P': '0.65',
#     'clf_11P': '0.70',
#     'clf_12P': '0.76'}},
#   'lista_eventi_scelti_intersezione_altri_errati': {18768: {'Sentence_1': 'Venendo al disegno di legge di ratifica, esso si compone di quattro articoli.',
#     'Sentence_2': "Passiamo alla votazione dell'articolo 90.",
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.71',
#     'c2pr': 1,
#     'c2P': '0.62',
#     'c3pr': 1,
#     'c3P': '0.54',
#     'c4pr': 1,
#     'c4P': '0.59',
#     'c5pr': 1,
#     'c5P': '0.56',
#     'c6pr': 1,
#     'c6P': '0.55',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.51',
#     'c9pr': 1,
#     'c9P': '0.51',
#     'c10pr': 1,
#     'c10P': '0.55',
#     'c11pr': 0,
#     'c11P': '0.59',
#     'c12pr': 1,
#     'c12P': '0.50'},
#    287660: {'Sentence_1': "Signor Presidente, onorevoli colleghi, volevo dire innanzitutto, con particolare riguardo all'intervento della senatrice De Petris, che è mio per prima il rammarico di non avere potuto convocare la Commissione per prendere atto della calendarizzazione in Aula della legge elettorale.",
#     'Sentence_2': "Tutti i colleghi hanno visto che ciò è stato impossibile per mancanza di una soluzione di continuità tra la Conferenza dei Capigruppo e l'inizio dei lavori d'Aula.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.54',
#     'c2pr': 0,
#     'c2P': '0.52',
#     'c3pr': 0,
#     'c3P': '0.58',
#     'c4pr': 0,
#     'c4P': '0.55',
#     'c5pr': 0,
#     'c5P': '0.55',
#     'c6pr': 0,
#     'c6P': '0.60',
#     'c7pr': 0,
#     'c7P': '0.58',
#     'c8pr': 0,
#     'c8P': '0.56',
#     'c9pr': 0,
#     'c9P': '0.51',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 1,
#     'c12P': '0.53'},
#    606882: {'Sentence_1': 'La seduta è sospesa.',
#     'Sentence_2': 'Il Governo, dunque, sta facendo tutto il possibile per migliorare la vita degli italiani e dare un impulso forte al rilancio economico e alla crescita.',
#     'Class': 1,
#     'c1pr': 1,
#     'c1P': '0.54',
#     'c2pr': 1,
#     'c2P': '0.53',
#     'c3pr': 1,
#     'c3P': '0.61',
#     'c4pr': 1,
#     'c4P': '0.55',
#     'c5pr': 1,
#     'c5P': '0.56',
#     'c6pr': 1,
#     'c6P': '0.61',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.56',
#     'c9pr': 0,
#     'c9P': '0.53',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 1,
#     'c11P': '0.53',
#     'c12pr': 1,
#     'c12P': '0.67'},
#    191503: {'Sentence_1': 'Signor Presidente, in primis vorrei dichiarare che nessuno della maggioranza ha mai detto di voler utilizzare le riserve auree per il pagamento del debito pubblico o per coprire le spese correnti.',
#     'Sentence_2': "Se si fa un'affermazione simile e poi si dà la colpa alla maggioranza dell'aumento dello spread e della sfiducia dei mercati verso l'Italia, è sempre un concetto sbagliato.",
#     'Class': 0,
#     'c1pr': 0,
#     'c1P': '0.53',
#     'c2pr': 1,
#     'c2P': '0.55',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.58',
#     'c5pr': 0,
#     'c5P': '0.62',
#     'c6pr': 0,
#     'c6P': '0.59',
#     'c7pr': 0,
#     'c7P': '0.58',
#     'c8pr': 0,
#     'c8P': '0.57',
#     'c9pr': 0,
#     'c9P': '0.61',
#     'c10pr': 0,
#     'c10P': '0.54',
#     'c11pr': 0,
#     'c11P': '0.51',
#     'c12pr': 0,
#     'c12P': '0.58'}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {877007: {'Sentence_1': "La norma oggetto di novella fa riferimento, oltre che all'incremento delle prestazioni a carico del dipartimento scientifico del Policlinico militare Celio, causato anche dalle emergenze biologiche e dalla connessa necessità di sviluppo di test per patogeni rari, alla finalità di far fronte alle esigenze straordinarie e urgenti derivanti dalla diffusione del virus SARS - Cov - 2 di garantire i livelli essenziali di assistenza e di sostenere e supportare le altre strutture del Servizio sanitario nazionale.",
#     'Sentence_2': "Ricordo che gli emendamenti approvati dalla Commissione sono stati inviati ai Gruppi, che hanno quindi un'ora di tempo a partire da ora per presentare subemendamenti.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.51',
#     'c2pr': 1,
#     'c2P': '0.62',
#     'c3pr': 1,
#     'c3P': '0.60',
#     'c4pr': 1,
#     'c4P': '0.60',
#     'c5pr': 1,
#     'c5P': '0.54',
#     'c6pr': 1,
#     'c6P': '0.58',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.60',
#     'c9pr': 1,
#     'c9P': '0.60',
#     'c10pr': 1,
#     'c10P': '0.51',
#     'c11pr': 0,
#     'c11P': '0.54',
#     'c12pr': 1,
#     'c12P': '0.52'},
#    122955: {'Sentence_1': 'I chiarimenti forniti dal Consiglio di Stato hanno, dunque, dato finalmente il necessario impulso alla redazione dello schema di decreto ministeriale e della bozza di correlato disciplinare tecnico, entrambi in fase di avanzatissima definizione.',
#     'Sentence_2': 'In questo contesto, come la storia insegna, sono compatibili modelli elettorali puramente proporzionali, modelli misti o modelli maggioritari.',
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.58',
#     'c2pr': 0,
#     'c2P': '0.64',
#     'c3pr': 0,
#     'c3P': '0.62',
#     'c4pr': 0,
#     'c4P': '0.60',
#     'c5pr': 0,
#     'c5P': '0.61',
#     'c6pr': 0,
#     'c6P': '0.67',
#     'c7pr': 0,
#     'c7P': '0.65',
#     'c8pr': 0,
#     'c8P': '0.67',
#     'c9pr': 0,
#     'c9P': '0.65',
#     'c10pr': 0,
#     'c10P': '0.52',
#     'c11pr': 1,
#     'c11P': '0.51',
#     'c12pr': 0,
#     'c12P': '0.51'},
#    61619: {'Sentence_1': "Onorevoli colleghi, il Ministro dell'economia e delle finanze ha presentato la Nota di variazioni al bilancio di previsione dello Stato per l'anno finanziario 2018 e bilancio pluriennale per il triennio 2018 - 2020.",
#     'Sentence_2': 'La revisione dei meccanismi di indicizzazione del provvedimento del 2011 ha interessato infatti circa il 30 per cento dei pensionati, vale a dire 4, 400 milioni di cittadini.',
#     'Class': 1,
#     'c1pr': 0,
#     'c1P': '0.55',
#     'c2pr': 1,
#     'c2P': '0.56',
#     'c3pr': 0,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.59',
#     'c5pr': 0,
#     'c5P': '0.59',
#     'c6pr': 0,
#     'c6P': '0.61',
#     'c7pr': 0,
#     'c7P': '0.64',
#     'c8pr': 0,
#     'c8P': '0.70',
#     'c9pr': 0,
#     'c9P': '0.65',
#     'c10pr': 0,
#     'c10P': '0.59',
#     'c11pr': 0,
#     'c11P': '0.58',
#     'c12pr': 0,
#     'c12P': '0.54'},
#    5811: {'Sentence_1': 'Risultano pertanto assorbiti gli emendamenti 23.0.5 e 23.0.270.',
#     'Sentence_2': "L'emendamento 23.410 è stato ritirato.",
#     'Class': 0,
#     'c1pr': 1,
#     'c1P': '0.58',
#     'c2pr': 1,
#     'c2P': '0.51',
#     'c3pr': 1,
#     'c3P': '0.52',
#     'c4pr': 0,
#     'c4P': '0.50',
#     'c5pr': 1,
#     'c5P': '0.61',
#     'c6pr': 1,
#     'c6P': '0.60',
#     'c7pr': 1,
#     'c7P': '0.60',
#     'c8pr': 1,
#     'c8P': '0.61',
#     'c9pr': 1,
#     'c9P': '0.52',
#     'c10pr': 1,
#     'c10P': '0.53',
#     'c11pr': 1,
#     'c11P': '0.52',
#     'c12pr': 1,
#     'c12P': '0.59'}}}}

# %%
def get_tabella_indici_leggibilita(distanze_considerate, tabella):
    
    diz_distanze = {}
    
    for dist in distanze_considerate:
        diz_distanze[dist] = {}
        
        if tabella.get(dist):
            for lista in tabella[dist]:
                diz_distanze[dist][lista] = {}
                eventi = []
                for evento in tabella[dist][lista]:
                    eventi.append(evento) 
                diz_distanze[dist][lista]['eventi'] = eventi  
        
    return diz_distanze

# %%
indici_eventi_svm = get_tabella_indici_leggibilita(distanze_considerate, tabella_svm)

# %%
indici_eventi_bert = get_tabella_indici_leggibilita(distanze_considerate, tabella_bert)

# %%
def verifica_assenza_intersezioni_in_insiemi_trovati(indici_eventi_modello):
    
    for dist in indici_eventi_modello:
        for lista in indici_eventi_modello[dist]:
            lista_insiemi = []

            l_eventi = indici_eventi_modello[dist][lista]['eventi']
            if len(l_eventi) != len(set(l_eventi)):
                print("{}: lista e insieme hanno lunghezze differenti! lista: {} - insieme: {}".format(dist, \
                                                                                            len(l_eventi), \
                                                                                            len(set(l_eventi))))

# %%
verifica_assenza_intersezioni_in_insiemi_trovati(indici_eventi_svm)

# %%
verifica_assenza_intersezioni_in_insiemi_trovati(indici_eventi_bert)

# %%
indici_eventi_svm
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': {'eventi': [228695,
#     195285]},
#   'lista_eventi_scelti_intersezione_corretti': {'eventi': [518453,
#     464910,
#     537330,
#     414778]},
#   'lista_eventi_scelti_intersezione_altri_errati': {'eventi': [5733,
#     557954,
#     368710,
#     45684]},
#   'lista_eventi_scelti_intersezione_altri_corretti': {'eventi': [124516,
#     260309,
#     440791,
#     50850]}},
#  'df_dist_30': {'lista_eventi_scelti_intersezione_errati': {'eventi': [451088,
#     289493,
#     880161,
#     791038]},
#   'lista_eventi_scelti_intersezione_corretti': {'eventi': [453798,
#     276356,
#     318497,
#     26475]},
#   'lista_eventi_scelti_intersezione_altri_errati': {'eventi': [512684,
#     280710,
#     637884,
#     634012]},
#   'lista_eventi_scelti_intersezione_altri_corretti': {'eventi': [187558,
#     527740,
#     111886,
#     622598]}},
#  'df_random_speech': {'lista_eventi_scelti_intersezione_errati': {'eventi': [636188,
#     167370,
#     44241,
#     490307]},
#   'lista_eventi_scelti_intersezione_corretti': {'eventi': [136364,
#     74785,
#     327854,
#     598163]},
#   'lista_eventi_scelti_intersezione_altri_errati': {'eventi': [18768,
#     287660,
#     606882,
#     191503]},
#   'lista_eventi_scelti_intersezione_altri_corretti': {'eventi': [877007,
#     122955,
#     61619,
#     5811]}}}

# %%
textstat.set_lang('it')

# %%
diz_indici_leggibilita_per_tipo_per_anno_svm = {}
diz_indici_leggibilita_per_tipo_per_anno_bert = {}

# %%
def get_indici_leggibilita_per_tipo_per_anno(diz_indici_leggibilita_per_tipo_per_anno, indici_eventi, dist, df):
    
    diz_indici_leggibilita_per_tipo_per_anno[dist] = {}
    for lista in indici_eventi[dist]:
        diz_indici_leggibilita_per_tipo_per_anno[dist][lista] = {}
        for evento in indici_eventi[dist][lista]['eventi']:
            val = df[df['Id'] == evento][['Sentence_1', 'Sentence_2', 'Class']].to_dict(orient='index')
            val_k = list(val.keys())[0]
            
            sent_1 = val[val_k]['Sentence_1']
            sent_2 = val[val_k]['Sentence_2']
            sent_1_sent_2 = " ".join([sent_1, sent_2])
            
            val[val_k]['flesch_reading_ease_S_1'] = textstat.flesch_reading_ease(sent_1)
            val[val_k]['flesch_reading_ease_S_2'] = textstat.flesch_reading_ease(sent_2)
            
            val[val_k]['gulpease_index_S_1'] = textstat.gulpease_index(sent_1)
            val[val_k]['gulpease_index_S_2'] = textstat.gulpease_index(sent_2)
            
            val[val_k]['flesch_reading_ease_S_1_S_2'] = textstat.flesch_reading_ease(sent_1_sent_2)
            val[val_k]['gulpease_index_S_1_S_2'] = textstat.gulpease_index(sent_1_sent_2)

            diz_indici_leggibilita_per_tipo_per_anno[dist][lista][evento] = val[val_k]

# %%
get_indici_leggibilita_per_tipo_per_anno(diz_indici_leggibilita_per_tipo_per_anno_svm, indici_eventi_svm, \
                                         'df_dist_5', df_dist_5_test)

# %%
diz_indici_leggibilita_per_tipo_per_anno_svm
# Out:
# {'df_dist_5': {'lista_eventi_scelti_intersezione_errati': {228695: {'Sentence_1': 'Il più comprende il meno, seppur fosse discutibile la questione che pongo.',
#     'Sentence_2': "Accogliendo il mio subemendamento si andrebbe ad inserire, rispetto ai soggetti indiziati del delitto di cui all'articolo 416 del codice penale, finalizzato alla commissione di taluno dei delitti di cui agli articoli 314, primo comma, 316, eccetera eccetera, anche l'articolo 640 - bis.",
#     'Class': 0,
#     'flesch_reading_ease_S_1': 81.4,
#     'flesch_reading_ease_S_2': 20.98,
#     'gulpease_index_S_1': 61.5,
#     'gulpease_index_S_2': 38.0,
#     'flesch_reading_ease_S_1_S_2': 45.22,
#     'gulpease_index_S_1_S_2': 43.3},
#    195285: {'Sentence_1': "Passiamo all'emendamento 13.0.13, su cui la 5ᵃ Commissione ha espresso parere contrario ai sensi dell'articolo 81 della Costituzione.",
#     'Sentence_2': 'Il Senato non approva.',
#     'Class': 1,
#     'flesch_reading_ease_S_1': 61.96,
#     'flesch_reading_ease_S_2': 91.8,
#     'gulpease_index_S_1': 57.9,
#     'gulpease_index_S_2': 116.5,
#     'flesch_reading_ease_S_1_S_2': 68.43,
#     'gulpease_index_S_1_S_2': 68.5}},
#   'lista_eventi_scelti_intersezione_corretti': {518453: {'Sentence_1': "Nei mari adiacenti, per il contrasto al fenomeno della pirateria, l'Italia partecipa alla missione europea Atalanta, con 2 mezzi navali, 2 aerei e un numero massimo di 407 unità di personale.",
#     'Sentence_2': "Per tutte le missioni già in atto, la proroga è fino al 31 dicembre e, per ogni missione, la relazione analitica riporta, come previsto dalla legge, due schede: la prima con il resoconto di quanto si è fatto nel 2018; la seconda con le risorse e gli assetti per l'anno in corso.",
#     'Class': 0,
#     'flesch_reading_ease_S_1': 47.04,
#     'flesch_reading_ease_S_2': 44.4,
#     'gulpease_index_S_1': 46.7,
#     'gulpease_index_S_2': 51.1,
#     'flesch_reading_ease_S_1_S_2': 48.81,
#     'gulpease_index_S_1_S_2': 49.5},
#    464910: {'Sentence_1': 'È cosa ben strana che si registri un dibattito sulla legge principale, che è la legge di stabilità, e non si senta la maggioranza difendere il Governo.',
#     'Sentence_2': "Non capisco se questo è dovuto al tentativo di anticipare quanto prima - saranno contenti loro - l'incardinamento della legge elettorale, o se, invece, è perché hanno serie difficoltà a difendere il Governo e a parlare bene della legge di stabilità.",
#     'Class': 0,
#     'flesch_reading_ease_S_1': 66.34,
#     'flesch_reading_ease_S_2': 29.38,
#     'gulpease_index_S_1': 53.8,
#     'gulpease_index_S_2': 43.1,
#     'flesch_reading_ease_S_1_S_2': 45.94,
#     'gulpease_index_S_1_S_2': 47.5},
#    537330: {'Sentence_1': "Con molta difficoltà avevamo erogato - e ribadiamo il nostro parere assolutamente contrario in proposito - ben 120 milioni di euro a otto Fondazioni lirico sinfoniche d'Italia indebitate per cattiva gestione dei loro consigli d'amministrazione, diretta emanazione dei Comuni e delle Province, secondo le compartecipazioni.",
#     'Sentence_2': 'La più indebitata, guarda caso, era quella del Maggio musicale fiorentino, per cui si è fatta anche la norma, è chiaro, infatti, che si doveva poi soddisfare le esigenze di tutti.',
#     'Class': 0,
#     'flesch_reading_ease_S_1': 0.66,
#     'flesch_reading_ease_S_2': 62.52,
#     'gulpease_index_S_1': 31.3,
#     'gulpease_index_S_2': 50.6,
#     'flesch_reading_ease_S_1_S_2': 27.84,
#     'gulpease_index_S_1_S_2': 39.4},
#    414778: {'Sentence_1': 'Signor Presidente, pur non avendo seguito specificamente il problema, quando qualche giorno fa è apparso chiaramente che in Assemblea i tempi non erano maturi se si voleva arrivare a una mozione condivisa anche con il Governo sul Venezuela, ho avanzato la proposta di sospendere il dibattito per un tempo - in quel caso fino a martedì - sufficiente per arrivare a una soluzione soddisfacente.',
#     'Sentence_2': 'E così è avvenuto, perché nel frattempo i contrasti di quel giorno si sono stemperati.',
#     'Class': 0,
#     'flesch_reading_ease_S_1': 6.74,
#     'flesch_reading_ease_S_2': 81.52,
#     'gulpease_index_S_1': 40.8,
#     'gulpease_index_S_2': 61.0,
#     'flesch_reading_ease_S_1_S_2': 39.93,
#     'gulpease_index_S_1_S_2': 44.7}},
#   'lista_eventi_scelti_intersezione_altri_errati': {5733: {'Sentence_1': 'Su questo ci dovete rispondere.',
#     'Sentence_2': "Come si fa a prendere come riferimento, per esempio, qualche altro Paese europeo che utilizza il meccanismo di elezione indiretta di una Camera, ma che nell'altro ramo del Parlamento utilizza il sistema proporzionale senza sbarramenti o comunque senza i premi di maggioranza che sono previsti dal nostro ordinamento?",
#     'Class': 1,
#     'flesch_reading_ease_S_1': 78.5,
#     'flesch_reading_ease_S_2': 20.86,
#     'gulpease_index_S_1': 95.0,
#     'gulpease_index_S_2': 39.2,
#     'flesch_reading_ease_S_1_S_2': 48.99,
#     'gulpease_index_S_1_S_2': 44.5},
#    557954: {'Sentence_1': 'Mi spiego.',
#     'Sentence_2': 'Noi invece non abbiamo voluto osare, il Governo non ha voluto osare e ci ritroviamo con questa proposta che secondo me è assolutamente asfittica.',
#     'Class': 1,
#     'flesch_reading_ease_S_1': 124.4,
#     'flesch_reading_ease_S_2': 58.3,
#     'gulpease_index_S_1': 194.0,
#     'gulpease_index_S_2': 50.7,
#     'flesch_reading_ease_S_1_S_2': 58.58,
#     'gulpease_index_S_1_S_2': 50.2},
#    368710: {'Sentence_1': "D'altra parte, ne abbiamo ratificati tanti in quest'Aula nel corso degli anni e già questa mattina.",
#     'Sentence_2': "Ho preso appunti e abbiamo, infatti, già ratificato lo stesso tipo di accordo con la Colombia, con la Giamaica e con l'Uruguay.",
#     'Class': 0,
#     'flesch_reading_ease_S_1': 72.42,
#     'flesch_reading_ease_S_2': 71.1,
#     'gulpease_index_S_1': 55.3,
#     'gulpease_index_S_2': 54.5,
#     'flesch_reading_ease_S_1_S_2': 72.3,
#     'gulpease_index_S_1_S_2': 54.8},
#    45684: {'Sentence_1': "All'AIFA spetta, inoltre, il mantenimento dell'equilibrio economico relativo al tetto fissato per la spesa farmaceutica convenzionata e ospedaliera - come ha puntualmente evidenziato il senatore Barani - che governa tramite l'applicazione di opportune misure di ripiano nel caso di sforamento, come il cosiddetto pay back - che esiste da qualche anno - e l'incentivazione all'impiego di medicinali equivalenti, cioè i generici.",
#     'Sentence_2': "In tal senso, le attività dell'AIFA, per quanto attiene all'ambito regolatorio, sono sicuramente - mi permetterei di segnalarlo - coerenti con l'assetto normativo comunitario e nazionale.",
#     'Class': 1,
#     'flesch_reading_ease_S_1': -10.77,
#     'flesch_reading_ease_S_2': 23.32,
#     'gulpease_index_S_1': 29.9,
#     'gulpease_index_S_2': 34.0,
#     'flesch_reading_ease_S_1_S_2': 8.05,
#     'gulpease_index_S_1_S_2': 31.1}},
#   'lista_eventi_scelti_intersezione_altri_corretti': {124516: {'Sentence_1': "Tempo fa, sul quotidiano «Corriere della sera» Celentano scrisse difendendo il diritto d'autore, in quel caso della musica, sostenendo che «Se non si pagasse più il pane non ci sarebbero più i fornai», perché nessuno farebbe il pane se fosse gratis.",
#     'Sentence_2': 'Celentano lo diceva per la musica: se la musica viene rubata - presa gratis - sul web, gli autori non hanno remunerazione.',
#     'Class': 0,
#     'flesch_reading_ease_S_1': 43.7,
#     'flesch_reading_ease_S_2': 65.0,
#     'gulpease_index_S_1': 45.3,
#     'gulpease_index_S_2': 53.5,
#     'flesch_reading_ease_S_1_S_2': 55.37,
#     'gulpease_index_S_1_S_2': 48.0},
#    260309: {'Sentence_1': "Ciò porterà anche a prevedere il doppio turno: penso ad esempio al ballottaggio nel caso dell'Italicum, per come è stato approvato in Parlamento; infatti, per quanto si possa immaginare di modificare quella legge, allo stato attuale abbiamo una situazione in cui sicuramente potremo avere non solo un primo turno, ma anche un secondo turno alle elezioni politiche, oltre che consultazioni regionali ed europee.",
#     'Sentence_2': "L'esigenza di coinvolgere il corpo elettorale è quindi molto presente, ma non di meno abbiamo l'esigenza di dare continuità scolastica e possibilità agli studenti di continuare regolarmente il loro corso di studi senza ripetute interruzioni.",
#     'Class': 0,
#     'flesch_reading_ease_S_1': -0.15,
#     'flesch_reading_ease_S_2': 24.08,
#     'gulpease_index_S_1': 38.5,
#     'gulpease_index_S_2': 38.4,
#     'flesch_reading_ease_S_1_S_2': 13.68,
#     'gulpease_index_S_1_S_2': 38.5},
#    440791: {'Sentence_1': 'Ogni giorno che si ritarda sono 2 milioni in più che il contribuente, attraverso i pedaggi autostradali, conferisce a queste società.',
#     'Sentence_2': "È giusto che guadagnino, ma questo guadagno potrebbe essere assottigliato a beneficio o dello Stato o dell'utente automobilista.",
#     'Class': 0,
#     'flesch_reading_ease_S_1': 61.12,
#     'flesch_reading_ease_S_2': 40.24,
#     'gulpease_index_S_1': 49.5,
#     'gulpease_index_S_2': 44.0,
#     'flesch_reading_ease_S_1_S_2': 51.67,
#     'gulpease_index_S_1_S_2': 46.9},
#    50850: {'Sentence_1': 'Fin dal mio insediamento, ho insistito su un concetto: le norme, anche le migliori, non bastano se non sono sostenute da misure organizzative.',
#     'Sentence_2': "Proprio il processo di globalizzazione, l'introduzione di nuove tecnologie in tutti i settori della vita umana, fa sì che il fattore tempo divenga un dato ancora più essenziale.",
#     'Class': 0,
#     'flesch_reading_ease_S_1': 59.3,
#     'flesch_reading_ease_S_2': 49.86,
#     'gulpease_index_S_1': 49.9,
#     'gulpease_index_S_2': 46.1,
#     'flesch_reading_ease_S_1_S_2': 54.43,
#     'gulpease_index_S_1_S_2': 47.8}}}}

# %%
get_indici_leggibilita_per_tipo_per_anno(diz_indici_leggibilita_per_tipo_per_anno_svm, indici_eventi_svm, \
                                         'df_dist_30', df_dist_30_test)

# %%
get_indici_leggibilita_per_tipo_per_anno(diz_indici_leggibilita_per_tipo_per_anno_svm, indici_eventi_svm, \
                                         'df_random_speech', df_random_speech_test)

# %%
get_indici_leggibilita_per_tipo_per_anno(diz_indici_leggibilita_per_tipo_per_anno_bert, indici_eventi_bert, \
                                         'df_dist_5', df_dist_5_test)

# %%
get_indici_leggibilita_per_tipo_per_anno(diz_indici_leggibilita_per_tipo_per_anno_bert, indici_eventi_bert, \
                                         'df_dist_30', df_dist_30_test)

# %%
get_indici_leggibilita_per_tipo_per_anno(diz_indici_leggibilita_per_tipo_per_anno_bert, indici_eventi_bert, \
                                         'df_random_speech', df_random_speech_test)

# %%
pd.set_option('display.max_colwidth', None)

# %%
df_indici_leggibilita_per_tipo_per_anno_svm = pd.DataFrame.from_dict({(i, j, z): diz_indici_leggibilita_per_tipo_per_anno_svm[i][j][z] 
                           for i in diz_indici_leggibilita_per_tipo_per_anno_svm.keys()
                           for j in diz_indici_leggibilita_per_tipo_per_anno_svm[i].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_svm[i][j].keys()},
                       orient='index')

# %%
df_indici_leggibilita_per_tipo_per_anno_svm_5 = pd.DataFrame.from_dict({(j, z): diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_5'][j][z] 
                           for j in diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_5'].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_5'][j].keys()},
                       orient='index')

# %%
df_indici_leggibilita_per_tipo_per_anno_svm_30 = pd.DataFrame.from_dict({(j, z): diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_30'][j][z] 
                           for j in diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_30'].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_30'][j].keys()},
                       orient='index')

# %%
df_indici_leggibilita_per_tipo_per_anno_svm_random_speech = pd.DataFrame.from_dict({(j, z): diz_indici_leggibilita_per_tipo_per_anno_svm['df_random_speech'][j][z] 
                           for j in diz_indici_leggibilita_per_tipo_per_anno_svm['df_random_speech'].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_svm['df_random_speech'][j].keys()},
                       orient='index')

# %%
df_indici_leggibilita_per_tipo_per_anno_svm
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Sentence_1  \
# df_dist_5        lista_eventi_scelti_intersezione_errati         228695                                                                                                                                                                                                                                                                                                                                                                                                                                                      Il più comprende il meno, seppur fosse discutibile la questione che pongo.
#                                                                  195285                                                                                                                                                                                                                                                                                                                                                                                           Passiamo all'emendamento 13.0.13, su cui la 5ᵃ Commissione ha espresso parere contrario ai sensi dell'articolo 81 della Costituzione.
#                  lista_eventi_scelti_intersezione_corretti       518453                                                                                                                                                                                                                                                                                                                                 Nei mari adiacenti, per il contrasto al fenomeno della pirateria, l'Italia partecipa alla missione europea Atalanta, con 2 mezzi navali, 2 aerei e un numero massimo di 407 unità di personale.
#                                                                  464910                                                                                                                                                                                                                                                                                                                                                                         È cosa ben strana che si registri un dibattito sulla legge principale, che è la legge di stabilità, e non si senta la maggioranza difendere il Governo.
#                                                                  537330                                                                                                                                                                                              Con molta difficoltà avevamo erogato - e ribadiamo il nostro parere assolutamente contrario in proposito - ben 120 milioni di euro a otto Fondazioni lirico sinfoniche d'Italia indebitate per cattiva gestione dei loro consigli d'amministrazione, diretta emanazione dei Comuni e delle Province, secondo le compartecipazioni.
#                                                                  414778                                                                                                                        Signor Presidente, pur non avendo seguito specificamente il problema, quando qualche giorno fa è apparso chiaramente che in Assemblea i tempi non erano maturi se si voleva arrivare a una mozione condivisa anche con il Governo sul Venezuela, ho avanzato la proposta di sospendere il dibattito per un tempo - in quel caso fino a martedì - sufficiente per arrivare a una soluzione soddisfacente.
#                  lista_eventi_scelti_intersezione_altri_errati   5733                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Su questo ci dovete rispondere.
#                                                                  557954                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Mi spiego.
#                                                                  368710                                                                                                                                                                                                                                                                                                                                                                                                                             D'altra parte, ne abbiamo ratificati tanti in quest'Aula nel corso degli anni e già questa mattina.
#                                                                  45684                                                                                      All'AIFA spetta, inoltre, il mantenimento dell'equilibrio economico relativo al tetto fissato per la spesa farmaceutica convenzionata e ospedaliera - come ha puntualmente evidenziato il senatore Barani - che governa tramite l'applicazione di opportune misure di ripiano nel caso di sforamento, come il cosiddetto pay back - che esiste da qualche anno - e l'incentivazione all'impiego di medicinali equivalenti, cioè i generici.
#                  lista_eventi_scelti_intersezione_altri_corretti 124516                                                                                                                                                                                                                                                                       Tempo fa, sul quotidiano «Corriere della sera» Celentano scrisse difendendo il diritto d'autore, in quel caso della musica, sostenendo che «Se non si pagasse più il pane non ci sarebbero più i fornai», perché nessuno farebbe il pane se fosse gratis.
#                                                                  260309                                                                                                      Ciò porterà anche a prevedere il doppio turno: penso ad esempio al ballottaggio nel caso dell'Italicum, per come è stato approvato in Parlamento; infatti, per quanto si possa immaginare di modificare quella legge, allo stato attuale abbiamo una situazione in cui sicuramente potremo avere non solo un primo turno, ma anche un secondo turno alle elezioni politiche, oltre che consultazioni regionali ed europee.
#                                                                  440791                                                                                                                                                                                                                                                                                                                                                                                           Ogni giorno che si ritarda sono 2 milioni in più che il contribuente, attraverso i pedaggi autostradali, conferisce a queste società.
#                                                                  50850                                                                                                                                                                                                                                                                                                                                                                                   Fin dal mio insediamento, ho insistito su un concetto: le norme, anche le migliori, non bastano se non sono sostenute da misure organizzative.
# df_dist_30       lista_eventi_scelti_intersezione_errati         451088                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Assolutamente no.
#                                                                  289493                                                                                                                                                                                                                                                                                                       Cito questo punto perché l'ho considerato un passo avanti molto importante delle istituzioni internazionali, che guardano e devono guardare sempre di più ai temi non soltanto nella centralità degli aspetti finanziari.
#                                                                  880161                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Il senatore Solinas entra in Aula.. Congratulazioni.
#                                                                  791038                                                                                                                                                                                                                                                                                    Analogamente è stato fatto in Egitto e in Algeria e analogamente viene fatto, per due volte, nella patria dell'illuminismo e della cultura europea, proprio in un centro che è il grande polo di attrazione turistica e culturale del mondo.
#                  lista_eventi_scelti_intersezione_corretti       453798                                                                                                                                                                                                               In primo luogo, le università cosiddette virtuose, cioè quelle con parametri di bilancio previsti dal decreto legislativo n. 49 del 2012, possono riutilizzare per intero i punti organico che si sono liberati per cessazione dei contratti dei ricercatori di tipo A, quelli senza tenure track per intenderci.
#                                                                  276356                                                                                                                                                                                                                                                                                                                                                                                   Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 2.44, presentato dal senatore D'Ambrosio Lettieri e da altri senatori.
#                                                                  318497                                                                                                                                                                                                                                                                                                              Non c'entrano niente l'articolo 68 o altri aspetti della tutela della funzione parlamentare: qui c'è una legge del 1989 che riguarda le funzioni del Governo e dei Ministri, alla quale abbiamo fatto riferimento.
#                                                                  26475                                                                                                                                                                                                                                                                                  Ricordo che quando tenemmo il primo incontro dopo il primo terremoto Renzi diceva di avere tutti i soldi per la ricostruzione: lo avete detto in Parlamento a gente che è ancora in mezzo alla strada perché i soldi non li avete tirati fuori.
#                  lista_eventi_scelti_intersezione_altri_errati   512684                                                                                                                                    Questa è l'essenza di questo Governo: togliere le libertà democratiche al nostro Paese, in uno Stato, signor Ministro, dove proprio in vista della stagione turistica si è permesso di tutto e di più, senza controlli, perché chi doveva controllare non ha controllato, per poi puntare il dito sulle Regioni, per poi dire che il Presidente della Regione Sardegna è stato inefficiente.
#                                                                  280710                                                                                                                                                                                                                                                                                                                                                                                                                 Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 8.135, presentato dal senatore Arrigoni.
#                                                                  637884                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Tuttavia, penso che su questo ci voglia un po' più di umiltà.
#                                                                  634012                                                                                                                                                                                                                                                            In più, leggendo le disposizioni che si vogliono introdurre con questo disegno di legge, si delinea un regime fortemente repressivo, peraltro dal profilo incerto; talvolta l'aspetto repressivo non assume i connotati di qualcosa che possa risolvere il problema.
#                  lista_eventi_scelti_intersezione_altri_corretti 187558                                                                                                                                                                                                                                        Il testo che abbiamo esaminato questa mattina prevede, invece, di istituire un apposito organismo consultivo, con la partecipazione di rappresentanti di tutti i soggetti pubblici e privati, e che ai componenti dei predetti organismi non spetta alcun compenso, indennità, eccetera.
#                                                                  527740                                                                                                                                                                                                                                                                                                                                                                                                           Lo dico anche agli editori: non si deve censurare nulla, ma allora si pubblicassero i libri nella collana dei Gialli.
#                                                                  111886                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Questo serve, infatti.
#                                                                  622598                                                                                        Ho retrodatato allora la polemica antiparlamentarista di cento anni, all'impresa fiumana, che faceva la costituzione, sì, ma con Keller e con D'Annunzio, era l'epoca in cui le trasvolate erano eroiche: erano andati a gettare volantini tricolori sopra l'Austria, nella fase della prima guerra mondiale; sono venuti sopra Montecitorio a gettare il vaso da notte, per dire che il Parlamento faceva schifo in segno di irrisione.
# df_random_speech lista_eventi_scelti_intersezione_errati         636188                                                                                                                                                                                                                                                                                                                                                                                                                                                   Ha facoltà di parlare il presidente del Consiglio dei ministri, dottor Renzi.
#                                                                  167370                                                                                                                                                                                                                                                                                                                                                                                                                                                               Signor Presidente, il parere sull'emendamento 34.200 è contrario.
#                                                                  44241                                                                                                                                                                                                                                                                                             Un Governo come quello Renzi, che fa di un argomento etico il fondamento del suo programma e che perciò pone su di esso una questione di fiducia, assume conseguentemente, fortemente, prepotentemente la forma di un Governo etico.
#                                                                  490307                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Il Senato non approva.
#                  lista_eventi_scelti_intersezione_corretti       518453                                                                                                                                                                                                                                                                                                             Per tutte le missioni già in atto, la proroga è fino al 31 dicembre e, per ogni missione, la relazione analitica riporta, come previsto dalla legge, due schede: la prima con il resoconto di quanto si è fatto nel 2018; la seconda con le risorse e gli assetti per l'anno in corso.
#                                                                  464910                                                                                                                                                                                                                                                                                                                                          Non capisco se questo è dovuto al tentativo di anticipare quanto prima - saranno contenti loro - l'incardinamento della legge elettorale, o se, invece, è perché hanno serie difficoltà a difendere il Governo e a parlare bene della legge di stabilità.
#                                                                  537330                                                                                                                                                                                                                                                                                                                                                                                                                La più indebitata, guarda caso, era quella del Maggio musicale fiorentino, per cui si è fatta anche la norma, è chiaro, infatti, che si doveva poi soddisfare le esigenze di tutti.
#                                                                  414778                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             E così è avvenuto, perché nel frattempo i contrasti di quel giorno si sono stemperati.
#                  lista_eventi_scelti_intersezione_altri_errati   5733                                                                                                                                                                                                                                                                         Come si fa a prendere come riferimento, per esempio, qualche altro Paese europeo che utilizza il meccanismo di elezione indiretta di una Camera, ma che nell'altro ramo del Parlamento utilizza il sistema proporzionale senza sbarramenti o comunque senza i premi di maggioranza che sono previsti dal nostro ordinamento?
#                                                                  557954                                                                                                                                                                                                                                                                                                                                                                                                                                                  Noi invece non abbiamo voluto osare, il Governo non ha voluto osare e ci ritroviamo con questa proposta che secondo me è assolutamente asfittica.
#                                                                  368710                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Ho preso appunti e abbiamo, infatti, già ratificato lo stesso tipo di accordo con la Colombia, con la Giamaica e con l'Uruguay.
#                                                                  45684                                                                                                                                                                                                                                                                                                                                                                                                         In tal senso, le attività dell'AIFA, per quanto attiene all'ambito regolatorio, sono sicuramente - mi permetterei di segnalarlo - coerenti con l'assetto normativo comunitario e nazionale.
#                  lista_eventi_scelti_intersezione_altri_corretti 124516                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Celentano lo diceva per la musica: se la musica viene rubata - presa gratis - sul web, gli autori non hanno remunerazione.
#                                                                  260309                                                                                                                                                                                                                                                                                                                                                  L'esigenza di coinvolgere il corpo elettorale è quindi molto presente, ma non di meno abbiamo l'esigenza di dare continuità scolastica e possibilità agli studenti di continuare regolarmente il loro corso di studi senza ripetute interruzioni.
#                                                                  440791                                                                                                                                                                                                                                                                                                                                                                                                                                                                   È giusto che guadagnino, ma questo guadagno potrebbe essere assottigliato a beneficio o dello Stato o dell'utente automobilista.
#                                                                  50850                                                                                                                                                                                                                                                                                                                                                                                                                   Proprio il processo di globalizzazione, l'introduzione di nuove tecnologie in tutti i settori della vita umana, fa sì che il fattore tempo divenga un dato ancora più essenziale.
# df_dist_30       lista_eventi_scelti_intersezione_errati         451088                                                                                                                                                                                                                                                            Con il "Drugs on street", un progetto di prevenzione notturna, con cui si mettevano insieme carabinieri, polizia, vigili urbani e associazioni di volontariato per controllare e monitorare dalle ore 23 fino alle 4 del mattino, specialmente nelle notti delle stragi, ossia il sabato sera, abbiamo ottenuto risultati straordinari.
#                                                                  289493                                                                                                                                                                                                                                                                                                                                                                                                          È un errore immaginare che il cuore di tutto siano le decisioni finanziarie: il cuore di tutto deve essere la somma delle decisioni, e bisogna cercare di mettere insieme i vari aspetti.
#                                                                  880161                                                                                                                                                                                                                                                                                                                                                                                                                                         Facciamo anche noi gli auguri al senatore Solinas, perché alleato con il centrodestra ha vinto, mentre alleati con i grillini svendono l'Italia alla Cina.
#                                                                  791038                                                                                                                                                                                                                                                                                                                                                                                                    A partire da noi, dall'Italia e dall'Europa, è necessaria una grande unità tra le forze politiche e devo dare atto ai due Ministri che sono intervenuti di aver fatto questo appello all'unità.
#                  lista_eventi_scelti_intersezione_corretti       453798                                                                                                                                                                                                                                      Per il triennio 2015 - 2017 - quindi da quest'anno fino al 2017 -, le università possono fissare il numero delle assunzioni dei professori ordinari, favorendo quindi il ricambio, perché - perdonatemi - i giovani non sono solo necessariamente ricercatori, ma possono esserci anche giovani brillanti che vanno in cattedra a un'età relativamente bassa.
#                                                                  276356                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Il Senato non approva.
#                                                                  318497                                                                                                                                                                                                                                                                                                                                                                                                                                                       Il tribunale dei Ministri, come ho detto, non ritiene che sia un atto puramente politico, ma amministrativo, quindi sindacabile dal giudice.
#                                                                  26475                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Dove li aveva Renzi?
#                  lista_eventi_scelti_intersezione_altri_errati   512684                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Bastava prendere uno di quelli che voi chiamate eroi e mandarlo all'Organizzazione mondiale della sanità.
#                                                                  280710                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Il Senato non approva.
#                                                                  637884                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        E pensiamo che questa battaglia politica che oggi combattiamo non la facciamo solo per noi.
#                                                                  634012                                                                                                                                                                                                                                                                                                                                                                                                                           Ecco perché il Gruppo di Forza Italia, a malincuore e con grande dispiacere, esprimerà un voto di astensione, quando avrebbe voluto essere favorevole.. Congratulazioni.
#                  lista_eventi_scelti_intersezione_altri_corretti 187558                                                                                                                                                                                                                                                                                                                                                                                      È del tutto evidente che in materia di protezione civile stiamo parlando di aria fritta, perché non c'è bisogno di una legge per comporre un organismo consultivo guidato dal sindaco all'interno del Comune.
#                                                                  527740                                                                                                                                                                                                                                                                                             Ebbene, si arrivò al punto - e qui interviene anche una memoria diretta e personale - che per molti mesi, signor Presidente, si scrisse che si trattava di una faida interna ai missini, come lo si scrisse per la strage di Primavalle, una vicenda che riguarda Potere operaio non le Brigate Rosse.
#                                                                  111886                                                                                                                                                                                                                                                                                                                                     In Commissione, però, grazie ad un emendamento della relatrice Granato, che all'epoca non era relatrice del provvedimento, appoggiato dalla relatrice di due settimane fa e da tutti noi, si era aumentata la quota destinata ai precari sino al 70 per cento.
#                                                                  622598                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Quindi non c'è niente di nuovo.
# ...
#                                                                  634012                38.2
#                  lista_eventi_scelti_intersezione_altri_corretti 187558                36.3
#                                                                  527740                55.0
#                                                                  111886               122.3
#                                                                  622598                38.2
# df_random_speech lista_eventi_scelti_intersezione_errati         636188                59.0
#                                                                  167370                91.5
#                                                                  44241                 45.2
#                                                                  490307               116.5
#                  lista_eventi_scelti_intersezione_corretti       136364                39.5
#                                                                  74785                 54.0
#                                                                  327854                36.9
#                                                                  598163                45.9
#                  lista_eventi_scelti_intersezione_altri_errati   18768                 62.1
#                                                                  287660                33.9
#                                                                  606882               121.5
#                                                                  191503                45.1
#                  lista_eventi_scelti_intersezione_altri_corretti 877007                34.3
#                                                                  122955                35.5
#                                                                  61619                 41.2
#                                                                  5811                  94.0
#
#                                                                          gulpease_index_S_2  \
# df_dist_5        lista_eventi_scelti_intersezione_errati         228695                38.0
#                                                                  195285               116.5
#                  lista_eventi_scelti_intersezione_corretti       518453                51.1
#                                                                  464910                43.1
#                                                                  537330                50.6
#                                                                  414778                61.0
#                  lista_eventi_scelti_intersezione_altri_errati   5733                  39.2
#                                                                  557954                50.7
#                                                                  368710                54.5
#                                                                  45684                 34.0
#                  lista_eventi_scelti_intersezione_altri_corretti 124516                53.5
#                                                                  260309                38.4
#                                                                  440791                44.0
#                                                                  50850                 46.1
# df_dist_30       lista_eventi_scelti_intersezione_errati         451088                36.9
#                                                                  289493                50.3
#                                                                  880161                46.9
#                                                                  791038                48.4
#                  lista_eventi_scelti_intersezione_corretti       453798                34.7
#                                                                  276356               116.5
#                                                                  318497                46.1
#                                                                  26475                121.5
#                  lista_eventi_scelti_intersezione_altri_errati   512684                48.3
#                                                                  280710               116.5
#                                                                  637884                57.7
#                                                                  634012                41.1
#                  lista_eventi_scelti_intersezione_altri_corretti 187558                45.7
#                                                                  527740                46.4
#                                                                  111886                44.1
#                                                                  622598                95.7
# df_random_speech lista_eventi_scelti_intersezione_errati         636188                47.6
#                                                                  167370                74.5
#                                                                  44241                 34.2
#                                                                  490307                38.9
#                  lista_eventi_scelti_intersezione_corretti       136364                55.7
#                                                                  74785                 41.4
#                                                                  327854                36.0
#                                                                  598163               119.0
#                  lista_eventi_scelti_intersezione_altri_errati   18768                 75.0
#                                                                  287660                49.4
#                                                                  606882                50.2
#                                                                  191503                47.9
#                  lista_eventi_scelti_intersezione_altri_corretti 877007                44.2
#                                                                  122955                36.2
#                                                                  61619                 47.2
#                                                                  5811                  81.0
#
#                                                                          flesch_reading_ease_S_1_S_2  \
# df_dist_5        lista_eventi_scelti_intersezione_errati         228695                        45.22
#                                                                  195285                        68.43
#                  lista_eventi_scelti_intersezione_corretti       518453                        48.81
#                                                                  464910                        45.94
#                                                                  537330                        27.84
#                                                                  414778                        39.93
#                  lista_eventi_scelti_intersezione_altri_errati   5733                          48.99
#                                                                  557954                        58.58
#                                                                  368710                        72.30
#                                                                  45684                          8.05
#                  lista_eventi_scelti_intersezione_altri_corretti 124516                        55.37
#                                                                  260309                        13.68
#                                                                  440791                        51.67
#                                                                  50850                         54.43
# df_dist_30       lista_eventi_scelti_intersezione_errati         451088                         9.20
#                                                                  289493                        42.73
#                                                                  880161                        59.45
#                                                                  791038                        46.65
#                  lista_eventi_scelti_intersezione_corretti       453798                        37.88
#                                                                  276356                        49.35
#                                                                  318497                        50.80
#                                                                  26475                         71.55
#                  lista_eventi_scelti_intersezione_altri_errati   512684                        42.08
#                                                                  280710                        40.15
#                                                                  637884                        92.77
#                                                                  634012                        36.36
#                  lista_eventi_scelti_intersezione_altri_corretti 187558                        33.11
#                                                                  527740                        54.08
#                                                                  111886                        60.24
#                                                                  622598                        39.03
# df_random_speech lista_eventi_scelti_intersezione_errati         636188                        59.34
#                                                                  167370                        68.68
#                                                                  44241                         21.85
#                                                                  490307                        25.17
#                  lista_eventi_scelti_intersezione_corretti       136364                        56.51
#                                                                  74785                         40.89
#                                                                  327854                        24.61
#                                                                  598163                        58.54
#                  lista_eventi_scelti_intersezione_altri_errati   18768                         61.96
#                                                                  287660                        33.22
#                                                                  606882                        71.97
#                                                                  191503                        54.57
#                  lista_eventi_scelti_intersezione_altri_corretti 877007                         9.61
#                                                                  122955                        23.96
#                                                                  61619                         47.02
#                                                                  5811                          63.69
#
#                                                                          gulpease_index_S_1_S_2
# df_dist_5        lista_eventi_scelti_intersezione_errati         228695                    43.3
#                                                                  195285                    68.5
#                  lista_eventi_scelti_intersezione_corretti       518453                    49.5
#                                                                  464910                    47.5
#                                                                  537330                    39.4
#                                                                  414778                    44.7
#                  lista_eventi_scelti_intersezione_altri_errati   5733                      44.5
#                                                                  557954                    50.2
#                                                                  368710                    54.8
#                                                                  45684                     31.1
#                  lista_eventi_scelti_intersezione_altri_corretti 124516                    48.0
#                                                                  260309                    38.5
#                                                                  440791                    46.9
#                                                                  50850                     47.8
# df_dist_30       lista_eventi_scelti_intersezione_errati         451088                    35.8
#                                                                  289493                    44.4
#                                                                  880161                    51.3
#                                                                  791038                    47.0
#                  lista_eventi_scelti_intersezione_corretti       453798                    40.6
#                                                                  276356                    64.9
#                                                                  318497                    44.9
#                                                                  26475                     56.2
#                  lista_eventi_scelti_intersezione_altri_errati   512684                    42.8
#                                                                  280710                    72.5
#                                                                  637884                    64.2
#                                                                  634012                    39.3
#                  lista_eventi_scelti_intersezione_altri_corretti 187558                    40.5
#                                                                  527740                    48.9
#                                                                  111886                    49.5
#                                                                  622598                    43.1
# df_random_speech lista_eventi_scelti_intersezione_errati         636188                    52.8
#                                                                  167370                    81.6
#                                                                  44241                     38.9
#                                                                  490307                    42.2
#                  lista_eventi_scelti_intersezione_corretti       136364                    47.4
#                                                                  74785                     46.6
#                                                                  327854                    36.5
#                                                                  598163                    49.9
#                  lista_eventi_scelti_intersezione_altri_errati   18768                     65.7
#                                                                  287660                    40.2
#                                                                  606882                    60.0
#                                                                  191503                    46.5
#                  lista_eventi_scelti_intersezione_altri_corretti 877007                    36.8
#                                                                  122955                    35.7
#                                                                  61619                     44.0
#                                                                  5811                      89.0

# %%
df_indici_leggibilita_per_tipo_per_anno_svm_5
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Sentence_1  \
# lista_eventi_scelti_intersezione_errati         228695                                                                                                                                                                                                                                                                                                                                                                   Il più comprende il meno, seppur fosse discutibile la questione che pongo.
#                                                 195285                                                                                                                                                                                                                                                                                                        Passiamo all'emendamento 13.0.13, su cui la 5ᵃ Commissione ha espresso parere contrario ai sensi dell'articolo 81 della Costituzione.
# lista_eventi_scelti_intersezione_corretti       518453                                                                                                                                                                                                                                              Nei mari adiacenti, per il contrasto al fenomeno della pirateria, l'Italia partecipa alla missione europea Atalanta, con 2 mezzi navali, 2 aerei e un numero massimo di 407 unità di personale.
#                                                 464910                                                                                                                                                                                                                                                                                      È cosa ben strana che si registri un dibattito sulla legge principale, che è la legge di stabilità, e non si senta la maggioranza difendere il Governo.
#                                                 464910                                                                     Non capisco se questo è dovuto al tentativo di anticipare quanto prima - saranno contenti loro - l'incardinamento della legge elettorale, o se, invece, è perché hanno serie difficoltà a difendere il Governo e a parlare bene della legge di stabilità.
#                                                 537330                                                                                                                                           La più indebitata, guarda caso, era quella del Maggio musicale fiorentino, per cui si è fatta anche la norma, è chiaro, infatti, che si doveva poi soddisfare le esigenze di tutti.
#                                                 414778                                                                                                                                                                                                                                        E così è avvenuto, perché nel frattempo i contrasti di quel giorno si sono stemperati.
# lista_eventi_scelti_intersezione_altri_errati   5733    Come si fa a prendere come riferimento, per esempio, qualche altro Paese europeo che utilizza il meccanismo di elezione indiretta di una Camera, ma che nell'altro ramo del Parlamento utilizza il sistema proporzionale senza sbarramenti o comunque senza i premi di maggioranza che sono previsti dal nostro ordinamento?
#                                                 557954                                                                                                                                                                             Noi invece non abbiamo voluto osare, il Governo non ha voluto osare e ci ritroviamo con questa proposta che secondo me è assolutamente asfittica.
#                                                 368710                                                                                                                                                                                               Ho preso appunti e abbiamo, infatti, già ratificato lo stesso tipo di accordo con la Colombia, con la Giamaica e con l'Uruguay.
#                                                 45684                                                                                                                                    In tal senso, le attività dell'AIFA, per quanto attiene all'ambito regolatorio, sono sicuramente - mi permetterei di segnalarlo - coerenti con l'assetto normativo comunitario e nazionale.
# lista_eventi_scelti_intersezione_altri_corretti 124516                                                                                                                                                                                                    Celentano lo diceva per la musica: se la musica viene rubata - presa gratis - sul web, gli autori non hanno remunerazione.
#                                                 260309                                                                             L'esigenza di coinvolgere il corpo elettorale è quindi molto presente, ma non di meno abbiamo l'esigenza di dare continuità scolastica e possibilità agli studenti di continuare regolarmente il loro corso di studi senza ripetute interruzioni.
#                                                 440791                                                                                                                                                                                              È giusto che guadagnino, ma questo guadagno potrebbe essere assottigliato a beneficio o dello Stato o dell'utente automobilista.
#                                                 50850                                                                                                                                              Proprio il processo di globalizzazione, l'introduzione di nuove tecnologie in tutti i settori della vita umana, fa sì che il fattore tempo divenga un dato ancora più essenziale.
#
#                                                         Class  \
# lista_eventi_scelti_intersezione_errati         228695      0
#                                                 195285      1
# lista_eventi_scelti_intersezione_corretti       518453      0
#                                                 464910      0
#                                                 537330      0
#                                                 414778      0
# lista_eventi_scelti_intersezione_altri_errati   5733        1
#                                                 557954      1
#                                                 368710      0
#                                                 45684       1
# lista_eventi_scelti_intersezione_altri_corretti 124516      0
#                                                 260309      0
#                                                 440791      0
#                                                 50850       0
#
#                                                         flesch_reading_ease_S_1  \
# lista_eventi_scelti_intersezione_errati         228695                    81.40
#                                                 195285                    61.96
# lista_eventi_scelti_intersezione_corretti       518453                    47.04
#                                                 464910                    66.34
#                                                 537330                     0.66
#                                                 414778                     6.74
# lista_eventi_scelti_intersezione_altri_errati   5733                      78.50
#                                                 557954                   124.40
#                                                 368710                    72.42
#                                                 45684                    -10.77
# lista_eventi_scelti_intersezione_altri_corretti 124516                    43.70
#                                                 260309                    -0.15
#                                                 440791                    61.12
#                                                 50850                     59.30
#
#                                                         flesch_reading_ease_S_2  \
# lista_eventi_scelti_intersezione_errati         228695                    20.98
#                                                 195285                    91.80
# lista_eventi_scelti_intersezione_corretti       518453                    44.40
#                                                 464910                    29.38
#                                                 537330                    62.52
#                                                 414778                    81.52
# lista_eventi_scelti_intersezione_altri_errati   5733                      20.86
#                                                 557954                    58.30
#                                                 368710                    71.10
#                                                 45684                     23.32
# lista_eventi_scelti_intersezione_altri_corretti 124516                    65.00
#                                                 260309                    24.08
#                                                 440791                    40.24
#                                                 50850                     49.86
#
#                                                         gulpease_index_S_1  \
# lista_eventi_scelti_intersezione_errati         228695                61.5
#                                                 195285                57.9
# lista_eventi_scelti_intersezione_corretti       518453                46.7
#                                                 464910                53.8
#                                                 537330                31.3
#                                                 414778                40.8
# lista_eventi_scelti_intersezione_altri_errati   5733                  95.0
#                                                 557954               194.0
#                                                 368710                55.3
#                                                 45684                 29.9
# lista_eventi_scelti_intersezione_altri_corretti 124516                45.3
#                                                 260309                38.5
#                                                 440791                49.5
#                                                 50850                 49.9
#
#                                                         gulpease_index_S_2  \
# lista_eventi_scelti_intersezione_errati         228695                38.0
#                                                 195285               116.5
# lista_eventi_scelti_intersezione_corretti       518453                51.1
#                                                 464910                43.1
#                                                 537330                50.6
#                                                 414778                61.0
# lista_eventi_scelti_intersezione_altri_errati   5733                  39.2
#                                                 557954                50.7
#                                                 368710                54.5
#                                                 45684                 34.0
# lista_eventi_scelti_intersezione_altri_corretti 124516                53.5
#                                                 260309                38.4
#                                                 440791                44.0
#                                                 50850                 46.1
#
#                                                         flesch_reading_ease_S_1_S_2  \
# lista_eventi_scelti_intersezione_errati         228695                        45.22
#                                                 195285                        68.43
# lista_eventi_scelti_intersezione_corretti       518453                        48.81
#                                                 464910                        45.94
#                                                 537330                        27.84
#                                                 414778                        39.93
# lista_eventi_scelti_intersezione_altri_errati   5733                          48.99
#                                                 557954                        58.58
#                                                 368710                        72.30
#                                                 45684                          8.05
# lista_eventi_scelti_intersezione_altri_corretti 124516                        55.37
#                                                 260309                        13.68
#                                                 440791                        51.67
#                                                 50850                         54.43
#
#                                                         gulpease_index_S_1_S_2
# lista_eventi_scelti_intersezione_errati         228695                    43.3
#                                                 195285                    68.5
# lista_eventi_scelti_intersezione_corretti       518453                    49.5
#                                                 464910                    47.5
#                                                 537330                    39.4
#                                                 414778                    44.7
# lista_eventi_scelti_intersezione_altri_errati   5733                      44.5
#                                                 557954                    50.2
#                                                 368710                    54.8
#                                                 45684                     31.1
# lista_eventi_scelti_intersezione_altri_corretti 124516                    48.0
#                                                 260309                    38.5
#                                                 440791                    46.9
#                                                 50850                     47.8

# %% [markdown]
# Errati da tutti
# Id 228695: leggibilità non alta, soprattutto per la seconda frase. Anche qui però proba del 50% circa per tutti.
#
# Id 195285: la prima frase risulta più difficile da leggere. Errato da tutti ma con proba del 50%.
#
# Corretti da tutti
# Id 518453: leggibilità non alta; corretto da tutti, ma con proba bassa.
#
# Id 464910: leggibilità più bassa per la seconda frase; proba 50% circa.
#
# Le rimanenti come sopra.
#
# Errati da uno solo: proba del 50%
#
# Corretti da uno solo: proba del 50%

# %%
df_indici_leggibilita_per_tipo_per_anno_svm_30
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Sentence_1  \
# lista_eventi_scelti_intersezione_errati         451088                                                                                                                                                                                                                                                                                                                                                                                                                         Assolutamente no.
#                                                 289493                                                                                                                                                                                                                 Cito questo punto perché l'ho considerato un passo avanti molto importante delle istituzioni internazionali, che guardano e devono guardare sempre di più ai temi non soltanto nella centralità degli aspetti finanziari.
#                                                 880161                                                                                                                                                                                                                                                                                                                                                                                      Il senatore Solinas entra in Aula.. Congratulazioni.
#                                                 791038                                                                                                                                                                                              Analogamente è stato fatto in Egitto e in Algeria e analogamente viene fatto, per due volte, nella patria dell'illuminismo e della cultura europea, proprio in un centro che è il grande polo di attrazione turistica e culturale del mondo.
# lista_eventi_scelti_intersezione_corretti       453798                                                                                                                         In primo luogo, le università cosiddette virtuose, cioè quelle con parametri di bilancio previsti dal decreto legislativo n. 49 del 2012, possono riutilizzare per intero i punti organico che si sono liberati per cessazione dei contratti dei ricercatori di tipo A, quelli senza tenure track per intenderci.
#                                                 276356                                                                                                                                                                                                                                                                                             Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 2.44, presentato dal senatore D'Ambrosio Lettieri e da altri senatori.
#                                                 318497                                                                                                                                                                                                                        Non c'entrano niente l'articolo 68 o altri aspetti della tutela della funzione parlamentare: qui c'è una legge del 1989 che riguarda le funzioni del Governo e dei Ministri, alla quale abbiamo fatto riferimento.
#                                                 26475                                                                                                                                                                                            Ricordo che quando tenemmo il primo incontro dopo il primo terremoto Renzi diceva di avere tutti i soldi per la ricostruzione: lo avete detto in Parlamento a gente che è ancora in mezzo alla strada perché i soldi non li avete tirati fuori.
# lista_eventi_scelti_intersezione_altri_errati   512684                                              Questa è l'essenza di questo Governo: togliere le libertà democratiche al nostro Paese, in uno Stato, signor Ministro, dove proprio in vista della stagione turistica si è permesso di tutto e di più, senza controlli, perché chi doveva controllare non ha controllato, per poi puntare il dito sulle Regioni, per poi dire che il Presidente della Regione Sardegna è stato inefficiente.
#                                                 280710                                                                                                                                                                                                                                                                                                                           Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 8.135, presentato dal senatore Arrigoni.
#                                                 637884                                                                                                                                                                                                                                                                                                                                                                             Tuttavia, penso che su questo ci voglia un po' più di umiltà.
#                                                 634012                                                                                                                                                                      In più, leggendo le disposizioni che si vogliono introdurre con questo disegno di legge, si delinea un regime fortemente repressivo, peraltro dal profilo incerto; talvolta l'aspetto repressivo non assume i connotati di qualcosa che possa risolvere il problema.
# lista_eventi_scelti_intersezione_altri_corretti 187558                                                                                                                                                  Il testo che abbiamo esaminato questa mattina prevede, invece, di istituire un apposito organismo consultivo, con la partecipazione di rappresentanti di tutti i soggetti pubblici e privati, e che ai componenti dei predetti organismi non spetta alcun compenso, indennità, eccetera.
#                                                 527740                                                                                                                                                                                                                                                                                                                     Lo dico anche agli editori: non si deve censurare nulla, ma allora si pubblicassero i libri nella collana dei Gialli.
#                                                 111886                                                                                                                                                                                                                                                                                                                                                                                                                    Questo serve, infatti.
#                                                 622598                                                                                                                                                                                                                                                                                                                                Quindi non c'è niente di nuovo.
#
#                                                         Class  \
# lista_eventi_scelti_intersezione_errati         451088      1
#                                                 289493      0
#                                                 880161      0
#                                                 791038      0
# lista_eventi_scelti_intersezione_corretti       453798      0
#                                                 276356      0
#                                                 318497      0
#                                                 26475       0
# lista_eventi_scelti_intersezione_altri_errati   512684      1
#                                                 280710      0
#                                                 637884      1
#                                                 634012      1
# lista_eventi_scelti_intersezione_altri_corretti 187558      0
#                                                 527740      1
#                                                 111886      1
#                                                 622598      0
#
#                                                         flesch_reading_ease_S_1  \
# lista_eventi_scelti_intersezione_errati         451088                     4.40
#                                                 289493                    35.40
#                                                 880161                    45.06
#                                                 791038                    41.68
# lista_eventi_scelti_intersezione_corretti       453798                    53.67
#                                                 276356                    38.62
#                                                 318497                    48.64
#                                                 26475                     45.30
# lista_eventi_scelti_intersezione_altri_errati   512684                    15.72
#                                                 280710                    23.93
#                                                 637884                   111.40
#                                                 634012                    27.08
# lista_eventi_scelti_intersezione_altri_corretti 187558                    18.00
#                                                 527740                    71.00
#                                                 111886                    73.12
#                                                 622598                    -3.23
#
#                                                         flesch_reading_ease_S_2  \
# lista_eventi_scelti_intersezione_errati         451088                    14.62
#                                                 289493                    49.76
#                                                 880161                    55.78
#                                                 791038                    51.62
# lista_eventi_scelti_intersezione_corretti       453798                    11.28
#                                                 276356                    91.80
#                                                 318497                    49.72
#                                                 26475                    106.80
# lista_eventi_scelti_intersezione_altri_errati   512684                    57.52
#                                                 280710                    91.80
#                                                 637884                    77.50
#                                                 634012                    45.82
# lista_eventi_scelti_intersezione_altri_corretti 187558                    50.44
#                                                 527740                    35.60
#                                                 111886                    36.38
#                                                 622598                   119.20
#
#                                                         gulpease_index_S_1  \
# lista_eventi_scelti_intersezione_errati         451088               159.0
#                                                 289493                38.4
#                                                 880161                66.1
#                                                 791038                45.9
# lista_eventi_scelti_intersezione_corretti       453798                46.7
#                                                 276356                53.4
#                                                 318497                44.2
#                                                 26475                 50.2
# lista_eventi_scelti_intersezione_altri_errati   512684                41.5
#                                                 280710                59.0
#                                                 637884                72.3
#                                                 634012                38.2
# lista_eventi_scelti_intersezione_altri_corretti 187558                36.3
#                                                 527740                55.0
#                                                 111886               122.3
#                                                 622598                38.2
#
#                                                         gulpease_index_S_2  \
# lista_eventi_scelti_intersezione_errati         451088                36.9
#                                                 289493                50.3
#                                                 880161                46.9
#                                                 791038                48.4
# lista_eventi_scelti_intersezione_corretti       453798                34.7
#                                                 276356               116.5
#                                                 318497                46.1
#                                                 26475                121.5
# lista_eventi_scelti_intersezione_altri_errati   512684                48.3
#                                                 280710               116.5
#                                                 637884                57.7
#                                                 634012                41.1
# lista_eventi_scelti_intersezione_altri_corretti 187558                45.7
#                                                 527740                46.4
#                                                 111886                44.1
#                                                 622598                95.7
#
#                                                         flesch_reading_ease_S_1_S_2  \
# lista_eventi_scelti_intersezione_errati         451088                         9.20
#                                                 289493                        42.73
#                                                 880161                        59.45
#                                                 791038                        46.65
# lista_eventi_scelti_intersezione_corretti       453798                        37.88
#                                                 276356                        49.35
#                                                 318497                        50.80
#                                                 26475                         71.55
# lista_eventi_scelti_intersezione_altri_errati   512684                        42.08
#                                                 280710                        40.15
#                                                 637884                        92.77
#                                                 634012                        36.36
# lista_eventi_scelti_intersezione_altri_corretti 187558                        33.11
#                                                 527740                        54.08
#                                                 111886                        60.24
#                                                 622598                        39.03
#
#                                                         gulpease_index_S_1_S_2
# lista_eventi_scelti_intersezione_errati         451088                    35.8
#                                                 289493                    44.4
#                                                 880161                    51.3
#                                                 791038                    47.0
# lista_eventi_scelti_intersezione_corretti       453798                    40.6
#                                                 276356                    64.9
#                                                 318497                    44.9
#                                                 26475                     56.2
# lista_eventi_scelti_intersezione_altri_errati   512684                    42.8
#                                                 280710                    72.5
#                                                 637884                    64.2
#                                                 634012                    39.3
# lista_eventi_scelti_intersezione_altri_corretti 187558                    40.5
#                                                 527740                    48.9
#                                                 111886                    49.5
#                                                 622598                    43.1

# %% [markdown]
# Hanno tutti proba intorno al 50%.

# %%
df_indici_leggibilita_per_tipo_per_anno_svm_random_speech
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Sentence_1  \
# lista_eventi_scelti_intersezione_errati         636188                                                                                                                                                                                                                                                                                                                                                                                                                                                   Ha facoltà di parlare il presidente del Consiglio dei ministri, dottor Renzi.
#                                                 167370                                                                                                                                                                                                                                                                                                                                                                                                                                                               Signor Presidente, il parere sull'emendamento 34.200 è contrario.
#                                                 44241                                                                                                                                                                                                                                                                                             Un Governo come quello Renzi, che fa di un argomento etico il fondamento del suo programma e che perciò pone su di esso una questione di fiducia, assume conseguentemente, fortemente, prepotentemente la forma di un Governo etico.
#                                                 490307                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Il Senato non approva.
# lista_eventi_scelti_intersezione_corretti       136364                                                                                                                                                                                                                                                                                                                                                                È davvero assurdo scrivere un emendamento, che per carità condividiamo, in cui prevediamo una premialità per la denuncia obbligatoria delle richieste estorsive.
#                                                 74785                                                                                                                                                                                                                                                                                                                                                                                                                                              Se mi è consentito, vorrei invitare i senatori proponenti a ritirare l'emendamento.
#                                                 327854                                                                                                                                                                                                                                                                                      Un ulteriore elemento, giustamente evidenziato e che ha anch'esso caratterizzato i lavori della Giunta, riguarda l'allocazione dei costi, o meglio, la previsione dei costi e la loro allocazione all'interno del Consiglio di Presidenza.
#                                                 598163                                                                                                                                                                                                                    Quindi, se a un certo punto la Francia decide di bombardare la Libia, va bene, perché non c'è un vincolo europeo che impedisca di muovere guerra contro gli interessi di un altro Stato membro dell'Unione europea; in compenso, ci dicono se le materie fecali le dobbiamo trattare come rifiuti oppure no.
# lista_eventi_scelti_intersezione_altri_errati   18768                                                                                                                                                                                                                                                                                                                                                                                                                                                    Venendo al disegno di legge di ratifica, esso si compone di quattro articoli.
#                                                 287660                                                                                                                                                                                                                                     Signor Presidente, onorevoli colleghi, volevo dire innanzitutto, con particolare riguardo all'intervento della senatrice De Petris, che è mio per prima il rammarico di non avere potuto convocare la Commissione per prendere atto della calendarizzazione in Aula della legge elettorale.
#                                                 606882                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Passiamo alla votazione dell'articolo 90.
#                                                 287660                                                                                                                                                                                                                                                                                                                                                                                                                                Tutti i colleghi hanno visto che ciò è stato impossibile per mancanza di una soluzione di continuità tra la Conferenza dei Capigruppo e l'inizio dei lavori d'Aula.
#                                                 606882                                                                                                                                                                                                                                                                                                                                                                                                                                            Il Governo, dunque, sta facendo tutto il possibile per migliorare la vita degli italiani e dare un impulso forte al rilancio economico e alla crescita.
#                                                 191503                                                                                                                                                                                                                                                                                                                                                                                                                       Se si fa un'affermazione simile e poi si dà la colpa alla maggioranza dell'aumento dello spread e della sfiducia dei mercati verso l'Italia, è sempre un concetto sbagliato.
# lista_eventi_scelti_intersezione_altri_corretti 877007                                                                                                                                                                                                                                                                                                                                                                                                                             Ricordo che gli emendamenti approvati dalla Commissione sono stati inviati ai Gruppi, che hanno quindi un'ora di tempo a partire da ora per presentare subemendamenti.
#                                                 122955                                                                                                                                                                                                                                                                                                                                                                                                                                                     In questo contesto, come la storia insegna, sono compatibili modelli elettorali puramente proporzionali, modelli misti o modelli maggioritari.
#                                                 61619                                                                                                                                                                                                                                                                                                                                                                                                                      La revisione dei meccanismi di indicizzazione del provvedimento del 2011 ha interessato infatti circa il 30 per cento dei pensionati, vale a dire 4, 400 milioni di cittadini.
#                                                 5811                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               L'emendamento 23.410 è stato ritirato.
#
#                                                         Class  \
# lista_eventi_scelti_intersezione_errati         636188      0
#                                                 167370      0
#                                                 44241       1
#                                                 490307      1
# lista_eventi_scelti_intersezione_corretti       136364      0
#                                                 74785       1
#                                                 327854      1
#                                                 598163      0
# lista_eventi_scelti_intersezione_altri_errati   18768       1
#                                                 287660      0
#                                                 606882      1
#                                                 191503      0
# lista_eventi_scelti_intersezione_altri_corretti 877007      0
#                                                 122955      1
#                                                 61619       1
#                                                 5811        0
#
#                                                         flesch_reading_ease_S_1  \
# lista_eventi_scelti_intersezione_errati         636188                    76.42
#                                                 167370                    54.30
#                                                 44241                     44.04
#                                                 490307                    91.80
# lista_eventi_scelti_intersezione_corretti       136364                    41.10
#                                                 74785                     41.38
#                                                 327854                    28.66
#                                                 598163                    30.70
# lista_eventi_scelti_intersezione_altri_errati   18768                     70.86
#                                                 287660                    14.02
#                                                 606882                    91.80
#                                                 191503                    48.96
# lista_eventi_scelti_intersezione_altri_corretti 877007                   -25.13
#                                                 122955                    19.26
#                                                 61619                     44.12
#                                                 5811                      69.30
#
#                                                         flesch_reading_ease_S_2  \
# lista_eventi_scelti_intersezione_errati         636188                    44.54
#                                                 167370                    78.93
#                                                 44241                      3.20
#                                                 490307                   -31.87
# lista_eventi_scelti_intersezione_corretti       136364                    72.58
#                                                 74785                     39.62
#                                                 327854                    20.02
#                                                 598163                    33.10
# lista_eventi_scelti_intersezione_altri_errati   18768                     30.50
#                                                 287660                    57.46
#                                                 606882                    57.30
#                                                 191503                    60.60
# lista_eventi_scelti_intersezione_altri_corretti 877007                    50.10
#                                                 122955                    23.62
#                                                 61619                     49.86
#                                                 5811                      54.50
#
#                                                         gulpease_index_S_1  \
# lista_eventi_scelti_intersezione_errati         636188                59.0
#                                                 167370                91.5
#                                                 44241                 45.2
#                                                 490307               116.5
# lista_eventi_scelti_intersezione_corretti       136364                39.5
#                                                 74785                 54.0
#                                                 327854                36.9
#                                                 598163                45.9
# lista_eventi_scelti_intersezione_altri_errati   18768                 62.1
#                                                 287660                33.9
#                                                 606882               121.5
#                                                 191503                45.1
# lista_eventi_scelti_intersezione_altri_corretti 877007                34.3
#                                                 122955                35.5
#                                                 61619                 41.2
#                                                 5811                  94.0
#
#                                                         gulpease_index_S_2  \
# lista_eventi_scelti_intersezione_errati         636188                47.6
#                                                 167370                74.5
#                                                 44241                 34.2
#                                                 490307                38.9
# lista_eventi_scelti_intersezione_corretti       136364                55.7
#                                                 74785                 41.4
#                                                 327854                36.0
#                                                 598163               119.0
# lista_eventi_scelti_intersezione_altri_errati   18768                 75.0
#                                                 287660                49.4
#                                                 606882                50.2
#                                                 191503                47.9
# lista_eventi_scelti_intersezione_altri_corretti 877007                44.2
#                                                 122955                36.2
#                                                 61619                 47.2
#                                                 5811                  81.0
#
#                                                         flesch_reading_ease_S_1_S_2  \
# lista_eventi_scelti_intersezione_errati         636188                        59.34
#                                                 167370                        68.68
#                                                 44241                         21.85
#                                                 490307                        25.17
# lista_eventi_scelti_intersezione_corretti       136364                        56.51
#                                                 74785                         40.89
#                                                 327854                        24.61
#                                                 598163                        58.54
# lista_eventi_scelti_intersezione_altri_errati   18768                         61.96
#                                                 287660                        33.22
#                                                 606882                        71.97
#                                                 191503                        54.57
# lista_eventi_scelti_intersezione_altri_corretti 877007                         9.61
#                                                 122955                        23.96
#                                                 61619                         47.02
#                                                 5811                          63.69
#
#                                                         gulpease_index_S_1_S_2
# lista_eventi_scelti_intersezione_errati         636188                    52.8
#                                                 167370                    81.6
#                                                 44241                     38.9
#                                                 490307                    42.2
# lista_eventi_scelti_intersezione_corretti       136364                    47.4
#                                                 74785                     46.6
#                                                 327854                    36.5
#                                                 598163                    49.9
# lista_eventi_scelti_intersezione_altri_errati   18768                     65.7
#                                                 287660                    40.2
#                                                 606882                    60.0
#                                                 191503                    46.5
# lista_eventi_scelti_intersezione_altri_corretti 877007                    36.8
#                                                 122955                    35.7
#                                                 61619                     44.0
#                                                 5811                      89.0

# %% [markdown]
# Errati da uno solo
# Id 18768:
# Le frasi risultano abbastanza semplici da leggere; la classificazione errata non ha una probabilità alta.
#
# Id 287660:
# in questo caso la prima frase risulta molto complessa; la classificazione errata non ha una probabilità alta.
#
# Id 606882:
# in questo caso le frasi sono semplici; la classificazione errata non ha una probabilità alta.
#
# Id 191503:
# in questo caso le frasi sono abbastanza semplici; la classificazione errata non ha una probabilità alta. Anche in questo caso le probabilità basse possono essere dovute anche a un lessico molto specifico che può avere comportato difficoltà per la classificazione.
#
# Corretti da uno solo
# Id 877007, 122955 e 61619:
# Le frasi risultano complesse, specialemente la prima; l'unica classifficazione corretta riporta un punteggio di probabilità basso.
# Per questi 3 eventi riscontriamo un lessico molto ricco, che può avere comportato ulteriori difficoltà per la classificazione.
#
# Id 61619:
# le due frasi sono semplici; l'unica classifficazione corretta riporta un punteggio di probabilità del 50%.
#
#
# Errati da tutti
# Id 636188:
# Le frasi non risultano complesse in termini di leggibilità; sebbene le probabilità delle classificazioni non siano molto alte, effettivamente le frasi potrebbero anche non essere consecutive.
#
# Id 167370:
# le due frasi non risultano molto complesse; probabilmente la classificazione errata è dovuta al fatto che sembra che le frasi esprimano lo stesso concetto.
#
# Id 44241:
# Le frasi in questo caso sono molto complesse, specialmente la seconda. La considerazione delle stesse come consecutive riporta degli score di probabilità molto bassi.
#
# Id 490307:
# In questo casoo c'è una grandissima differenza in termini di leggibilità delle frasi, infatti la seconda risulta estremamente complessa; ciononostante, le due frasi potrebbero essere considerate anche consecutive, come da classificazionne errata.
#
# Corretti da tutti
# Id 136364:
# La seconda frase risulta più semplice della prima; si ripete in entrambe lo stesso tema, ma la probabilità di classificazione risulta in generale abbastanza bassa.
#
# Id 74785:
# Le frasi non risultano semplicissime in termini di leggibilità. La probabilità di classificazione risulta abbastanza bassa: probabilmente questo è dovuto al fatto che si ripetono in entrambe le frasi termini simili.
#
# Id 327854:
# Entrambe le frasi risultano complesse in termini di leggibilità; tuttavia, la clasificazione risulta corretta per evidente mancanza di nesso logico fra le due frasi.
#
# Id 598163:
# La prima frase risulta molto difficile in termini di leggibilità; la classificazione è stata eseguita in modo corretto da tutti, sebbene con una probabilità in generale bassa.

# %% [markdown]
# Errati da tutti
# Id 636168: leggibilità della seconda più bassa --> proba più alta.
#
# Id 167370: leggibilità abbastanza alta per entrambe; proba alta --> non sembra esserci un filo logico.
#
# Id 44241: in questo caso entrambe le frasi sono poco leggibili, soprattutto la seconda.
#
# Id 490307: differenza importante di difficoltà di lettura fra la prima e la seconda frase.
#
# Corretti da tutti
# Id 136364: leggibilità più alta e condivisione del tema; proba più alte, circa del 60%.
#
# Id 74785: leggibilità medio-bassa, proba media.
#
# Id 327854: caso interessante --> leggibilità bassa per entrambe le frasi, ma tutti corretto, anche se proba bassa.
#
# Id 598163: prima frase molto complicata da leggere --> tutti corretti ma terza epoca e ultime due con proba più alta.
#
# Errati da uno solo
# Sempre proba abbastanza basse
#
# Corretti da uno solo
# Annche qua proba abbastanza basse

# %%
df_indici_leggibilita_per_tipo_per_anno_bert = pd.DataFrame.from_dict({(i, j, z): diz_indici_leggibilita_per_tipo_per_anno_bert[i][j][z] 
                           for i in diz_indici_leggibilita_per_tipo_per_anno_bert.keys() 
                           for j in diz_indici_leggibilita_per_tipo_per_anno_bert[i].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_bert[i][j].keys()},
                       orient='index')

# %%
df_indici_leggibilita_per_tipo_per_anno_bert_5 = pd.DataFrame.from_dict({(j, z): diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_5'][j][z] 
                           for j in diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_5'].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_5'][j].keys()},
                       orient='index')

# %%
df_indici_leggibilita_per_tipo_per_anno_bert_30 = pd.DataFrame.from_dict({(j, z): diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_30'][j][z] 
                           for j in diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_30'].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_30'][j].keys()},
                       orient='index')

# %%
df_indici_leggibilita_per_tipo_per_anno_bert_random_speech = pd.DataFrame.from_dict({(j, z): diz_indici_leggibilita_per_tipo_per_anno_bert['df_random_speech'][j][z] 
                           for j in diz_indici_leggibilita_per_tipo_per_anno_bert['df_random_speech'].keys()
                           for z in diz_indici_leggibilita_per_tipo_per_anno_bert['df_random_speech'][j].keys()},
                       orient='index')

# %%
def costruisci_df_classificazioni_corrette_errate_da_tutti_svm(params, tipo_classificazioni, indici_leggibilita):
    
    mldx_arrays_totali = []
    
    lista_eventi = []
    lista_classi = []
    lista_predizioni = []
    lista_intestazioni = []
    chiavi = {}
    
    
    for evento in params:
    
        #Creo gli indici della tabella (Id, Classe, Predizione, Frasi, Probabilità e Indici leggibilità)
        lista_eventi.extend([evento]*4)
        lista_classi.extend([params[evento]['Class']]*4)
        lista_predizioni.extend([params[evento]['Pred']]*4)
        lista_intestazioni.extend(['S_1', 'S_2', 'P', 'Idx_l'])
        chiavi[evento] = {}
        chiavi[evento]['S_1'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'S_1')
        chiavi[evento]['S_2'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'S_2')
        chiavi[evento]['P'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'P')
        chiavi[evento]['Idx_l'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'Idx_l')

    mldx_arrays_totali.append(lista_eventi)
    mldx_arrays_totali.append(lista_classi)
    mldx_arrays_totali.append(lista_predizioni)
    mldx_arrays_totali.append(lista_intestazioni)
        
    multiindex_df = pd.DataFrame(index=mldx_arrays_totali, columns=['']*12)
    
    for evento in params:
        #valorizzo la prima colona con la frase S1 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_1']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_1']][0] = params[evento]['Sentence_1']
        
        #valorizzo la prima colona con la frase S2 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_2']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_2']][0] = params[evento]['Sentence_2']
        
        #Probabilità
        proba = [params[evento][prob] for prob in params[evento] if prob.startswith('clf')]
        multiindex_df.loc[chiavi[evento]['P']] = proba
        
        #Indici di leggibilità
        idx_leggibilita = []
        
        for i in indici_leggibilita[evento].keys():
            if i == 'flesch_reading_ease_S_1':
                idx_leggibilita.extend(['FR_1', indici_leggibilita[evento][i]])
            if i == 'flesch_reading_ease_S_2':
                idx_leggibilita.extend(['FR_2', indici_leggibilita[evento][i]])
                
            if i == 'gulpease_index_S_1':
                idx_leggibilita.extend(['GI_1', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_2':
                idx_leggibilita.extend(['GI_2', indici_leggibilita[evento][i]])
                
            if i == 'flesch_reading_ease_S_1_S_2':
                idx_leggibilita.extend(['FR', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_1_S_2':
                idx_leggibilita.extend(['GI', indici_leggibilita[evento][i]])
        
        multiindex_df.loc[chiavi[evento]['Idx_l']] = idx_leggibilita
        
        
    multiindex_df.index.names = ['Id', 'Cl', 'Pr', '']
    multiindex_df.columns = pd.MultiIndex.from_product([[tipo_classificazioni],multiindex_df.columns])
    
    return multiindex_df

# %%
def costruisci_df_classificazioni_corrette_errate_da_tutti_bert(params, tipo_classificazioni, indici_leggibilita):
    
    mldx_arrays_totali = []
    
    lista_eventi = []
    lista_classi = []
    lista_predizioni = []
    lista_intestazioni = []
    chiavi = {}
    
    
    for evento in params:
    
        #Creo gli indici della tabella (Id, Classe, Predizione, Frasi, Probabilità e Indici leggibilità)
        lista_eventi.extend([evento]*4)
        lista_classi.extend([params[evento]['Class']]*4)
        lista_predizioni.extend([params[evento]['Pred']]*4)
        lista_intestazioni.extend(['S_1', 'S_2', 'P', 'Idx_l'])
        chiavi[evento] = {}
        chiavi[evento]['S_1'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'S_1')
        chiavi[evento]['S_2'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'S_2')
        chiavi[evento]['P'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'P')
        chiavi[evento]['Idx_l'] = (evento, params[evento]['Class'], params[evento]['Pred'], 'Idx_l')

    mldx_arrays_totali.append(lista_eventi)
    mldx_arrays_totali.append(lista_classi)
    mldx_arrays_totali.append(lista_predizioni)
    mldx_arrays_totali.append(lista_intestazioni)
        
    multiindex_df = pd.DataFrame(index=mldx_arrays_totali, columns=['']*12)
    
    for evento in params:
        #valorizzo la prima colona con la frase S1 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_1']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_1']][0] = params[evento]['Sentence_1']
        
        #valorizzo la prima colona con la frase S2 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_2']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_2']][0] = params[evento]['Sentence_2']
        
        #Probabilità (aggiustate) --> abbiamo 12 colonne
        proba = [params[evento][prob] for prob in params[evento] if prob.startswith('Epoch')]
        proba_adjusted = []
        for p in proba:
            proba_adjusted.append(p)
            proba_adjusted.append('')
        proba_adjusted.append('')
        proba_adjusted.append('')
        multiindex_df.loc[chiavi[evento]['P']] = proba_adjusted
        
        #Indici di leggibilità
        idx_leggibilita = []
        
        for i in indici_leggibilita[evento].keys():
            if i == 'flesch_reading_ease_S_1':
                idx_leggibilita.extend(['FR_1', indici_leggibilita[evento][i]])
            if i == 'flesch_reading_ease_S_2':
                idx_leggibilita.extend(['FR_2', indici_leggibilita[evento][i]])
                
            if i == 'gulpease_index_S_1':
                idx_leggibilita.extend(['GI_1', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_2':
                idx_leggibilita.extend(['GI_2', indici_leggibilita[evento][i]])
                
            if i == 'flesch_reading_ease_S_1_S_2':
                idx_leggibilita.extend(['FR', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_1_S_2':
                idx_leggibilita.extend(['GI', indici_leggibilita[evento][i]])
        
        multiindex_df.loc[chiavi[evento]['Idx_l']] = idx_leggibilita
        
        
    multiindex_df.index.names = ['Id', 'Cl', 'Pr', '']
    multiindex_df.columns = pd.MultiIndex.from_product([[tipo_classificazioni],multiindex_df.columns])
    
    return multiindex_df

# %%
def costruisci_df_classificazioni_corrette_errate_da_uno_solo_bert(params, tipo_classificazioni, indici_leggibilita):
    
    mldx_arrays_totali = []
    
    lista_eventi = []
    lista_classi = []
    lista_intestazioni = []
    chiavi = {}
    
    
    for evento in params:
    
        #Creo gli indici della tabella (Id, Classe, Predizione, Frasi, Probabilità e Indici leggibilità)
        lista_eventi.extend([evento]*4)
        lista_classi.extend([params[evento]['Class']]*4)
        lista_intestazioni.extend(['S_1', 'S_2', 'Pred - P', 'Idx_l'])
        chiavi[evento] = {}
        chiavi[evento]['S_1'] = (evento, params[evento]['Class'], 'S_1')
        chiavi[evento]['S_2'] = (evento, params[evento]['Class'], 'S_2')
        chiavi[evento]['Pred - P'] = (evento, params[evento]['Class'], 'Pred - P')
        chiavi[evento]['Idx_l'] = (evento, params[evento]['Class'], 'Idx_l')

    mldx_arrays_totali.append(lista_eventi)
    mldx_arrays_totali.append(lista_classi)
    mldx_arrays_totali.append(lista_intestazioni)
        
    multiindex_df = pd.DataFrame(index=mldx_arrays_totali, columns=['']*12)
    
    for evento in params:
        #valorizzo la prima colona con la frase S1 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_1']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_1']][0] = params[evento]['Sentence_1']
        
        #valorizzo la prima colona con la frase S2 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_2']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_2']][0] = params[evento]['Sentence_2']
        
        #Probabilità (aggiustate) --> abbiamo 12 colonne
        pred_proba = [params[evento][pred_prob] for pred_prob in params[evento] if pred_prob.startswith('Epoch')]
        proba_adjusted = []
        for p in pred_proba:
            proba_adjusted.append(p)
        proba_adjusted.append('')
        proba_adjusted.append('')
        multiindex_df.loc[chiavi[evento]['Pred - P']] = proba_adjusted
        
        #Indici di leggibilità
        idx_leggibilita = []
        
        for i in indici_leggibilita[evento].keys():
            if i == 'flesch_reading_ease_S_1':
                idx_leggibilita.extend(['FR_1', indici_leggibilita[evento][i]])
            if i == 'flesch_reading_ease_S_2':
                idx_leggibilita.extend(['FR_2', indici_leggibilita[evento][i]])
                
            if i == 'gulpease_index_S_1':
                idx_leggibilita.extend(['GI_1', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_2':
                idx_leggibilita.extend(['GI_2', indici_leggibilita[evento][i]])
                
            if i == 'flesch_reading_ease_S_1_S_2':
                idx_leggibilita.extend(['FR', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_1_S_2':
                idx_leggibilita.extend(['GI', indici_leggibilita[evento][i]])
        
        multiindex_df.loc[chiavi[evento]['Idx_l']] = idx_leggibilita
        
        
    multiindex_df.index.names = ['Id', 'Cl', '']
    multiindex_df.columns = pd.MultiIndex.from_product([[tipo_classificazioni],multiindex_df.columns])
    
    return multiindex_df

# %%
def costruisci_df_classificazioni_corrette_errate_da_uno_solo_svm(params, tipo_classificazioni, indici_leggibilita):
    
    mldx_arrays_totali = []
    
    lista_eventi = []
    lista_classi = []
    lista_intestazioni = []
    chiavi = {}
    
    
    for evento in params:
    
        #Creo gli indici della tabella (Id, Classe, Predizione, Frasi, Probabilità e Indici leggibilità)
        lista_eventi.extend([evento]*5)
        lista_classi.extend([params[evento]['Class']]*5)
        lista_intestazioni.extend(['S_1', 'S_2', 'Pred - P (1-6)', 'Pred - P (7-12)', 'Idx_l'])
        chiavi[evento] = {}
        chiavi[evento]['S_1'] = (evento, params[evento]['Class'], 'S_1')
        chiavi[evento]['S_2'] = (evento, params[evento]['Class'], 'S_2')
        chiavi[evento]['Pred - P (1-6)'] = (evento, params[evento]['Class'], 'Pred - P (1-6)')
        chiavi[evento]['Pred - P (7-12)'] = (evento, params[evento]['Class'], 'Pred - P (7-12)')
        chiavi[evento]['Idx_l'] = (evento, params[evento]['Class'], 'Idx_l')

    mldx_arrays_totali.append(lista_eventi)
    mldx_arrays_totali.append(lista_classi)
    mldx_arrays_totali.append(lista_intestazioni)
        
    multiindex_df = pd.DataFrame(index=mldx_arrays_totali, columns=['']*12)
    
    for evento in params:
        #valorizzo la prima colona con la frase S1 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_1']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_1']][0] = params[evento]['Sentence_1']
        
        #valorizzo la prima colona con la frase S2 e metto le altre colonne come stringhe vuote
        multiindex_df.loc[chiavi[evento]['S_2']] = ['']*12
        multiindex_df.loc[chiavi[evento]['S_2']][0] = params[evento]['Sentence_2']
        
        #Probabilità (aggiustate) --> abbiamo 12 colonne
        pred_proba = [params[evento][k] for k in params[evento] if k.startswith('c')]
        proba_adjusted = []
        for p in pred_proba:
            proba_adjusted.append(p)
        multiindex_df.loc[chiavi[evento]['Pred - P (1-6)']] = proba_adjusted[:12]
        multiindex_df.loc[chiavi[evento]['Pred - P (7-12)']] = proba_adjusted[12:]
        
        #Indici di leggibilità
        idx_leggibilita = []
        
        for i in indici_leggibilita[evento].keys():
            if i == 'flesch_reading_ease_S_1':
                idx_leggibilita.extend(['FR_1', indici_leggibilita[evento][i]])
            if i == 'flesch_reading_ease_S_2':
                idx_leggibilita.extend(['FR_2', indici_leggibilita[evento][i]])
                
            if i == 'gulpease_index_S_1':
                idx_leggibilita.extend(['GI_1', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_2':
                idx_leggibilita.extend(['GI_2', indici_leggibilita[evento][i]])
                
            if i == 'flesch_reading_ease_S_1_S_2':
                idx_leggibilita.extend(['FR', indici_leggibilita[evento][i]])
            if i == 'gulpease_index_S_1_S_2':
                idx_leggibilita.extend(['GI', indici_leggibilita[evento][i]])
        
        multiindex_df.loc[chiavi[evento]['Idx_l']] = idx_leggibilita
        
        
    multiindex_df.index.names = ['Id', 'Cl', '']
    multiindex_df.columns = pd.MultiIndex.from_product([[tipo_classificazioni],multiindex_df.columns])
    
    return multiindex_df

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_errati'

svm_5_errati_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_svm(tabella_svm['df_dist_5'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_5'][tipo_classificazioni])

# %%
print(svm_5_errati_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_errati} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                 &        &       &        &       &       &       &        &       &        &       &       \\
# \midrule
# 228695 & 0 & 1 & S\_1 &                                                                                                                                                                                                                      Il più comprende il meno, seppur fosse discutibile la questione che pongo. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &  Accogliendo il mio subemendamento si andrebbe ad inserire, rispetto ai soggetti indiziati del delitto di cui all'articolo 416 del codice penale, finalizzato alla commissione di taluno dei delitti di cui agli articoli 314, primo comma, 316, eccetera eccetera, anche l'articolo 640 - bis. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                            0.52 &   0.52 &  0.50 &   0.50 &  0.50 &  0.50 &  0.50 &   0.50 &  0.51 &   0.51 &  0.53 &  0.51 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                            FR\_1 &   81.4 &  FR\_2 &  20.98 &  GI\_1 &  61.5 &  GI\_2 &   38.0 &    FR &  45.22 &    GI &  43.3 \\
# 195285 & 1 & 0 & S\_1 &                                                                                                                                                           Passiamo all'emendamento 13.0.13, su cui la 5ᵃ Commissione ha espresso parere contrario ai sensi dell'articolo 81 della Costituzione. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                          Il Senato non approva. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                            0.51 &   0.51 &  0.50 &   0.50 &  0.50 &  0.50 &  0.50 &   0.50 &  0.50 &   0.51 &  0.51 &  0.51 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                            FR\_1 &  61.96 &  FR\_2 &   91.8 &  GI\_1 &  57.9 &  GI\_2 &  116.5 &    FR &  68.43 &    GI &  68.5 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/363015256.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_5_errati_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_corretti'

svm_5_corretti_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_svm(tabella_svm['df_dist_5'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_5'][tipo_classificazioni])

# %%
print(svm_5_corretti_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_corretti} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                                                                                                                           &        &       &        &       &       &       &       &       &        &       &       \\
# \midrule
# 518453 & 0 & 0 & S\_1 &                                                                                                                                                                                                           Nei mari adiacenti, per il contrasto al fenomeno della pirateria, l'Italia partecipa alla missione europea Atalanta, con 2 mezzi navali, 2 aerei e un numero massimo di 407 unità di personale. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                    Per tutte le missioni già in atto, la proroga è fino al 31 dicembre e, per ogni missione, la relazione analitica riporta, come previsto dalla legge, due schede: la prima con il resoconto di quanto si è fatto nel 2018; la seconda con le risorse e gli assetti per l'anno in corso. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                      0.51 &   0.50 &  0.50 &   0.51 &  0.50 &  0.50 &  0.50 &  0.50 &  0.50 &   0.51 &  0.51 &  0.50 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &  47.04 &  FR\_2 &   44.4 &  GI\_1 &  46.7 &  GI\_2 &  51.1 &    FR &  48.81 &    GI &  49.5 \\
# 464910 & 0 & 0 & S\_1 &                                                                                                                                                                                                                                                   È cosa ben strana che si registri un dibattito sulla legge principale, che è la legge di stabilità, e non si senta la maggioranza difendere il Governo. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                 Non capisco se questo è dovuto al tentativo di anticipare quanto prima - saranno contenti loro - l'incardinamento della legge elettorale, o se, invece, è perché hanno serie difficoltà a difendere il Governo e a parlare bene della legge di stabilità. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                      0.51 &   0.51 &  0.50 &   0.51 &  0.50 &  0.50 &  0.50 &  0.50 &  0.51 &   0.51 &  0.50 &  0.50 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &  66.34 &  FR\_2 &  29.38 &  GI\_1 &  53.8 &  GI\_2 &  43.1 &    FR &  45.94 &    GI &  47.5 \\
# 537330 & 0 & 0 & S\_1 &                                                                        Con molta difficoltà avevamo erogato - e ribadiamo il nostro parere assolutamente contrario in proposito - ben 120 milioni di euro a otto Fondazioni lirico sinfoniche d'Italia indebitate per cattiva gestione dei loro consigli d'amministrazione, diretta emanazione dei Comuni e delle Province, secondo le compartecipazioni. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                       La più indebitata, guarda caso, era quella del Maggio musicale fiorentino, per cui si è fatta anche la norma, è chiaro, infatti, che si doveva poi soddisfare le esigenze di tutti. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                      0.51 &   0.52 &  0.50 &   0.50 &  0.50 &  0.50 &  0.50 &  0.51 &  0.51 &   0.50 &  0.51 &  0.50 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &   0.66 &  FR\_2 &  62.52 &  GI\_1 &  31.3 &  GI\_2 &  50.6 &    FR &  27.84 &    GI &  39.4 \\
# 414778 & 0 & 0 & S\_1 &  Signor Presidente, pur non avendo seguito specificamente il problema, quando qualche giorno fa è apparso chiaramente che in Assemblea i tempi non erano maturi se si voleva arrivare a una mozione condivisa anche con il Governo sul Venezuela, ho avanzato la proposta di sospendere il dibattito per un tempo - in quel caso fino a martedì - sufficiente per arrivare a una soluzione soddisfacente. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                    E così è avvenuto, perché nel frattempo i contrasti di quel giorno si sono stemperati. &        &       &        &       &       &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                      0.51 &   0.52 &  0.50 &   0.51 &  0.50 &  0.50 &  0.50 &  0.51 &  0.51 &   0.51 &  0.51 &  0.50 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &   6.74 &  FR\_2 &  81.52 &  GI\_1 &  40.8 &  GI\_2 &  61.0 &    FR &  39.93 &    GI &  44.7 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/3753272877.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_5_corretti_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_corretti'

svm_5_corretti_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_svm(tabella_svm['df_dist_5'][tipo_classificazioni],\
                                                                    tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_5'][tipo_classificazioni])

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_errati'

svm_5_errati_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_svm(tabella_svm['df_dist_5'][tipo_classificazioni],\
                                                                    tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_5'][tipo_classificazioni])

# %%
print(svm_5_corretti_da_uno_solo.to_latex())
# Out:
# \begin{tabular}{lllllllllllllll}
# \toprule
#        &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_altri\_corretti} \\
#        &   &       \\
# Id & Cl & {} &                                                                                                                                                                                                                                                                                                                                                                                                                             &        &       &        &       &       &       &       &     &        &     &       \\
# \midrule
# 124516 & 0 & S\_1 &                                                                                                                                                                   Tempo fa, sul quotidiano «Corriere della sera» Celentano scrisse difendendo il diritto d'autore, in quel caso della musica, sostenendo che «Se non si pagasse più il pane non ci sarebbero più i fornai», perché nessuno farebbe il pane se fosse gratis. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                                                                                                                                                                  Celentano lo diceva per la musica: se la musica viene rubata - presa gratis - sul web, gli autori non hanno remunerazione. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P (1-6) &                                                                                                                                                                                                                                                                                                                                                                                                                           1 &   0.50 &     1 &   0.51 &     1 &  0.50 &     1 &  0.50 &   1 &   0.50 &   1 &  0.50 \\
#        &   & Pred - P (7-12) &                                                                                                                                                                                                                                                                                                                                                                                                                           1 &   0.50 &     0 &   0.51 &     1 &  0.51 &     1 &  0.50 &   1 &   0.50 &   1 &  0.51 \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                        FR\_1 &   43.7 &  FR\_2 &   65.0 &  GI\_1 &  45.3 &  GI\_2 &  53.5 &  FR &  55.37 &  GI &  48.0 \\
# 260309 & 0 & S\_1 &  Ciò porterà anche a prevedere il doppio turno: penso ad esempio al ballottaggio nel caso dell'Italicum, per come è stato approvato in Parlamento; infatti, per quanto si possa immaginare di modificare quella legge, allo stato attuale abbiamo una situazione in cui sicuramente potremo avere non solo un primo turno, ma anche un secondo turno alle elezioni politiche, oltre che consultazioni regionali ed europee. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                
\\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/3431068501.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(bert_5_corretti_da_uno_solo.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_errati'

svm_30_errati_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_svm(tabella_svm['df_dist_30'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_30'][tipo_classificazioni])

# %%
print(svm_30_errati_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_errati} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                                                          &        &       &        &       &        &       &       &       &        &       &       \\
# \midrule
# 451088 & 1 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                        Assolutamente no. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &  Con il "Drugs on street", un progetto di prevenzione notturna, con cui si mettevano insieme carabinieri, polizia, vigili urbani e associazioni di volontariato per controllare e monitorare dalle ore 23 fino alle 4 del mattino, specialmente nelle notti delle stragi, ossia il sabato sera, abbiamo ottenuto risultati straordinari. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                     0.54 &   0.55 &  0.57 &   0.53 &  0.56 &   0.53 &  0.54 &  0.55 &  0.51 &   0.53 &  0.52 &  0.51 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                     FR\_1 &    4.4 &  FR\_2 &  14.62 &  GI\_1 &  159.0 &  GI\_2 &  36.9 &    FR &    9.2 &    GI &  35.8 \\
# 289493 & 0 & 1 & S\_1 &                                                                                                                Cito questo punto perché l'ho considerato un passo avanti molto importante delle istituzioni internazionali, che guardano e devono guardare sempre di più ai temi non soltanto nella centralità degli aspetti finanziari. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                È un errore immaginare che il cuore di tutto siano le decisioni finanziarie: il cuore di tutto deve essere la somma delle decisioni, e bisogna cercare di mettere insieme i vari aspetti. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                     0.56 &   0.53 &  0.52 &   0.53 &  0.51 &   0.52 &  0.51 &  0.53 &  0.52 &   0.51 &  0.54 &  0.51 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                     FR\_1 &   35.4 &  FR\_2 &  49.76 &  GI\_1 &   38.4 &  GI\_2 &  50.3 &    FR &  42.73 &    GI &  44.4 \\
# 880161 & 0 & 1 & S\_1 &                                                                                                                                                                                                                                                                                     Il senatore Solinas entra in Aula.. Congratulazioni. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                               Facciamo anche noi gli auguri al senatore Solinas, perché alleato con il centrodestra ha vinto, mentre alleati con i grillini svendono l'Italia alla Cina. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                     0.59 &   0.53 &  0.52 &   0.51 &  0.52 &   0.51 &  0.53 &  0.53 &  0.53 &   0.53 &  0.57 &  0.57 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                     FR\_1 &  45.06 &  FR\_2 &  55.78 &  GI\_1 &   66.1 &  GI\_2 &  46.9 &    FR &  59.45 &    GI &  51.3 \\
# 791038 & 0 & 1 & S\_1 &                                                                                             Analogamente è stato fatto in Egitto e in Algeria e analogamente viene fatto, per due volte, nella patria dell'illuminismo e della cultura europea, proprio in un centro che è il grande polo di attrazione turistica e culturale del mondo. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                          A partire da noi, dall'Italia e dall'Europa, è necessaria una grande unità tra le forze politiche e devo dare atto ai due Ministri che sono intervenuti di aver fatto questo appello all'unità. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                     0.53 &   0.51 &  0.51 &   0.53 &  0.51 &   0.52 &  0.53 &  0.53 &  0.51 &   0.51 &  0.51 &  0.53 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                     FR\_1 &  41.68 &  FR\_2 &  51.62 &  GI\_1 &   45.9 &  GI\_2 &  48.4 &    FR &  46.65 &    GI &  47.0 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/2211385684.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_30_errati_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_corretti'

svm_30_corretti_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_svm(tabella_svm['df_dist_30'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_dist_30'][tipo_classificazioni])

# %%
print(svm_30_corretti_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_corretti} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                                                                                &        &       &        &       &       &       &        &       &        &       &       \\
# \midrule
# 453798 & 0 & 0 & S\_1 &                                              In primo luogo, le università cosiddette virtuose, cioè quelle con parametri di bilancio previsti dal decreto legislativo n. 49 del 2012, possono riutilizzare per intero i punti organico che si sono liberati per cessazione dei contratti dei ricercatori di tipo A, quelli senza tenure track per intenderci. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &  Per il triennio 2015 - 2017 - quindi da quest'anno fino al 2017 -, le università possono fissare il numero delle assunzioni dei professori ordinari, favorendo quindi il ricambio, perché - perdonatemi - i giovani non sono solo necessariamente ricercatori, ma possono esserci anche giovani brillanti che vanno in cattedra a un'età relativamente bassa. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                           0.51 &   0.54 &  0.53 &   0.54 &  0.52 &  0.53 &  0.53 &   0.52 &  0.52 &   0.50 &  0.53 &  0.54 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                           FR\_1 &  53.67 &  FR\_2 &  11.28 &  GI\_1 &  46.7 &  GI\_2 &   34.7 &    FR &  37.88 &    GI &  40.6 \\
# 276356 & 0 & 0 & S\_1 &                                                                                                                                                                                                                  Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 2.44, presentato dal senatore D'Ambrosio Lettieri e da altri senatori. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                         Il Senato non approva. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                           0.54 &   0.52 &  0.51 &   0.51 &  0.52 &  0.51 &  0.51 &   0.51 &  0.51 &   0.51 &  0.53 &  0.51 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                           FR\_1 &  38.62 &  FR\_2 &   91.8 &  GI\_1 &  53.4 &  GI\_2 &  116.5 &    FR &  49.35 &    GI &  64.9 \\
# 318497 & 0 & 0 & S\_1 &                                                                                                                                             Non c'entrano niente l'articolo 68 o altri aspetti della tutela della funzione parlamentare: qui c'è una legge del 1989 che riguarda le funzioni del Governo e dei Ministri, alla quale abbiamo fatto riferimento. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                   Il tribunale dei Ministri, come ho detto, non ritiene che sia un atto puramente politico, ma amministrativo, quindi sindacabile dal giudice. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                           0.56 &   0.53 &  0.55 &   0.55 &  0.51 &  0.51 &  0.52 &   0.51 &  0.51 &   0.51 &  0.51 &  0.50 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                           FR\_1 &  48.64 &  FR\_2 &  49.72 &  GI\_1 &  44.2 &  GI\_2 &   46.1 &    FR &   50.8 &    GI &  44.9 \\
# 26475  & 0 & 0 & S\_1 &                                                                                                                Ricordo che quando tenemmo il primo incontro dopo il primo terremoto Renzi diceva di avere tutti i soldi per la ricostruzione: lo avete detto in Parlamento a gente che è ancora in mezzo alla strada perché i soldi non li avete tirati fuori. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                           Dove li aveva Renzi? &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                           0.59 &   0.53 &  0.53 &   0.53 &  0.54 &  0.54 &  0.51 &   0.51 &  0.51 &   0.52 &  0.51 &  0.52 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                           FR\_1 &   45.3 &  FR\_2 &  106.8 &  GI\_1 &  50.2 &  GI\_2 &  121.5 &    FR &  71.55 &    GI &  56.2 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/1773631452.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_30_corretti_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_errati'

bert_30_errati_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_bert(tabella_bert['df_dist_30'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_30'][tipo_classificazioni])

# %%
print(bert_30_errati_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_errati} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                           &        &       &        &       &       &       &        &       &        &     &        \\
# \midrule
# 237514 & 1 & 0 & S\_1 &                                                                                                                                                                                                                                                      L'emendamento 2.13 è stato ritirato. &        &       &        &       &       &       &        &       &        &     &        \\
#        &   &   & S\_2 &                                                                                                                                                                                                                
py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_30_errati_da_uno_solo.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_corretti'

bert_30_corretti_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_bert(tabella_bert['df_dist_30'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_30'][tipo_classificazioni])

# %%
print(bert_30_corretti_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_corretti} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        &        &       &        &       &       &       &       &       &        &     &       \\
# \midrule
# 522394 & 1 & 1 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Quando parliamo di piccoli Comuni, ci riferiamo al 70 per cento dei Comuni italiani, che ha una popolazione pari o inferiore ai 5.000 abitanti. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &  Tuttavia questa nostra proposta è stata accolta dal Governo con l'approvazione di un ordine del giorno che prevede, fra l'altro, l'impegno ad assumere apposite iniziative, anche di carattere normativo, per l'attivazione di misure per la riduzione degli imballaggi, anche attraverso progetti sperimentali per ridurre l'utilizzo di contenitori e stoviglie di plastica monouso non biodegradabili dalle mense di enti pubblici e privati, ospedali, uffici pubblici e privati, aziende e istituti scolastici, così come fra l'altro abbiamo proposto in un disegno di legge a mia prima firma, l'Atto Senato 2804, che purtroppo temo giacerà in un cassetto fino alla fine della legislatura. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.66 &        &  0.74 &        &  0.94 &       &  0.99 &       &  1.00 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   FR\_1 &  63.28 &  FR\_2 & -52.81 &  GI\_1 &  51.5 &  GI\_2 &  34.2 &    FR &  -0.05 &  GI &  37.5 \\
# 26864  & 0 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Abbiamo una Costituzione che ha avuto, allora, un'ispirazione dallo Spirito Santo. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Mi chiedo a chi si sia ispirata questa pseudoriforma. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.68 &        &  0.92 &        &  0.86 &       &  1.00 &       &  1.00 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   FR\_1 &   50.0 &  FR\_2 &  91.96 &  GI\_1 &  50.8 &  GI\_2 &  72.3 &    FR &   69.0 &  GI &  60.5 \\
# 593663 & 0 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Do altresì atto al collega Carraro della sua correttezza, come sempre, perché interviene allo stesso modo in Commissione e in Assemblea. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                   Egli, infatti, pur non mancando di manifestare dal suo punto di vista limiti e insufficienze, ha riconosciuto un lavoro positivo, a differenza di altri interventi in cui, al clima costruttivo registrato in Commissione, poi in Assemblea hanno fatto seguire veri e propri comizi di propaganda con insulti vari. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.73 &        &  0.92 &        &  0.93 &       &  0.93 &       &  1.00 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   FR\_1 &   58.3 &  FR\_2 &  22.12 &  GI\_1 &  48.0 &  GI\_2 &  40.9 &    FR &  39.97 &  GI &  43.1 \\
# 314849 & 0 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Se la Presidenza sarà clemente, cercherò di seguire, al meglio di quello che mi riesce, una via di mezzo per non eludere le questioni che sono state poste. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                                                                                      Il tempo del dibattito e anche il modo - fatemi dire - politicamente congestionato con cui ciascuno ha approfittato di questa finestra per scaricare dentro questioni così diverse, è un po' metafora di quello che è successo negli ultimi anni. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   0.63 &        &  0.78 &        &  0.87 &       &  0.91 &       &  0.99 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   FR\_1 &   75.6 &  FR\_2 &  34.94 &  GI\_1 &  54.0 &  GI\_2 &  43.7 &    FR &   53.2 &  GI &  48.1 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/1395976221.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(bert_30_corretti_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_errati'

bert_30_errati_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_bert(tabella_bert['df_dist_30'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_30'][tipo_classificazioni])

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_corretti'

bert_30_corretti_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_bert(tabella_bert['df_dist_30'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_dist_30'][tipo_classificazioni])

# %%
print(bert_30_errati_da_uno_solo.to_latex())
# Out:
# \begin{tabular}{lllllllllllllll}
# \toprule
#        &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_altri\_errati} \\
#        &   &       \\
# Id & Cl & {} &                                                                                                                                                                                                                                                                                                                                                
       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                           E quando lo ha consentito se un dibattito vero in Parlamento non c'è mai stato e lei viene qui oggi? &        &       &       &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                              0 &   0.64 &     0 &  0.73 &     0 &  0.52 &     0 &  0.80 &   1 &   0.98 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                           FR\_1 &  45.52 &  FR\_2 &  89.0 &  GI\_1 &  47.7 &  GI\_2 &  63.5 &  FR &  70.83 &  GI &  56.7 \\
# 410172 & 0 & S\_1 &                                                                                                                                                                 Qui voglio ripetere una mia ferma convinzione. &        &       &       &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                      È noto che l'economia moderna nasce nell'ambito delle scienze giuridiche e morali e non si tratta di una nascita casuale. &        &       &       &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                              1 &   0.66 &     0 &  0.56 &     1 &  0.79 &     1 &  0.89 &   1 &   1.00 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                           FR\_1 &  79.32 &  FR\_2 &  65.0 &  GI\_1 &  74.7 &  GI\_2 &  53.0 &  FR &  72.79 &  GI &  58.6 \\
# 729329 & 0 & S\_1 &  L'ordinanza ricostruisce poi la vicenda inerente la campagna di diffamazione in danno dell'onorevole Caldoro, candidato a presidente della Regione Campania, al fine di favorire la candidatura di Cosentino. &        &       &       &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                     Un altro fronte di attività del gruppo è quello delle interferenze nei confronti di componenti del Consiglio superiore della magistratura. &        &       &       &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                              1 &   0.64 &     1 &  0.74 &     1 &  0.91 &     0 &  0.68 &   1 &   1.00 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                           FR\_1 &  22.02 &  FR\_2 &  50.0 &  GI\_1 &  36.1 &  GI\_2 &  44.5 &  FR &  34.54 &  GI &  39.6 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/2636052555.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(bert_30_corretti_da_uno_solo.to_latex())

# %%
tabella_svm['df_random_speech']['lista_eventi_scelti_intersezione_errati']
# Out:
# {636188: {'Sentence_1': 'Ha facoltà di parlare il presidente del Consiglio dei ministri, dottor Renzi.',
#   'Sentence_2': 'Avverto che le proposte di risoluzione dovranno essere presentate entro la conclusione del dibattito.',
#   'Class': 0,
#   'Pred': 1,
#   'clf_1P': '0.69',
#   'clf_2P': '0.58',
#   'clf_3P': '0.61',
#   'clf_4P': '0.64',
#   'clf_5P': '0.64',
#   'clf_6P': '0.66',
#   'clf_7P': '0.66',
#   'clf_8P': '0.68',
#   'clf_9P': '0.69',
#   'clf_10P': '0.69',
#   'clf_11P': '0.55',
#   'clf_12P': '0.69'},
#  167370: {'Sentence_1': "Signor Presidente, il parere sull'emendamento 34.200 è contrario.",
#   'Sentence_2': 'Signor Presidente, esprimo parere contrario sugli emendamenti 37.200, 37.201 e 37.202.',
#   'Class': 0,
#   'Pred': 1,
#   'clf_1P': '0.74',
#   'clf_2P': '0.69',
#   'clf_3P': '0.69',
#   'clf_4P': '0.70',
#   'clf_5P': '0.71',
#   'clf_6P': '0.73',
#   'clf_7P': '0.76',
#   'clf_8P': '0.77',
#   'clf_9P': '0.74',
#   'clf_10P': '0.68',
#   'clf_11P': '0.59',
#   'clf_12P': '0.59'},
#  44241: {'Sentence_1': 'Un Governo come quello Renzi, che fa di un argomento etico il fondamento del suo programma e che perciò pone su di esso una questione di fiducia, assume conseguentemente, fortemente, prepotentemente la forma di un Governo etico.',
#   'Sentence_2': 'Siamo anche convinti che la possibilità di formare specialisti del territorio, pronti per affrontare le sfide del Servizio sanitario nazionale che sono rappresentate dai mutati scenari di salute, dal maggiore impatto delle cronicità e dalle incombenze poste dalla stessa pandemia, richieda risposte organizzate e integrate proprio a livello di comunità.',
#   'Class': 1,
#   'Pred': 0,
#   'clf_1P': '0.65',
#   'clf_2P': '0.67',
#   'clf_3P': '0.59',
#   'clf_4P': '0.61',
#   'clf_5P': '0.59',
#   'clf_6P': '0.61',
#   'clf_7P': '0.62',
#   'clf_8P': '0.59',
#   'clf_9P': '0.58',
#   'clf_10P': '0.59',
#   'clf_11P': '0.54',
#   'clf_12P': '0.50'},
#  490307: {'Sentence_1': 'Il Senato non approva.',
#   'Sentence_2': "Verrà esclusa la responsabilità penale del medico, anche per colpa grave, se rispetterà le buone pratiche e le linee guida previste, come a dire che ci si potrà trincerare al sicuro dietro un testo, evitando l'adozione delle scelte terapeutiche più adeguate e sfociando verso una standardizzazione a discapito del rapporto medico - paziente, per un risarcimento che già oggi tarda ad arrivare e facendo sì che coloro che si sono resi colpevoli con il loro operato, ma salvi dalle linee guida, continueranno ad operare nelle stesse strutture mettendo in pericolo altri pazienti.",
#   'Class': 1,
#   'Pred': 0,
#   'clf_1P': '0.66',
#   'clf_2P': '0.66',
#   'clf_3P': '0.66',
#   'clf_4P': '0.66',
#   'clf_5P': '0.70',
#   'clf_6P': '0.67',
#   'clf_7P': '0.64',
#   'clf_8P': '0.64',
#   'clf_9P': '0.61',
#   'clf_10P': '0.55',
#   'clf_11P': '0.56',
#   'clf_12P': '0.62'}}

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_errati'

svm_random_speech_errati_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_svm(tabella_svm['df_random_speech'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_random_speech'][tipo_classificazioni])

# %%
print(svm_random_speech_errati_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_errati} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    &        &       &        &       &        &       &       &       &        &       &       \\
# \midrule
# 636188 & 0 & 1 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Ha facoltà di parlare il presidente del Consiglio dei ministri, dottor Renzi. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Avverto che le proposte di risoluzione dovranno essere presentate entro la conclusione del dibattito. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.69 &   0.58 &  0.61 &   0.64 &  0.64 &   0.66 &  0.66 &  0.68 &  0.69 &   0.69 &  0.55 &  0.69 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               FR\_1 &  76.42 &  FR\_2 &  44.54 &  GI\_1 &   59.0 &  GI\_2 &  47.6 &    FR &  59.34 &    GI &  52.8 \\
# 167370 & 0 & 1 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Signor Presidente, il parere sull'emendamento 34.200 è contrario. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Signor Presidente, esprimo parere contrario sugli emendamenti 37.200, 37.201 e 37.202. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.74 &   0.69 &  0.69 &   0.70 &  0.71 &   0.73 &  0.76 &  0.77 &  0.74 &   0.68 &  0.59 &  0.59 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               FR\_1 &   54.3 &  FR\_2 &  78.93 &  GI\_1 &   91.5 &  GI\_2 &  74.5 &    FR &  68.68 &    GI &  81.6 \\
# 44241  & 1 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                                                               Un Governo come quello Renzi, che fa di un argomento etico il fondamento del suo programma e che perciò pone su di esso una questione di fiducia, assume conseguentemente, fortemente, prepotentemente la forma di un Governo etico. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                  Siamo anche convinti che la possibilità di formare specialisti del territorio, pronti per affrontare le sfide del Servizio sanitario nazionale che sono rappresentate dai mutati scenari di salute, dal maggiore impatto delle cronicità e dalle incombenze poste dalla stessa pandemia, richieda risposte organizzate e integrate proprio a livello di comunità. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.65 &   0.67 &  0.59 &   0.61 &  0.59 &   0.61 &  0.62 &  0.59 &  0.58 &   0.59 &  0.54 &  0.50 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               FR\_1 &  44.04 &  FR\_2 &    3.2 &  GI\_1 &   45.2 &  GI\_2 &  34.2 &    FR &  21.85 &    GI &  38.9 \\
# 490307 & 1 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Il Senato non approva. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & S\_2 &  Verrà esclusa la responsabilità penale del medico, anche per colpa grave, se rispetterà le buone pratiche e le linee guida previste, come a dire che ci si potrà trincerare al sicuro dietro un testo, evitando l'adozione delle scelte terapeutiche più adeguate e sfociando verso una standardizzazione a discapito del rapporto medico - paziente, per un risarcimento che già oggi tarda ad arrivare e facendo sì che coloro che si sono resi colpevoli con il loro operato, ma salvi dalle linee guida, continueranno ad operare nelle stesse strutture mettendo in pericolo altri pazienti. &        &       &        &       &        &       &       &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.66 &   0.66 &  0.66 &   0.66 &  0.70 &   0.67 &  0.64 &  0.64 &  0.61 &   0.55 &  0.56 &  0.62 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               FR\_1 &   91.8 &  FR\_2 & -31.87 &  GI\_1 &  116.5 &  GI\_2 &  38.9 &    FR &  25.17 &    GI &  42.2 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/2677134757.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_random_speech_errati_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_corretti'

svm_random_speech_corretti_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_svm(tabella_svm['df_random_speech'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_random_speech'][tipo_classificazioni])

# %%
svm_random_speech_corretti_da_tutti
# Out:
#                                                                                                                                                                                                                                                                                        lista_eventi_scelti_intersezione_corretti  \
#
# Id     Cl Pr
# 136364 0  0  S_1                                                                                                                                                È davvero assurdo scrivere un emendamento, che per carità condividiamo, in cui prevediamo una premialità per la denuncia obbligatoria delle richieste estorsive.
#              S_2                                                                                                                                                                                        Se uno viene da me e avanza una richiesta di estorsione sono obbligato ad andare dal magistrato e a presentare denuncia.
#              P                                                                                                                                                                                                                                                                                                              0.57
#              Idx_l                                                                                                                                                                                                                                                                                                          FR_1
# 74785  1  1  S_1                                                                                                                                                                                                                             Se mi è consentito, vorrei invitare i senatori proponenti a ritirare l'emendamento.
#              S_2                                                                                                                                                                                 Se invece venisse accolta l'osservazione che ho fatto sull'emendamento del senatore Casson, potrei ritirare il mio emendamento.
#              P                                                                                                                                                                                                                                                                                                              0.63
#              Idx_l                                                                                                                                                                                                                                                                                                          FR_1
# 327854 1  1  S_1                                                                      Un ulteriore elemento, giustamente evidenziato e che ha anch'esso caratterizzato i lavori della Giunta, riguarda l'allocazione dei costi, o meglio, la previsione dei costi e la loro allocazione all'interno del Consiglio di Presidenza.
#              S_2                                                                                      Proclamo il risultato della votazione a scrutinio segreto per l'elezione del Presidente del Senato: Hanno ottenuto voti i senatori: Proclamo eletta Presidente del Senato la senatrice Maria Elisabetta Alberti Casellati.
#              P                                                                                                                                                                                                                                                                                                              0.61
#              Idx_l                                                                                                                                                                                                                                                                                                          FR_1
# 598163 0  0  S_1    Quindi, se a un certo punto la Francia decide di bombardare la Libia, va bene, perché non c'è un vincolo europeo che impedisca di muovere guerra contro gli interessi di un altro Stato membro dell'Unione europea; in compenso, ci dicono se le materie fecali le dobbiamo trattare come rifiuti oppure no.
#              S_2                                                                                                                                                                                                                                                                                         Cosa sosteniamo allora?
#              P                                                                                                                                                                                                                                                                                                              0.53
#              Idx_l                                                                                                                                                                                                                                                                                                          FR_1
#
#                                                                               \
#
# Id     Cl Pr
# 136364 0  0  S_1
#              S_2
#              P       0.65  0.62   0.66  0.60  0.60  0.63   0.57  0.57   0.55
#              Idx_l   41.1  FR_2  72.58  GI_1  39.5  GI_2   55.7    FR  56.51
# 74785  1  1  S_1
#              S_2
#              P       0.62  0.65   0.59  0.55  0.53  0.50   0.54  0.62   0.63
#              Idx_l  41.38  FR_2  39.62  GI_1  54.0  GI_2   41.4    FR  40.89
# 327854 1  1  S_1
#              S_2
#              P       0.52  0.56   0.59  0.60  0.56  0.50   0.53  0.52   0.54
#              Idx_l  28.66  FR_2  20.02  GI_1  36.9  GI_2   36.0    FR  24.61
# 598163 0  0  S_1
#              S_2
#              P       0.59  0.72   0.63  0.54  0.59  0.59   0.64  0.66   0.65
#              Idx_l   30.7  FR_2   33.1  GI_1  45.9  GI_2  119.0    FR  58.54
#
#
#
# Id     Cl Pr
# 136364 0  0  S_1
#              S_2
#              P      0.55  0.62
#              Idx_l    GI  47.4
# 74785  1  1  S_1
#              S_2
#              P      0.66  0.61
#              Idx_l    GI  46.6
# 327854 1  1  S_1
#              S_2
#              P      0.56  0.63
#              Idx_l    GI  36.5
# 598163 0  0  S_1
#              S_2
#              P      0.70  0.76
#              Idx_l    GI  49.9

# %%
print(svm_random_speech_corretti_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_corretti} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                               &        &       &        &       &       &       &        &       &        &       &       \\
# \midrule
# 136364 & 0 & 0 & S\_1 &                                                                                                                                              È davvero assurdo scrivere un emendamento, che per carità condividiamo, in cui prevediamo una premialità per la denuncia obbligatoria delle richieste estorsive. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                      Se uno viene da me e avanza una richiesta di estorsione sono obbligato ad andare dal magistrato e a presentare denuncia. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                          0.57 &   0.65 &  0.62 &   0.66 &  0.60 &  0.60 &  0.63 &   0.57 &  0.57 &   0.55 &  0.55 &  0.62 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                          FR\_1 &   41.1 &  FR\_2 &  72.58 &  GI\_1 &  39.5 &  GI\_2 &   55.7 &    FR &  56.51 &    GI &  47.4 \\
# 74785  & 1 & 1 & S\_1 &                                                                                                                                                                                                                           Se mi è consentito, vorrei invitare i senatori proponenti a ritirare l'emendamento. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                               Se invece venisse accolta l'osservazione che ho fatto sull'emendamento del senatore Casson, potrei ritirare il mio emendamento. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                          0.63 &   0.62 &  0.65 &   0.59 &  0.55 &  0.53 &  0.50 &   0.54 &  0.62 &   0.63 &  0.66 &  0.61 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                          FR\_1 &  41.38 &  FR\_2 &  39.62 &  GI\_1 &  54.0 &  GI\_2 &   41.4 &    FR &  40.89 &    GI &  46.6 \\
# 327854 & 1 & 1 & S\_1 &                                                                    Un ulteriore elemento, giustamente evidenziato e che ha anch'esso caratterizzato i lavori della Giunta, riguarda l'allocazione dei costi, o meglio, la previsione dei costi e la loro allocazione all'interno del Consiglio di Presidenza. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                    Proclamo il risultato della votazione a scrutinio segreto per l'elezione del Presidente del Senato: Hanno ottenuto voti i senatori: Proclamo eletta Presidente del Senato la senatrice Maria Elisabetta Alberti Casellati. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                          0.61 &   0.52 &  0.56 &   0.59 &  0.60 &  0.56 &  0.50 &   0.53 &  0.52 &   0.54 &  0.56 &  0.63 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                          FR\_1 &  28.66 &  FR\_2 &  20.02 &  GI\_1 &  36.9 &  GI\_2 &   36.0 &    FR &  24.61 &    GI &  36.5 \\
# 598163 & 0 & 0 & S\_1 &  Quindi, se a un certo punto la Francia decide di bombardare la Libia, va bene, perché non c'è un vincolo europeo che impedisca di muovere guerra contro gli interessi di un altro Stato membro dell'Unione europea; in compenso, ci dicono se le materie fecali le dobbiamo trattare come rifiuti oppure no. &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                       Cosa sosteniamo allora? &        &       &        &       &       &       &        &       &        &       &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                          0.53 &   0.59 &  0.72 &   0.63 &  0.54 &  0.59 &  0.59 &   0.64 &  0.66 &   0.65 &  0.70 &  0.76 \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                          FR\_1 &   30.7 &  FR\_2 &   33.1 &  GI\_1 &  45.9 &  GI\_2 &  119.0 &    FR &  58.54 &    GI &  49.9 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/1526883251.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_random_speech_corretti_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_errati'

bert_random_speech_errati_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_bert(tabella_bert['df_random_speech'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_random_speech'][tipo_classificazioni])

# %%
print(bert_random_speech_errati_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_errati} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                                                                                                                            &        &       &        &       &       &       &       &       &        &     &       \\
# \midrule
# 781854 & 1 & 0 & S\_1 &  Fondo centrale di garanzia, riserva per la garanzia ai consorzi fidi e alle cooperative di garanzia, rafforzamento della cooperazione per lo sviluppo e per l'internazionalizzazione delle imprese, misure per l'accelerazione dell'utilizzo dei fondi europei; e poi, altre misure di politica industriale, come quelle per la governance dell'Agenda digitale, la diffusione delle tecnologie digitali. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                      Differenziamo gli interventi e destiniamo le risorse, perché di chiacchiere se ne possono fare tante. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                       0.52 &        &  0.67 &        &  0.96 &       &  0.99 &       &  0.99 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                       FR\_1 & -10.43 &  FR\_2 &  61.48 &  GI\_1 &  30.3 &  GI\_2 &  51.0 &    FR &  19.26 &  GI &  34.9 \\
# 615072 & 0 & 1 & S\_1 &                                                                                                                                                                                                                                                                               Ci sono problemi e segnalo all'attuale Governo la sua distrazione anche per le isole maggiori, non solo per le isole minori. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                   Recentemente è scaduto il termine per una gara, che doveva essere indetta entro la fine di settembre - così mi sembra -, per una linea di aliscafi che unisce Reggio Calabria a Messina. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                       0.69 &        &  0.90 &        &  0.98 &       &  0.95 &       &  1.00 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                       FR\_1 &   69.7 &  FR\_2 &  58.62 &  GI\_1 &  53.8 &  GI\_2 &  49.6 &    FR &  64.34 &  GI &  51.3 \\
# 351925 & 0 & 1 & S\_1 &                                                                                                                                                                           Credo che, se l'Italia non vince la battaglia fondamentale per una ripartizione più equa dei profughi, andando avanti così, con nuovi futuri flussi, si rischierà di mettere a repentaglio la stessa coesione sociale del Paese. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                          La non risposta alle mie domande, signor Ministro, la dice lunga sulla volontà del Governo di affrontare seriamente la questione. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                       0.84 &        &  0.92 &        &  0.94 &       &  0.91 &       &  0.99 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                       FR\_1 &  48.08 &  FR\_2 &   62.0 &  GI\_1 &  43.3 &  GI\_2 &  49.0 &    FR &  55.79 &  GI &  45.4 \\
# 465592 & 0 & 1 & S\_1 &                                                                                                                                                                                                                                                    Nel testo dell'ordine del giorno G1.100 si parla sempre di vittime «innocenti» con riferimento al titolo che aveva precedentemente il disegno di legge. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                      Chiederei alla presentatrice dell'emendamento se intenda aggiornare il testo, anche se ovviamente non è obbligatorio. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                       0.82 &        &  0.87 &        &  0.95 &       &  0.97 &       &  0.98 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                       FR\_1 &  71.61 &  FR\_2 &  33.52 &  GI\_1 &  59.0 &  GI\_2 &  40.3 &    FR &  56.79 &  GI &  51.6 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/2787510565.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(bert_random_speech_errati_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_corretti'

svm_random_speech_corretti_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_svm(tabella_svm['df_random_speech'][tipo_classificazioni],\
                                                                    tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_random_speech'][tipo_classificazioni])

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_errati'

svm_random_speech_errati_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_svm(tabella_svm['df_random_speech'][tipo_classificazioni],\
                                                                    tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_svm['df_random_speech'][tipo_classificazioni])

# %%
print(svm_random_speech_corretti_da_uno_solo.to_latex())
# Out:
# \begin{tabular}{lllllllllllllll}
# \toprule
#        &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_altri\_corretti} \\
#        &   &       \\
# Id & Cl & {} &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 &        &       &        &       &       &       &       &     &        &     &       \\
# \midrule
# 877007 & 0 & S\_1 &  La norma oggetto di novella fa riferimento, oltre che all'incremento delle prestazioni a carico del dipartimento scientifico del Policlinico militare Celio, causato anche dalle emergenze biologiche e dalla connessa necessità di sviluppo di test per patogeni rari, alla finalità di far fronte alle esigenze straordinarie e urgenti derivanti dalla diffusione del virus SARS - Cov - 2 di garantire i livelli essenziali di assistenza e di sostenere e supportare le altre strutture del Servizio sanitario nazionale. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                          Ricordo che gli emendamenti approvati dalla Commissione sono stati inviati ai Gruppi, che hanno quindi un'ora di tempo a partire da ora per presentare subemendamenti. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P (1-6) &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1 &   0.51 &     1 &   0.62 &     1 &  0.60 &     1 &  0.60 &   1 &   0.54 &   1 &  0.58 \\
#        &   & Pred - P (7-12) &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1 &   0.60 &     1 &   0.60 &     1 &  0.60 &     1 &  0.51 &   0 &   0.54 &   1 &  0.52 \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            FR\_1 & -25.13 &  FR\_2 &   50.1 &  GI\_1 &  34.3 &  GI\_2 &  44.2 &  FR &   9.61 &  GI &  36.8 \\
# 122955 & 1 & S\_1 &                                                                                                                                                                                                                                                                           I chiarimenti forniti dal Consiglio di Stato hanno, dunque, dato finalmente il necessario impulso alla redazione dello schema di decreto ministeriale e della bozza di correlato disciplinare tecnico, entrambi in fase di avanzatissima definizione. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                  In questo contesto, come la storia insegna, sono compatibili modelli elettorali puramente proporzionali, modelli misti o modelli maggioritari. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P (1-6) &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0 &   0.58 &     0 &   0.64 &     0 &  0.62 &     0 &  0.60 &   0 &   0.61 &   0 &  0.67 \\
#        &   & Pred - P (7-12) &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0 &   0.65 &     0 &   0.67 &     0 &  0.65 &     0 &  0.52 &   1 &   0.51 &   0 &  0.51 \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            FR\_1 &  19.26 &  FR\_2 &  23.62 &  GI\_1 &  35.5 &  GI\_2 &  36.2 &  FR &  23.96 &  GI &  35.7 \\
# 61619  & 1 & S\_1 &                                                                                                                                                                                                                                                                                                         Onorevoli colleghi, il Ministro dell'economia e delle finanze ha presentato la Nota di variazioni al bilancio di previsione dello Stato per l'anno finanziario 2018 e bilancio pluriennale per il triennio 2018 - 2020. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                                                                                                                                                                                                
\\
#        &   & Pred - P (7-12) &                                                                                                                                                                                                                                                                                            1 &   0.60 &     1 &   0.56 &     0 &   0.53 &     1 &  0.51 &   1 &   0.53 &   1 &  0.67 \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                         FR\_1 &   91.8 &  FR\_2 &   57.3 &  GI\_1 &  121.5 &  GI\_2 &  50.2 &  FR &  71.97 &  GI &  60.0 \\
# 191503 & 0 & S\_1 &                                                                                         Signor Presidente, in primis vorrei dichiarare che nessuno della maggioranza ha mai detto di voler utilizzare le riserve auree per il pagamento del debito pubblico o per coprire le spese correnti. &        &       &        &       &        &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                 Se si fa un'affermazione simile e poi si dà la colpa alla maggioranza dell'aumento dello spread e della sfiducia dei mercati verso l'Italia, è sempre un concetto sbagliato. &        &       &        &       &        &       &       &     &        &     &       \\
#        &   & Pred - P (1-6) &                                                                                                                                                                                                                                                                                            0 &   0.53 &     1 &   0.55 &     0 &   0.52 &     0 &  0.58 &   0 &   0.62 &   0 &  0.59 \\
#        &   & Pred - P (7-12) &                                                                                                                                                                                                                                                                                            0 &   0.58 &     0 &   0.57 &     0 &   0.61 &     0 &  0.54 &   0 &   0.51 &   0 &  0.58 \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                         FR\_1 &  48.96 &  FR\_2 &   60.6 &  GI\_1 &   45.1 &  GI\_2 &  47.9 &  FR &  54.57 &  GI &  46.5 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/567368616.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(svm_random_speech_errati_da_uno_solo.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_corretti'

bert_random_speech_corretti_da_tutti = \
    costruisci_df_classificazioni_corrette_errate_da_tutti_bert(tabella_bert['df_random_speech'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_random_speech'][tipo_classificazioni])

# %%
print(bert_random_speech_corretti_da_tutti.to_latex())
# Out:
# \begin{tabular}{llllllllllllllll}
# \toprule
#        &   &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_corretti} \\
#        &   &   &       \\
# Id & Cl & Pr & {} &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         &        &       &        &       &       &       &       &       &        &     &       \\
# \midrule
# 574299 & 0 & 0 & S\_1 &                                                                                                                                                                                                                                                                    Il Ministero della giustizia cura, peraltro, con cadenza biennale, la Verifica di impatto della regolamentazione, ai sensi di quanto previsto dal decreto del Presidente del Consiglio dei ministri 19 novembre 2009, n. 212, prendendo a base i dati risultanti dal monitoraggio degli effetti dell'intervento normativo ai fini di eventuali modifiche correttive. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                  Con specifico riferimento, infine, a quanto dedotto nell'atto ispettivo in ordine alla possibilità di destinare parte delle risorse che confluiscono nel Fondo unico di giustizia al funzionamento e al potenziamento degli uffici giudiziari - tra cui, nella specie, quelli della Procura della Repubblica barese - si rappresenta che - come noto - l'articolo 2 del decreto - legge 16 settembre 2008, n. 143, convertito con modificazioni dalla legge n. 181 del 13 novembre 2008, ha affidato ad Equitalia Giustizia SpA la gestione del Fondo. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.93 &        &  0.98 &        &  1.00 &       &  1.00 &       &  1.00 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    FR\_1 &  41.47 &  FR\_2 &  48.35 &  GI\_1 &  40.8 &  GI\_2 &  43.3 &    FR &  45.68 &  GI &  42.3 \\
# 168734 & 1 & 1 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Come mai oggi manca il coraggio di dire che il popolo curdo viene sterminato? &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Non si accettano altre iscrizioni a parlare. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.78 &        &  0.98 &        &  0.98 &       &  0.96 &       &  1.00 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    FR\_1 &  83.06 &  FR\_2 &  79.32 &  GI\_1 &  64.7 &  GI\_2 &  77.6 &    FR &  83.35 &  GI &  69.0 \\
# 716760 & 1 & 1 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Pochi ricordano che Breivik non rientra assolutamente nella categoria dei folli. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           D'altra parte, siccome la morte è un destino comune e non è possibile sottrarvisi, nelle nostre mani è solo come affrontarla. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.61 &        &  0.71 &        &  0.99 &       &  0.82 &       &  0.99 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    FR\_1 &   55.4 &  FR\_2 &   64.0 &  GI\_1 &  52.6 &  GI\_2 &  53.3 &    FR &  63.06 &  GI &  53.1 \\
# 343387 & 1 & 1 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Pertanto decorre da questo momento il termine di venti minuti dal preavviso previsto dall'articolo 119, comma 1, del Regolamento. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & S\_2 &  Il passaggio al nuovo regime ha sostanzialmente previsto tre fasi: una ricognizione straordinaria degli spazi aziendali, al fine di verificare se tutta l'attività fosse riconducibile all'interno delle strutture; la predisposizione e l'attivazione di infrastrutture di rete attraverso le quali gestire tutte le prestazioni, dalla prenotazione al pagamento; l'adozione di un programma sperimentale nel caso in cui le strutture interne non fossero sufficienti, consentendo ai professionisti di svolgere attività libero professionale intramuraria all'interno di propri studi previa stipula di una apposita convenzione. &        &       &        &       &       &       &       &       &        &     &       \\
#        &   &   & P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    0.96 &        &  0.98 &        &  0.99 &       &  0.99 &       &  1.00 &        &     &       \\
#        &   &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    FR\_1 &  50.22 &  FR\_2 & -45.33 &  GI\_1 &  46.4 &  GI\_2 &  26.8 &    FR &  -2.21 &  GI &  30.5 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/3657917018.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(bert_random_speech_corretti_da_tutti.to_latex())

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_errati'

bert_random_speech_errati_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_bert(tabella_bert['df_random_speech'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_random_speech'][tipo_classificazioni])

# %%
tipo_classificazioni = 'lista_eventi_scelti_intersezione_altri_corretti'

bert_random_speech_corretti_da_uno_solo = \
    costruisci_df_classificazioni_corrette_errate_da_uno_solo_bert(tabella_bert['df_random_speech'][tipo_classificazioni],\
                                                                      tipo_classificazioni,
                                diz_indici_leggibilita_per_tipo_per_anno_bert['df_random_speech'][tipo_classificazioni])

# %%
print(bert_random_speech_errati_da_uno_solo.to_latex())
# Out:
# \begin{tabular}{lllllllllllllll}
# \toprule
#        &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_altri\_errati} \\
#        &   &       \\
# Id & Cl & {} &                                                                                                                                                                                                                                                                                                                                                                                                                                           &        &       &        &       &       &       &       &     &        &     &       \\
# \midrule
# 701817 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                          Le brigate rosse hanno scelto questi come loro ultimi obiettivi. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                                                                       Insieme a loro, nei decenni, sono stati ricordati - e mi associo al ricordo - appartenenti alle Forze dell'ordine e alle Forze armate, da quelli colpiti nell'Alto Adige negli anni Cinquanta e Sessanta, alle vittime più recenti. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                                                                                                                                                                                                                                                         0 &   0.55 &     1 &   0.53 &     0 &  0.99 &     0 &  1.00 &   0 &   0.99 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &   72.0 &  FR\_2 &  36.08 &  GI\_1 &  64.0 &  GI\_2 &  43.0 &  FR &  53.11 &  GI &  47.7 \\
# 74365  & 0 & S\_1 &                                                                                                                                                                                                                                                                                                Le mozioni, interpellanze e interrogazioni pervenute alla Presidenza saranno pubblicate nell'allegato B al Resoconto della seduta odierna. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                                                                                                                                                                    Ricordo che il Senato tornerà a riunirsi in seduta pubblica oggi, alle ore 16, 30, con l'ordine del giorno già stampato e distribuito. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                                                                                                                                                                                                                                                         1 &   0.56 &     0 &   0.84 &     0 &  0.95 &     0 &  1.00 &   0 &   1.00 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &   14.9 &  FR\_2 &   67.1 &  GI\_1 &  34.9 &  GI\_2 &  53.3 &  FR &   45.5 &  GI &  45.5 \\
# 363150 & 0 & S\_1 &                                                                                                                                                       La nostra posizione in questo senso è che non ci si discosti dalla proposta della Commissione quanto al volume e alla composizione ad ampia prevalenza di grant e che rimanga fermo il principio di un finanziamento straordinario e a lungo termine tramite debito comune europeo. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &                                                                                                                                                           Inoltre - l'ho già ricordato - l'accordo dovrà giungere in tempi rapidi, per consentire, dopo le necessarie approvazioni al Parlamento europeo e ai Parlamenti nazionali, un celere avvio dell'attuazione del next generation EU e del prossimo quadro finanziario pluriennale. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                                                                                                                                                                                                                                                         1 &   0.52 &     0 &   0.70 &     0 &  1.00 &     0 &  0.99 &   0 &   0.99 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &  31.84 &  FR\_2 &  22.98 &  GI\_1 &  44.3 &  GI\_2 &  34.1 &  FR &  28.34 &  GI &  39.7 \\
# 450666 & 0 & S\_1 &                                                                                                                                                               Tutto questo si perderà, perché nella visione puramente autocratica del Governo che governa se stesso e risponde solo a se stesso delle proprie decisioni noi perderemo di vista che è nella divisione dei poteri che si costruisce la struttura profonda della democrazia. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &  Non possiamo permettere queste ingerenze, né la riduzione del Parlamento, perché, giustamente, come è stato detto, la questione non sta nel numero di parlamentari, ma nel fatto che questa scelta risponde a una manovra elettorale e con essa si dice: signori, in settant'anni di Repubblica, un terzo dei senatori che si sono seduti in quelle Aule era del tutto inutile e, facendo i conti, pensate a quanto avreste risparmiato. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                                                                                                                                                                                                                                                         0 &   0.70 &     1 &   0.54 &     0 &  0.92 &     0 &  0.97 &   0 &   0.95 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                      FR\_1 &  32.38 &  FR\_2 &   4.72 &  GI\_1 &  42.3 &  GI\_2 &  41.8 &  FR &  19.45 &  GI &  42.0 \\
# \bottomrule
# \end{tabular}
# /var/folders/zr/x6zkwkj55dl2mb3rc8k8h1_h0000gn/T/ipykernel_43326/3577557826.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(bert_random_speech_errati_da_uno_solo.to_latex())

# %%
print(bert_random_speech_corretti_da_uno_solo.to_latex())
# Out:
# \begin{tabular}{lllllllllllllll}
# \toprule
#        &   &       & \multicolumn{12}{l}{lista\_eventi\_scelti\_intersezione\_altri\_corretti} \\
#        &   &       \\
# Id & Cl & {} &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        &        &       &        &       &       &       &       &     &        &     &       \\
# \midrule
# 805466 & 0 & S\_1 &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Per questo - in chiusura - sono qui a ribadirle che lei, ministro Tria, non ha un mandato in bianco, mi consenta. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & S\_2 &  Noi chiediamo di vincolare la sua trattativa, anche alla luce della legge Moavero, la n. 234 del 2012, a rispettare questi quattro punti: fornire tempestivamente tutta la documentazione relativa ai temi all'ordine del giorno del Consiglio Ecofin del 14 giugno 2019, in particolare per quanto attiene alla riforma del Trattato sul Meccanismo europeo di stabilità - tra l'altro, ci aspettavamo anche qualche parola in più sull'Ecofin, visto che faceva parte dell'ordine del giorno -; apporre una riserva di esame parlamentare su qualsiasi nuovo emendamento o testo proposto in sede europea sulla riforma del MES stesso; apporre una riserva di esame parlamentare su un eventuale testo proposto in sede europea su qualsiasi proposta relativa alla ponderazione del rischio sui titoli di Stato; richiedere la specifica previsione di strumenti di debito comune a livello di Unione monetaria europea da utilizzare in funzione anticiclica e stabilizzatrice all'interno di un bilancio comune dell'area euro. &        &       &        &       &       &       &       &     &        &     &       \\
#        &   & Pred - P &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1 &   0.88 &     1 &   0.91 &     1 &  0.97 &     0 &  0.50 &   1 &   1.00 &     &       \\
#        &   & Idx\_l &                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Come mai oggi manca il coraggio di dire che il popolo curdo viene sterminato?
#                                                                  716760                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Pochi ricordano che Breivik non rientra assolutamente nella categoria dei folli.
#                                                                  343387                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Pertanto decorre da questo momento il termine di venti minuti dal preavviso previsto dall'articolo 119, comma 1, del Regolamento.
#                  lista_eventi_scelti_intersezione_altri_errati   701817                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Le brigate rosse hanno scelto questi come loro ultimi obiettivi.
#                                                                  74365                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Le mozioni, interpellanze e interrogazioni pervenute alla Presidenza saranno pubblicate nell'allegato B al Resoconto della seduta odierna.
#                                                                  363150                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  La nostra posizione in questo senso è che non ci si discosti dalla proposta della Commissione quanto al volume e alla composizione ad ampia prevalenza di grant e che rimanga fermo il principio di un finanziamento straordinario e a lungo termine tramite debito comune europeo.
#                                                                  450666                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Tutto questo si perderà, perché nella visione puramente autocratica del Governo che governa se stesso e risponde solo a se stesso delle proprie decisioni noi perderemo di vista che è nella divisione dei poteri che si costruisce la struttura profonda della democrazia.
#                  lista_eventi_scelti_intersezione_altri_corretti 805466                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Per questo - in chiusura - sono qui a ribadirle che lei, ministro Tria, non ha un mandato in bianco, mi consenta.
#                                                                  321950                                                                                                                                                                                                                                                                                                                                                                                                                                 Tuttavia - ripeto - se stabiliamo per legge che queste cose si possono fare, mettiamo a rischio altre eventuali attività che, in corso d'opera, l'ente parco voglia mettere in piedi, ma che, non essendo previste dalla legge secondo un'interpretazione dei rapporti sociali che non ci è assolutamente confacente, possa eventualmente avere delle remore a fare.
#                                                                  600234  L'ordine del giorno reca il seguito della discussione dei disegni di legge 1385, già approvato dalla Camera dei deputati in un testo risultante dall'unificazione di un disegno di legge d'iniziativa popolare e dei disegni di legge d'iniziativa dei deputati Cirielli; Pisicchio; Bersani ed altri; Francesco Saverio Romano; Migliore ed altri; Lenzi; Zampa e Marzano; Zampa e Ghizzoni; Martella; Francesco Sanna; Bobba ed altri; Giachetti ed altri; Giorgia Meloni ed altri; Rigoni ed altri; Rigoni ed altri; Nicoletti ed altri; Martella ed altri; Vargiu; Burtone ed altri; Balduzzi ed altri; Laffranco ed altri; Vargiu; Toninelli ed altri; Porta ed altri; Zaccagnini ed altri; Valiante ed altri; Lauricella; Michele Bordo; Marco Meloni ed altri; Di Battista ed altri, e 1449.
#                                                                  780547                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               È a verbale, è agli atti del Parlamento, Presidente, che addirittura con 231 voti favorevoli su 234 votanti, praticamente all'unanimità, quest'Assemblea aveva già licenziato una definizione di tortura senza il termine «reiterate».
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Sentence_2  \
# df_dist_5        lista_eventi_scelti_intersezione_errati         717398                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Lei, signor Presidente, ha dimostrato proprio ieri un notevole coraggio, andando a dichiarare le inammissibilità rispetto agli emendamenti premissivi.
#                                                                  360018                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Però era importante dare un quadro normativo e questa legge finalmente lo dà.
#                                                                  330672                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Si può fare: lo ha fatto il Giappone, è stato fatto in altri Paesi.
#                                                                  747146                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Quindi perché non far votare questo Parlamento?
#                  lista_eventi_scelti_intersezione_corretti       173046                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Il Senato non approva.
# ...
#                                                                  615072                53.8
#                                                                  351925                43.3
#                                                                  465592                59.0
#                  lista_eventi_scelti_intersezione_corretti       574299                40.8
#                                                                  168734                64.7
#                                                                  716760                52.6
#                                                                  343387                46.4
#                  lista_eventi_scelti_intersezione_altri_errati   701817                64.0
#                                                                  74365                 34.9
#                                                                  363150                44.3
#                                                                  450666                42.3
#                  lista_eventi_scelti_intersezione_altri_corretti 805466                58.0
#                                                                  321950                37.7
#                                                                  600234                36.1
#                                                                  780547                36.2
#
#                                                                          gulpease_index_S_2  \
# df_dist_5        lista_eventi_scelti_intersezione_errati         717398                35.3
#                                                                  360018                62.1
#                                                                  330672                71.9
#                                                                  747146                73.3
#                  lista_eventi_scelti_intersezione_corretti       173046               116.5
#                                                                  461426                42.1
#                                                                  548144                44.0
#                                                                  530704                42.4
#                  lista_eventi_scelti_intersezione_altri_errati   529548                57.8
#                                                                  148614                46.3
#                                                                  892241                46.8
#                                                                  604431                43.8
#                  lista_eventi_scelti_intersezione_altri_corretti 290747                50.1
#                                                                  849431                49.0
#                                                                  718961                48.1
#                                                                  638696                71.5
# df_dist_30       lista_eventi_scelti_intersezione_errati         237514               145.3
#                                                                  793878                41.1
#                                                                  532423                52.9
#                                                                  282654                34.3
#                  lista_eventi_scelti_intersezione_corretti       522394                34.2
#                                                                  26864                 72.3
#                                                                  593663                40.9
#                                                                  314849                43.7
#                  lista_eventi_scelti_intersezione_altri_errati   835626                45.1
#                                                                  398376                52.1
#                                                                  837800                30.8
#                                                                  149195                87.8
#                  lista_eventi_scelti_intersezione_altri_corretti 822263                55.9
#                                                                  393080                63.5
#                                                                  410172                53.0
#                                                                  729329                44.5
# df_random_speech lista_eventi_scelti_intersezione_errati         781854                51.0
#                                                                  615072                49.6
#                                                                  351925                49.0
#                                                                  465592                40.3
#                  lista_eventi_scelti_intersezione_corretti       574299                43.3
#                                                                  168734                77.6
#                                                                  716760                53.3
#                                                                  343387                26.8
#                  lista_eventi_scelti_intersezione_altri_errati   701817                43.0
#                                                                  74365                 53.3
#                                                                  363150                34.1
#                                                                  450666                41.8
#                  lista_eventi_scelti_intersezione_altri_corretti 805466                35.8
#                                                                  321950                39.0
#                                                                  600234                40.4
#                                                                  780547                52.9
#
#                                                                          flesch_reading_ease_S_1_S_2  \
# df_dist_5        lista_eventi_scelti_intersezione_errati         717398                        55.55
#                                                                  360018                        63.06
#                                                                  330672                        77.94
#                                                                  747146                        87.95
#                  lista_eventi_scelti_intersezione_corretti       173046                        91.80
#                                                                  461426                        36.62
#                                                                  548144                        47.51
#                                                                  530704                        46.04
#                  lista_eventi_scelti_intersezione_altri_errati   529548                        50.76
#                                                                  148614                        52.14
#                                                                  892241                        54.43
#                                                                  604431                        44.61
#                  lista_eventi_scelti_intersezione_altri_corretti 290747                        -0.87
#                                                                  849431                        56.86
#                                                                  718961                        59.77
#                                                                  638696                        76.42
# df_dist_30       lista_eventi_scelti_intersezione_errati         237514                        74.23
#                                                                  793878                        32.70
#                                                                  532423                        62.06
#                                                                  282654                        29.30
#                  lista_eventi_scelti_intersezione_corretti       522394                        -0.05
#                                                                  26864                         69.00
#                                                                  593663                        39.97
#                                                                  314849                        53.20
#                  lista_eventi_scelti_intersezione_altri_errati   835626                        36.53
#                                                                  398376                        49.48
#                                                                  837800                        36.69
#                                                                  149195                        52.27
#                  lista_eventi_scelti_intersezione_altri_corretti 822263                        70.09
#                                                                  393080                        70.83
#                                                                  410172                        72.79
#                                                                  729329                        34.54
# df_random_speech lista_eventi_scelti_intersezione_errati         781854                        19.26
#                                                                  615072                        64.34
#                                                                  351925                        55.79
#                                                                  465592                        56.79
#                  lista_eventi_scelti_intersezione_corretti       574299                        45.68
#                                                                  168734                        83.35
#                                                                  716760                        63.06
#                                                                  343387                        -2.21
#                  lista_eventi_scelti_intersezione_altri_errati   701817                        53.11
#                                                                  74365                         45.50
#                                                                  363150                        28.34
#                                                                  450666                        19.45
#                  lista_eventi_scelti_intersezione_altri_corretti 805466                        11.36
#                                                                  321950                        22.33
#                                                                  600234                        -7.16
#                                                                  780547                        41.63
#
#                                                                          gulpease_index_S_1_S_2
# df_dist_5        lista_eventi_scelti_intersezione_errati         717398                    47.7
#                                                                  360018                    53.4
#                                                                  330672                    55.8
#                                                                  747146                    62.6
#                  lista_eventi_scelti_intersezione_corretti       173046                   116.5
#                                                                  461426                    42.0
#                                                                  548144                    46.7
#                                                                  530704                    45.4
#                  lista_eventi_scelti_intersezione_altri_errati   529548                    69.0
#                                                                  148614                    46.3
#                                                                  892241                    49.0
#                                                                  604431                    43.2
#                  lista_eventi_scelti_intersezione_altri_corretti 290747                    31.3
#                                                                  849431                    50.2
#                                                                  718961                    52.3
#                                                                  638696                    60.7
# df_dist_30       lista_eventi_scelti_intersezione_errati         237514                   122.1
#                                                                  793878                    40.8
#                                                                  532423                    50.9
#                                                                  282654                    36.2
#                  lista_eventi_scelti_intersezione_corretti       522394                    37.5
#                                                                  26864                     60.5
#                                                                  593663                    43.1
#                                                                  314849                    48.1
#                  lista_eventi_scelti_intersezione_altri_errati   835626                    44.6
#                                                                  398376                    52.5
#                                                                  837800                    37.3
#                                                                  149195                    45.5
#                  lista_eventi_scelti_intersezione_altri_corretti 822263                    54.8
#                                                                  393080                    56.7
#                                                                  410172                    58.6
#                                                                  729329                    39.6
# df_random_speech lista_eventi_scelti_intersezione_errati         781854                    34.9
#                                                                  615072                    51.3
#                                                                  351925                    45.4
#                                                                  465592                    51.6
#                  lista_eventi_scelti_intersezione_corretti       574299                    42.3
#                                                                  168734                    69.0
#                                                                  716760                    53.1
#                                                                  343387                    30.5
#                  lista_eventi_scelti_intersezione_altri_errati   701817                    47.7
#                                                                  74365                     45.5
#                                                                  363150                    39.7
#                                                                  450666                    42.0
#                  lista_eventi_scelti_intersezione_altri_corretti 805466                    38.4
#                                                                  321950                    38.2
#                                                                  600234                    36.8
#                                                                  780547                    43.2

# %%
df_indici_leggibilita_per_tipo_per_anno_bert_5
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
#                                                 360018                                                                                                                                                                                                                  Però era importante dare un quadro normativo e questa legge finalmente lo dà.
#                                                 330672                                                                                                                                                                                                                            Si può fare: lo ha fatto il Giappone, è stato fatto in altri Paesi.
#                                                 747146                                                                                                                                                                                                                                                Quindi perché non far votare questo Parlamento?
# lista_eventi_scelti_intersezione_corretti       173046                                                                                                                                                                                                                                                                         Il Senato non approva.
#                                                 461426  Dobbiamo avere la determinazione, la forza e la consapevolezza di colpire quello che abbiamo qualificato come rendita, lasciando libero il reddito, dal quale si genera la capacità di ricchezza e il consumo, che è uno degli elementi di spinta e di trazione dell'economia quando riparte.
#                                                 548144                                                                                             Lei, signor Ministro, più volte ha violato gli articoli fondamentali della nostra Carta costituzionale o se ne è dimenticato, tant'è che la stessa Corte costituzionale ha impugnato le sue leggi.
#                                                 530704                                                                                              Signor Presidente, ovviamente non sono molto soddisfatto, perché, come avrà notato, ha risposto solamente ad una delle due domande: sul decreto flussi mi ha risposto, sui rimpatri purtroppo no.
# lista_eventi_scelti_intersezione_altri_errati   529548                                                                                                                                                              Indìco la votazione nominale con scrutinio simultaneo dell'emendamento 1.4, presentato dal senatore Vallardi e da altri senatori.
#                                                 148614     Rabbia, perché troppe volte ci siamo detti «mai più», di fronte al ripetersi di queste tragedie, e frustrazione, perché non posso e non voglio pensare che la nostra Europa non sia in grado di fare alcunché e resti impotente di fronte a questa continua ecatombe nel mar Mediterraneo.
#                                                 892241                                                                                                                                          Sta di fatto che questa dilazione dei tempi è difficile da giustificare e da motivare per ragioni diverse dall'assenza della famosa volontà politica.
#                                                 604431                                   Ma domenica, signor Presidente, un tam tam anche sui social media - strumento che, tra l'altro, Gianluca utilizzava con una certa frequenza - ha messo in condizione tutti noi di vivere prima la sorpresa e poi la meraviglia, lo sgomento e l'incredulità.
# lista_eventi_scelti_intersezione_altri_corretti 290747                                                                                                                                                                         La solidarietà ha come suo significato principale una forma di impegno personale etico - sociale a favore degli altri.
#                                                 849431                                                                                                                      Credo che il termine «proponente» possa essere riferibile ad un senatore, ad un Gruppo, al Presidente della Commissione o a chi si voglia, ma sicuramente non al Governo.
#                                                 718961                                                                                               Contro quella deriva autoritaria e illiberale che mina i fondamentali di uno Stato di diritto e di una cultura giuridica, che il mondo intero ci invidia, il Partito Democratico ci sarà sempre.
#                                                 638696                                                                                                                                                                                                                                 Ci proponiamo di farlo in pochi mesi, entro la metà di aprile.
#
#                                                         Class  \
# lista_eventi_scelti_intersezione_errati         717398      0
#                                                 360018      1
#                                                 330672      0
#                                                 747146      1
# lista_eventi_scelti_intersezione_corretti       173046      1
#                                                 461426      1
#                                                 548144      1
#                                                 530704      1
# lista_eventi_scelti_intersezione_altri_errati   529548      0
#                                                 148614      1
#                                                 892241      1
#                                                 604431      1
# lista_eventi_scelti_intersezione_altri_corretti 290747      1
#                                                 849431      1
#                                                 718961      0
#                                                 638696      1
#
#                                                         flesch_reading_ease_S_1  \
# lista_eventi_scelti_intersezione_errati         717398                    91.42
#                                                 360018                    53.34
#                                                 330672                    59.98
#                                                 747146                    86.92
# lista_eventi_scelti_intersezione_corretti       173046                    91.80
#                                                 461426                    40.74
#                                                 548144                    50.88
#                                                 530704                    38.48
# lista_eventi_scelti_intersezione_altri_errati   529548                    91.80
#                                                 148614                    58.58
#                                                 892241                    62.94
#                                                 604431                    38.10
# lista_eventi_scelti_intersezione_altri_corretti 290747                   -39.93
#                                                 849431                    53.06
#                                                 718961                    80.10
#                                                 638696                    56.38
#
#                                                         flesch_reading_ease_S_2  \
# lista_eventi_scelti_intersezione_errati         717398                    31.26
#                                                 360018                    75.48
#                                                 330672                   104.54
#                                                 747146                    79.32
# lista_eventi_scelti_intersezione_corretti       173046                    91.80
#                                                 461426                    25.18
#                                                 548144                    44.02
#                                                 530704                    51.02
# lista_eventi_scelti_intersezione_altri_errati   529548                    40.05
#                                                 148614                    42.10
#                                                 892241                    46.22
#                                                 604431                    45.00
# lista_eventi_scelti_intersezione_altri_corretti 290747                    50.26
#                                                 849431                    54.18
#                                                 718961                    44.12
#                                                 638696                    96.40
#
#                                                         gulpease_index_S_1  \
# lista_eventi_scelti_intersezione_errati         717398                67.3
#                                                 360018                47.4
#                                                 330672                48.3
#                                                 747146                58.4
# lista_eventi_scelti_intersezione_corretti       173046               116.5
#                                                 461426                41.6
#                                                 548144                49.3
#                                                 530704                47.3
# lista_eventi_scelti_intersezione_altri_errati   529548               116.5
#                                                 148614                46.3
#                                                 892241                51.3
#                                                 604431                42.2
# lista_eventi_scelti_intersezione_altri_corretti 290747                26.6
#                                                 849431                52.6
#                                                 718961                62.8
#                                                 638696                49.8
#
#                                                         gulpease_index_S_2  \
# lista_eventi_scelti_intersezione_errati         717398                35.3
#                                                 360018                62.1
#                                                 330672                71.9
#                                                 747146                73.3
# lista_eventi_scelti_intersezione_corretti       173046               116.5
#                                                 461426                42.1
#                                                 548144                44.0
#                                                 530704                42.4
# lista_eventi_scelti_intersezione_altri_errati   529548                57.8
#                                                 148614                46.3
#                                                 892241                46.8
#                                                 604431                43.8
# lista_eventi_scelti_intersezione_altri_corretti 290747                50.1
#                                                 849431                49.0
#                                                 718961                48.1
#                                                 638696                71.5
#
#                                                         flesch_reading_ease_S_1_S_2  \
# lista_eventi_scelti_intersezione_errati         717398                        55.55
#                                                 360018                        63.06
#                                                 330672                        77.94
#                                                 747146                        87.95
# lista_eventi_scelti_intersezione_corretti       173046                        91.80
#                                                 461426                        36.62
#                                                 548144                        47.51
#                                                 530704                        46.04
# lista_eventi_scelti_intersezione_altri_errati   529548                        50.76
#                                                 148614                        52.14
#                                                 892241                        54.43
#                                                 604431                        44.61
# lista_eventi_scelti_intersezione_altri_corretti 290747                        -0.87
#                                                 849431                        56.86
#                                                 718961                        59.77
#                                                 638696                        76.42
#
#                                                         gulpease_index_S_1_S_2
# lista_eventi_scelti_intersezione_errati         717398                    47.7
#                                                 360018                    53.4
#                                                 330672                    55.8
#                                                 747146                    62.6
# lista_eventi_scelti_intersezione_corretti       173046                   116.5
#                                                 461426                    42.0
#                                                 548144                    46.7
#                                                 530704                    45.4
# lista_eventi_scelti_intersezione_altri_errati   529548                    69.0
#                                                 148614                    46.3
#                                                 892241                    49.0
#                                                 604431                    43.2
# lista_eventi_scelti_intersezione_altri_corretti 290747                    31.3
#                                                 849431                    50.2
#                                                 718961                    52.3
#                                                 638696                    60.7

# %% [markdown]
# Errati da una sola epoca
# Id 529548:
# la seconda frase risulta più complessa. Le probabilità delle classificazioni risultano in realtà tutte basse perchè non c'è un chiaro nesso logico fra le due, ma potrebbbero essere (e sono) consecutive.
#
# Id 148614:
# le frasi sono abbastanza lunghe, ma non eccessivamente complesse. L'unica classificazione sbagliata ripoorta uno score di probabilità abbastanza alto, probabilmente è stata influenzata dalla presenza dello stessoo nome, e delle trattazione del medesimo argomento.
#
# Id 892241:
# le frasi risultano abbastanza semplici. l'unica classificazione sbagliata riporta uno score di probabilità basso.
#
# Id 604431:
# frasi abbastanza lunghe e complesse. Non esiste un nesso logico fra le dude frasi. L'unica classificazioone errata riporta una probabilità el 50 %, quindi si tratta di una scelta casuale.
#
# Corretti da una sola epoca
# Id 290747:
# la prima frase è molto complessa rispetto alla seconda. La classificazione è corretta solo per l'ultima epoca. Le altre riportanno score di probabilità abbastanza bassi.
#
# Id 849431:
# le frasi risultano abbastanza semplici. Per la coassificazione come prima.
#
# Id 718961:
# frasi semplici. l'unica classificazione corretta riporta una probabilità bassa. Infatti non è evidente il nesso logico fra le due frasi, si ripete semplicemente lo stesso termine.
#
# Id 638696:
# frasi semplici. l'unica classificazione corretta riporta la probabilità più bassa. Probabilmente le altre epoche hanno considerato le due frasi come consecutive per via del possibile riferimento anaforico.
#
# Errati da tutti
# Id 717398:
# La seconda frase risulta più complessa rispetto alla prima; nonostante la classificazione sia stata sbagliata da tutte le epoche, notiamo hce che gli score di probbilità con cui è stata determinata la scelta non risultano alti.
#
# Id 360018:
# Le frasi non risultano troppo semplici; la classificazione è stata sbagliata da tutte le epoche con probabilità alta, ed effettivamente le due frasi pootrebbero essere considerate come consecutive.
#
# Id 330672:
# la seconda frase è più semplice della prima. Classificazione sbagliata da tutte le epoche, dalle prime con probabilità più bassa, dalle ultime con proba alta. Non è evidente un nesso logico fra le due, nel sennso che non viene trovato lo stesso argomento, quindi forse per questo prevale la considerazionne delle due frasi come non consecutive.
#
# Id 747146:
# le frasi non risultano difficili. Tuttavia la classificazione risulta sbagliata da tutte le epoche, con probabilità più alta nelle ultime, e probabilmente ancora una volta questo è dovuto al fatto che si ripete lo stesso nome, lo stesso argomento, per cui le frasi sono state considerate erroneamente come consecutive.
#
# Corretti da tutti
# Id 173046: le frasi sono identiche e molto semplici; non stupisce che la classificazione sia stata eseguita in nmodo corretto da tutte le epoche.
#
# Id 461426:
# le frasi sono entrambe complesse; la classificazione è stata eseguita in modo corretto da tutte le epoche, sebbene con score di probabilità abbastanza bassi, tranne per l'ultima epoca.
#
# Id 548144:
# Abbastanza semplici. Classificazione corretta aiutata dalla mancanza di nesso logico fra le frasi.
#
# Id 530704:
# Le frasi non risultano molto semplici, eppure la classificazione è stata eseguita in modo corretto grazie alla mancanza di nesso logico e condivisione di tema fra le frasi.

# %% [markdown]
# Errati da tutti:
# Id 717398: la seconda frase è molto poco leggibile, proba basse, tranne per la terza epoca.
#
# Id 360018: la prima frase è più difficile, proba alte --> effettivamente le frasi potrebbero essere consecutive.
#
# Id 330672: la prima è più difficile; prime epoche proba bassa, le ultime alta.
#
# Id 747146: leggibilità alta per entrambe le frasi; prime tre epoche proba bassa, le altre due alta.
#
# Corretti da tutti:
# Id 461426: frasi entrambe molto complesse, infatti hanno score di leggibilità basso; le prime due epoche e la quarta hanno proba bassa, le altre alta.
#
# Id 548144: anche qui come il precedente, solo che le ultile 3 epoche hanno proba alta.
#
# Id 530704: come il precedente.
#
# Errati da uno solo:
# Id 529548: la seconda è più difficile; errato da uno solo ma con proba bassa; anche gli altri che hanno fatto giusto avevano proba bassa.
#
# Id 148614: frasi entrambe complesse; l'ha sbagliato solo uno, ma con proba alta --> il tema è lo stesso.
#
# Id 892241: difficile entrambe; sbagliato solo da uno e con proba bassa.
#
# Id 604431: complesse entrambe; l'ha sbagliato solo uno con proba del 50%.
#
# Corretti solo da uno:
# Id 290747: difficili entrambe, soprattutto la prima; corretto solo da una (l'ultima) con proba abbastanza alta.
#
# Id 849431: complesse entrambe; corretto solo da uno con proba massima.
#
# Id 718961: la secondad è un po' più complessa; corretto da una sola epoca, ma con proba bassa.
#
# Id 638696: la prima è più difficile; giusto solo da uno con proba bassa --> effettivamente potrebbe essere consecutivo.

# %%
df_indici_leggibilita_per_tipo_per_anno_bert_30
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                      Sentence_1  \
# lista_eventi_scelti_intersezione_errati         237514                                                                                                                                                                                                                                                                                                                                     L'emendamento 2.13 è stato ritirato.
#                                                 793878                                                                                                                                                      Il Governo coglie anche questa occasione per unirsi al dolore dei familiari delle vittime dell'attacco terroristico, i disegnatori, i poliziotti, gli ostaggi, tutte le vittime di questo ignobile atto di terrore.
#                                                 532423                                                                                                                                                                                                                   Signora Presidente, innanzitutto voglio anticipare che il voto di Forza Italia su questo disegno di legge sarà un voto negativo, a scanso di equivoci.
#                                                 282654                                                                                                                                            Una premessa di metodo consiste nel fatto che la Commissione ha proceduto all'esame degli emendamenti dopo un'approfondita attività istruttoria, che ha potuto contare sui contributi di molti ed autorevoli soggetti auditi.
# lista_eventi_scelti_intersezione_corretti       522394                                                                                                                                                                                                                          Quando parliamo di piccoli Comuni, ci riferiamo al 70 per cento dei Comuni italiani, che ha una popolazione pari o inferiore ai 5.000 abitanti.
#                                                 26864                                                                                                                                                                                                                                                                                        Abbiamo una Costituzione che ha avuto, allora, un'ispirazione dallo Spirito Santo.
#                                                 593663                                                                                                                                                                                                                                 Do altresì atto al collega Carraro della sua correttezza, come sempre, perché interviene allo stesso modo in Commissione e in Assemblea.
#                                                 314849                                                                                                                                                                                                              Se la Presidenza sarà clemente, cercherò di seguire, al meglio di quello che mi riesce, una via di mezzo per non eludere le questioni che sono state poste.
# lista_eventi_scelti_intersezione_altri_errati   835626                                                                              Attenti, colleghi, era il 1905 e la Montessori diceva: «Ora non si troveranno deputati che per la solidarietà e la difesa della donna dedichino la loro esistenza di uomini politici - come sarebbe necessario - se le donne non potranno dare il loro voto, cioè farli eleggere deputati».
                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Vi ricordo che, nella civile Italia e nella moderna lotta per la rappresentanza paritaria, esistono ancora Regioni con una sola eletta e una Regione, la Basilicata, con un Consiglio regionale di soli uomini.
#                                                 398376                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Passiamo alla votazione della prima parte dell'emendamento 4.101, sul quale da parte del prescritto numero di senatori è stata presentata richiesta di votazione a scrutinio segreto.
#                                                 837800                                                                                                                                                                                                                                                                                                                                                                                                                                  Abbiamo mancato l'obiettivo nell'ultimo tratto di strada, perché alla fine hanno prevalso calcoli meschini, astuzie parlamentari di piccolo cabotaggio, interessi di partito ed elettorali, paura di sondaggi drogati da un'informazione spesso parziale e scorretta.
#                                                 149195                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Ma non è la soluzione a quel problema.
# lista_eventi_scelti_intersezione_altri_corretti 822263                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Poi ci sono state solo promesse e speranze deluse, passando attraverso Pacs, Dico, fino ai Didore.
#                                                 393080                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   E quando lo ha consentito se un dibattito vero in Parlamento non c'è mai stato e lei viene qui oggi?
#                                                 410172                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              È noto che l'economia moderna nasce nell'ambito delle scienze giuridiche e morali e non si tratta di una nascita casuale.
#                                                 729329                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Un altro fronte di attività del gruppo è quello delle interferenze nei confronti di componenti del Consiglio superiore della magistratura.
#
#                                                         Class  \
# lista_eventi_scelti_intersezione_errati         237514      1
#                                                 793878      0
#                                                 532423      1
#                                                 282654      0
# lista_eventi_scelti_intersezione_corretti       522394      1
#                                                 26864       0
#                                                 593663      0
#                                                 314849      0
# lista_eventi_scelti_intersezione_altri_errati   835626      1
#                                                 398376      1
#                                                 837800      0
#                                                 149195      1
# lista_eventi_scelti_intersezione_altri_corretti 822263      0
#                                                 393080      1
#                                                 410172      0
#                                                 729329      0
#
#                                                         flesch_reading_ease_S_1  \
# lista_eventi_scelti_intersezione_errati         237514                    54.50
#                                                 793878                    37.32
#                                                 532423                    53.32
#                                                 282654                    27.66
# lista_eventi_scelti_intersezione_corretti       522394                    63.28
#                                                 26864                     50.00
#                                                 593663                    58.30
#                                                 314849                    75.60
# lista_eventi_scelti_intersezione_altri_errati   835626                    29.40
#                                                 398376                    36.51
#                                                 837800                    62.16
#                                                 149195                    17.88
# lista_eventi_scelti_intersezione_altri_corretti 822263                    71.36
#                                                 393080                    45.52
#                                                 410172                    79.32
#                                                 729329                    22.02
#
#                                                         flesch_reading_ease_S_2  \
# lista_eventi_scelti_intersezione_errati         237514                    85.99
#                                                 793878                    27.12
#                                                 532423                    69.18
#                                                 282654                    21.52
# lista_eventi_scelti_intersezione_corretti       522394                   -52.81
#                                                 26864                     91.96
#                                                 593663                    22.12
#                                                 314849                    34.94
# lista_eventi_scelti_intersezione_altri_errati   835626                    43.18
#                                                 398376                    57.00
#                                                 837800                    17.52
#                                                 149195                   109.10
# lista_eventi_scelti_intersezione_altri_corretti 822263                    68.70
#                                                 393080                    89.00
#                                                 410172                    65.00
#                                                 729329                    50.00
#
#                                                         gulpease_index_S_1  \
# lista_eventi_scelti_intersezione_errati         237514                85.0
#                                                 793878                40.3
#                                                 532423                48.6
#                                                 282654                37.1
# lista_eventi_scelti_intersezione_corretti       522394                51.5
#                                                 26864                 50.8
#                                                 593663                48.0
#                                                 314849                54.0
# lista_eventi_scelti_intersezione_altri_errati   835626                44.2
#                                                 398376                53.1
#                                                 837800                69.0
#                                                 149195                39.4
# lista_eventi_scelti_intersezione_altri_corretti 822263                53.7
#                                                 393080                47.7
#                                                 410172                74.7
#                                                 729329                36.1
#
#                                                         gulpease_index_S_2  \
# lista_eventi_scelti_intersezione_errati         237514               145.3
#                                                 793878                41.1
#                                                 532423                52.9
#                                                 282654                34.3
# lista_eventi_scelti_intersezione_corretti       522394                34.2
#                                                 26864                 72.3
#                                                 593663                40.9
#                                                 314849                43.7
# lista_eventi_scelti_intersezione_altri_errati   835626                45.1
#                                                 398376                52.1
#                                                 837800                30.8
#                                                 149195                87.8
# lista_eventi_scelti_intersezione_altri_corretti 822263                55.9
#                                                 393080                63.5
#                                                 410172                53.0
#                                                 729329                44.5
#
#                                                         flesch_reading_ease_S_1_S_2  \
# lista_eventi_scelti_intersezione_errati         237514                        74.23
#                                                 793878                        32.70
#                                                 532423                        62.06
#                                                 282654                        29.30
# lista_eventi_scelti_intersezione_corretti       522394                        -0.05
#                                                 26864                         69.00
#                                                 593663                        39.97
#                                                 314849                        53.20
# lista_eventi_scelti_intersezione_altri_errati   835626                        36.53
#                                                 398376                        49.48
#                                                 837800                        36.69
#                                                 149195                        52.27
# lista_eventi_scelti_intersezione_altri_corretti 822263                        70.09
#                                                 393080                        70.83
#                                                 410172                        72.79
#                                                 729329                        34.54
#
#                                                         gulpease_index_S_1_S_2
# lista_eventi_scelti_intersezione_errati         237514                   122.1
#                                                 793878                    40.8
#                                                 532423                    50.9
#                                                 282654                    36.2
# lista_eventi_scelti_intersezione_corretti       522394                    37.5
#                                                 26864                     60.5
#                                                 593663                    43.1
#                                                 314849                    48.1
# lista_eventi_scelti_intersezione_altri_errati   835626                    44.6
#                                                 398376                    52.5
#                                                 837800                    37.3
#                                                 149195                    45.5
# lista_eventi_scelti_intersezione_altri_corretti 822263                    54.8
#                                                 393080                    56.7
#                                                 410172                    58.6
#                                                 729329                    39.6

# %% [markdown]
# Errati da una sola epoca
# Id 835626:
# le frasi risultano complesse, in modo particolare la prima. Probabilmente l'ultima epoca ha consierato le due proposizioni come consecutive per via della condivisione del tema politico.
#
# Id 398376:
# le frasi non risultano complesse; probabilmente i puntegggi di leggibilità bassi sono dovuti ai termini molto specifici del campo della politica. L'unica classificazione errata riporta abbastanza alto, forse per via della ripetizione di alcuni termini.
#
# Id 837800:
# la seconda frase risulta più difficile della prima. L'unica classificazione sbagliata riporta una probabilità bassa.
#
# Id 149195:
# la prima frase risulta estremamente complessa e lunga. L'unica classificazione sbagliata riporta una probabilità bassa.
#
# Corretti da una sola epoca
# Id 822263:
# le due frasi non risultano complesse. Effettivamente le due frasi potrebbero anche non essere consecutive.
#
# Id 393080:
# la prima frase è più complessa della seconda. l'unica classificazione corretta riporta la probabilità più alta.
#
# Id 410172:
# le frasi risultano abbastanza semplici. Non è evidente un nesso logico.
#
# Id 729329:
# le frasi non risultano molto semplici in termini di complessità. Anche qui non è evidennte un collegamento fra le due frasi e la classificazione è stata resa più ddifficile dalla complessità delle proposizioni.
#
# Errati da tutte le epoche
# Id 237514:
# le frasi non risultano difficili. Sebbene le probabilità della classificazione non siano alte, effettivamente le frasi potrebbero anche essere consecutive.
#
# Id 793878:
# Entrambe le frasi risultano complesse, in modo particolare la seconda. Sebbene le due frasi siano coerenti lette una accanto all'altra, probabilmente la complessità della seconda ha reso più difficile la classificazione.
#
# Id 532423:
# le frasi risultano abbastanza complesse. In questo caso tutte le epoche hanno sbagliato con uno score di probabilità alto, poichè effettivamente le due frasi risulterebbero coerenti dal punto di vista del tema trattato, ma non dal punto di vista del contesto generale, dato che la seconda frase costituisce una critica a quanto detto nella prima.
#
# Id 282654:
# entrambe le frasi risultano complesse. Non emerge un chiaro nesso logico fra le due frasi..
#
# Corretti da tutte le epoche
# Id 522394:
# la prima frase è abbastanza semplice, mentre le seconda risulta estremamente lunga e dunque complessa in termini di leggibilità. La classificazione risulta corretta per tutte le epoche; infatti non emerge nessun collegamento che possa rendere le due frasi coerenti se viste affiancate.
#
# Id 26864:
# la prima frase risulta un po' più complessa. La classififcazione corretta probabilmente è stata guidata dalla ripetizione dello stesso verbo.
#
# Id 593663:
# la seconda frase è più lunga e più difficile. Le probabilità della classificazione risultano alte da parte di tutte le epoche, infatti è evidente il collegamento fra le due frasi.
#
# Id 314849:
# la seconda frase è più difficile. Effettivamente le due frasi risultano coerenti se lette una accanto all'altra.

# %% [markdown]
# Errati da tutti:
# Id 237514: abbastanza semplici da leggere; errato da tutti con proba bassa.
#
# Id 793878: complesse entrambe; sbagliato dalle ultime con proba più alta.
#
# Id 532423: abbastanza complesse entrambe; proba alta per tutte le epoche, il tema potrebbe essere lo stesso.
#
# Id 282654: molto complesse entrambe; ultime epoche con proba più alta.
#
# Corretti da tutti:
# Id 522394: difficili entrambe, specialmente la seconda; corretto da tutte, proba alta per tutte, eccetto per la prima epoca.
#
# Id 26864: la seconda sembra più semplice della prima; per le proba come il precedente.
#
# Id 593663: entrambe complesse, specialmente la seconda. Proba come il precedente.
#
# Id 314849: la prima è unn po' più semplice della seconda; anche qui proba come il precedente.
#
# Errati da uno solo:
# Id 835626: complesse entrambe; errato dall'ultima con proba discreta.
#
# Id 398376: difficili entrambe; sbagliato dalla prima epoca con proba discreta.
#
# Id 837800: la seconda è più difficile; sbagliato dall'ultima ma con proba bassa.
#
# Id 149195: prima frase molto complicata; ha sbagliato solo la terza epoca ma con proba bassa.
#
# Corretti da uno solo:
# Id 822263: frasi abbastanza semplici da leggere; corretto solo da uno con proba bassa.
#
# Id 393080: la prima è più difficile della seconda; corretto solo dall'ultima epoca e con proba altissima.
#
# Id 410172: semplici da leggere; corretto solo da una ma con proba bassa.
#
# Id 729329: abbastanza complesse, in modo particolare la prima; giusta solo una con proba abbastanza bassa.

# %%
df_indici_leggibilita_per_tipo_per_anno_bert_random_speech
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Sentence_1  \
# lista_eventi_scelti_intersezione_errati         781854                                                                                                                                                                                                                                                                                                                                                                                            Fondo centrale di garanzia, riserva per la garanzia ai consorzi fidi e alle cooperative di garanzia, rafforzamento della cooperazione per lo sviluppo e per l'internazionalizzazione delle imprese, misure per l'accelerazione dell'utilizzo dei fondi europei; e poi, altre misure di politica industriale, come quelle per la governance dell'Agenda digitale, la diffusione delle tecnologie digitali.
#                                                 615072                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Ci sono problemi e segnalo all'attuale Governo la sua distrazione anche per le isole maggiori, non solo per le isole minori.
#                                                 351925                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Credo che, se l'Italia non vince la battaglia fondamentale per una ripartizione più equa dei profughi, andando avanti così, con nuovi futuri flussi, si rischierà di mettere a repentaglio la stessa coesione sociale del Paese.
#                                                 465592                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Nel testo dell'ordine del giorno G1.100 si parla sempre di vittime «innocenti» con riferimento al titolo che aveva precedentemente il disegno di legge.
# lista_eventi_scelti_intersezione_corretti       574299                                                                                                                                                                                                                                                                                                                                                                                                                                 Il Ministero della giustizia cura, peraltro, con cadenza biennale, la Verifica di impatto della regolamentazione, ai sensi di quanto previsto dal decreto del Presidente del Consiglio dei ministri 19 novembre 2009, n. 212, prendendo a base i dati risultanti dal monitoraggio degli effetti dell'intervento normativo ai fini di eventuali modifiche correttive.
#                                                 168734                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Come mai oggi manca il coraggio di dire che il popolo curdo viene sterminato?
#                                                 716760                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Pochi ricordano che Breivik non rientra assolutamente nella categoria dei folli.
#                                                 343387                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Pertanto decorre da questo momento il termine di venti minuti dal preavviso previsto dall'articolo 119, comma 1, del Regolamento.
# lista_eventi_scelti_intersezione_altri_errati   701817                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Le brigate rosse hanno scelto questi come loro ultimi obiettivi.
#                                                 74365                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Le mozioni, interpellanze e interrogazioni pervenute alla Presidenza saranno pubblicate nell'allegato B al Resoconto della seduta odierna.
#                                                 363150                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  La nostra posizione in questo senso è che non ci si discosti dalla proposta della Commissione quanto al volume e alla composizione ad ampia prevalenza di grant e che rimanga fermo il principio di un finanziamento straordinario e a lungo termine tramite debito comune europeo.
#                                                 450666                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Tutto questo si perderà, perché nella visione puramente autocratica del Governo che governa se stesso e risponde solo a se stesso delle proprie decisioni noi perderemo di vista che è nella divisione dei poteri che si costruisce la struttura profonda della democrazia.
# lista_eventi_scelti_intersezione_altri_corretti 805466                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Per questo - in chiusura - sono qui a ribadirle che lei, ministro Tria, non ha un mandato in bianco, mi consenta.
#                                                 321950                                                                                                                                                                                                                                                                                                                                                                                                                                 Tuttavia - ripeto - se stabiliamo per legge che queste cose si possono fare, mettiamo a rischio altre eventuali attività che, in corso d'opera, l'ente parco voglia mettere in piedi, ma che, non essendo previste dalla legge secondo un'interpretazione dei rapporti sociali che non ci è assolutamente confacente, possa eventualmente avere delle remore a fare.
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Non possiamo permettere queste ingerenze, né la riduzione del Parlamento, perché, giustamente, come è stato detto, la questione non sta nel numero di parlamentari, ma nel fatto che questa scelta risponde a una manovra elettorale e con essa si dice: signori, in settant'anni di Repubblica, un terzo dei senatori che si sono seduti in quelle Aule era del tutto inutile e, facendo i conti, pensate a quanto avreste risparmiato.
# lista_eventi_scelti_intersezione_altri_corretti 805466  Noi chiediamo di vincolare la sua trattativa, anche alla luce della legge Moavero, la n. 234 del 2012, a rispettare questi quattro punti: fornire tempestivamente tutta la documentazione relativa ai temi all'ordine del giorno del Consiglio Ecofin del 14 giugno 2019, in particolare per quanto attiene alla riforma del Trattato sul Meccanismo europeo di stabilità - tra l'altro, ci aspettavamo anche qualche parola in più sull'Ecofin, visto che faceva parte dell'ordine del giorno -; apporre una riserva di esame parlamentare su qualsiasi nuovo emendamento o testo proposto in sede europea sulla riforma del MES stesso; apporre una riserva di esame parlamentare su un eventuale testo proposto in sede europea su qualsiasi proposta relativa alla ponderazione del rischio sui titoli di Stato; richiedere la specifica previsione di strumenti di debito comune a livello di Unione monetaria europea da utilizzare in funzione anticiclica e stabilizzatrice all'interno di un bilancio comune dell'area euro.
#                                                 321950                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Signora Presidente, come avevo detto illustrando gli emendamenti, questo è uno degli articoli più importanti del provvedimento ed è, ahimè, quello su cui noi abbiamo rilevato gli aspetti critici più rilevanti, proprio in ordine alla riforma della governance dei parchi.
#                                                 600234                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Ricordo che nella seduta del 19 dicembre la presidente della 1ᵃ Commissione permanente, senatrice Finocchiaro, ha riferito sui lavori della Commissione.
#                                                 780547                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                E ricordo il voto favorevole di Giovanardi, di Nitto Palma e della senatrice Bonfrisco, che cito solo perché hanno parlato prima di me.
#
#                                                         Class  \
# lista_eventi_scelti_intersezione_errati         781854      1
#                                                 615072      0
#                                                 351925      0
#                                                 465592      0
# lista_eventi_scelti_intersezione_corretti       574299      0
#                                                 168734      1
#                                                 716760      1
#                                                 343387      1
# lista_eventi_scelti_intersezione_altri_errati   701817      0
#                                                 74365       0
#                                                 363150      0
#                                                 450666      0
# lista_eventi_scelti_intersezione_altri_corretti 805466      0
#                                                 321950      0
#                                                 600234      0
#                                                 780547      0
#
#                                                         flesch_reading_ease_S_1  \
# lista_eventi_scelti_intersezione_errati         781854                   -10.43
#                                                 615072                    69.70
#                                                 351925                    48.08
#                                                 465592                    71.61
# lista_eventi_scelti_intersezione_corretti       574299                    41.47
#                                                 168734                    83.06
#                                                 716760                    55.40
#                                                 343387                    50.22
# lista_eventi_scelti_intersezione_altri_errati   701817                    72.00
#                                                 74365                     14.90
#                                                 363150                    31.84
#                                                 450666                    32.38
# lista_eventi_scelti_intersezione_altri_corretti 805466                    89.00
#                                                 321950                    14.54
#                                                 600234                   -67.09
#                                                 780547                    25.40
#
#                                                         flesch_reading_ease_S_2  \
# lista_eventi_scelti_intersezione_errati         781854                    61.48
#                                                 615072                    58.62
#                                                 351925                    62.00
#                                                 465592                    33.52
# lista_eventi_scelti_intersezione_corretti       574299                    48.35
#                                                 168734                    79.32
#                                                 716760                    64.00
#                                                 343387                   -45.33
# lista_eventi_scelti_intersezione_altri_errati   701817                    36.08
#                                                 74365                     67.10
#                                                 363150                    22.98
#                                                 450666                     4.72
# lista_eventi_scelti_intersezione_altri_corretti 805466                   -16.25
#                                                 321950                    30.00
#                                                 600234                    38.26
#                                                 780547                    61.88
#
#                                                         gulpease_index_S_1  \
# lista_eventi_scelti_intersezione_errati         781854                30.3
#                                                 615072                53.8
#                                                 351925                43.3
#                                                 465592                59.0
# lista_eventi_scelti_intersezione_corretti       574299                40.8
#                                                 168734                64.7
#                                                 716760                52.6
#                                                 343387                46.4
# lista_eventi_scelti_intersezione_altri_errati   701817                64.0
#                                                 74365                 34.9
#                                                 363150                44.3
#                                                 450666                42.3
# lista_eventi_scelti_intersezione_altri_corretti 805466                58.0
#                                                 321950                37.7
#                                                 600234                36.1
#                                                 780547                36.2
#
#                                                         gulpease_index_S_2  \
# lista_eventi_scelti_intersezione_errati         781854                51.0
#                                                 615072                49.6
#                                                 351925                49.0
#                                                 465592                40.3
# lista_eventi_scelti_intersezione_corretti       574299                43.3
#                                                 168734                77.6
#                                                 716760                53.3
#                                                 343387                26.8
# lista_eventi_scelti_intersezione_altri_errati   701817                43.0
#                                                 74365                 53.3
#                                                 363150                34.1
#                                                 450666                41.8
# lista_eventi_scelti_intersezione_altri_corretti 805466                35.8
#                                                 321950                39.0
#                                                 600234                40.4
#                                                 780547                52.9
#
#                                                         flesch_reading_ease_S_1_S_2  \
# lista_eventi_scelti_intersezione_errati         781854                        19.26
#                                                 615072                        64.34
#                                                 351925                        55.79
#                                                 465592                        56.79
# lista_eventi_scelti_intersezione_corretti       574299                        45.68
#                                                 168734                        83.35
#                                                 716760                        63.06
#                                                 343387                        -2.21
# lista_eventi_scelti_intersezione_altri_errati   701817                        53.11
#                                                 74365                         45.50
#                                                 363150                        28.34
#                                                 450666                        19.45
# lista_eventi_scelti_intersezione_altri_corretti 805466                        11.36
#                                                 321950                        22.33
#                                                 600234                        -7.16
#                                                 780547                        41.63
#
#                                                         gulpease_index_S_1_S_2
# lista_eventi_scelti_intersezione_errati         781854                    34.9
#                                                 615072                    51.3
#                                                 351925                    45.4
#                                                 465592                    51.6
# lista_eventi_scelti_intersezione_corretti       574299                    42.3
#                                                 168734                    69.0
#                                                 716760                    53.1
#                                                 343387                    30.5
# lista_eventi_scelti_intersezione_altri_errati   701817                    47.7
#                                                 74365                     45.5
#                                                 363150                    39.7
#                                                 450666                    42.0
# lista_eventi_scelti_intersezione_altri_corretti 805466                    38.4
#                                                 321950                    38.2
#                                                 600234                    36.8
#                                                 780547                    43.2

# %% [markdown]
# Errati da una sola epoca
# Id 701817:
# le frasi risultano abbastanza semplici, un po' meno la seconda. Qui il nesso logico è evidente, infatti l'unica classifficazione sbagliata ha probabilità bassa.
#
# Id 74365:
# la prima frase risulta più difficile della seconda. L'unica classificazione errata riporta una probabilità bassa.
#
# Id 363150:
# le frasi sono entrambe complesse. L'unica classificazione errata riporta una probabilità bassa.
#
# Id 450666:
# entrambe le frasi sono difficili, in modo particolare la seconda. L'unica classificazione sbagliata riporta lo score di probabilità più basso.
#
# Corretti da una sola epoca
# Id 805466:
# la seconda frase risulta estremamente complessa rispetto alla prima. Inoltre, l'unica classificazione corretta riporta uno score di probabilità del 50%, dunque è una scelta casuale.
#
# Id 321950:
# entrambe le frasi non sono semplici e probabilmente questo ha causato problemi nella classificazione.
#
# Id 600234:
# la prima frase risulta molto complessa in termini di leggibilità. Non risulta un nnesso logico, infatti l'unica classificazione corretta ha la probabilità più bassa.
#
# Id 780547:
# la prima frase risulta più difficile della seconda. Non risulta un nesso logico evidente, quindi è comprensibile che quasi tutte le epcohe abbiano sbagliato.
#
# Errati da tutte le epoche
# Id 781854:
# le frasi sono diverse: la prima molto complessa, la seconda no. Probabilmente tutte le epoche hanno sbagliato a causa anche della complessità della prima frase.
#
# Id 615072 e 361925 e 465592:
# le frasi non sono molto complesse. In questo caso non risulta evidente il collegamento fra le due frasi, quindi la classificazione sbagliata è plausibile.
#
# Corretti da tutte le epoche
# Id 574299:
# entrambe le frasi sono lunghe e complesse. Nonostante questo, la classificazione risulta corretta per tutte le epoche.
#
# Id 168734:
# entrambe le frasi sono molto semplici ed è evidente la mancanza di nesso logico.
#
# Id 716760:
# le frasi risultano abbastanza semplici. per la coassificazione non c'è un nesso logico.
#
# Id 343387:
# le frasi non sono semplici, in modo particolare la seconnda. La classificazione risulta corretta per via della mancanza di coerenza nell'accostamento delle due frasi.

# %% [markdown]
# Errati da tutti:
# Id 781854: la prima è difficile; le ultime tre epoche con proba alta.
#
# Id 615072: entrambe non sono semplicissime; errori con proba alta.
#
# Id 351925: abbastanza difficili entrambe, specie la prima; sbagliate tutte con proba alta.
#
# Id 465592: la seconda è più difficile; sbagliato da tutti con proba alta.
#
# Corretti da tutti:
# Id 574299: entrambe difficili; proba alta per tutti.
#
# Id 168734: semplici entrambe; proba alta per tutti.
#
# Id 716760: abbastanza semplici; proba alta per tutti.
#
# Id 343387: difficili entrambe, specialmente la seconda; proba alta per tutti.
#
# Errati da uno solo:
# Id 701817: la seconda è più difficile; errato da una sola con proba bassa.
#
# Id 74365: la prima è più difficile; proba bassa per l'errore.
#
# Id 363150: difficili entrambe; proba bassa;
#
# Id 450666: difficili entrambe; proba bassa dell'errore.
#
# Corretti da uno solo:
# Id 805466: la seconda è più difficile della prima; corretto da una sola con proba del 50%.
#
# Id 321950: difficili entrambe; corretto da una con proba abbastanza alta.
#
# Id 600234: entrambe difficili; corretto solo da una con proba bassa.
#
# Id 780547: la prima è più difficile della seconda; corretto solo da una con proba alta.

# %%
#save_dataframe('df_indici_leggibilita_per_tipo_per_anno_svm', df_indici_leggibilita_per_tipo_per_anno_svm)
# Out:
# File salvato correttamente

# %%
#save_dataframe('df_indici_leggibilita_per_tipo_per_anno_bert', df_indici_leggibilita_per_tipo_per_anno_bert)
# Out:
# File salvato correttamente
